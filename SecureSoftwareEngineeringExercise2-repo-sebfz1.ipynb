# %%
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install pygithub
# !{sys.executable} -m pip install gitpython
# !conda install --yes --prefix {sys.prefix} git
# Out:
# Requirement already satisfied: pygithub in c:\users\shaun\anaconda4\lib\site-packages (1.43.8)
# Requirement already satisfied: deprecated in c:\users\shaun\anaconda4\lib\site-packages (from pygithub) (1.2.6)
# Requirement already satisfied: requests>=2.14.0 in c:\users\shaun\anaconda4\lib\site-packages (from pygithub) (2.21.0)
# Requirement already satisfied: pyjwt in c:\users\shaun\anaconda4\lib\site-packages (from pygithub) (1.7.1)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\shaun\anaconda4\lib\site-packages (from deprecated->pygithub) (1.11.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shaun\anaconda4\lib\site-packages (from requests>=2.14.0->pygithub) (2019.3.9)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\shaun\anaconda4\lib\site-packages (from requests>=2.14.0->pygithub) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\shaun\anaconda4\lib\site-packages (from requests>=2.14.0->pygithub) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\shaun\anaconda4\lib\site-packages (from requests>=2.14.0->pygithub) (1.24.1)
# Requirement already satisfied: gitpython in c:\users\shaun\anaconda4\lib\site-packages (3.0.2)
# Requirement already satisfied: gitdb2>=2.0.0 in c:\users\shaun\anaconda4\lib\site-packages (from gitpython) (2.0.5)
# Requirement already satisfied: smmap2>=2.0.0 in c:\users\shaun\anaconda4\lib\site-packages (from gitdb2>=2.0.0->gitpython) (2.0.5)
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
import numpy as np
import pandas as pd
import os

# Specify git executable file for GitPython in Jupyter Notebook (In IDE, it can still work without this line.)
os.environ["GIT_PYTHON_GIT_EXECUTABLE"] = "C:\Program Files\Git\cmd\git.exe"

import git
from git import RemoteProgress

from git import Repo
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

class Progress(RemoteProgress):
    def update(self, op_code, cur_count, max_count=None, message=''):
        print(self._cur_line)
        
remote_link = "https://github.com/sebfz1/wicket-jquery-ui"
local_link = "repo/sebfz1"
# Uncomment to clone
Repo.clone_from(remote_link, local_link, progress=Progress())

repo = Repo(local_link)
fixing_commit = "82d81bf704bef90b42f62aecbcc7e8c460814b67"
affected_file = "wicket-jquery-ui-plugins/src/main/java/com/googlecode/wicket/jquery/ui/plugins/wysiwyg/WysiwygEditor.java"
affected_file1 = "wicket-jquery-ui-plugins/pom.xml"
# Out:
# remote: Counting objects:   0% (1/289)
# remote: Counting objects:   1% (3/289)
# remote: Counting objects:   2% (6/289)
# remote: Counting objects:   3% (9/289)
# remote: Counting objects:   4% (12/289)
# remote: Counting objects:   5% (15/289)
# remote: Counting objects:   6% (18/289)
# remote: Counting objects:   7% (21/289)
# remote: Counting objects:   8% (24/289)
# remote: Counting objects:   9% (27/289)
# remote: Counting objects:  10% (29/289)
# remote: Counting objects:  11% (32/289)
# remote: Counting objects:  12% (35/289)
# remote: Counting objects:  13% (38/289)
# remote: Counting objects:  14% (41/289)
# remote: Counting objects:  15% (44/289)
# remote: Counting objects:  16% (47/289)
# remote: Counting objects:  17% (50/289)
# remote: Counting objects:  18% (53/289)
# remote: Counting objects:  19% (55/289)
# remote: Counting objects:  20% (58/289)
# remote: Counting objects:  21% (61/289)
# remote: Counting objects:  22% (64/289)
# remote: Counting objects:  23% (67/289)
# remote: Counting objects:  24% (70/289)
# remote: Counting objects:  25% (73/289)
# remote: Counting objects:  26% (76/289)
# remote: Counting objects:  27% (79/289)
# remote: Counting objects:  28% (81/289)
# remote: Counting objects:  29% (84/289)
# remote: Counting objects:  30% (87/289)
# remote: Counting objects:  31% (90/289)
# remote: Counting objects:  32% (93/289)
# remote: Counting objects:  33% (96/289)
# remote: Counting objects:  34% (99/289)
# remote: Counting objects:  35% (102/289)
# remote: Counting objects:  36% (105/289)
# remote: Counting objects:  37% (107/289)
# remote: Counting objects:  38% (110/289)
# remote: Counting objects:  39% (113/289)
# remote: Counting objects:  40% (116/289)
# remote: Counting objects:  41% (119/289)
# remote: Counting objects:  42% (122/289)
# remote: Counting objects:  43% (125/289)
# remote: Counting objects:  44% (128/289)
# remote: Counting objects:  45% (131/289)
# remote: Counting objects:  46% (133/289)
# remote: Counting objects:  47% (136/289)
# remote: Counting objects:  48% (139/289)
# remote: Counting objects:  49% (142/289)
# remote: Counting objects:  50% (145/289)
# remote: Counting objects:  51% (148/289)
# remote: Counting objects:  52% (151/289)
# remote: Counting objects:  53% (154/289)
# remote: Counting objects:  54% (157/289)
# remote: Counting objects:  55% (159/289)
# remote: Counting objects:  56% (162/289)
# remote: Counting objects:  57% (165/289)
# remote: Counting objects:  58% (168/289)
# remote: Counting objects:  59% (171/289)
# remote: Counting objects:  60% (174/289)
# remote: Counting objects:  61% (177/289)
# remote: Counting objects:  62% (180/289)
# remote: Counting objects:  63% (183/289)
# remote: Counting objects:  64% (185/289)
# remote: Counting objects:  65% (188/289)
# remote: Counting objects:  66% (191/289)
# remote: Counting objects:  67% (194/289)
# remote: Counting objects:  68% (197/289)
# remote: Counting objects:  69% (200/289)
# remote: Counting objects:  70% (203/289)
# remote: Counting objects:  71% (206/289)
# remote: Counting objects:  72% (209/289)
# remote: Counting objects:  73% (211/289)
# remote: Counting objects:  74% (214/289)
# remote: Counting objects:  75% (217/289)
# remote: Counting objects:  76% (220/289)
# remote: Counting objects:  77% (223/289)
# remote: Counting objects:  78% (226/289)
# remote: Counting objects:  79% (229/289)
# remote: Counting objects:  80% (232/289)
# remote: Counting objects:  81% (235/289)
# remote: Counting objects:  82% (237/289)
# remote: Counting objects:  83% (240/289)
# remote: Counting objects:  84% (243/289)
# remote: Counting objects:  85% (246/289)
# remote: Counting objects:  86% (249/289)
# remote: Counting objects:  87% (252/289)
# remote: Counting objects:  88% (255/289)
# remote: Counting objects:  89% (258/289)
# remote: Counting objects:  90% (261/289)
# remote: Counting objects:  91% (263/289)
# remote: Counting objects:  92% (266/289)
# remote: Counting objects:  93% (269/289)
# remote: Counting objects:  94% (272/289)
# remote: Counting objects:  95% (275/289)
# remote: Counting objects:  96% (278/289)
# remote: Counting objects:  97% (281/289)
# remote: Counting objects:  98% (284/289)
# remote: Counting objects:  99% (287/289)
# remote: Counting objects: 100% (289/289)
# remote: Counting objects: 100% (289/289), done.
# remote: Compressing objects:   0% (1/152)
# remote: Compressing objects:   1% (2/152)
# remote: Compressing objects:   2% (4/152)
# remote: Compressing objects:   3% (5/152)
# remote: Compressing objects:   4% (7/152)
# remote: Compressing objects:   5% (8/152)
# remote: Compressing objects:   6% (10/152)
# remote: Compressing objects:   7% (11/152)
# remote: Compressing objects:   8% (13/152)
# remote: Compressing objects:   9% (14/152)
# remote: Compressing objects:  10% (16/152)
# remote: Compressing objects:  11% (17/152)
# remote: Compressing objects:  12% (19/152)
# remote: Compressing objects:  13% (20/152)
# remote: Compressing objects:  14% (22/152)
# remote: Compressing objects:  15% (23/152)
# remote: Compressing objects:  16% (25/152)
# remote: Compressing objects:  17% (26/152)
# remote: Compressing objects:  18% (28/152)
# remote: Compressing objects:  19% (29/152)
# remote: Compressing objects:  20% (31/152)
# remote: Compressing objects:  21% (32/152)
# remote: Compressing objects:  22% (34/152)
# remote: Compressing objects:  23% (35/152)
# remote: Compressing objects:  24% (37/152)
# remote: Compressing objects:  25% (38/152)
# remote: Compressing objects:  26% (40/152)
# remote: Compressing objects:  27% (42/152)
# remote: Compressing objects:  28% (43/152)
# remote: Compressing objects:  29% (45/152)
# remote: Compressing objects:  30% (46/152)
# remote: Compressing objects:  31% (48/152)
# remote: Compressing objects:  32% (49/152)
# remote: Compressing objects:  33% (51/152)
# remote: Compressing objects:  34% (52/152)
# remote: Compressing objects:  35% (54/152)
# remote: Compressing objects:  36% (55/152)
# remote: Compressing objects:  37% (57/152)
# remote: Compressing objects:  38% (58/152)
# remote: Compressing objects:  39% (60/152)
# remote: Compressing objects:  40% (61/152)
# remote: Compressing objects:  41% (63/152)
# remote: Compressing objects:  42% (64/152)
# remote: Compressing objects:  43% (66/152)
# remote: Compressing objects:  44% (67/152)
# remote: Compressing objects:  45% (69/152)
# remote: Compressing objects:  46% (70/152)
# remote: Compressing objects:  47% (72/152)
# remote: Compressing objects:  48% (73/152)
# remote: Compressing objects:  49% (75/152)
# remote: Compressing objects:  50% (76/152)
# remote: Compressing objects:  51% (78/152)
# remote: Compressing objects:  52% (80/152)
# remote: Compressing objects:  53% (81/152)
# remote: Compressing objects:  54% (83/152)
# remote: Compressing objects:  55% (84/152)
# remote: Compressing objects:  56% (86/152)
# remote: Compressing objects:  57% (87/152)
# remote: Compressing objects:  58% (89/152)
# remote: Compressing objects:  59% (90/152)
# remote: Compressing objects:  60% (92/152)
# remote: Compressing objects:  61% (93/152)
# remote: Compressing objects:  62% (95/152)
# remote: Compressing objects:  63% (96/152)
# remote: Compressing objects:  64% (98/152)
# remote: Compressing objects:  65% (99/152)
# remote: Compressing objects:  66% (101/152)
# remote: Compressing objects:  67% (102/152)
# remote: Compressing objects:  68% (104/152)
# remote: Compressing objects:  69% (105/152)
# remote: Compressing objects:  70% (107/152)
# remote: Compressing objects:  71% (108/152)
# remote: Compressing objects:  72% (110/152)
# remote: Compressing objects:  73% (111/152)
# remote: Compressing objects:  74% (113/152)
# remote: Compressing objects:  75% (114/152)
# remote: Compressing objects:  76% (116/152)
# remote: Compressing objects:  77% (118/152)
# remote: Compressing objects:  78% (119/152)
# remote: Compressing objects:  79% (121/152)
# remote: Compressing objects:  80% (122/152)
# remote: Compressing objects:  81% (124/152)
# remote: Compressing objects:  82% (125/152)
# remote: Compressing objects:  83% (127/152)
# remote: Compressing objects:  84% (128/152)
# remote: Compressing objects:  85% (130/152)
# remote: Compressing objects:  86% (131/152)
# remote: Compressing objects:  87% (133/152)
# remote: Compressing objects:  88% (134/152)
# remote: Compressing objects:  89% (136/152)
# remote: Compressing objects:  90% (137/152)
# remote: Compressing objects:  91% (139/152)
# remote: Compressing objects:  92% (140/152)
# remote: Compressing objects:  93% (142/152)
# remote: Compressing objects:  94% (143/152)
# remote: Compressing objects:  95% (145/152)
# remote: Compressing objects:  96% (146/152)
# remote: Compressing objects:  97% (148/152)
# remote: Compressing objects:  98% (149/152)
# remote: Compressing objects:  99% (151/152)
# remote: Compressing objects: 100% (152/152)
# remote: Compressing objects: 100% (152/152), done.
# Receiving objects:   0% (1/91399)
# Receiving objects:   1% (914/91399)
# Receiving objects:   2% (1828/91399), 228.01 KiB | 439.00 KiB/s
# Receiving objects:   3% (2742/91399), 228.01 KiB | 439.00 KiB/s
# Receiving objects:   3% (3045/91399), 228.01 KiB | 439.00 KiB/s
# Receiving objects:   4% (3656/91399), 1.07 MiB | 1.05 MiB/s
# Receiving objects:   5% (4570/91399), 2.38 MiB | 1.57 MiB/s
# Receiving objects:   6% (5484/91399), 2.38 MiB | 1.57 MiB/s
# Receiving objects:   6% (6120/91399), 2.38 MiB | 1.57 MiB/s
# Receiving objects:   7% (6398/91399), 3.75 MiB | 1.86 MiB/s
# Receiving objects:   8% (7312/91399), 3.75 MiB | 1.86 MiB/s
# Receiving objects:   9% (8226/91399), 3.75 MiB | 1.86 MiB/s
# Receiving objects:  10% (9140/91399), 3.75 MiB | 1.86 MiB/s
# Receiving objects:  11% (10054/91399), 4.79 MiB | 1.90 MiB/s
# Receiving objects:  12% (10968/91399), 4.79 MiB | 1.90 MiB/s
# Receiving objects:  12% (11498/91399), 4.79 MiB | 1.90 MiB/s
# Receiving objects:  12% (11694/91399), 6.06 MiB | 1.49 MiB/s
# Receiving objects:  12% (11695/91399), 6.45 MiB | 1.35 MiB/s
# Receiving objects:  12% (11698/91399), 6.78 MiB | 1.23 MiB/s
# Receiving objects:  12% (11700/91399), 7.31 MiB | 781.00 KiB/s
# Receiving objects:  12% (11705/91399), 8.03 MiB | 553.00 KiB/s
# Receiving objects:  12% (11725/91399), 8.90 MiB | 626.00 KiB/s
# Receiving objects:  12% (11862/91399), 9.46 MiB | 662.00 KiB/s
# Receiving objects:  13% (11882/91399), 9.46 MiB | 662.00 KiB/s
# Receiving objects:  13% (12197/91399), 10.09 MiB | 678.00 KiB/s
# Receiving objects:  14% (12796/91399), 10.90 MiB | 730.00 KiB/s
# Receiving objects:  14% (13082/91399), 10.90 MiB | 730.00 KiB/s
# Receiving objects:  14% (13390/91399), 12.00 MiB | 688.00 KiB/s
# Receiving objects:  14% (13391/91399), 12.48 MiB | 667.00 KiB/s
# Receiving objects:  14% (13392/91399), 12.89 MiB | 616.00 KiB/s
# Receiving objects:  14% (13394/91399), 13.18 MiB | 600.00 KiB/s
# Receiving objects:  14% (13397/91399), 14.00 MiB | 590.00 KiB/s
# Receiving objects:  15% (13710/91399), 14.00 MiB | 590.00 KiB/s
# Receiving objects:  16% (14624/91399), 14.47 MiB | 603.00 KiB/s
# Receiving objects:  16% (15300/91399), 15.04 MiB | 658.00 KiB/s
# Receiving objects:  17% (15538/91399), 15.04 MiB | 658.00 KiB/s
# Receiving objects:  17% (16310/91399), 15.43 MiB | 695.00 KiB/s
# Receiving objects:  18% (16452/91399), 15.83 MiB | 736.00 KiB/s
# Receiving objects:  19% (17366/91399), 16.32 MiB | 803.00 KiB/s
# Receiving objects:  20% (18280/91399), 16.32 MiB | 803.00 KiB/s
# Receiving objects:  21% (19194/91399), 16.32 MiB | 803.00 KiB/s
# Receiving objects:  21% (19487/91399), 16.32 MiB | 803.00 KiB/s
# Receiving objects:  22% (20108/91399), 17.35 MiB | 918.00 KiB/s
# Receiving objects:  22% (20573/91399), 17.35 MiB | 918.00 KiB/s
# Receiving objects:  23% (21022/91399), 17.86 MiB | 953.00 KiB/s
# Receiving objects:  24% (21936/91399), 18.24 MiB | 931.00 KiB/s
# Receiving objects:  24% (22096/91399), 18.24 MiB | 931.00 KiB/s
# Receiving objects:  24% (22832/91399), 19.11 MiB | 907.00 KiB/s
# Receiving objects:  25% (22850/91399), 19.66 MiB | 943.00 KiB/s
# Receiving objects:  26% (23764/91399), 19.66 MiB | 943.00 KiB/s
# Receiving objects:  27% (24678/91399), 20.29 MiB | 991.00 KiB/s
# Receiving objects:  27% (24760/91399), 20.29 MiB | 991.00 KiB/s
# Receiving objects:  28% (25592/91399), 20.77 MiB | 991.00 KiB/s
# Receiving objects:  28% (26190/91399), 21.19 MiB | 962.00 KiB/s
# Receiving objects:  29% (26506/91399), 21.71 MiB | 972.00 KiB/s
# Receiving objects:  30% (27420/91399), 21.71 MiB | 972.00 KiB/s
# Receiving objects:  30% (28191/91399), 22.29 MiB | 987.00 KiB/s
# Receiving objects:  31% (28334/91399), 22.29 MiB | 987.00 KiB/s
# Receiving objects:  31% (29173/91399), 23.71 MiB | 1.12 MiB/s
# Receiving objects:  32% (29248/91399), 23.71 MiB | 1.12 MiB/s
# Receiving objects:  33% (30162/91399), 24.37 MiB | 1.16 MiB/s
# Receiving objects:  34% (31076/91399), 24.37 MiB | 1.16 MiB/s
# Receiving objects:  34% (31467/91399), 24.86 MiB | 1.14 MiB/s
# Receiving objects:  35% (31990/91399), 24.86 MiB | 1.14 MiB/s
# Receiving objects:  36% (32904/91399), 25.39 MiB | 1.12 MiB/s
# Receiving objects:  36% (33293/91399), 26.04 MiB | 1.16 MiB/s
# Receiving objects:  37% (33818/91399), 26.04 MiB | 1.16 MiB/s
# Receiving objects:  37% (34409/91399), 27.34 MiB | 1.24 MiB/s
# Receiving objects:  38% (34732/91399), 27.34 MiB | 1.24 MiB/s
# Receiving objects:  39% (35646/91399), 27.90 MiB | 1.23 MiB/s
# Receiving objects:  40% (36560/91399), 28.39 MiB | 1.19 MiB/s
# Receiving objects:  40% (36760/91399), 28.39 MiB | 1.19 MiB/s
# Receiving objects:  80% (73120/91399), 36.49 MiB | 953.00 KiB/s
# Receiving objects:  81% (74034/91399), 36.49 MiB | 953.00 KiB/s
# Receiving objects:  82% (74948/91399), 36.49 MiB | 953.00 KiB/s
# Receiving objects:  83% (75862/91399), 36.83 MiB | 885.00 KiB/s
# Receiving objects:  84% (76776/91399), 36.83 MiB | 885.00 KiB/s
# Receiving objects:  84% (76812/91399), 36.83 MiB | 885.00 KiB/s
# Receiving objects:  85% (77690/91399), 36.83 MiB | 885.00 KiB/s
# Receiving objects:  86% (78604/91399), 37.16 MiB | 797.00 KiB/s
# Receiving objects:  87% (79518/91399), 37.16 MiB | 797.00 KiB/s
# Receiving objects:  87% (79689/91399), 37.58 MiB | 709.00 KiB/s
# Receiving objects:  88% (80432/91399), 37.58 MiB | 709.00 KiB/s
# Receiving objects:  89% (81346/91399), 37.58 MiB | 709.00 KiB/s
# Receiving objects:  90% (82260/91399), 37.58 MiB | 709.00 KiB/s
# Receiving objects:  91% (83174/91399), 38.08 MiB | 654.00 KiB/s
# Receiving objects:  92% (84088/91399), 38.08 MiB | 654.00 KiB/s
# Receiving objects:  93% (85002/91399), 38.66 MiB | 668.00 KiB/s
# Receiving objects:  93% (85180/91399), 38.66 MiB | 668.00 KiB/s
# Receiving objects:  94% (85916/91399), 38.66 MiB | 668.00 KiB/s
# Receiving objects:  95% (86830/91399), 38.66 MiB | 668.00 KiB/s
# Receiving objects:  96% (87744/91399), 38.66 MiB | 668.00 KiB/s
# Receiving objects:  97% (88658/91399), 38.66 MiB | 668.00 KiB/s
# Receiving objects:  98% (89572/91399), 38.66 MiB | 668.00 KiB/s
# Receiving objects:  99% (90486/91399), 39.27 MiB | 765.00 KiB/s
# Receiving objects:  99% (91344/91399), 40.46 MiB | 951.00 KiB/s
# Receiving objects: 100% (91399/91399), 40.46 MiB | 951.00 KiB/s
# Receiving objects: 100% (91399/91399), 40.70 MiB | 975.00 KiB/s, done.
# Resolving deltas:   0% (0/39939)
# Resolving deltas:   1% (494/39939)
# Resolving deltas:   2% (806/39939)
# Resolving deltas:   3% (1230/39939)
# Resolving deltas:   4% (1740/39939)
# Resolving deltas:   5% (2006/39939)
# Resolving deltas:   6% (2418/39939)
# Resolving deltas:   7% (2829/39939)
# Resolving deltas:   8% (3214/39939)
# Resolving deltas:   9% (3598/39939)
# Resolving deltas:  10% (4020/39939)
# Resolving deltas:  11% (4428/39939)
# Resolving deltas:  12% (4813/39939)
# Resolving deltas:  13% (5212/39939)
# Resolving deltas:  14% (5599/39939)
# Resolving deltas:  15% (5999/39939)
# Resolving deltas:  16% (6417/39939)
# Resolving deltas:  17% (6846/39939)
# Resolving deltas:  18% (7214/39939)
# Resolving deltas:  19% (7597/39939)
# Resolving deltas:  20% (7991/39939)
# Resolving deltas:  21% (8408/39939)
# Resolving deltas:  22% (8879/39939)
# Resolving deltas:  24% (9597/39939)
# Resolving deltas:  25% (9987/39939)
# Resolving deltas:  26% (10398/39939)
# Resolving deltas:  27% (10905/39939)
# Resolving deltas:  28% (11195/39939)
# Resolving deltas:  29% (11610/39939)
# Resolving deltas:  30% (12002/39939)
# Resolving deltas:  31% (12399/39939)
# Resolving deltas:  32% (12785/39939)
# Resolving deltas:  33% (13197/39939)
# Resolving deltas:  34% (13615/39939)
# Resolving deltas:  35% (14014/39939)
# Resolving deltas:  36% (14512/39939)
# Resolving deltas:  37% (14807/39939)
# Resolving deltas:  38% (15180/39939)
# Resolving deltas:  39% (15667/39939)
# Resolving deltas:  40% (16099/39939)
# Resolving deltas:  41% (16396/39939)
# Resolving deltas:  42% (16783/39939)
# Resolving deltas:  43% (17175/39939)
# Resolving deltas:  44% (17576/39939)
# Resolving deltas:  45% (17973/39939)
# Resolving deltas:  46% (18383/39939)
# Resolving deltas:  47% (18780/39939)
# Resolving deltas:  48% (19179/39939)
# Resolving deltas:  49% (19578/39939)
# Resolving deltas:  50% (20016/39939)
# Resolving deltas:  51% (20484/39939)
# Resolving deltas:  52% (20801/39939)
# Resolving deltas:  53% (21202/39939)
# Resolving deltas:  54% (21580/39939)
# Resolving deltas:  55% (21968/39939)
# Resolving deltas:  56% (22383/39939)
# Resolving deltas:  57% (22804/39939)
# Resolving deltas:  58% (23206/39939)
# Resolving deltas:  59% (23568/39939)
# Resolving deltas:  60% (23965/39939)
# Resolving deltas:  61% (24364/39939)
# Resolving deltas:  62% (24763/39939)
# Resolving deltas:  63% (25165/39939)
# Resolving deltas:  64% (25562/39939)
# Resolving deltas:  65% (25969/39939)
# Resolving deltas:  66% (26365/39939)
# Resolving deltas:  67% (26824/39939)
# Resolving deltas:  68% (27166/39939)
# Resolving deltas:  69% (27586/39939)
# Resolving deltas:  70% (27959/39939)
# Resolving deltas:  71% (28360/39939)
# Resolving deltas:  72% (28819/39939)
# Resolving deltas:  73% (29157/39939)
# Resolving deltas:  74% (29568/39939)
# Resolving deltas:  75% (29955/39939)
# Resolving deltas:  76% (30358/39939)
# Resolving deltas:  77% (30754/39939)
# Resolving deltas:  78% (31185/39939)
# Resolving deltas:  79% (31623/39939)
# Resolving deltas:  80% (31975/39939)
# Resolving deltas:  81% (32356/39939)
# Resolving deltas:  82% (32754/39939)
# Resolving deltas:  83% (33154/39939)
# Resolving deltas:  84% (33549/39939)
# Resolving deltas:  85% (33979/39939)
# Resolving deltas:  86% (34362/39939)
# Resolving deltas:  87% (34755/39939)
# Resolving deltas:  88% (35169/39939)
# Resolving deltas:  89% (35550/39939)
# Resolving deltas:  90% (35971/39939)
# Resolving deltas:  91% (36345/39939)
# Resolving deltas:  92% (36750/39939)
# Resolving deltas:  93% (37158/39939)
# Resolving deltas:  94% (37547/39939)
# Resolving deltas:  95% (37954/39939)
# Resolving deltas:  96% (38348/39939)
# Resolving deltas:  97% (38741/39939)
# Resolving deltas:  98% (39142/39939)
# Resolving deltas:  99% (39540/39939)
# Resolving deltas: 100% (39939/39939)
# Resolving deltas: 100% (39939/39939), done.
# Checking out files:  34% (1743/4985)
# Checking out files:  35% (1745/4985)
# Checking out files:  36% (1795/4985)
# Checking out files:  37% (1845/4985)
# Checking out files:  38% (1895/4985)
# Checking out files:  39% (1945/4985)
# Checking out files:  40% (1994/4985)
# Checking out files:  41% (2044/4985)
# Checking out files:  42% (2094/4985)
# Checking out files:  43% (2144/4985)
# Checking out files:  44% (2194/4985)
# Checking out files:  45% (2244/4985)
# Checking out files:  46% (2294/4985)
# Checking out files:  47% (2343/4985)
# Checking out files:  48% (2393/4985)
# Checking out files:  49% (2443/4985)
# Checking out files:  50% (2493/4985)
# Checking out files:  51% (2543/4985)
# Checking out files:  52% (2593/4985)
# Checking out files:  53% (2643/4985)
# Checking out files:  54% (2692/4985)
# Checking out files:  55% (2742/4985)
# Checking out files:  56% (2792/4985)
# Checking out files:  57% (2842/4985)
# Checking out files:  58% (2892/4985)
# Checking out files:  59% (2942/4985)
# Checking out files:  60% (2991/4985)
# Checking out files:  61% (3041/4985)
# Checking out files:  62% (3091/4985)
# Checking out files:  63% (3141/4985)
# Checking out files:  64% (3191/4985)
# Checking out files:  65% (3241/4985)
# Checking out files:  66% (3291/4985)
# Checking out files:  67% (3340/4985)
# Checking out files:  68% (3390/4985)
# Checking out files:  69% (3440/4985)
# Checking out files:  70% (3490/4985)
# Checking out files:  71% (3540/4985)
# Checking out files:  72% (3590/4985)
# Checking out files:  72% (3613/4985)
# Checking out files:  73% (3640/4985)
# Checking out files:  74% (3689/4985)
# Checking out files:  75% (3739/4985)
# Checking out files:  76% (3789/4985)
# Checking out files:  77% (3839/4985)
# Checking out files:  78% (3889/4985)
# Checking out files:  79% (3939/4985)
# Checking out files:  80% (3988/4985)
# Checking out files:  81% (4038/4985)
# Checking out files:  82% (4088/4985)
# Checking out files:  83% (4138/4985)
# Checking out files:  84% (4188/4985)
# Checking out files:  85% (4238/4985)
# Checking out files:  86% (4288/4985)
# Checking out files:  87% (4337/4985)
# Checking out files:  88% (4387/4985)
# Checking out files:  89% (4437/4985)
# Checking out files:  90% (4487/4985)
# Checking out files:  91% (4537/4985)
# Checking out files:  91% (4562/4985)
# Checking out files:  92% (4587/4985)
# Checking out files:  93% (4637/4985)
# Checking out files:  94% (4686/4985)
# Checking out files:  95% (4736/4985)
# Checking out files:  96% (4786/4985)
# Checking out files:  97% (4836/4985)
# Checking out files:  98% (4886/4985)
# Checking out files:  99% (4936/4985)
# Checking out files: 100% (4985/4985)
# Checking out files: 100% (4985/4985), done.

# %%
#a.	What was the message and title of the fixing commit? 
#Was there any mention of fixing a bug or vulnerability? 
#Hint: git diff or git show
show_data = repo.git.show("-s",fixing_commit).splitlines()
for line in show_data:
    print(line)
# Out:
# commit 82d81bf704bef90b42f62aecbcc7e8c460814b67
# Author: Maxim Solodovnik <solomax666@gmail.com>
# Date:   Sun Dec 24 19:00:50 2017 +0700
#
#     Plugins: Editor, added OWASP sanitizer

# %%
#b.	How many total files were affected in the fixing commit? 
#Hint: git diff or git show
diff_data = repo.git.diff(fixing_commit + "^", fixing_commit).splitlines()
for line in diff_data:
    print(line)
# Out:
# diff --git a/wicket-jquery-ui-plugins/pom.xml b/wicket-jquery-ui-plugins/pom.xml
# index e4479d49c..5bcc52467 100644
# --- a/wicket-jquery-ui-plugins/pom.xml
# +++ b/wicket-jquery-ui-plugins/pom.xml
# @@ -13,8 +13,8 @@
#  	<artifactId>wicket-jquery-ui-plugins</artifactId>
#  	<packaging>bundle</packaging>
#
# -    <properties>
# -	    <bundle.namespace>com.googlecode.wicket.jquery.ui.plugins</bundle.namespace>
# +	<properties>
# +		<bundle.namespace>com.googlecode.wicket.jquery.ui.plugins</bundle.namespace>
#  	</properties>
#
#  	<dependencies>
# @@ -39,6 +39,13 @@
#  			<scope>provided</scope>
#  		</dependency>
#
# +		<!-- SANITIZER DEPENDENCIES -->
# +		<dependency>
# +			<groupId>com.googlecode.owasp-java-html-sanitizer</groupId>
# +			<artifactId>owasp-java-html-sanitizer</artifactId>
# +			<version>20171016.1</version>
# +		</dependency>
# +
#  		<!-- JUNIT DEPENDENCY FOR TESTING -->
#  		<dependency>
#  			<groupId>junit</groupId>
# @@ -48,13 +55,13 @@
#  		</dependency>
#  	</dependencies>
#
# -    <build>
# -        <plugins>
# -            <plugin>
# -                <groupId>org.apache.felix</groupId>
# -                <artifactId>maven-bundle-plugin</artifactId>
# -            </plugin>
# -        </plugins>
# -    </build>
# +	<build>
# +		<plugins>
# +			<plugin>
# +				<groupId>org.apache.felix</groupId>
# +				<artifactId>maven-bundle-plugin</artifactId>
# +			</plugin>
# +		</plugins>
# +	</build>
#
#  </project>
# diff --git a/wicket-jquery-ui-plugins/src/main/java/com/googlecode/wicket/jquery/ui/plugins/wysiwyg/WysiwygEditor.java b/wicket-jquery-ui-plugins/src/main/java/com/googlecode/wicket/jquery/ui/plugins/wysiwyg/WysiwygEditor.java
# index 35be43280..51ff60602 100644
# --- a/wicket-jquery-ui-plugins/src/main/java/com/googlecode/wicket/jquery/ui/plugins/wysiwyg/WysiwygEditor.java
# +++ b/wicket-jquery-ui-plugins/src/main/java/com/googlecode/wicket/jquery/ui/plugins/wysiwyg/WysiwygEditor.java
# @@ -24,6 +24,8 @@ import org.apache.wicket.markup.html.form.Form;
#  import org.apache.wicket.markup.html.form.FormComponentPanel;
#  import org.apache.wicket.markup.html.form.TextArea;
#  import org.apache.wicket.model.IModel;
# +import org.owasp.html.HtmlPolicyBuilder;
# +import org.owasp.html.PolicyFactory;
#
#  import com.googlecode.wicket.jquery.core.IJQueryWidget;
#  import com.googlecode.wicket.jquery.core.JQueryBehavior;
# @@ -112,10 +114,29 @@ public class WysiwygEditor extends FormComponentPanel<String> implements IJQuery
#
#  	// Methods //
#
# +	/**
# +	 * Gets a new {@link PolicyFactory} to sanitize editor input
# +	 *
# +	 * @return a new {@code PolicyFactory}
# +	 */
# +	protected PolicyFactory newPolicyFactory()
# +	{
# +		return new HtmlPolicyBuilder() // lf
# +				.allowCommonInlineFormattingElements() // lf
# +				.allowCommonBlockElements() // lf
# +				.allowElements("a").allowAttributes("href", "target").onElements("a") // lf
# +				.allowAttributes("size").onElements("font") // lf
# +				.allowAttributes("class", "style").globally() // lf
# +				.toFactory();
# +	}
# +
#  	@Override
#  	public void convertInput()
#  	{
# -		this.setConvertedInput(this.textarea.getConvertedInput());
# +		final PolicyFactory policy = this.newPolicyFactory();
# +		final String html = this.textarea.getConvertedInput();
# +
# +		this.setConvertedInput(policy.sanitize(html));
#  	}
#
#  	@Override

# %%
#c.	How many total directories were affected in the fixing commit? 
#For example, if a file path is: abc/def/File.java, 
#then its directory is abc/def. Hint: git diff or git show
diff_data = repo.git.diff(fixing_commit + "^", fixing_commit).splitlines()
for line in diff_data:
    print(line)
# Out:
# diff --git a/wicket-jquery-ui-plugins/pom.xml b/wicket-jquery-ui-plugins/pom.xml
# index e4479d49c..5bcc52467 100644
# --- a/wicket-jquery-ui-plugins/pom.xml
# +++ b/wicket-jquery-ui-plugins/pom.xml
# @@ -13,8 +13,8 @@
#  	<artifactId>wicket-jquery-ui-plugins</artifactId>
#  	<packaging>bundle</packaging>
#
# -    <properties>
# -	    <bundle.namespace>com.googlecode.wicket.jquery.ui.plugins</bundle.namespace>
# +	<properties>
# +		<bundle.namespace>com.googlecode.wicket.jquery.ui.plugins</bundle.namespace>
#  	</properties>
#
#  	<dependencies>
# @@ -39,6 +39,13 @@
#  			<scope>provided</scope>
#  		</dependency>
#
# +		<!-- SANITIZER DEPENDENCIES -->
# +		<dependency>
# +			<groupId>com.googlecode.owasp-java-html-sanitizer</groupId>
# +			<artifactId>owasp-java-html-sanitizer</artifactId>
# +			<version>20171016.1</version>
# +		</dependency>
# +
#  		<!-- JUNIT DEPENDENCY FOR TESTING -->
#  		<dependency>
#  			<groupId>junit</groupId>
# @@ -48,13 +55,13 @@
#  		</dependency>
#  	</dependencies>
#
# -    <build>
# -        <plugins>
# -            <plugin>
# -                <groupId>org.apache.felix</groupId>
# -                <artifactId>maven-bundle-plugin</artifactId>
# -            </plugin>
# -        </plugins>
# -    </build>
# +	<build>
# +		<plugins>
# +			<plugin>
# +				<groupId>org.apache.felix</groupId>
# +				<artifactId>maven-bundle-plugin</artifactId>
# +			</plugin>
# +		</plugins>
# +	</build>
#
#  </project>
# diff --git a/wicket-jquery-ui-plugins/src/main/java/com/googlecode/wicket/jquery/ui/plugins/wysiwyg/WysiwygEditor.java b/wicket-jquery-ui-plugins/src/main/java/com/googlecode/wicket/jquery/ui/plugins/wysiwyg/WysiwygEditor.java
# index 35be43280..51ff60602 100644
# --- a/wicket-jquery-ui-plugins/src/main/java/com/googlecode/wicket/jquery/ui/plugins/wysiwyg/WysiwygEditor.java
# +++ b/wicket-jquery-ui-plugins/src/main/java/com/googlecode/wicket/jquery/ui/plugins/wysiwyg/WysiwygEditor.java
# @@ -24,6 +24,8 @@ import org.apache.wicket.markup.html.form.Form;
#  import org.apache.wicket.markup.html.form.FormComponentPanel;
#  import org.apache.wicket.markup.html.form.TextArea;
#  import org.apache.wicket.model.IModel;
# +import org.owasp.html.HtmlPolicyBuilder;
# +import org.owasp.html.PolicyFactory;
#
#  import com.googlecode.wicket.jquery.core.IJQueryWidget;
#  import com.googlecode.wicket.jquery.core.JQueryBehavior;
# @@ -112,10 +114,29 @@ public class WysiwygEditor extends FormComponentPanel<String> implements IJQuery
#
#  	// Methods //
#
# +	/**
# +	 * Gets a new {@link PolicyFactory} to sanitize editor input
# +	 *
# +	 * @return a new {@code PolicyFactory}
# +	 */
# +	protected PolicyFactory newPolicyFactory()
# +	{
# +		return new HtmlPolicyBuilder() // lf
# +				.allowCommonInlineFormattingElements() // lf
# +				.allowCommonBlockElements() // lf
# +				.allowElements("a").allowAttributes("href", "target").onElements("a") // lf
# +				.allowAttributes("size").onElements("font") // lf
# +				.allowAttributes("class", "style").globally() // lf
# +				.toFactory();
# +	}
# +
#  	@Override
#  	public void convertInput()
#  	{
# -		this.setConvertedInput(this.textarea.getConvertedInput());
# +		final PolicyFactory policy = this.newPolicyFactory();
# +		final String html = this.textarea.getConvertedInput();
# +
# +		this.setConvertedInput(policy.sanitize(html));
#  	}
#
#  	@Override

# %%
#d.	How many total lines of code (including comments and blank lines) \
#were deleted? Hint: git diff or git show
#e.	How many total lines of code (including comments and blank lines) 
#were added? Hint: git diff or git show
del_data = repo.git.log("--numstat","--oneline",fixing_commit).splitlines()
for line in del_data:
    print(line)
# Out:
# 82d81bf70 Plugins: Editor, added OWASP sanitizer
# 17	10	wicket-jquery-ui-plugins/pom.xml
# 22	1	wicket-jquery-ui-plugins/src/main/java/com/googlecode/wicket/jquery/ui/plugins/wysiwyg/WysiwygEditor.java
# 96d55ac0c jQuery: added TabbedPanel#enable(handler); fixes #279 jQuery: added TabbedPanel#enable(index, handler); fixes #279 jQuery: added TabbedPanel#disable(handler); fixes #279 jQuery: added TabbedPanel#disable(index, handler); fixes #279
# 42	0	wicket-jquery-ui/src/main/java/com/googlecode/wicket/jquery/ui/widget/tabs/TabbedPanel.java
# 42	0	wicket-jquery-ui/src/main/java/com/googlecode/wicket/jquery/ui/widget/tabs/TabsBehavior.java
# 1466a6187 Kendo UI: fixed AbstractColumn#editable (should now be a function)
# 1	1	wicket-kendo-ui/src/main/java/com/googlecode/wicket/kendo/ui/datatable/column/AbstractColumn.java
# cc4299116 [maven-release-plugin] prepare for next development iteration
# 2	2	pom.xml
# 2	2	wicket-jquery-ui-calendar/pom.xml
# 1	1	wicket-jquery-ui-core/pom.xml
# 2	2	wicket-jquery-ui-plugins/pom.xml
# 8	8	wicket-jquery-ui-samples/pom.xml
# 2	2	wicket-jquery-ui-themes/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-base/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-black-tie/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-blitzer/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-cupertino/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-dark-hive/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-dot-luv/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-eggplant/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-excite-bike/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-flick/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-hot-sneaks/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-humanity/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-le-frog/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-mint-choc/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-overcast/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-pepper-grinder/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-redmond/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-smoothness/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-south-street/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-start/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-sunny/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-swanky-purse/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-trontastic/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-ui-darkness/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-ui-lightness/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-vader/pom.xml
# 2	2	wicket-jquery-ui/pom.xml
# 2	2	wicket-kendo-ui-culture/pom.xml
# 1	1	wicket-kendo-ui-themes/pom.xml
# 2	2	wicket-kendo-ui-themes/theme-black/pom.xml
# 2	2	wicket-kendo-ui-themes/theme-blue-opal/pom.xml
# 2	2	wicket-kendo-ui-themes/theme-bootstrap/pom.xml
# 2	2	wicket-kendo-ui-themes/theme-default/pom.xml
# 2	2	wicket-kendo-ui-themes/theme-fiori/pom.xml
# 2	2	wicket-kendo-ui-themes/theme-flat/pom.xml
# 2	2	wicket-kendo-ui-themes/theme-high-contrast/pom.xml
# 2	2	wicket-kendo-ui-themes/theme-material-black/pom.xml
# 2	2	wicket-kendo-ui-themes/theme-material/pom.xml
# 2	2	wicket-kendo-ui-themes/theme-metro-black/pom.xml
# 2	2	wicket-kendo-ui-themes/theme-metro/pom.xml
# 2	2	wicket-kendo-ui-themes/theme-moonlight/pom.xml
# 2	2	wicket-kendo-ui-themes/theme-nova/pom.xml
# 2	2	wicket-kendo-ui-themes/theme-office365/pom.xml
# 2	2	wicket-kendo-ui-themes/theme-silver/pom.xml
# 2	2	wicket-kendo-ui-themes/theme-uniform/pom.xml
# 2	2	wicket-kendo-ui/pom.xml
# 261bda97e [maven-release-plugin] prepare release wicket-jquery-ui-8.0.0-M8
# 2	2	pom.xml
# 2	2	wicket-jquery-ui-calendar/pom.xml
# 1	1	wicket-jquery-ui-core/pom.xml
# 2	2	wicket-jquery-ui-plugins/pom.xml
# 8	8	wicket-jquery-ui-samples/pom.xml
# 2	2	wicket-jquery-ui-themes/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-base/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-black-tie/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-blitzer/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-cupertino/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-dark-hive/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-dot-luv/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-eggplant/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-excite-bike/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-flick/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-hot-sneaks/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-humanity/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-le-frog/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-mint-choc/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-overcast/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-pepper-grinder/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-redmond/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-smoothness/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-south-street/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-start/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-sunny/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-swanky-purse/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-trontastic/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-ui-darkness/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-ui-lightness/pom.xml
# 1	1	wicket-jquery-ui-themes/theme-vader/pom.xml
# 2	2	wicket-jquery-ui/pom.xml
# 2	2	wicket-kendo-ui-culture/pom.xml
# 1	1	wicket-kendo-ui-themes/pom.xml
# 2	2	wicket-kendo-ui-themes/theme-black/pom.xml
# 2	2	wicket-kendo-ui-themes/theme-blue-opal/pom.xml
# 2	2	wicket-kendo-ui-themes/theme-bootstrap/pom.xml
# 2	2	wicket-kendo-ui-themes/theme-default/pom.xml
# 2	2	wicket-kendo-ui-themes/theme-fiori/pom.xml
# 2	2	wicket-kendo-ui-themes/theme-flat/pom.xml
# 2	2	wicket-kendo-ui-themes/theme-high-contrast/pom.xml
# 2	2	wicket-kendo-ui-themes/theme-material-black/pom.xml
# 2	2	wicket-kendo-ui-themes/theme-material/pom.xml
# 2	2	wicket-kendo-ui-themes/theme-metro-black/pom.xml
# 2	2	wicket-kendo-ui-themes/theme-metro/pom.xml
# 2	2	wicket-kendo-ui-themes/theme-moonlight/pom.xml
# 2	2	wicket-kendo-ui-themes/theme-nova/pom.xml
# 2	2	wicket-kendo-ui-themes/theme-office365/pom.xml
# 2	2	wicket-kendo-ui-themes/theme-silver/pom.xml
# 2	2	wicket-kendo-ui-themes/theme-uniform/pom.xml
# 2	2	wicket-kendo-ui/pom.xml
# 60d58c33e Versions: upgraded to wicket-8.0.0-M8
# 2	2	pom.xml
# 0	1	wicket-jquery-ui-core/src/main/java/com/googlecode/wicket/jquery/core/utils/BroadcastUtils.java
# 13	10	wicket-kendo-ui/src/main/java/com/googlecode/wicket/kendo/ui/datatable/export/CSVDataExporter.java
# 1	2	wicket-kendo-ui/src/main/java/com/googlecode/wicket/kendo/ui/widget/tabs/TabbedPanelNavigator.java
# 9d0556e4f Core: deprecated AjaxPayload, use HandlerPayload instead Core: FeedbackPayload now takes IPartialPageRequestHandler as arg, intead of AjaxRequestTarget Core: BroadcastUtils#breadth(Component, AjaxPayload) is deprecated Core: BroadcastUtils#bubble(Component, AjaxPayload) is deprecated Core: BroadcastUtils#depth(Component, AjaxPayload) is deprecated Core: BroadcastUtils#exact(Component, AjaxPayload) is deprecated
# 2	0	wicket-jquery-ui-core/src/main/java/com/googlecode/wicket/jquery/core/ajax/AjaxPayload.java
# 10	9	wicket-jquery-ui-core/src/main/java/com/googlecode/wicket/jquery/core/ajax/FeedbackPayload.java
# 97	1	wicket-jquery-ui-core/src/main/java/com/googlecode/wicket/jquery/core/utils/BroadcastUtils.java
# 146	105	wicket-jquery-ui-core/src/main/java/com/googlecode/wicket/jquery/core/utils/FeedbackUtils.java
# 7	6	wicket-kendo-ui/src/main/java/com/googlecode/wicket/kendo/ui/dataviz/chart/ChartPayload.java
# 11	11	wicket-kendo-ui/src/main/java/com/googlecode/wicket/kendo/ui/utils/KendoEffectUtils.java
# 5	3	wicket-kendo-ui/src/main/java/com/googlecode/wicket/kendo/ui/widget/tabs/TabbedPanelNavigator.java
# b4e7f8b50 Merge pull request #277 from solomax/wicket8.x
# 8b47928a5 Typo is fixed
# 1	1	wicket-jquery-ui-plugins/src/main/java/com/googlecode/wicket/jquery/ui/plugins/wysiwyg/resource/PrettifyJavaScriptResourceReference.java
# 56b8cccd2 jQuery UI: wizard, setEnabled(boolean, IPartialPageRequestHandler) should call setEnabled(boolean)
# 2	0	wicket-jquery-ui/src/main/java/com/googlecode/wicket/jquery/ui/widget/dialog/DialogButton.java
# 439907a94 Kendo UI: DataTable, added AbstractButton#CSS_ICON_ONLY Kendo UI: DataTable, AbstractButton#getText to #getTextModel **API BREAK**
# 2	2	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/kendoui/datatable/CommandsDataTablePage.java
# 83	5	wicket-kendo-ui/src/main/java/com/googlecode/wicket/kendo/ui/datatable/button/AbstractButton.java
# 1	42	wicket-kendo-ui/src/main/java/com/googlecode/wicket/kendo/ui/datatable/button/CommandButton.java
# 1	42	wicket-kendo-ui/src/main/java/com/googlecode/wicket/kendo/ui/datatable/button/ToolbarButton.java
# f6d05077d Kendo UI: DataTable, minor refactoring
# 6	2	wicket-kendo-ui/src/main/java/com/googlecode/wicket/kendo/ui/datatable/DataTable.js
# dc6cc1e0a Kendo UI: handle disabled columns & command buttons (warning, edit & destroy are hidden if disabled)
# 1	0	wicket-kendo-ui/src/main/java/com/googlecode/wicket/kendo/ui/datatable/DataTable.java
# 18	0	wicket-kendo-ui/src/main/java/com/googlecode/wicket/kendo/ui/datatable/DataTable.js
# 12	2	wicket-kendo-ui/src/main/java/com/googlecode/wicket/kendo/ui/datatable/button/AbstractButton.java
# 6	2	wicket-kendo-ui/src/main/java/com/googlecode/wicket/kendo/ui/datatable/button/CommandAjaxBehavior.java
# 1	12	wicket-kendo-ui/src/main/java/com/googlecode/wicket/kendo/ui/datatable/button/CommandButton.java
# 1	11	wicket-kendo-ui/src/main/java/com/googlecode/wicket/kendo/ui/datatable/button/ToolbarButton.java
# e4edd5e99 Kendo UI: upgraded to kendoui.2017.3.913.core Kendo UI: added KendoAllResourceReference (CDN)
# 1	1	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/SampleApplication.java
# 583	166	wicket-kendo-ui-culture/src/main/java/com/googlecode/wicket/kendo/ui/KendoCulture.java
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.aa-DJ.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.aa-DJ.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.aa-ER.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.aa-ER.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.aa-ET.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.aa-ET.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.aa.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.aa.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.af-NA.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.af-NA.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.af-ZA.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.af-ZA.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.af.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.af.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.agq-CM.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.agq-CM.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.agq.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.agq.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ak-GH.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ak-GH.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ak.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ak.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.am-ET.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.am-ET.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.am.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.am.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-001.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-001.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-AE.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-AE.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-BH.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-BH.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-DJ.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-DJ.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-DZ.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-DZ.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-EG.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-EG.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-ER.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-ER.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-IL.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-IL.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-IQ.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-IQ.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-JO.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-JO.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-KM.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-KM.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-KW.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-KW.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-LB.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-LB.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-LY.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-LY.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-MA.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-MA.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-MR.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-MR.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-OM.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-OM.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-PS.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-PS.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-QA.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-QA.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-SA.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-SA.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-SD.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-SD.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-SO.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-SO.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-SS.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-SS.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-SY.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-SY.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-TD.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-TD.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-TN.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-TN.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-YE.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar-YE.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ar.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.arn-CL.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.arn-CL.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.arn.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.arn.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.asa-TZ.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.asa-TZ.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.asa.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.asa.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ast-ES.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ast-ES.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ast.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ast.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.az-Cyrl-AZ.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.az-Cyrl-AZ.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.az-Cyrl.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.az-Cyrl.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.az-Latn-AZ.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.az-Latn-AZ.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.az-Latn.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.az-Latn.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.az.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.az.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bas-CM.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bas-CM.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bas.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bas.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.be-BY.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.be-BY.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.be.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.be.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bem-ZM.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bem-ZM.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bem.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bem.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bez-TZ.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bez-TZ.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bez.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bez.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bg-BG.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bg-BG.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bg.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bg.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bin-NG.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bin-NG.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bin.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bin.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bm-Latn-ML.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bm-Latn-ML.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bm-Latn.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bm-Latn.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bm.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bm.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bn-BD.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bn-BD.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bn-IN.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bn-IN.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bn.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bn.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bo-CN.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bo-CN.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bo-IN.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bo-IN.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bo.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bo.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.br-FR.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.br-FR.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.br.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.br.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.brx-IN.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.brx-IN.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.brx.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.brx.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bs-Cyrl-BA.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bs-Cyrl-BA.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bs-Cyrl.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bs-Cyrl.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bs-Latn-BA.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bs-Latn-BA.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bs-Latn.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bs-Latn.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bs.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.bs.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.byn-ER.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.byn-ER.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.byn.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.byn.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ca-AD.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ca-AD.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ca-ES-valencia.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ca-ES-valencia.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ca-ES.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ca-ES.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ca-FR.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ca-FR.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ca-IT.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ca-IT.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ca.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ca.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ce-RU.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ce-RU.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ce.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ce.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.cgg-UG.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.cgg-UG.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.cgg.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.cgg.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.chr-Cher-US.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.chr-Cher-US.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.chr-Cher.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.chr-Cher.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.chr.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.chr.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.cs-CZ.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.cs-CZ.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.cs.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.cs.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.cu-RU.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.cu-RU.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.cu.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.cu.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.cy-GB.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.cy-GB.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.cy.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.cy.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.da-DK.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.da-DK.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.da-GL.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.da-GL.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.da.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.da.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.dav-KE.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.dav-KE.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.dav.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.dav.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.de-AT.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.de-AT.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.de-BE.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.de-BE.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.de-CH.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.de-CH.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.de-LI.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.de-LI.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.de-LU.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.de-LU.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.dje-NE.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.dje-NE.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.dje.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.dje.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.dua-CM.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.dua-CM.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.dua.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.dua.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.dyo-SN.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.dyo-SN.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.dyo.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.dyo.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.dz-BT.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.dz-BT.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.dz.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.dz.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ebu-KE.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ebu-KE.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ebu.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ebu.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ee-GH.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ee-GH.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ee-TG.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ee-TG.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ee.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.ee.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.el-CY.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.el-CY.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-001.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-001.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-150.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-150.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-AG.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-AG.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-AI.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-AI.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-AS.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-AS.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-AT.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-AT.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-AU.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-AU.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-BB.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-BB.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-BE.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-BE.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-BI.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-BI.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-BM.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-BM.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-BS.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-BS.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-BW.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-BW.min.js.map
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-BZ.min.js
# 1	1	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-BZ.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-CC.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-CC.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-CH.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-CH.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-CK.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-CK.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-CM.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-CM.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-CX.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-CX.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-CY.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-CY.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-DE.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-DE.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-DK.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-DK.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-DM.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-DM.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-ER.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-ER.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-FI.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-FI.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-FJ.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-FJ.min.js.map
# 26	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-FK.min.js
# 1	0	wicket-kendo-ui-culture/src/main/resources/com/googlecode/wicket/kendo/ui/resource/cultures/kendo.culture.en-FK.min.js.map
# ...
# 7728c45b9 Method is renamed
# 1	1	wicket-jquery-ui-plugins/src/main/java/com/googlecode/wicket/jquery/ui/plugins/wysiwyg/settings/IWysiwygLibrarySettings.java
# 5ea3762a6 DataTableBehavior: modified constructors, takes list of IColumn
# 1	0	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/kendo/datatable/DefaultDataTablePage.java
# 3	4	wicket-kendo-ui/src/main/java/com/googlecode/wicket/kendo/ui/datatable/{ButtonAjaxBehavior.java => ColumnButtonAjaxBehavior.java}
# 3	3	wicket-kendo-ui/src/main/java/com/googlecode/wicket/kendo/ui/datatable/DataSourceBehavior.java
# 66	15	wicket-kendo-ui/src/main/java/com/googlecode/wicket/kendo/ui/datatable/DataTable.java
# 46	47	wicket-kendo-ui/src/main/java/com/googlecode/wicket/kendo/ui/datatable/DataTableBehavior.java
# 9	2	wicket-kendo-ui/src/main/java/com/googlecode/wicket/kendo/ui/datatable/column/PropertyColumn.java
# 54	0	wicket-kendo-ui/src/main/java/com/googlecode/wicket/kendo/ui/utils/PropertyUtils.java
# a7ac34fdc Reverted change in Options
# 4	2	wicket-jquery-ui-core/src/main/java/com/googlecode/wicket/jquery/core/JQueryBehavior.java
# 7	7	wicket-jquery-ui-core/src/main/java/com/googlecode/wicket/jquery/core/Options.java
# c29362647 DataTable: Added DatePropertyColumn; fixes #71
# 2	3	wicket-jquery-ui-core/src/main/java/com/googlecode/wicket/jquery/core/JQueryBehavior.java
# 14	14	wicket-jquery-ui-core/src/main/java/com/googlecode/wicket/jquery/core/Options.java
# 48	0	wicket-jquery-ui-core/src/main/java/com/googlecode/wicket/jquery/core/utils/DateUtils.java
# 9	0	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/data/bean/Product.java
# 4	8	wicket-kendo-ui/src/main/java/com/googlecode/wicket/kendo/ui/datatable/DataSourceBehavior.java
# 26	13	wicket-kendo-ui/src/main/java/com/googlecode/wicket/kendo/ui/datatable/DataTableBehavior.java
# 7	1	wicket-kendo-ui/src/main/java/com/googlecode/wicket/kendo/ui/datatable/column/AbstractColumn.java
# 126	0	wicket-kendo-ui/src/main/java/com/googlecode/wicket/kendo/ui/datatable/column/DatePropertyColumn.java
# 7	0	wicket-kendo-ui/src/main/java/com/googlecode/wicket/kendo/ui/datatable/column/IColumn.java
# 17	1	wicket-kendo-ui/src/main/java/com/googlecode/wicket/kendo/ui/utils/KendoDateTimeUtils.java
# f5bd5b61a Homepage: Updated version
# 1	1	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/HomePage.html
# d6c47ab90 Updated README (version)
# 3	1	README.md
# babab6472 [maven-release-plugin] prepare for next development iteration
# 1	1	pom.xml
# 2	2	wicket-jquery-ui-calendar/pom.xml
# 1	1	wicket-jquery-ui-core/pom.xml
# 2	2	wicket-jquery-ui-plugins/pom.xml
# 5	5	wicket-jquery-ui-samples/pom.xml
# 2	2	wicket-jquery-ui/pom.xml
# 2	2	wicket-kendo-ui/pom.xml
# f648f2ae2 [maven-release-plugin] prepare release wicket-jquery-ui-6.13.0
# 1	1	pom.xml
# 2	2	wicket-jquery-ui-calendar/pom.xml
# 1	1	wicket-jquery-ui-core/pom.xml
# 2	2	wicket-jquery-ui-plugins/pom.xml
# 5	5	wicket-jquery-ui-samples/pom.xml
# 2	2	wicket-jquery-ui/pom.xml
# 2	2	wicket-kendo-ui/pom.xml
# 9e5b24734 Missing Javadoc
# 7	7	wicket-kendo-ui/src/main/java/com/googlecode/wicket/kendo/ui/datatable/DataSourceBehavior.java
# 3dd979c42 Sample: Enabled groupable option in DefaultDataTablePage
# 7	2	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/data/bean/Product.java
# 78	78	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/data/dao/ProductsDAO.java
# 2	2	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/data/provider/ProductDataProvider.java
# 7	5	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/kendo/datatable/DefaultDataTablePage.java
# 6	0	wicket-jquery-ui-samples/src/main/resources/com/googlecode/wicket/jquery/ui/samples/pages/kendo/datatable/DefaultDataTablePage.text
# 1a4eed624 Sample: Added ProductDataProvider Sample: Enabled sortable option in DefaultDataTablePage
# 89	0	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/data/provider/ProductDataProvider.java
# 2	3	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/kendo/datatable/DefaultDataTablePage.java
# d06cb4ee8 Samples: moved DAOs to samples.data.dao
# 2	1	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/data/DemoCalendarModel.java
# 8	7	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/data/{DemoCalendarDAO.java => dao/CalendarDAO.java}
# 1	1	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/data/{ => dao}/GenresDAO.java
# 1	1	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/data/{ => dao}/ProductsDAO.java
# 1	1	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/autocomplete/ConverterAutoCompletePage.java
# 1	1	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/autocomplete/CustomAutoCompletePage.java
# 1	1	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/autocomplete/RendererAutoCompletePage.java
# 1	1	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/autocomplete/TemplateAutoCompletePage.java
# 8	8	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/calendar/ExtendedCalendarPage.java
# 1	1	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/kendo/combobox/CustomComboBoxPage.java
# 1	1	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/kendo/combobox/RendererComboBoxPage.java
# 1	1	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/kendo/combobox/TemplateComboBoxPage.java
# 1	1	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/kendo/datatable/CommandsDataTablePage.java
# 2	1	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/kendo/datatable/DefaultDataTablePage.java
# 1	1	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/kendo/datatable/InfiniteDataTablePage.java
# 1	1	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/selectable/TableDraggableSelectablePage.java
# 1	1	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/tooltip/CustomTooltipPage.java
# 4ed75939d Selectable: Added #setSelectedItems to allow overriding #newWidgetBehavior
# 31	18	wicket-jquery-ui/src/main/java/com/googlecode/wicket/jquery/ui/interaction/selectable/Selectable.java
# 8555cafe5 DataTable: Added AbstractColumn#isVisible()
# 1	1	wicket-kendo-ui/src/main/java/com/googlecode/wicket/kendo/ui/datatable/DataSourceBehavior.java
# 9	1	wicket-kendo-ui/src/main/java/com/googlecode/wicket/kendo/ui/datatable/column/AbstractColumn.java
# b71f7c9ec Wysiwyg: Fixed HTML warnings
# 3	3	wicket-jquery-ui-plugins/src/main/java/com/googlecode/wicket/jquery/ui/plugins/wysiwyg/toolbar/DefaultWysiwygToolbar.html
# 83f19bec1 DataTable: Handling IFilterStateLocator (without 'logic' & 'operator')
# 64	15	wicket-kendo-ui/src/main/java/com/googlecode/wicket/kendo/ui/datatable/DataSourceBehavior.java
# 1	0	wicket-kendo-ui/src/main/java/com/googlecode/wicket/kendo/ui/datatable/DataTableBehavior.java
# 78672c42f DataTable: Handling ISortStateLocator
# 29	2	wicket-kendo-ui/src/main/java/com/googlecode/wicket/kendo/ui/datatable/DataSourceBehavior.java
# 1	0	wicket-kendo-ui/src/main/java/com/googlecode/wicket/kendo/ui/datatable/DataTable.java
# 1	0	wicket-kendo-ui/src/main/java/com/googlecode/wicket/kendo/ui/datatable/DataTableBehavior.java
# 03470fe3f Updated DateRange & RangeDatePicker, Dates are UTC based, JSON is timezone agnostic; **API Break (functional)**
# 20	2	wicket-jquery-ui-plugins/src/main/java/com/googlecode/wicket/jquery/ui/plugins/datepicker/DateRange.java
# 10	25	wicket-jquery-ui-plugins/src/main/java/com/googlecode/wicket/jquery/ui/plugins/datepicker/RangeDatePicker.java
# 16	8	wicket-jquery-ui-plugins/src/main/java/com/googlecode/wicket/jquery/ui/plugins/datepicker/RangeDatePickerBehavior.java
# abeb52882 Updated pom version to 6.13.0-SNAPSHOT
# 1	1	pom.xml
# 2	2	wicket-jquery-ui-calendar/pom.xml
# 1	1	wicket-jquery-ui-core/pom.xml
# 2	2	wicket-jquery-ui-plugins/pom.xml
# 5	5	wicket-jquery-ui-samples/pom.xml
# 2	2	wicket-jquery-ui/pom.xml
# 2	2	wicket-kendo-ui/pom.xml
# 1b6fdc361 Wysiwyg, fix PackageResourceGuard initialization issue
# 62	0	wicket-jquery-ui-plugins/src/main/java/com/googlecode/wicket/jquery/ui/plugins/Initializer.java
# 1	17	wicket-jquery-ui-plugins/src/main/java/com/googlecode/wicket/jquery/ui/plugins/wysiwyg/WysiwygBehavior.java
# 1	0	wicket-jquery-ui-plugins/src/main/resources/wicket.properties
# 418a62e19 Updated CalendarModel javadoc
# 4	6	wicket-jquery-ui-calendar/src/main/java/com/googlecode/wicket/jquery/ui/calendar/CalendarModel.java
# 7e55100a2 Fixed Kendo UI ButtonBehavior (wrong extends)
# 2	1	wicket-kendo-ui/src/main/java/com/googlecode/wicket/kendo/ui/form/button/Button.java
# 26736474e Demo, fixed AdvancedTabsPage (count of visible tabs)
# 26	8	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/tabs/AdvancedTabsPage.java
# e6eaa352f Upgraded to wicket-6.13.0
# 1	1	pom.xml
# a3b9a578c DatePicket plugin: Updated DateRange#today (0:00:00 to 23:59:59)
# 24	2	wicket-jquery-ui-plugins/src/main/java/com/googlecode/wicket/jquery/ui/plugins/datepicker/DateRange.java
# e4365d758 Added DataTable #show(target) & #hide(target) Added DataTable #onShow(target) & #onHide(target) Added IColumn#getMenu Added IColumn#getFilterable Added IColumn#getAggregates Added IColumn#getGroupHeaderTemplate & Added IColumn#getGroupFooterTemplate
# 2	2	wicket-kendo-ui/src/main/java/com/googlecode/wicket/kendo/ui/datatable/DataSourceBehavior.java
# 47	0	wicket-kendo-ui/src/main/java/com/googlecode/wicket/kendo/ui/datatable/DataTable.java
# 96	5	wicket-kendo-ui/src/main/java/com/googlecode/wicket/kendo/ui/datatable/column/AbstractColumn.java
# 47	3	wicket-kendo-ui/src/main/java/com/googlecode/wicket/kendo/ui/datatable/column/IColumn.java
# bf15a3f2a Added KendoBehaviorFactory#show & KendoBehaviorFactory#hide
# 84	8	wicket-kendo-ui/src/main/java/com/googlecode/wicket/kendo/ui/KendoBehaviorFactory.java
# 8ffa060e6 Updated RangeDatePicker; triggering on onRangeChange event (instead of onChange). API Break.
# 4	4	wicket-jquery-ui-plugins/src/main/java/com/googlecode/wicket/jquery/ui/plugins/datepicker/RangeDatePickerBehavior.java
# 21	9	wicket-jquery-ui-plugins/src/main/resources/com/googlecode/wicket/jquery/ui/plugins/datepicker/js/datepicker.js
# b83b7eac1 Updated LabelPabel ctor (generic '?')
# 1	1	wicket-jquery-ui-core/src/main/java/com/googlecode/wicket/jquery/core/panel/LabelPanel.java
# ffec1c630 Fixed few HTML warnings
# 2	2	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/SiteMapPage.html
# 1	1	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/TemplatePage.html
# 2	2	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/selectable/DraggableSelectablePage.html
# 9734a9680 WysiwygEditor: fixed model issue
# 8	19	wicket-jquery-ui-plugins/src/main/java/com/googlecode/wicket/jquery/ui/plugins/wysiwyg/WysiwygEditor.java
# 2	0	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/SampleApplication.java
# 20	0	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/test/editor/EditorPage.html
# 50	0	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/test/editor/EditorPage.java
# 11	0	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/test/editor/EditorPanel.html
# 47	0	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/test/editor/EditorPanel.java
# 25	0	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/test/editor/EditorWindow.java
# 0	0	wicket-jquery-ui-samples/src/main/resources/com/googlecode/wicket/jquery/ui/samples/pages/test/editor/EditorPage.text
# ed925f73f Renamed com.googlecode.wicket.jquery.ui.kendo to com.googlecode.wicket.kendo.ui
# 1	1	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/component/DemoCalendarDialog.java
# 1	1	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/effect/ContainerEffectPage.java
# 3	3	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/kendo/combobox/CustomComboBoxPage.java
# 3	3	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/kendo/combobox/DefaultComboBoxPage.java
# 4	4	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/kendo/combobox/RendererComboBoxPage.java
# 3	3	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/kendo/combobox/TemplateComboBoxPage.java
# 2	2	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/kendo/console/DefaultConsolePage.java
# 2	2	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/kendo/console/FeedbackConsolePage.java
# 5	5	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/kendo/datatable/CommandsDataTablePage.java
# 4	4	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/kendo/datatable/DefaultDataTablePage.java
# 3	3	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/kendo/datatable/InfiniteDataTablePage.java
# 2	2	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/kendo/datetimepicker/AjaxDatePickerPage.java
# 2	2	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/kendo/datetimepicker/AjaxDateTimePickerPage.java
# 2	2	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/kendo/datetimepicker/AjaxTimePickerPage.java
# 4	3	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/kendo/datetimepicker/DateTimePickerPage.java
# 3	3	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/kendo/datetimepicker/DefaultTimePickerPage.java
# 3	3	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/kendo/datetimepicker/KendoDatePickerPage.java
# 3	3	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/kendo/datetimepicker/LocaleDatePickerPage.java
# 5	5	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/kendo/datetimepicker/LocaleDateTimePickerPage.java
# 3	3	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/kendo/datetimepicker/LocaleTimePickerPage.java
# 3	3	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/kendo/datetimepicker/PatternDatePickerPage.java
# 3	3	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/kendo/datetimepicker/PatternDateTimePickerPage.java
# 4	3	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/kendo/datetimepicker/PatternTimePickerPage.java
# 2	2	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/kendo/dropdown/AjaxDropDownPage.java
# 3	3	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/kendo/dropdown/DefaultDropDownPage.java
# 2	2	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/kendo/editor/DefaultEditorPage.java
# 1	1	wicket-jquery-ui-samples/src/main/java/com/googlecode/wicket/jquery/ui/samples/pages/kendo/splitter/BorderLayoutPage.java
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# 82d81bf70 Plugins: Editor, added OWASP sanitizer
# 17	10	wicket-jquery-ui-plugins/pom.xml
# 22	1	wicket-jquery-ui-plugins/src/main/java/com/googlecode/wicket/jquery/ui/plugins/wysiwyg/WysiwygEditor.java

# %%
#f.	How many total lines of code (excluding comments and blank lines) 
#were deleted? Hint: git diff or git show
#g.	How many total lines of code (excluding comments and blank lines) 
#were added? Hint: git diff or git show
#Look at C Manually Work out

# %%
#h.	How many days were between the current fixing commit and the previous 
#commit of each affected file? Hint: git log
#AffectedFile
log_data = repo.git.log("--parents",affected_file).splitlines()
for line in log_data:
    print(line)
# Out:
# commit a1a97302afa08902175192f3fca9321a960c2e61 4ade74d87389935dee5ba49b8cdd0abb075cc506
# Author: Maxim Solodovnik <solomax666@gmail.com>
# Date:   Sat Apr 28 12:49:53 2018 +0700
#
#     Fullcalendar is updated to version 3.9.0, memento.js is updated, minor code clean-up
#
# commit 4ade74d87389935dee5ba49b8cdd0abb075cc506 0e3fda077f990d809480ad4f78c0de3759db02a2
# Author: sbriquet <sbriquet@apache.org>
# Date:   Sun Mar 11 13:45:31 2018 +0100
#
#     Plugins: WysiwygEditor, replaced textarea by hidden input
#
# commit 0e3fda077f990d809480ad4f78c0de3759db02a2 b2231e6e81f2ea449aacde6fa7111f91576c4c4e
# Author: sbriquet <sbriquet@apache.org>
# Date:   Sat Mar 10 17:41:49 2018 +0100
#
#     Samples: WysiwygEditorPage, use submit button
#
# commit b2231e6e81f2ea449aacde6fa7111f91576c4c4e c8718f10d719be65bd06a05544f3b643998a83ba
# Author: sbriquet <sbriquet@apache.org>
# Date:   Sat Mar 10 16:01:06 2018 +0100
#
#     Plugins: WysiwygEditor, sanitized escaped input
#
# commit c8718f10d719be65bd06a05544f3b643998a83ba 936c12a2db262cf471c781f0d3c0d0ad61c35c7b
# Author: Maxim Solodovnik <solomax666@gmail.com>
# Date:   Sat Jan 27 18:47:51 2018 +0700
#
#     Hrefs with protocols are being stripped
#
#     This tiny fix allows absolute URLs to be entered i.e. `http://example.com`, `https://example.com`, `mailto:https@example.com`
#
# commit 936c12a2db262cf471c781f0d3c0d0ad61c35c7b 42294cc890536459b13cf16844cd65cccf665787
# Author: sbriquet <sbriquet@apache.org>
# Date:   Wed Dec 27 23:14:33 2017 +0100
#
#     Kendo UI: Editor#newPolicyFactory, removed static
#     Plugins: WysiwygEditor#newPolicyFactory, removed static
#
# commit 42294cc890536459b13cf16844cd65cccf665787 82d81bf704bef90b42f62aecbcc7e8c460814b67
# Author: sbriquet <sbriquet@apache.org>
# Date:   Wed Dec 27 20:07:49 2017 +0100
#
#     Kendo UI: Editor, added OWASP sanitizer
#     Kendo UI: **API BREAK** Editor model object is now String type (no more generic T)
#
# commit 82d81bf704bef90b42f62aecbcc7e8c460814b67 3579a23338e6a3f1667d8fc0de8c986c9288b70a
# Author: Maxim Solodovnik <solomax666@gmail.com>
# Date:   Sun Dec 24 19:00:50 2017 +0700
#
#     Plugins: Editor, added OWASP sanitizer
#
# commit 3579a23338e6a3f1667d8fc0de8c986c9288b70a 92105b005eeaa484d1964b625c61c34a007e5583
# Author: Maxim Solodovnik <solomax666@gmail.com>
# Date:   Thu Jun 22 10:18:58 2017 +0700
#
#     Wysiwyg editor is updated to have latest dependencies, code clean-up
#
# commit 92105b005eeaa484d1964b625c61c34a007e5583 a972ac3a2ef9d2ee6c7f3af55fe9f6cc882a16d4
# Author: sbriquet <sbriquet@apache.org>
# Date:   Sat Dec 3 20:30:29 2016 +0100
#
#     Fixed javadoc errors
#
# commit a972ac3a2ef9d2ee6c7f3af55fe9f6cc882a16d4 552056abbb64a43d5f90e318dc2f2942f79f8222
# Author: Sebastien Briquet <sebfz1@gmail.com>
# Date:   Wed Nov 23 14:17:57 2016 +0100
#
#     fixed javadoc errors (<br/> w/ java8)
#
# commit 552056abbb64a43d5f90e318dc2f2942f79f8222 593ec5d62461343df7db131bcd2e3e56ab8a041f
# Author: Sebastien Briquet <sbriquet@apache.org>
# Date:   Sun Apr 17 16:21:38 2016 +0200
#
#     Reverted (restored) IJQueryWidget#JQueryWidget
#     Aligned with master
#
# commit 593ec5d62461343df7db131bcd2e3e56ab8a041f 61839a95e378f17adf766c11b68fcb7da7ec4879
# Author: Sebastien Briquet <sbriquet@apache.org>
# Date:   Mon Feb 22 20:33:44 2016 +0100
#
#     **API BREAK** - Core: IJQueryWidget: removed static class JQueryWidget
#
# commit 61839a95e378f17adf766c11b68fcb7da7ec4879 e2ed846d4aeb7efc3afcebe8fa338890461a5962
# Author: Sebastien <sebfz1@gmail.com>
# Date:   Tue Jul 14 17:59:08 2015 +0200
#
#     wicket7.x is now master
#
# commit e2ed846d4aeb7efc3afcebe8fa338890461a5962 0395e2144b2fd092c141728eacad5a2cdf6a265a
# Author: Maxim Solodovnik <solomax666@gmail.com>
# Date:   Sat Jan 31 00:01:21 2015 +0600
#
#     Fixed Issue #151 hyperlink seems to work as expected, styles are fixed
#
# commit 0395e2144b2fd092c141728eacad5a2cdf6a265a 64721a7422e9732d5d68a3f34a4b1a9905d53be3
# Author: Sebastien Briquet <sebastien.briquet@amadeus.com>
# Date:   Mon Dec 15 10:22:20 2014 +0100
#
#     Review of #141
#
# commit 64721a7422e9732d5d68a3f34a4b1a9905d53be3 a67ce4c7daaf153edf9c25ef719a4f17f84747ee
# Author: Maxim Solodovnik <solomax666@gmail.com>
# Date:   Fri Dec 12 17:30:02 2014 +0600
#
#     Whitespaces are corrected; redundant comment is removed
#
# commit a67ce4c7daaf153edf9c25ef719a4f17f84747ee 271aee7867d057bb0b362b5d4016d21a286be076
# Author: Maxim Solodovnik <solomax666@gmail.com>
# Date:   Fri Dec 12 16:45:10 2014 +0600
#
#     Fixes issue #128: wisywig editor gets disabled of form disable; editor JS file is updated with most recent version from Github
#
# commit 271aee7867d057bb0b362b5d4016d21a286be076 9734a9680f9afb997a13464dbbeaebb5fc49e3be
# Author: Sebastien Briquet <sebastien.briquet@amadeus.com>
# Date:   Fri Oct 31 17:15:13 2014 +0100
#
#     WysiwygEditor, setEscapeModelStrings(false) // fixes #121
#
# commit 9734a9680f9afb997a13464dbbeaebb5fc49e3be 9bf68584f329f3eedf0914bbb545ab9da2fd5042
# Author: Sebastien <sebfz1@gmail.com>
# Date:   Sun Dec 22 16:10:02 2013 +0100
#
#     WysiwygEditor: fixed model issue
#
# commit 9bf68584f329f3eedf0914bbb545ab9da2fd5042 caade8f7e786fe03910c1e99954b8234b602fe6f
# Author: Sebastien <sebfz1@gmail.com>
# Date:   Sat Nov 30 01:18:56 2013 +0100
#
#     Some code cosmetic...
#
# commit caade8f7e786fe03910c1e99954b8234b602fe6f f3fb719b702690c9e0baafc823998c9576ac9ee6
# Author: Maxim Solodovnik <solomax666@gmail.com>
# Date:   Mon Aug 26 23:56:07 2013 +0700
#
#     Update WysiwygEditor.java
#
#     Text modified via WysiwygEditor displayed incorrectly due to "input" text escaping.
#
# commit f3fb719b702690c9e0baafc823998c9576ac9ee6 9b781cd0b284d709b12f5d69bfbbe8e29312e987
# Author: Sebastien <sebfz1@gmail.com>
# Date:   Wed Jul 17 00:00:46 2013 +0200
#
#     Added IJQueryWidget#onBeforeRender(JQueryBehavior) & IJQueryWidget#onConfigure(JQueryBehavior); fixes #43
#
# commit 9b781cd0b284d709b12f5d69bfbbe8e29312e987 540c28147ef8ac72035d9d65b2a996ae94fade44
# Author: Sebastien <sebfz1@gmail.com>
# Date:   Wed Jun 26 22:29:41 2013 +0200
#
#     Upgraded to wicket-6.9.0
#
# commit 540c28147ef8ac72035d9d65b2a996ae94fade44 a7b9f7961e02e2a801f5031f39e6088b49f71dea
# Author: Sebastien <sebfz1@gmail.com>
# Date:   Tue Jun 18 23:23:47 2013 +0200
#
#     Javadoc
#
# commit a7b9f7961e02e2a801f5031f39e6088b49f71dea
# Author: Sebastien <sebfz1@gmail.com>
# Date:   Sun Jun 16 18:09:34 2013 +0200
#
#     Added WysiwygEditor

# %% [markdown]
# commit 82d81bf704bef90b42f62aecbcc7e8c460814b67 3579a23338e6a3f1667d8fc0de8c986c9288b70a
# Author: Maxim Solodovnik <solomax666@gmail.com>
# Date:   Sun Dec 24 19:00:50 2017 +0700
#
#     Plugins: Editor, added OWASP sanitizer
#
# commit 3579a23338e6a3f1667d8fc0de8c986c9288b70a 92105b005eeaa484d1964b625c61c34a007e5583
# Author: Maxim Solodovnik <solomax666@gmail.com>
# Date:   Thu Jun 22 10:18:58 2017 +0700
#
#     Wysiwyg editor is updated to have latest dependencies, code clean-up
#
# 185 days difference

# %%
#h.	How many days were between the current fixing commit and the previous 
#commit of each affected file? Hint: git log
#AffectedFile1
log_data = repo.git.log("--parents",affected_file1).splitlines()
for line in log_data:
    print(line)
# Out:
# commit 8677492ebaf6a101eca56eb1cec9ac86f6635c0c dcabf081c072c95725f93159f3d5eb8b1ac0417b
# Author: Sebastien Briquet <sbriquet@apache.org>
# Date:   Tue Mar 19 11:20:42 2019 +0100
#
#     [maven-release-plugin] prepare for next development iteration
#
# commit dcabf081c072c95725f93159f3d5eb8b1ac0417b fe755b328561a62cf2bfb0a78ac79547895767e2
# Author: Sebastien Briquet <sbriquet@apache.org>
# Date:   Tue Mar 19 11:20:25 2019 +0100
#
#     [maven-release-plugin] prepare release wicket-jquery-ui-8.3.0
#
# commit fe755b328561a62cf2bfb0a78ac79547895767e2 0028399049d7277acce6a2c20c315b90e53249d1
# Author: Sebastien Briquet <sbriquet@apache.org>
# Date:   Mon Mar 18 14:17:44 2019 +0100
#
#     [maven-release-plugin] rollback the release of wicket-jquery-ui-8.3.0
#
# commit 0028399049d7277acce6a2c20c315b90e53249d1 dcbde31c3182875efe0002482e8392a39d5d31aa
# Author: Sebastien Briquet <sbriquet@apache.org>
# Date:   
# Author: Sebastien Briquet <sebfz1@gmail.com>
# Date:   Sat Oct 20 19:18:10 2012 +0200
#
#     [maven-release-plugin] prepare for next development iteration
#
# commit 762e572a9329ca7ff5b2991555e7f3fdd99bd3f2 ce6a7495bd40ad632970d8d97ab8cab33a7e05d7
# Author: Sebastien Briquet <sebfz1@gmail.com>
# Date:   Sat Oct 20 19:17:47 2012 +0200
#
#     [maven-release-plugin] prepare release wicket-jquery-ui-1.3.0
#
# commit ce6a7495bd40ad632970d8d97ab8cab33a7e05d7 ed5de8e39da3b54737abe793b5a21a744b09c1db
# Author: Sebastien Briquet <sebfz1@gmail.com>
# Date:   Tue Aug 28 21:39:11 2012 +0200
#
#     [maven-release-plugin] prepare for next development iteration
#
# commit ed5de8e39da3b54737abe793b5a21a744b09c1db 468261780ac238aa1598ff54ea04e1ffea3fa277
# Author: Sebastien Briquet <sebfz1@gmail.com>
# Date:   Tue Aug 28 21:38:53 2012 +0200
#
#     [maven-release-plugin] prepare release wicket-jquery-ui-1.2.2
#
# commit 468261780ac238aa1598ff54ea04e1ffea3fa277 b6105398e3105813a11fc68f8b89f714a35fa9f7
# Author: Sebastien Briquet <sebfz1@gmail.com>
# Date:   Tue Jun 12 23:08:36 2012 +0200
#
#     [maven-release-plugin] prepare for next development iteration
#
# commit b6105398e3105813a11fc68f8b89f714a35fa9f7 122be1b28237846431ebc9919d47c43eb99735f7
# Author: Sebastien Briquet <sebfz1@gmail.com>
# Date:   Tue Jun 12 23:08:21 2012 +0200
#
#     [maven-release-plugin] prepare release jquery-ui-parent-1.2.1
#
# commit 122be1b28237846431ebc9919d47c43eb99735f7 ec6b058f8a8bd475e711816396454d4a11320b69
# Author: Sebastien Briquet <sebfz1@gmail.com>
# Date:   Mon May 21 22:34:03 2012 +0200
#
#     [maven-release-plugin] prepare for next development iteration
#
# commit ec6b058f8a8bd475e711816396454d4a11320b69 cc1e81b2fb16c83656b529333bb9fdba7fb467ca
# Author: Sebastien Briquet <sebfz1@gmail.com>
# Date:   Mon May 21 22:33:48 2012 +0200
#
#     [maven-release-plugin] prepare release wicket-jquery-ui-1.2.0
#
# commit cc1e81b2fb16c83656b529333bb9fdba7fb467ca 69e93a6a6b4217d7ed96b9fd573bf5cdca1a6956
# Author: Sebastien Briquet <sebfz1@gmail.com>
# Date:   Mon May 21 22:24:19 2012 +0200
#
#     Updates on BorderLayout (+ IBorderLayout)
#
# commit 69e93a6a6b4217d7ed96b9fd573bf5cdca1a6956 f46ba8c84a052b6410a04417a64a294571e2166a
# Author: Sebastien Briquet <sebfz1@gmail.com>
# Date:   Mon May 21 01:00:50 2012 +0200
#
#     [maven-release-plugin] prepare for next development iteration
#
# commit f46ba8c84a052b6410a04417a64a294571e2166a d41c392032da80738b292e4b41eb569324e9f2ad
# Author: Sebastien Briquet <sebfz1@gmail.com>
# Date:   Mon May 21 01:00:31 2012 +0200
#
#     [maven-release-plugin] prepare release wicket-jquery-ui-1.2.0
#
# commit d41c392032da80738b292e4b41eb569324e9f2ad 433f0db67007426147071e8f53ceb9b4c03332fa
# Author: Sebastien Briquet <sebfz1@gmail.com>
# Date:   Mon May 21 00:59:11 2012 +0200
#
#     pom.xml
#
# commit 433f0db67007426147071e8f53ceb9b4c03332fa b56baa0f212e5d1011d75ca42da0d15bb832c43d
# Author: Sebastien Briquet <sebfz1@gmail.com>
# Date:   Mon May 21 00:46:09 2012 +0200
#
#     changed pom.xml structure
#
# commit b56baa0f212e5d1011d75ca42da0d15bb832c43d 4055b7258ae3b2aa98a5789490bc027abc5d5f61
# Author: Sebastien Briquet <sebfz1@gmail.com>
# Date:   Sun May 20 18:56:37 2012 +0200
#
#     kendo-ui editor + missing javadoc
#
# commit 4055b7258ae3b2aa98a5789490bc027abc5d5f61 d23d409778402b7e7fcdf971973ffbb0dbacd9c9
# Author: Sebastien Briquet <sebfz1@gmail.com>
# Date:   Fri May 18 21:56:57 2012 +0200
#
#     webapp-doc + pom/xml (1.1.1-SNAPSHOT) + kendo-ui 2012.1.322
#
# commit d23d409778402b7e7fcdf971973ffbb0dbacd9c9
# Author: Sebastien Briquet <sebfz1@gmail.com>
# Date:   Tue May 8 22:21:06 2012 +0200
#
#     initial commit (1.2-SNAPSHOT)

# %% [markdown]
# commit 82d81bf704bef90b42f62aecbcc7e8c460814b67 cc42991163a137c2ad8fbf146a526fc091ff24dc
# Author: Maxim Solodovnik <solomax666@gmail.com>
# Date:   Sun Dec 24 19:00:50 2017 +0700
#
#     Plugins: Editor, added OWASP sanitizer
#
# commit cc42991163a137c2ad8fbf146a526fc091ff24dc 261bda97e77bbc23b06574969509bf53b62ef265
# Author: sbriquet <sbriquet@apache.org>
# Date:   Fri Oct 27 18:39:41 2017 +0200
#
#     [maven-release-plugin] prepare for next development iteration
# 58 days difference

# %%
#i.	How many time has each affected file of the current fixing commit 
#been modified in the past since their creation (including rename of the file)? Hint: git log
#Affected File
log_data = repo.git.log("--oneline",affected_file).splitlines()
print("Number of commits in between:", len(log_data))
for line in log_data:
    print(line)
# Out:
# Number of commits in between: 26
# a1a97302a Fullcalendar is updated to version 3.9.0, memento.js is updated, minor code clean-up
# 4ade74d87 Plugins: WysiwygEditor, replaced textarea by hidden input
# 0e3fda077 Samples: WysiwygEditorPage, use submit button
# b2231e6e8 Plugins: WysiwygEditor, sanitized escaped input
# c8718f10d Hrefs with protocols are being stripped
# 936c12a2d Kendo UI: Editor#newPolicyFactory, removed static Plugins: WysiwygEditor#newPolicyFactory, removed static
# 42294cc89 Kendo UI: Editor, added OWASP sanitizer Kendo UI: **API BREAK** Editor model object is now String type (no more generic T)
# 82d81bf70 Plugins: Editor, added OWASP sanitizer
# 3579a2333 Wysiwyg editor is updated to have latest dependencies, code clean-up
# 92105b005 Fixed javadoc errors
# a972ac3a2 fixed javadoc errors (<br/> w/ java8)
# 552056abb Reverted (restored) IJQueryWidget#JQueryWidget Aligned with master
# 593ec5d62 **API BREAK** - Core: IJQueryWidget: removed static class JQueryWidget
# 61839a95e wicket7.x is now master
# e2ed846d4 Fixed Issue #151 hyperlink seems to work as expected, styles are fixed
# 0395e2144 Review of #141
# 64721a742 Whitespaces are corrected; redundant comment is removed
# a67ce4c7d Fixes issue #128: wisywig editor gets disabled of form disable; editor JS file is updated with most recent version from Github
# 271aee786 WysiwygEditor, setEscapeModelStrings(false) // fixes #121
# 9734a9680 WysiwygEditor: fixed model issue
# 9bf68584f Some code cosmetic...
# caade8f7e Update WysiwygEditor.java
# f3fb719b7 Added IJQueryWidget#onBeforeRender(JQueryBehavior) & IJQueryWidget#onConfigure(JQueryBehavior); fixes #43
# 9b781cd0b Upgraded to wicket-6.9.0
# 540c28147 Javadoc
# a7b9f7961 Added WysiwygEditor

# %%
#i.	How many time has each affected file of the current fixing commit 
#been modified in the past since their creation (including rename of the file)? Hint: git log
#Affected File1
log_data = repo.git.log("--oneline",affected_file1).splitlines()
print("Number of commits in between:", len(log_data))
for line in log_data:
    print(line)
# Out:
# Number of commits in between: 143
# 8677492eb [maven-release-plugin] prepare for next development iteration
# dcabf081c [maven-release-plugin] prepare release wicket-jquery-ui-8.3.0
# fe755b328 [maven-release-plugin] rollback the release of wicket-jquery-ui-8.3.0
# 002839904 [maven-release-plugin] prepare for next development iteration
# dcbde31c3 [maven-release-plugin] prepare release wicket-jquery-ui-8.3.0
# 2df5276cb [maven-release-plugin] prepare for next development iteration
# fcd310f34 [maven-release-plugin] prepare release wicket-jquery-ui-8.1.0
# 38592ab56 Versions: upgraded to 8.1.0-SNAPSHOT
# 393ca2e73 [maven-release-plugin] prepare for next development iteration
# f817324d7 [maven-release-plugin] prepare release wicket-jquery-ui-8.0.0
# faccc1b6f [maven-release-plugin] prepare for next development iteration
# 8d49b82af [maven-release-plugin] prepare release wicket-jquery-ui-8.0.0-M9.2
# 2ee384f1d [maven-release-plugin] prepare for next development iteration
# 4f0a6dec9 [maven-release-plugin] prepare release wicket-jquery-ui-8.0.0-M9.1
# d14d02950 [maven-release-plugin] prepare for next development iteration
# 4bae4726a [maven-release-plugin] prepare release wicket-jquery-ui-8.0.0-M9
# 8f54db45b [maven-release-plugin] prepare for next development iteration
# 7451300ac [maven-release-plugin] prepare release wicket-jquery-ui-8.0.0-M8.1
# 42294cc89 Kendo UI: Editor, added OWASP sanitizer Kendo UI: **API BREAK** Editor model object is now String type (no more generic T)
# 82d81bf70 Plugins: Editor, added OWASP sanitizer
# cc4299116 [maven-release-plugin] prepare for next development iteration
# 261bda97e [maven-release-plugin] prepare release wicket-jquery-ui-8.0.0-M8
# c64fffb8a [maven-release-plugin] prepare for next development iteration
# 380e5e536 [maven-release-plugin] prepare release wicket-jquery-ui-8.0.0-M7
# ce3b51fa6 [maven-release-plugin] prepare for next development iteration
# a258779fa [maven-release-plugin] prepare release wicket-jquery-ui-8.0.0-M6
# 11f44dc35 [maven-release-plugin] prepare for next development iteration
# c624024c6 [maven-release-plugin] prepare release wicket-jquery-ui-8.0.0-M5
# 3eb353f4a [maven-release-plugin] prepare for next development iteration
# d211ff0b3 [maven-release-plugin] prepare release wicket-jquery-ui-8.0.0-M4.1
# 3d7e63dd1 [maven-release-plugin] prepare for next development iteration
# 6d34d8eff [maven-release-plugin] prepare release wicket-jquery-ui-8.0.0-M4
# 4ce04a9e2 [maven-release-plugin] prepare for next development iteration
# 1f72799a8 [maven-release-plugin] prepare release wicket-jquery-ui-8.0.0-M3
# 4e2fa8c76 [maven-release-plugin] prepare for next development iteration
# e4b61aeee [maven-release-plugin] prepare release wicket-jquery-ui-8.0.0-M2
# 59ab12d18 [maven-release-plugin] prepare for next development iteration
# 43a6e22a9 [maven-release-plugin] prepare release wicket-jquery-ui-8.0.0-M1.1
# 4c79938ba [maven-release-plugin] rollback the release of wicket-jquery-ui-8.0.0-M1.1
# d99378f29 [maven-release-plugin] prepare release wicket-jquery-ui-8.0.0-M1.1
# 432055b75 [maven-release-plugin] prepare for next development iteration
# 9b43643be [maven-release-plugin] prepare release wicket-jquery-ui-8.0.0-M1.1
# b0ce80152 [maven-release-plugin] prepare for next development iteration
# 27ec11046 [maven-release-plugin] prepare release wicket-jquery-ui-8.0.0-M1
# 90c341115 mvn versions:set to 8.0.0-SNAPSHOT
# 217d30098 [maven-release-plugin] prepare for next development iteration
# 92251f856 [maven-release-plugin] prepare release wicket-jquery-ui-7.2.0
# fb60355df Updated version to 7.2.0-SNAPSHOT
# 6fee5510b [maven-release-plugin] prepare for next development iteration
# 7c6c1a90c [maven-release-plugin] prepare release wicket-jquery-ui-7.1.0
# c630cc227 [maven-release-plugin] prepare for next development iteration
# 43655bfab [maven-release-plugin] prepare release wicket-jquery-ui-7.0.2
# 1e7e541dd [maven-release-plugin] prepare for next development iteration
# c6b20d770 [maven-release-plugin] prepare release wicket-jquery-ui-7.0.1
# 4dd986dcb [maven-release-plugin] prepare for next development iteration
# be7daa360 [maven-release-plugin] prepare release wicket-jquery-ui-7.0.0
# 61839a95e wicket7.x is now master
# c11a0988a [maven-release-plugin] prepare for next development iteration
# a256ebc2d [maven-release-plugin] prepare release wicket-jquery-ui-6.20.0
# ca974983c [maven-release-plugin] rollback the release of wicket-jquery-ui-6.20.0
# dc3316c63 [maven-release-plugin] prepare release wicket-jquery-ui-6.20.0
# 081816b8e [maven-release-plugin] rollback the release of wicket-jquery-ui-6.20.0
# b1354accc [maven-release-plugin] prepare for next development iteration
# 7f32e4c06 [maven-release-plugin] prepare release wicket-jquery-ui-6.20.0
# dc12873c9 Updated versions
# 96aaa876c [maven-release-plugin] prepare for next development iteration
# ab760d23a [maven-release-plugin] prepare release wicket-jquery-ui-6.19.2
# ef79e2314 mvn version:set 6.19.2-SNAPSHOT
# 8ad0169df [maven-release-plugin] prepare for next development iteration
# bea498c67 [maven-release-plugin] prepare release wicket-jquery-ui-parent-6.19.2
# fd948b9dd [maven-release-plugin] prepare for next development iteration
# f31915ae7 [maven-release-plugin] prepare release wicket-jquery-ui-6.19.1
# 14f73210d [maven-release-plugin] prepare for next development iteration
# bfda7b114 [maven-release-plugin] prepare release wicket-jquery-ui-6.19.0
# ac36a1fb2 Upgraded to wicket-6.19.0, updated version to 6.19.0-SNAPSHOT
# a5e406328 [maven-release-plugin] prepare for next development iteration
# 6cae2399c [maven-release-plugin] prepare release wicket-jquery-ui-parent-6.18.1
# 6ca68abf0 [maven-release-plugin] prepare for next development iteration
# bd8f6868a [maven-release-plugin] prepare release wicket-jquery-ui-6.18.0
# 4749965b7 Upgraded poms to 6.18.0-SNAPSHOT
# 973111f83 Updated poms for OSGI support; #127
# 63c624e68 [maven-release-plugin] prepare for next development iteration
# 092077784 [maven-release-plugin] prepare release wicket-jquery-ui-6.17.0
# 09df88b52 [maven-release-plugin] prepare for next development iteration
# ee1f5c58a [maven-release-plugin] prepare release wicket-jquery-ui-6.16.0
# 57a12f28d Updated poms to support OSGI; #104
# 4fbb16c68 [maven-release-plugin] prepare for next development iteration
# fc79c339f [maven-release-plugin] prepare release wicket-jquery-ui-6.15.0
# 66db42220 [maven-release-plugin] rollback the release of wicket-jquery-ui-6.15.0
# a4a8a3f54 [maven-release-plugin] prepare release wicket-jquery-ui-6.15.0
# 66eb67d88 Upgraded to wicket-6.15.0
# 386dc5e18 [maven-release-plugin] prepare for next development iteration
# cedae074f [maven-release-plugin] prepare release wicket-jquery-ui-6.14.0
# 88f5f8d65 [maven-release-plugin] prepare for next development iteration
# 80c16f620 [maven-release-plugin] prepare release wicket-jquery-ui-6.13.1
# 30c9d7b72 Restored pom versions
# fcba52b62 [maven-release-plugin] prepare release wicket-jquery-ui-6.13.1
# babab6472 [maven-release-plugin] prepare for next development iteration
# f648f2ae2 [maven-release-plugin] prepare release wicket-jquery-ui-6.13.0
# abeb52882 Updated pom version to 6.13.0-SNAPSHOT
# 9a4daa128 Changed version to 6.12.2-SNAPSHOT
# c572172f1 [maven-release-plugin] prepare for next development iteration
# e6a1821c3 [maven-release-plugin] prepare release wicket-jquery-ui-6.12.0
# 51275f70a [maven-release-plugin] prepare for next development iteration
# 1184d38a5 [maven-release-plugin] prepare release wicket-jquery-ui-parent-6.11.0
# 49fd732c2 Update the version to 6.11.0-SNAPSHOT
# 2236192de [maven-release-plugin] prepare for next development iteration
# e29d8738e [maven-release-plugin] prepare release wicket-jquery-ui-6.10.0
# 574ae912a [maven-release-plugin] prepare for next development iteration
# 59e7915e2 [maven-release-plugin] prepare release wicket-jquery-ui-6.9.1
# 29fc2af5f [maven-release-plugin] prepare for next development iteration
# f63b53a14 [maven-release-plugin] prepare release wicket-jquery-ui-6.9.0
# 06f115401 [maven-release-plugin] prepare for next development iteration
# 0d83928dc [maven-release-plugin] prepare release wicket-jquery-ui-6.8.1
# 3d5be0e22 [maven-release-plugin] prepare for next development iteration
# 7e51a6b08 [maven-release-plugin] prepare release wicket-jquery-ui-6.8.0
# 2c2aec5a9 [maven-release-plugin] prepare for next development iteration
# 069b76728 [maven-release-plugin] prepare release wicket-jquery-ui-6.7.0
# 127f5918a moved wicket6 to master
# 65d73e742 [maven-release-plugin] prepare for next development iteration
# 879f75530 [maven-release-plugin] prepare release wicket-jquery-1.4.2
# 56b63d6ee [maven-release-plugin] prepare for next development iteration
# 4cefdfe19 [maven-release-plugin] prepare release wicket-jquery-ui-1.4.1
# de9cefcf3 [maven-release-plugin] prepare for next development iteration
# 880f0ffd2 [maven-release-plugin] prepare release wicket-jquery-ui-1.4.0
# 3165cf650 [maven-release-plugin] prepare for next development iteration
# 9804d3092 [maven-release-plugin] prepare release wicket-jquery-ui-1.3.1
# c63ab210e [maven-release-plugin] prepare for next development iteration
# 762e572a9 [maven-release-plugin] prepare release wicket-jquery-ui-1.3.0
# ce6a7495b [maven-release-plugin] prepare for next development iteration
# ed5de8e39 [maven-release-plugin] prepare release wicket-jquery-ui-1.2.2
# 468261780 [maven-release-plugin] prepare for next development iteration
# b6105398e [maven-release-plugin] prepare release jquery-ui-parent-1.2.1
# 122be1b28 [maven-release-plugin] prepare for next development iteration
# ec6b058f8 [maven-release-plugin] prepare release wicket-jquery-ui-1.2.0
# cc1e81b2f Updates on BorderLayout (+ IBorderLayout)
# 69e93a6a6 [maven-release-plugin] prepare for next development iteration
# f46ba8c84 [maven-release-plugin] prepare release wicket-jquery-ui-1.2.0
# d41c39203 pom.xml
# 433f0db67 changed pom.xml structure
# b56baa0f2 kendo-ui editor + missing javadoc
# 4055b7258 webapp-doc + pom/xml (1.1.1-SNAPSHOT) + kendo-ui 2012.1.322
# d23d40977 initial commit (1.2-SNAPSHOT)

# %%
#j.	Which developers have modified each affected file since its creation? 
#Hint: git log
#AffectedFile
log_data = repo.git.log("--pretty=format:%an",affected_file).splitlines()
df = pd.DataFrame(log_data, columns=['Author'])
df['count'] = 1
answer = df.groupby(['Author']).count()
print(answer)
# Out:
#                    count
# Author
# Maxim Solodovnik       8
# Sebastien              7
# Sebastien Briquet      5
# sbriquet               6

# %%
#j.	Which developers have modified each affected file since its creation? 
#Hint: git log
#AffectedFile1
log_data = repo.git.log("--pretty=format:%an",affected_file1).splitlines()
df = pd.DataFrame(log_data, columns=['Author'])
df['count'] = 1
answer = df.groupby(['Author']).count().reset_index(0, drop=False)
answer
# Out:
#                       Author  count
# 0  Martin Tzvetanov Grigorov      9
# 1           Maxim Solodovnik      1
# 2                  Sebastien     47
# 3          Sebastien Briquet     61
# 4                   sbriquet     25

# %%
#k.	For each developer identified, how many commits have each of them 
#submitted? From your observation, are the involving developers
#experienced (with many commits) or new ones (with few commits) or both? 
#Hint: git log or git shortlog
commit_authors = repo.git.shortlog("-sne", "--all").splitlines()

author_commits = []

for commit_author in commit_authors:
    commit, author = commit_author.split("\t")
    author_commits.append([int(commit), author])
df = pd.DataFrame(author_commits, columns=['Commit', 'Author'])
print(df)
# Out:
#     Commit                                             Author
# 0      608                       Sebastien <sebfz1@gmail.com>
# 1      361                     sbriquet <sbriquet@apache.org>
# 2      303               Sebastien Briquet <sebfz1@gmail.com>
# 3      275  Sebastien Briquet <sebastien.briquet@amadeus.com>
# 4      259            Sebastien Briquet <sbriquet@apache.org>
# 5       91   Martin Tzvetanov Grigorov <mgrigorov@apache.org>
# 6       56        Sebastien Briquet <sbriquet.ext@orange.com>
# 7       35  Sebastien Briquet <sebfz1@users.noreply.github...
# 8       33            Maxim Solodovnik <solomax666@gmail.com>
# 9       31                  davids <patrick.davids@nuboit.de>
# 10       9              JavaLuigi <lkluitmann@googlemail.com>
# 11       8                          sebfz1 <sebfz1@gmail.com>
# 12       4              Tedlabs46 <steven.baldet@amadeus.com>
# 13       4                 Tedlabs46 <stevenbaldet@gmail.com>
# 14       3         Alexey Prudnikov <a.m.prudnikov@gmail.com>
# 15       3                      Jezza <jezzadabomb@gmail.com>
# 16       3                      davids <ethan.hunt.me@web.de>
# 17       2                      davids <p.davids@healthag.de>
# 18       1  Francesco Chicchiriccò <ilgrosso@users.noreply...
# 19       1  Fridolin Jackstadt <fridolin.jackstadt@lindenb...
# 20       1         Kazuki Shintani <kazukishintani@gmail.com>
# 21       1  Martin Grigorov <martin-g@users.noreply.github...
# 22       1             Martin Grigorov <mgrigorov@apache.org>
# 23       1           Sebastien Briquet <sbriquet@amadeus.com>
# 24       1                               klu <klu@klu-ubuntu>
# 25       1                sbaldet <steven.baldet@amadeus.com>
# 26       1           solomax <solomax@solomax-desktop.(none)>
# 27       1                        ymlaine <ymlaine@gmail.com>

# %%
com = df[["Commit"]].copy()
df = pd.DataFrame(df.Author.str.split(' <',1).tolist(),columns = ['Author','email'])
df["Commit"] = com["Commit"]
names = answer["Author"].tolist()
for name in names:
    print(df[(df["Author"] == name)])
# Out:
#                       Author                  email  Commit
# 5  Martin Tzvetanov Grigorov  mgrigorov@apache.org>      91
#              Author                  email  Commit
# 8  Maxim Solodovnik  solomax666@gmail.com>      33
#       Author              email  Commit
# 0  Sebastien  sebfz1@gmail.com>     608
#                Author                             email  Commit
# 2   Sebastien Briquet                 sebfz1@gmail.com>     303
# 3   Sebastien Briquet    sebastien.briquet@amadeus.com>     275
# 4   Sebastien Briquet              sbriquet@apache.org>     259
# 6   Sebastien Briquet          sbriquet.ext@orange.com>      56
# 7   Sebastien Briquet  sebfz1@users.noreply.github.com>      35
# 23  Sebastien Briquet             sbriquet@amadeus.com>       1
#      Author                 email  Commit
# 1  sbriquet  sbriquet@apache.org>     361
