# %%
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install pygithub
# !{sys.executable} -m pip install gitpython
# !conda install --yes --prefix {sys.prefix} git
# Out:
# Requirement already satisfied: pygithub in c:\users\shaun\anaconda4\lib\site-packages (1.43.8)
# Requirement already satisfied: pyjwt in c:\users\shaun\anaconda4\lib\site-packages (from pygithub) (1.7.1)
# Requirement already satisfied: deprecated in c:\users\shaun\anaconda4\lib\site-packages (from pygithub) (1.2.6)
# Requirement already satisfied: requests>=2.14.0 in c:\users\shaun\anaconda4\lib\site-packages (from pygithub) (2.21.0)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\shaun\anaconda4\lib\site-packages (from deprecated->pygithub) (1.11.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\shaun\anaconda4\lib\site-packages (from requests>=2.14.0->pygithub) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shaun\anaconda4\lib\site-packages (from requests>=2.14.0->pygithub) (2019.3.9)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\shaun\anaconda4\lib\site-packages (from requests>=2.14.0->pygithub) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\shaun\anaconda4\lib\site-packages (from requests>=2.14.0->pygithub) (1.24.1)
# Requirement already satisfied: gitpython in c:\users\shaun\anaconda4\lib\site-packages (3.0.2)
# Requirement already satisfied: gitdb2>=2.0.0 in c:\users\shaun\anaconda4\lib\site-packages (from gitpython) (2.0.5)
# Requirement already satisfied: smmap2>=2.0.0 in c:\users\shaun\anaconda4\lib\site-packages (from gitdb2>=2.0.0->gitpython) (2.0.5)
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
import numpy as np
import pandas as pd
import os

# Specify git executable file for GitPython in Jupyter Notebook (In IDE, it can still work without this line.)
os.environ["GIT_PYTHON_GIT_EXECUTABLE"] = "C:\Program Files\Git\cmd\git.exe"

import git
from git import RemoteProgress

from git import Repo
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

class Progress(RemoteProgress):
    def update(self, op_code, cur_count, max_count=None, message=''):
        print(self._cur_line)
        
remote_link = "https://github.com/apache/commons-compress"
local_link = "repo/apache2"
# Uncomment to clone
Repo.clone_from(remote_link, local_link, progress=Progress())

repo = Repo(local_link)
fixing_commit = "a41ce6892cb0590b2e658704434ac0dbcb6834c8"
affected_file = "src/changes/changes.xml"
affected_file1 = "src/main/java/org/apache/commons/compress/archivers/zip/ZipArchiveInputStream.java"
affected_file2 = "src/test/java/org/apache/commons/compress/archivers/zip/Maven221MultiVolumeTest.java"
affected_file3 = "src/test/java/org/apache/commons/compress/archivers/zip/ZipArchiveInputStreamTest.java"
# Out:
# remote: Counting objects:   0% (1/383)
# remote: Counting objects:   1% (4/383)
# remote: Counting objects:   2% (8/383)
# remote: Counting objects:   3% (12/383)
# remote: Counting objects:   4% (16/383)
# remote: Counting objects:   5% (20/383)
# remote: Counting objects:   6% (23/383)
# remote: Counting objects:   7% (27/383)
# remote: Counting objects:   8% (31/383)
# remote: Counting objects:   9% (35/383)
# remote: Counting objects:  10% (39/383)
# remote: Counting objects:  11% (43/383)
# remote: Counting objects:  12% (46/383)
# remote: Counting objects:  13% (50/383)
# remote: Counting objects:  14% (54/383)
# remote: Counting objects:  15% (58/383)
# remote: Counting objects:  16% (62/383)
# remote: Counting objects:  17% (66/383)
# remote: Counting objects:  18% (69/383)
# remote: Counting objects:  19% (73/383)
# remote: Counting objects:  20% (77/383)
# remote: Counting objects:  21% (81/383)
# remote: Counting objects:  22% (85/383)
# remote: Counting objects:  23% (89/383)
# remote: Counting objects:  24% (92/383)
# remote: Counting objects:  25% (96/383)
# remote: Counting objects:  26% (100/383)
# remote: Counting objects:  27% (104/383)
# remote: Counting objects:  28% (108/383)
# remote: Counting objects:  29% (112/383)
# remote: Counting objects:  30% (115/383)
# remote: Counting objects:  31% (119/383)
# remote: Counting objects:  32% (123/383)
# remote: Counting objects:  33% (127/383)
# remote: Counting objects:  34% (131/383)
# remote: Counting objects:  35% (135/383)
# remote: Counting objects:  36% (138/383)
# remote: Counting objects:  37% (142/383)
# remote: Counting objects:  38% (146/383)
# remote: Counting objects:  39% (150/383)
# remote: Counting objects:  40% (154/383)
# remote: Counting objects:  41% (158/383)
# remote: Counting objects:  42% (161/383)
# remote: Counting objects:  43% (165/383)
# remote: Counting objects:  44% (169/383)
# remote: Counting objects:  45% (173/383)
# remote: Counting objects:  46% (177/383)
# remote: Counting objects:  47% (181/383)
# remote: Counting objects:  48% (184/383)
# remote: Counting objects:  49% (188/383)
# remote: Counting objects:  50% (192/383)
# remote: Counting objects:  51% (196/383)
# remote: Counting objects:  52% (200/383)
# remote: Counting objects:  53% (203/383)
# remote: Counting objects:  54% (207/383)
# remote: Counting objects:  55% (211/383)
# remote: Counting objects:  56% (215/383)
# remote: Counting objects:  57% (219/383)
# remote: Counting objects:  58% (223/383)
# remote: Counting objects:  59% (226/383)
# remote: Counting objects:  60% (230/383)
# remote: Counting objects:  61% (234/383)
# remote: Counting objects:  62% (238/383)
# remote: Counting objects:  63% (242/383)
# remote: Counting objects:  64% (246/383)
# remote: Counting objects:  65% (249/383)
# remote: Counting objects:  66% (253/383)
# remote: Counting objects:  67% (257/383)
# remote: Counting objects:  68% (261/383)
# remote: Counting objects:  69% (265/383)
# remote: Counting objects:  70% (269/383)
# remote: Counting objects:  71% (272/383)
# remote: Counting objects:  72% (276/383)
# remote: Counting objects:  73% (280/383)
# remote: Counting objects:  74% (284/383)
# remote: Counting objects:  75% (288/383)
# remote: Counting objects:  76% (292/383)
# remote: Counting objects:  77% (295/383)
# remote: Counting objects:  78% (299/383)
# remote: Counting objects:  79% (303/383)
# remote: Counting objects:  80% (307/383)
# remote: Counting objects:  81% (311/383)
# remote: Counting objects:  82% (315/383)
# remote: Counting objects:  83% (318/383)
# remote: Counting objects:  84% (322/383)
# remote: Counting objects:  85% (326/383)
# remote: Counting objects:  86% (330/383)
# remote: Counting objects:  87% (334/383)
# remote: Counting objects:  88% (338/383)
# remote: Counting objects:  89% (341/383)
# remote: Counting objects:  90% (345/383)
# remote: Counting objects:  91% (349/383)
# remote: Counting objects:  92% (353/383)
# remote: Counting objects:  93% (357/383)
# remote: Counting objects:  94% (361/383)
# remote: Counting objects:  95% (364/383)
# remote: Counting objects:  96% (368/383)
# remote: Counting objects:  97% (372/383)
# remote: Counting objects:  98% (376/383)
# remote: Counting objects:  99% (380/383)
# remote: Counting objects: 100% (383/383)
# remote: Counting objects: 100% (383/383), done.
# remote: Compressing objects:   0% (1/167)
# remote: Compressing objects:   1% (2/167)
# remote: Compressing objects:   2% (4/167)
# remote: Compressing objects:   3% (6/167)
# remote: Compressing objects:   4% (7/167)
# remote: Compressing objects:   5% (9/167)
# remote: Compressing objects:   6% (11/167)
# remote: Compressing objects:   7% (12/167)
# remote: Compressing objects:   8% (14/167)
# remote: Compressing objects:   9% (16/167)
# remote: Compressing objects:  10% (17/167)
# remote: Compressing objects:  11% (19/167)
# remote: Compressing objects:  12% (21/167)
# remote: Compressing objects:  13% (22/167)
# remote: Compressing objects:  14% (24/167)
# remote: Compressing objects:  15% (26/167)
# remote: Compressing objects:  16% (27/167)
# remote: Compressing objects:  17% (29/167)
# remote: Compressing objects:  18% (31/167)
# remote: Compressing objects:  19% (32/167)
# remote: Compressing objects:  20% (34/167)
# remote: Compressing objects:  21% (36/167)
# remote: Compressing objects:  22% (37/167)
# remote: Compressing objects:  23% (39/167)
# remote: Compressing objects:  24% (41/167)
# remote: Compressing objects:  25% (42/167)
# remote: Compressing objects:  26% (44/167)
# remote: Compressing objects:  27% (46/167)
# remote: Compressing objects:  28% (47/167)
# remote: Compressing objects:  29% (49/167)
# remote: Compressing objects:  30% (51/167)
# remote: Compressing objects:  31% (52/167)
# remote: Compressing objects:  32% (54/167)
# remote: Compressing objects:  33% (56/167)
# remote: Compressing objects:  34% (57/167)
# remote: Compressing objects:  35% (59/167)
# remote: Compressing objects:  36% (61/167)
# remote: Compressing objects:  37% (62/167)
# remote: Compressing objects:  38% (64/167)
# remote: Compressing objects:  39% (66/167)
# remote: Compressing objects:  40% (67/167)
# remote: Compressing objects:  41% (69/167)
# remote: Compressing objects:  42% (71/167)
# remote: Compressing objects:  43% (72/167)
# remote: Compressing objects:  44% (74/167)
# remote: Compressing objects:  45% (76/167)
# remote: Compressing objects:  46% (77/167)
# remote: Compressing objects:  47% (79/167)
# remote: Compressing objects:  48% (81/167)
# remote: Compressing objects:  49% (82/167)
# remote: Compressing objects:  50% (84/167)
# remote: Compressing objects:  51% (86/167)
# remote: Compressing objects:  52% (87/167)
# remote: Compressing objects:  53% (89/167)
# remote: Compressing objects:  54% (91/167)
# remote: Compressing objects:  55% (92/167)
# remote: Compressing objects:  56% (94/167)
# remote: Compressing objects:  57% (96/167)
# remote: Compressing objects:  58% (97/167)
# remote: Compressing objects:  59% (99/167)
# remote: Compressing objects:  60% (101/167)
# remote: Compressing objects:  61% (102/167)
# remote: Compressing objects:  62% (104/167)
# remote: Compressing objects:  63% (106/167)
# remote: Compressing objects:  64% (107/167)
# remote: Compressing objects:  65% (109/167)
# remote: Compressing objects:  66% (111/167)
# remote: Compressing objects:  67% (112/167)
# remote: Compressing objects:  68% (114/167)
# remote: Compressing objects:  69% (116/167)
# remote: Compressing objects:  70% (117/167)
# remote: Compressing objects:  71% (119/167)
# remote: Compressing objects:  72% (121/167)
# remote: Compressing objects:  73% (122/167)
# remote: Compressing objects:  74% (124/167)
# remote: Compressing objects:  75% (126/167)
# remote: Compressing objects:  76% (127/167)
# remote: Compressing objects:  77% (129/167)
# remote: Compressing objects:  78% (131/167)
# remote: Compressing objects:  79% (132/167)
# remote: Compressing objects:  80% (134/167)
# remote: Compressing objects:  81% (136/167)
# remote: Compressing objects:  82% (137/167)
# remote: Compressing objects:  83% (139/167)
# remote: Compressing objects:  84% (141/167)
# remote: Compressing objects:  85% (142/167)
# remote: Compressing objects:  86% (144/167)
# remote: Compressing objects:  87% (146/167)
# remote: Compressing objects:  88% (147/167)
# remote: Compressing objects:  89% (149/167)
# remote: Compressing objects:  90% (151/167)
# remote: Compressing objects:  91% (152/167)
# remote: Compressing objects:  92% (154/167)
# remote: Compressing objects:  93% (156/167)
# remote: Compressing objects:  94% (157/167)
# remote: Compressing objects:  95% (159/167)
# remote: Compressing objects:  96% (161/167)
# remote: Compressing objects:  97% (162/167)
# remote: Compressing objects:  98% (164/167)
# remote: Compressing objects:  99% (166/167)
# remote: Compressing objects: 100% (167/167)
# remote: Compressing objects: 100% (167/167), done.
# Receiving objects:   0% (1/37808)
# Receiving objects:   1% (379/37808)
# Receiving objects:   2% (757/37808)
# Receiving objects:   3% (1135/37808), 180.01 KiB | 349.00 KiB/s
# Receiving objects:   4% (1513/37808), 180.01 KiB | 349.00 KiB/s
# Receiving objects:   5% (1891/37808), 180.01 KiB | 349.00 KiB/s
# Receiving objects:   6% (2269/37808), 180.01 KiB | 349.00 KiB/s
# Receiving objects:   7% (2647/37808), 180.01 KiB | 349.00 KiB/s
# Receiving objects:   8% (3025/37808), 180.01 KiB | 349.00 KiB/s
# Receiving objects:   8% (3145/37808), 868.01 KiB | 858.00 KiB/s
# Receiving objects:   9% (3403/37808), 868.01 KiB | 858.00 KiB/s
# Receiving objects:  10% (3781/37808), 868.01 KiB | 858.00 KiB/s
# Receiving objects:  11% (4159/37808), 1.57 MiB | 1.04 MiB/s
# Receiving objects:  11% (4420/37808), 2.14 MiB | 1.06 MiB/s
# Receiving objects:  11% (4421/37808), 3.03 MiB | 1.00 MiB/s
# Receiving objects:  11% (4421/37808), 4.20 MiB | 1.04 MiB/s
# Receiving objects:  11% (4421/37808), 5.39 MiB | 1.15 MiB/s
# Receiving objects:  11% (4442/37808), 6.03 MiB | 1.14 MiB/s
# Receiving objects:  12% (4537/37808), 6.69 MiB | 1.13 MiB/s
# Receiving objects:  12% (4595/37808), 7.98 MiB | 1.19 MiB/s
# Receiving objects:  12% (4595/37808), 9.52 MiB | 1.30 MiB/s
# Receiving objects:  13% (4916/37808), 9.52 MiB | 1.30 MiB/s
# Receiving objects:  14% (5294/37808), 9.52 MiB | 1.30 MiB/s
# Receiving objects:  15% (5672/37808), 10.41 MiB | 1.37 MiB/s
# Receiving objects:  16% (6050/37808), 10.41 MiB | 1.37 MiB/s
# Receiving objects:  17% (6428/37808), 10.41 MiB | 1.37 MiB/s
# Receiving objects:  18% (6806/37808), 10.41 MiB | 1.37 MiB/s
# Receiving objects:  19% (7184/37808), 10.41 MiB | 1.37 MiB/s
# Receiving objects:  20% (7562/37808), 10.41 MiB | 1.37 MiB/s
# Receiving objects:  21% (7940/37808), 10.41 MiB | 1.37 MiB/s
# Receiving objects:  21% (8101/37808), 10.41 MiB | 1.37 MiB/s
# Receiving objects:  22% (8318/37808), 10.41 MiB | 1.37 MiB/s
# Receiving objects:  22% (8523/37808), 11.96 MiB | 1.28 MiB/s
# Receiving objects:  22% (8523/37808), 12.47 MiB | 1.10 MiB/s
# Receiving objects:  23% (8696/37808), 12.83 MiB | 1.04 MiB/s
# Receiving objects:  24% (9074/37808), 12.83 MiB | 1.04 MiB/s
# Receiving objects:  25% (9452/37808), 12.83 MiB | 1.04 MiB/s
# Receiving objects:  26% (9831/37808), 12.83 MiB | 1.04 MiB/s
# Receiving objects:  27% (10209/37808), 12.83 MiB | 1.04 MiB/s
# Receiving objects:  28% (10587/37808), 12.83 MiB | 1.04 MiB/s
# Receiving objects:  29% (10965/37808), 12.83 MiB | 1.04 MiB/s
# Receiving objects:  29% (11217/37808), 12.83 MiB | 1.04 MiB/s
# Receiving objects:  30% (11343/37808), 12.83 MiB | 1.04 MiB/s
# Receiving objects:  31% (11721/37808), 12.83 MiB | 1.04 MiB/s
# Receiving objects:  32% (12099/37808), 12.83 MiB | 1.04 MiB/s
# Receiving objects:  33% (12477/37808), 12.83 MiB | 1.04 MiB/s
# Receiving objects:  34% (12855/37808), 12.83 MiB | 1.04 MiB/s
# Receiving objects:  35% (13233/37808), 13.29 MiB | 1000.00 KiB/s
# Receiving objects:  36% (13611/37808), 13.29 MiB | 1000.00 KiB/s
# Receiving objects:  37% (13989/37808), 13.29 MiB | 1000.00 KiB/s
# Receiving objects:  38% (14368/37808), 13.29 MiB | 1000.00 KiB/s
# Receiving objects:  39% (14746/37808), 13.77 MiB | 935.00 KiB/s
# Receiving objects:  40% (15124/37808), 13.77 MiB | 935.00 KiB/s
# Receiving objects:  41% (15502/37808), 13.77 MiB | 935.00 KiB/s
# Receiving objects:  41% (15593/37808), 13.77 MiB | 935.00 KiB/s
# Receiving objects:  42% (15880/37808), 13.77 MiB | 935.00 KiB/s
# Receiving objects:  43% (16258/37808), 13.77 MiB | 935.00 KiB/s
# Receiving objects:  44% (16636/37808), 13.77 MiB | 935.00 KiB/s
# Receiving objects:  45% (17014/37808), 13.77 MiB | 935.00 KiB/s
# Receiving objects:  46% (17392/37808), 13.77 MiB | 935.00 KiB/s
# Receiving objects:  47% (17770/37808), 14.32 MiB | 860.00 KiB/s
# Receiving objects:  48% (18148/37808), 14.32 MiB | 860.00 KiB/s
# Receiving objects:  49% (18526/37808), 14.32 MiB | 860.00 KiB/s
# Receiving objects:  50% (18904/37808), 14.32 MiB | 860.00 KiB/s
# Receiving objects:  51% (19283/37808), 14.32 MiB | 860.00 KiB/s
# Receiving objects:  52% (19661/37808), 14.32 MiB | 860.00 KiB/s
# Receiving objects:  53% (20039/37808), 14.32 MiB | 860.00 KiB/s
# Receiving objects:  54% (20417/37808), 14.84 MiB | 837.00 KiB/s
# Receiving objects:  55% (20795/37808), 14.84 MiB | 837.00 KiB/s
# Receiving objects:  56% (21173/37808), 14.84 MiB | 837.00 KiB/s
# Receiving objects:  57% (21551/37808), 14.84 MiB | 837.00 KiB/s
# Receiving objects:  58% (21929/37808), 14.84 MiB | 837.00 KiB/s
# Receiving objects:  59% (22307/37808), 14.84 MiB | 837.00 KiB/s
# Receiving objects:  60% (22685/37808), 14.84 MiB | 837.00 KiB/s
# Receiving objects:  61% (23063/37808), 14.84 MiB | 837.00 KiB/s
# Receiving objects:  62% (23441/37808), 14.84 MiB | 837.00 KiB/s
# Receiving objects:  62% (23738/37808), 14.84 MiB | 837.00 KiB/s
# Receiving objects:  63% (23820/37808), 14.84 MiB | 837.00 KiB/s
# Receiving objects:  64% (24198/37808), 14.84 MiB | 837.00 KiB/s
# Receiving objects:  65% (24576/37808), 14.84 MiB | 837.00 KiB/s
# Receiving objects:  66% (24954/37808), 14.84 MiB | 837.00 KiB/s
# Receiving objects:  67% (25332/37808), 14.84 MiB | 837.00 KiB/s
# Receiving objects:  68% (25710/37808), 14.84 MiB | 837.00 KiB/s
# Receiving objects:  69% (26088/37808), 14.84 MiB | 837.00 KiB/s
# Receiving objects:  70% (26466/37808), 14.84 MiB | 837.00 KiB/s
# Receiving objects:  71% (26844/37808), 14.84 MiB | 837.00 KiB/s
# Receiving objects:  72% (27222/37808), 15.25 MiB | 840.00 KiB/s
# Receiving objects:  73% (27600/37808), 15.25 MiB | 840.00 KiB/s
# Receiving objects:  74% (27978/37808), 15.25 MiB | 840.00 KiB/s
# Receiving objects:  75% (28356/37808), 15.25 MiB | 840.00 KiB/s
# Receiving objects:  76% (28735/37808), 15.25 MiB | 840.00 KiB/s
# Receiving objects:  77% (29113/37808), 15.25 MiB | 840.00 KiB/s
# Receiving objects:  78% (29491/37808), 15.25 MiB | 840.00 KiB/s
# Receiving objects:  79% (29869/37808), 15.25 MiB | 840.00 KiB/s
# Receiving objects:  80% (30247/37808), 15.25 MiB | 840.00 KiB/s
# Receiving objects:  81% (30625/37808), 15.25 MiB | 840.00 KiB/s
# Receiving objects:  82% (31003/37808), 15.25 MiB | 840.00 KiB/s
# Receiving objects:  83% (31381/37808), 15.25 MiB | 840.00 KiB/s
# Receiving objects:  84% (31759/37808), 15.25 MiB | 840.00 KiB/s
# Receiving objects:  85% (32137/37808), 15.25 MiB | 840.00 KiB/s
# Receiving objects:  86% (32515/37808), 15.25 MiB | 840.00 KiB/s
# Receiving objects:  87% (32893/37808), 15.25 MiB | 840.00 KiB/s
# Receiving objects:  88% (33272/37808), 15.25 MiB | 840.00 KiB/s
# Receiving objects:  89% (33650/37808), 15.25 MiB | 840.00 KiB/s
# Receiving objects:  90% (34028/37808), 15.25 MiB | 840.00 KiB/s
# Receiving objects:  91% (34406/37808), 15.25 MiB | 840.00 KiB/s
# Receiving objects:  92% (34784/37808), 15.25 MiB | 840.00 KiB/s
# Receiving objects:  93% (35162/37808), 15.25 MiB | 840.00 KiB/s
# Receiving objects:  94% (35540/37808), 15.25 MiB | 840.00 KiB/s
# Receiving objects:  95% (35918/37808), 15.74 MiB | 847.00 KiB/s
# Receiving objects:  96% (36296/37808), 15.74 MiB | 847.00 KiB/s
# Receiving objects:  97% (36674/37808), 15.74 MiB | 847.00 KiB/s
# Receiving objects:  98% (37052/37808), 15.74 MiB | 847.00 KiB/s
# Receiving objects:  99% (37430/37808), 15.74 MiB | 847.00 KiB/s
# Receiving objects:  99% (37725/37808), 15.74 MiB | 847.00 KiB/s
# Receiving objects: 100% (37808/37808), 15.74 MiB | 847.00 KiB/s
# Receiving objects: 100% (37808/37808), 16.11 MiB | 1.07 MiB/s, done.
# Resolving deltas:   0% (0/18566)
# Resolving deltas:   1% (186/18566)
# Resolving deltas:   2% (466/18566)
# Resolving deltas:   4% (763/18566)
# Resolving deltas:   5% (965/18566)
# Resolving deltas:   6% (1231/18566)
# Resolving deltas:   7% (1350/18566)
# Resolving deltas:   8% (1489/18566)
# Resolving deltas:   9% (1698/18566)
# Resolving deltas:  10% (1857/18566)
# Resolving deltas:  11% (2050/18566)
# Resolving deltas:  12% (2233/18566)
# Resolving deltas:  13% (2431/18566)
# Resolving deltas:  14% (2608/18566)
# Resolving deltas:  15% (2807/18566)
# Resolving deltas:  16% (2995/18566)
# Resolving deltas:  17% (3162/18566)
# Resolving deltas:  18% (3343/18566)
# Resolving deltas:  19% (3543/18566)
# Resolving deltas:  20% (3740/18566)
# Resolving deltas:  21% (3899/18566)
# Resolving deltas:  22% (4094/18566)
# Resolving deltas:  23% (4288/18566)
# Resolving deltas:  24% (4509/18566)
# Resolving deltas:  25% (4651/18566)
# Resolving deltas:  26% (4832/18566)
# Resolving deltas:  27% (5024/18566)
# Resolving deltas:  28% (5208/18566)
# Resolving deltas:  29% (5397/18566)
# Resolving deltas:  30% (5573/18566)
# Resolving deltas:  31% (5767/18566)
# Resolving deltas:  32% (5956/18566)
# Resolving deltas:  33% (6129/18566)
# Resolving deltas:  34% (6338/18566)
# Resolving deltas:  35% (6646/18566)
# Resolving deltas:  36% (6687/18566)
# Resolving deltas:  37% (6870/18566)
# Resolving deltas:  38% (7160/18566)
# Resolving deltas:  39% (7250/18566)
# Resolving deltas:  40% (7439/18566)
# Resolving deltas:  41% (7613/18566)
# Resolving deltas:  42% (7875/18566)
# Resolving deltas:  43% (7984/18566)
# Resolving deltas:  44% (8174/18566)
# Resolving deltas:  45% (8355/18566)
# Resolving deltas:  46% (8550/18566)
# Resolving deltas:  47% (8727/18566)
# Resolving deltas:  48% (8974/18566)
# Resolving deltas:  49% (9104/18566)
# Resolving deltas:  50% (9343/18566)
# Resolving deltas:  51% (9473/18566)
# Resolving deltas:  52% (9673/18566)
# Resolving deltas:  53% (9841/18566)
# Resolving deltas:  54% (10040/18566)
# Resolving deltas:  55% (10214/18566)
# Resolving deltas:  56% (10527/18566)
# Resolving deltas:  57% (10602/18566)
# Resolving deltas:  58% (10867/18566)
# Resolving deltas:  59% (10990/18566)
# Resolving deltas:  60% (11190/18566)
# Resolving deltas:  61% (11347/18566)
# Resolving deltas:  62% (11578/18566)
# Resolving deltas:  63% (11733/18566)
# Resolving deltas:  64% (11885/18566)
# Resolving deltas:  65% (12076/18566)
# Resolving deltas:  66% (12318/18566)
# Resolving deltas:  67% (12441/18566)
# Resolving deltas:  68% (12625/18566)
# Resolving deltas:  69% (12812/18566)
# Resolving deltas:  70% (13025/18566)
# Resolving deltas:  71% (13185/18566)
# Resolving deltas:  72% (13381/18566)
# Resolving deltas:  73% (13581/18566)
# Resolving deltas:  74% (13755/18566)
# Resolving deltas:  75% (14003/18566)
# Resolving deltas:  76% (14222/18566)
# Resolving deltas:  77% (14351/18566)
# Resolving deltas:  78% (14519/18566)
# Resolving deltas:  79% (14669/18566)
# Resolving deltas:  80% (14863/18566)
# Resolving deltas:  81% (15081/18566)
# Resolving deltas:  82% (15316/18566)
# Resolving deltas:  83% (15530/18566)
# Resolving deltas:  84% (15596/18566)
# Resolving deltas:  85% (15813/18566)
# Resolving deltas:  86% (16060/18566)
# Resolving deltas:  87% (16161/18566)
# Resolving deltas:  88% (16343/18566)
# Resolving deltas:  89% (16529/18566)
# Resolving deltas:  90% (16744/18566)
# Resolving deltas:  91% (16904/18566)
# Resolving deltas:  92% (17081/18566)
# Resolving deltas:  93% (17275/18566)
# Resolving deltas:  94% (17454/18566)
# Resolving deltas:  95% (17643/18566)
# Resolving deltas:  96% (17898/18566)
# Resolving deltas:  97% (18016/18566)
# Resolving deltas:  98% (18202/18566)
# Resolving deltas:  99% (18381/18566)
# Resolving deltas: 100% (18566/18566)
# Resolving deltas: 100% (18566/18566), done.

# %%
#a.	What was the message and title of the fixing commit? 
#Was there any mention of fixing a bug or vulnerability? 
#Hint: git diff or git show
show_data = repo.git.show("-s",fixing_commit).splitlines()
for line in show_data:
    print(line)
# Out:
# commit a41ce6892cb0590b2e658704434ac0dbcb6834c8
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu Aug 9 20:39:23 2018 +0200
#
#     COMPRESS-463 throw exception when detecting a truncated stored entry

# %%
#b.	How many total files were affected in the fixing commit? 
#Hint: git diff or git show
diff_data = repo.git.diff(fixing_commit + "^", fixing_commit).splitlines()
for line in diff_data:
    print(line)
# Out:
# diff --git a/src/changes/changes.xml b/src/changes/changes.xml
# index bb477f36..7546871d 100644
# --- a/src/changes/changes.xml
# +++ b/src/changes/changes.xml
# @@ -74,6 +74,11 @@ The <action> type attribute can be add,update,fix,remove.
#          It is now possible to specify the arguments of zstd-jni's
#          ZstdOutputStream constructors via Commons Compress as well.
#        </action>
# +      <action issue="COMPRESS-463" type="fix" date="2018-08-09">
# +        ZipArchiveInputStream#read would silently return -1 on a
# +        corrupted stored entry and even return > 0 after hitting the
# +        end of the archive.
# +      </action>
#      </release>
#      <release version="1.17" date="2018-06-03"
#               description="Release 1.17">
# diff --git a/src/main/java/org/apache/commons/compress/archivers/zip/ZipArchiveInputStream.java b/src/main/java/org/apache/commons/compress/archivers/zip/ZipArchiveInputStream.java
# index 0a2c1aa0..e1995d7a 100644
# --- a/src/main/java/org/apache/commons/compress/archivers/zip/ZipArchiveInputStream.java
# +++ b/src/main/java/org/apache/commons/compress/archivers/zip/ZipArchiveInputStream.java
# @@ -525,7 +525,8 @@ private int readStored(final byte[] buffer, final int offset, final int length)
#              buf.position(0);
#              final int l = in.read(buf.array());
#              if (l == -1) {
# -                return -1;
# +                buf.limit(0);
# +                throw new IOException("Truncated ZIP file");
#              }
#              buf.limit(l);
#
# diff --git a/src/test/java/org/apache/commons/compress/archivers/zip/Maven221MultiVolumeTest.java b/src/test/java/org/apache/commons/compress/archivers/zip/Maven221MultiVolumeTest.java
# index c28f3dec..0a905e3a 100644
# --- a/src/test/java/org/apache/commons/compress/archivers/zip/Maven221MultiVolumeTest.java
# +++ b/src/test/java/org/apache/commons/compress/archivers/zip/Maven221MultiVolumeTest.java
# @@ -96,6 +96,13 @@ public void testRead7ZipMultiVolumeArchiveForStream() throws IOException {
#                  assertEquals("Truncated ZIP file", e.getMessage());
#              }
#
# +            try {
# +                zi.read(buffer);
# +                fail("shouldn't be able to read from truncated entry after exception");
# +            } catch (final IOException e) {
# +                assertEquals("Truncated ZIP file", e.getMessage());
# +            }
# +
#              // and now we get another entry, which should also yield
#              // an exception
#              try {
# diff --git a/src/test/java/org/apache/commons/compress/archivers/zip/ZipArchiveInputStreamTest.java b/src/test/java/org/apache/commons/compress/archivers/zip/ZipArchiveInputStreamTest.java
# index 5b659568..b9395fbf 100644
# --- a/src/test/java/org/apache/commons/compress/archivers/zip/ZipArchiveInputStreamTest.java
# +++ b/src/test/java/org/apache/commons/compress/archivers/zip/ZipArchiveInputStreamTest.java
# @@ -421,6 +421,75 @@ private void multiByteReadConsistentlyReturnsMinusOneAtEof(File file) throws Exc
#          }
#      }
#
# +    @Test
# +    public void singleByteReadThrowsAtEofForCorruptedStoredEntry() throws Exception {
# +        byte[] content;
# +        try (FileInputStream fs = new FileInputStream(getFile("COMPRESS-264.zip"))) {
# +            content = IOUtils.toByteArray(fs);
# +        }
# +        // make size much bigger than entry's real size
# +        for (int i = 17; i < 26; i++) {
# +            content[i] = (byte) 0xff;
# +        }
# +        try (ByteArrayInputStream in = new ByteArrayInputStream(content);
# +             ZipArchiveInputStream archive = new ZipArchiveInputStream(in)) {
# +            ArchiveEntry e = archive.getNextEntry();
# +            try {
# +                IOUtils.toByteArray(archive);
# +                fail("expected exception");
# +            } catch (IOException ex) {
# +                assertEquals("Truncated ZIP file", ex.getMessage());
# +            }
# +            try {
# +                archive.read();
# +                fail("expected exception");
# +            } catch (IOException ex) {
# +                assertEquals("Truncated ZIP file", ex.getMessage());
# +            }
# +            try {
# +                archive.read();
# +                fail("expected exception");
# +            } catch (IOException ex) {
# +                assertEquals("Truncated ZIP file", ex.getMessage());
# +            }
# +        }
# +    }
# +
# +    @Test
# +    public void multiByteReadThrowsAtEofForCorruptedStoredEntry() throws Exception {
# +        byte[] content;
# +        try (FileInputStream fs = new FileInputStream(getFile("COMPRESS-264.zip"))) {
# +            content = IOUtils.toByteArray(fs);
# +        }
# +        // make size much bigger than entry's real size
# +        for (int i = 17; i < 26; i++) {
# +            content[i] = (byte) 0xff;
# +        }
# +        byte[] buf = new byte[2];
# +        try (ByteArrayInputStream in = new ByteArrayInputStream(content);
# +             ZipArchiveInputStream archive = new ZipArchiveInputStream(in)) {
# +            ArchiveEntry e = archive.getNextEntry();
# +            try {
# +                IOUtils.toByteArray(archive);
# +                fail("expected exception");
# +            } catch (IOException ex) {
# +                assertEquals("Truncated ZIP file", ex.getMessage());
# +            }
# +            try {
# +                archive.read(buf);
# +                fail("expected exception");
# +            } catch (IOException ex) {
# +                assertEquals("Truncated ZIP file", ex.getMessage());
# +            }
# +            try {
# +                archive.read(buf);
# +                fail("expected exception");
# +            } catch (IOException ex) {
# +                assertEquals("Truncated ZIP file", ex.getMessage());
# +            }
# +        }
# +    }
# +
#      private static byte[] readEntry(ZipArchiveInputStream zip, ZipArchiveEntry zae) throws IOException {
#          final int len = (int)zae.getSize();
#          final byte[] buff = new byte[len];

# %%
#c.	How many total directories were affected in the fixing commit? 
#For example, if a file path is: abc/def/File.java, 
#then its directory is abc/def. Hint: git diff or git show
diff_data = repo.git.diff(fixing_commit + "^", fixing_commit).splitlines()
for line in diff_data:
    print(line)
# Out:
# diff --git a/src/changes/changes.xml b/src/changes/changes.xml
# index bb477f36..7546871d 100644
# --- a/src/changes/changes.xml
# +++ b/src/changes/changes.xml
# @@ -74,6 +74,11 @@ The <action> type attribute can be add,update,fix,remove.
#          It is now possible to specify the arguments of zstd-jni's
#          ZstdOutputStream constructors via Commons Compress as well.
#        </action>
# +      <action issue="COMPRESS-463" type="fix" date="2018-08-09">
# +        ZipArchiveInputStream#read would silently return -1 on a
# +        corrupted stored entry and even return > 0 after hitting the
# +        end of the archive.
# +      </action>
#      </release>
#      <release version="1.17" date="2018-06-03"
#               description="Release 1.17">
# diff --git a/src/main/java/org/apache/commons/compress/archivers/zip/ZipArchiveInputStream.java b/src/main/java/org/apache/commons/compress/archivers/zip/ZipArchiveInputStream.java
# index 0a2c1aa0..e1995d7a 100644
# --- a/src/main/java/org/apache/commons/compress/archivers/zip/ZipArchiveInputStream.java
# +++ b/src/main/java/org/apache/commons/compress/archivers/zip/ZipArchiveInputStream.java
# @@ -525,7 +525,8 @@ private int readStored(final byte[] buffer, final int offset, final int length)
#              buf.position(0);
#              final int l = in.read(buf.array());
#              if (l == -1) {
# -                return -1;
# +                buf.limit(0);
# +                throw new IOException("Truncated ZIP file");
#              }
#              buf.limit(l);
#
# diff --git a/src/test/java/org/apache/commons/compress/archivers/zip/Maven221MultiVolumeTest.java b/src/test/java/org/apache/commons/compress/archivers/zip/Maven221MultiVolumeTest.java
# index c28f3dec..0a905e3a 100644
# --- a/src/test/java/org/apache/commons/compress/archivers/zip/Maven221MultiVolumeTest.java
# +++ b/src/test/java/org/apache/commons/compress/archivers/zip/Maven221MultiVolumeTest.java
# @@ -96,6 +96,13 @@ public void testRead7ZipMultiVolumeArchiveForStream() throws IOException {
#                  assertEquals("Truncated ZIP file", e.getMessage());
#              }
#
# +            try {
# +                zi.read(buffer);
# +                fail("shouldn't be able to read from truncated entry after exception");
# +            } catch (final IOException e) {
# +                assertEquals("Truncated ZIP file", e.getMessage());
# +            }
# +
#              // and now we get another entry, which should also yield
#              // an exception
#              try {
# diff --git a/src/test/java/org/apache/commons/compress/archivers/zip/ZipArchiveInputStreamTest.java b/src/test/java/org/apache/commons/compress/archivers/zip/ZipArchiveInputStreamTest.java
# index 5b659568..b9395fbf 100644
# --- a/src/test/java/org/apache/commons/compress/archivers/zip/ZipArchiveInputStreamTest.java
# +++ b/src/test/java/org/apache/commons/compress/archivers/zip/ZipArchiveInputStreamTest.java
# @@ -421,6 +421,75 @@ private void multiByteReadConsistentlyReturnsMinusOneAtEof(File file) throws Exc
#          }
#      }
#
# +    @Test
# +    public void singleByteReadThrowsAtEofForCorruptedStoredEntry() throws Exception {
# +        byte[] content;
# +        try (FileInputStream fs = new FileInputStream(getFile("COMPRESS-264.zip"))) {
# +            content = IOUtils.toByteArray(fs);
# +        }
# +        // make size much bigger than entry's real size
# +        for (int i = 17; i < 26; i++) {
# +            content[i] = (byte) 0xff;
# +        }
# +        try (ByteArrayInputStream in = new ByteArrayInputStream(content);
# +             ZipArchiveInputStream archive = new ZipArchiveInputStream(in)) {
# +            ArchiveEntry e = archive.getNextEntry();
# +            try {
# +                IOUtils.toByteArray(archive);
# +                fail("expected exception");
# +            } catch (IOException ex) {
# +                assertEquals("Truncated ZIP file", ex.getMessage());
# +            }
# +            try {
# +                archive.read();
# +                fail("expected exception");
# +            } catch (IOException ex) {
# +                assertEquals("Truncated ZIP file", ex.getMessage());
# +            }
# +            try {
# +                archive.read();
# +                fail("expected exception");
# +            } catch (IOException ex) {
# +                assertEquals("Truncated ZIP file", ex.getMessage());
# +            }
# +        }
# +    }
# +
# +    @Test
# +    public void multiByteReadThrowsAtEofForCorruptedStoredEntry() throws Exception {
# +        byte[] content;
# +        try (FileInputStream fs = new FileInputStream(getFile("COMPRESS-264.zip"))) {
# +            content = IOUtils.toByteArray(fs);
# +        }
# +        // make size much bigger than entry's real size
# +        for (int i = 17; i < 26; i++) {
# +            content[i] = (byte) 0xff;
# +        }
# +        byte[] buf = new byte[2];
# +        try (ByteArrayInputStream in = new ByteArrayInputStream(content);
# +             ZipArchiveInputStream archive = new ZipArchiveInputStream(in)) {
# +            ArchiveEntry e = archive.getNextEntry();
# +            try {
# +                IOUtils.toByteArray(archive);
# +                fail("expected exception");
# +            } catch (IOException ex) {
# +                assertEquals("Truncated ZIP file", ex.getMessage());
# +            }
# +            try {
# +                archive.read(buf);
# +                fail("expected exception");
# +            } catch (IOException ex) {
# +                assertEquals("Truncated ZIP file", ex.getMessage());
# +            }
# +            try {
# +                archive.read(buf);
# +                fail("expected exception");
# +            } catch (IOException ex) {
# +                assertEquals("Truncated ZIP file", ex.getMessage());
# +            }
# +        }
# +    }
# +
#      private static byte[] readEntry(ZipArchiveInputStream zip, ZipArchiveEntry zae) throws IOException {
#          final int len = (int)zae.getSize();
#          final byte[] buff = new byte[len];

# %%
#d.	How many total lines of code (including comments and blank lines) \
#were deleted? Hint: git diff or git show
#e.	How many total lines of code (including comments and blank lines) 
#were added? Hint: git diff or git show
del_data = repo.git.log("--numstat","--oneline",fixing_commit).splitlines()
for line in del_data:
    print(line)
# Out:
# a41ce689 COMPRESS-463 throw exception when detecting a truncated stored entry
# 5	0	src/changes/changes.xml
# 2	1	src/main/java/org/apache/commons/compress/archivers/zip/ZipArchiveInputStream.java
# 7	0	src/test/java/org/apache/commons/compress/archivers/zip/Maven221MultiVolumeTest.java
# 69	0	src/test/java/org/apache/commons/compress/archivers/zip/ZipArchiveInputStreamTest.java
# 64ed6dde ensure archive streams really mean EOF if they say so
# 3	1	src/main/java/org/apache/commons/compress/archivers/cpio/CpioArchiveInputStream.java
# 132	11	src/test/java/org/apache/commons/compress/archivers/SevenZTestCase.java
# 42	0	src/test/java/org/apache/commons/compress/archivers/ar/ArArchiveInputStreamTest.java
# 26	0	src/test/java/org/apache/commons/compress/archivers/arj/ArjArchiveInputStreamTest.java
# 26	0	src/test/java/org/apache/commons/compress/archivers/cpio/CpioArchiveInputStreamTest.java
# 25	0	src/test/java/org/apache/commons/compress/archivers/dump/DumpArchiveInputStreamTest.java
# 24	0	src/test/java/org/apache/commons/compress/archivers/tar/TarArchiveInputStreamTest.java
# 81	0	src/test/java/org/apache/commons/compress/archivers/zip/ZipArchiveInputStreamTest.java
# 83	0	src/test/java/org/apache/commons/compress/archivers/zip/ZipFileTest.java
# 0fe6ae31 verify the compressor streams really mean EOF when they say so
# 27	0	src/test/java/org/apache/commons/compress/compressors/GZipTestCase.java
# 27	0	src/test/java/org/apache/commons/compress/compressors/LZMATestCase.java
# 42	0	src/test/java/org/apache/commons/compress/compressors/Pack200TestCase.java
# 16	1	src/test/java/org/apache/commons/compress/compressors/brotli/BrotliCompressorInputStreamTest.java
# 30	0	src/test/java/org/apache/commons/compress/compressors/bzip2/BZip2CompressorInputStreamTest.java
# 16	1	src/test/java/org/apache/commons/compress/compressors/deflate/DeflateCompressorInputStreamTest.java
# 24	0	src/test/java/org/apache/commons/compress/compressors/deflate64/Deflate64CompressorInputStreamTest.java
# 27	0	src/test/java/org/apache/commons/compress/compressors/lz4/BlockLZ4CompressorInputStreamTest.java
# 27	0	src/test/java/org/apache/commons/compress/compressors/lz4/FramedLZ4CompressorInputStreamTest.java
# 27	0	src/test/java/org/apache/commons/compress/compressors/snappy/FramedSnappyCompressorInputStreamTest.java
# 53	0	src/test/java/org/apache/commons/compress/compressors/xz/XZCompressorInputStreamTest.java
# 32	0	src/test/java/org/apache/commons/compress/compressors/z/ZCompressorInputStreamTest.java
# 16	1	src/test/java/org/apache/commons/compress/compressors/zstandard/ZstdCompressorInputStreamTest.java
# 792da673 COMPRESS-460 rudimentary javadocs and tests
# 5	0	src/changes/changes.xml
# 31	2	src/main/java/org/apache/commons/compress/compressors/zstandard/ZstdCompressorOutputStream.java
# 44	1	src/test/java/org/apache/commons/compress/compressors/zstandard/ZstdRoundtripTest.java
# c5c231e6 Allow specifying Zstandard compression level
# 14	2	src/main/java/org/apache/commons/compress/compressors/zstandard/ZstdCompressorOutputStream.java
# 6f8c4960 COMPRESS-459 no reason to encode the name twice
# 7	15	src/main/java/org/apache/commons/compress/archivers/cpio/CpioArchiveEntry.java
# 3	2	src/main/java/org/apache/commons/compress/archivers/cpio/CpioArchiveOutputStream.java
# 430e1267 COMPRESS-459 record change
# 5	0	src/changes/changes.xml
# c8ee9f78 COMPRESS-459 use ZipEncoding consistently
# 15	7	src/main/java/org/apache/commons/compress/archivers/cpio/CpioArchiveEntry.java
# 2	3	src/main/java/org/apache/commons/compress/archivers/cpio/CpioArchiveOutputStream.java
# 72bfc124 COMPRESS-459 fix writing of multibyte names and add a test as proof
# 25	10	src/main/java/org/apache/commons/compress/archivers/cpio/CpioArchiveOutputStream.java
# 74	0	src/test/java/org/apache/commons/compress/archivers/cpio/CpioArchiveTest.java
# 17575b88 whitespace
# 7	7	src/main/java/org/apache/commons/compress/archivers/cpio/CpioArchiveEntry.java
# 2	2	src/main/java/org/apache/commons/compress/archivers/cpio/CpioArchiveInputStream.java
# 1fbb16b0 Fix writing of multibyte name entries
# 24	2	src/main/java/org/apache/commons/compress/archivers/cpio/CpioArchiveEntry.java
# 3	2	src/main/java/org/apache/commons/compress/archivers/cpio/CpioArchiveOutputStream.java
# 9e80104b Fix reading of multibyte name entries
# 16	1	src/main/java/org/apache/commons/compress/archivers/cpio/CpioArchiveEntry.java
# 2	2	src/main/java/org/apache/commons/compress/archivers/cpio/CpioArchiveInputStream.java
# 16	0	src/test/java/org/apache/commons/compress/archivers/cpio/CpioArchiveInputStreamTest.java
# -	-	src/test/resources/COMPRESS-459.cpio
# f5330f7e (doc) fix typo in javadoc
# 1	1	src/main/java/org/apache/commons/compress/utils/SkipShieldingInputStream.java
# 3125fb60 upgrade to parent 47
# 1	1	pom.xml
# 1478499b closes #65
# 15baa60c fix typo in syntax. Files is a static method so there shouldn't be a constructor
# 1	1	src/site/xdoc/examples.xml
# 22b0d062 whitespace
# 4	4	src/main/java/org/apache/commons/compress/archivers/zip/ZipArchiveInputStream.java
# af6fe141 COMPRESS-455 handle APK Signing Block
# 5	0	src/changes/changes.xml
# 67	4	src/main/java/org/apache/commons/compress/archivers/zip/ZipArchiveInputStream.java
# 53f6d42f whitespace changes
# 5	5	src/main/java/org/apache/commons/compress/archivers/ar/ArArchiveOutputStream.java
# 7	7	src/main/java/org/apache/commons/compress/archivers/cpio/CpioArchiveOutputStream.java
# 4	4	src/main/java/org/apache/commons/compress/archivers/sevenz/SevenZOutputFile.java
# 7	7	src/main/java/org/apache/commons/compress/archivers/tar/TarArchiveOutputStream.java
# 2	2	src/main/java/org/apache/commons/compress/archivers/zip/ScatterZipOutputStream.java
# 10	10	src/main/java/org/apache/commons/compress/archivers/zip/ZipArchiveOutputStream.java
# 2	2	src/main/java/org/apache/commons/compress/compressors/bzip2/BZip2CompressorOutputStream.java
# 5	5	src/main/java/org/apache/commons/compress/compressors/deflate64/Deflate64CompressorInputStream.java
# 4	4	src/main/java/org/apache/commons/compress/compressors/gzip/GzipCompressorOutputStream.java
# 2	2	src/main/java/org/apache/commons/compress/compressors/lz4/BlockLZ4CompressorOutputStream.java
# 5	5	src/main/java/org/apache/commons/compress/compressors/lz4/FramedLZ4CompressorInputStream.java
# 2	2	src/main/java/org/apache/commons/compress/compressors/lz4/FramedLZ4CompressorOutputStream.java
# 6	6	src/main/java/org/apache/commons/compress/compressors/pack200/Pack200CompressorOutputStream.java
# 2	2	src/main/java/org/apache/commons/compress/compressors/pack200/TempFileCachingStreamBridge.java
# 5	5	src/main/java/org/apache/commons/compress/compressors/snappy/FramedSnappyCompressorInputStream.java
# 2	2	src/main/java/org/apache/commons/compress/compressors/snappy/FramedSnappyCompressorOutputStream.java
# 2	2	src/main/java/org/apache/commons/compress/compressors/snappy/SnappyCompressorOutputStream.java
# 2	2	src/main/java/org/apache/commons/compress/parallel/FileBasedScatterGatherBackingStore.java
# 2	2	src/main/java/org/apache/commons/compress/utils/FixedLengthBlockOutputStream.java
# 16e358e2 COMPRESS-457 improve resource cleanup in close() implementations
# 5	0	src/changes/changes.xml
# 3	0	src/main/java/org/apache/commons/compress/archivers/ar/ArArchiveOutputStream.java
# 3	1	src/main/java/org/apache/commons/compress/archivers/cpio/CpioArchiveOutputStream.java
# 3	0	src/main/java/org/apache/commons/compress/archivers/sevenz/SevenZOutputFile.java
# 3	1	src/main/java/org/apache/commons/compress/archivers/tar/TarArchiveOutputStream.java
# 3	0	src/main/java/org/apache/commons/compress/archivers/zip/ScatterZipOutputStream.java
# 6	0	src/main/java/org/apache/commons/compress/archivers/zip/ZipArchiveOutputStream.java
# 3	0	src/main/java/org/apache/commons/compress/compressors/bzip2/BZip2CompressorOutputStream.java
# 3	0	src/main/java/org/apache/commons/compress/compressors/deflate64/Deflate64CompressorInputStream.java
# 3	0	src/main/java/org/apache/commons/compress/compressors/gzip/GzipCompressorOutputStream.java
# 3	0	src/main/java/org/apache/commons/compress/compressors/lz4/BlockLZ4CompressorOutputStream.java
# 3	0	src/main/java/org/apache/commons/compress/compressors/lz4/FramedLZ4CompressorInputStream.java
# 3	0	src/main/java/org/apache/commons/compress/compressors/lz4/FramedLZ4CompressorOutputStream.java
# 3	0	src/main/java/org/apache/commons/compress/compressors/pack200/Pack200CompressorOutputStream.java
# 3	0	src/main/java/org/apache/commons/compress/compressors/pack200/TempFileCachingStreamBridge.java
# 3	0	src/main/java/org/apache/commons/compress/compressors/snappy/FramedSnappyCompressorInputStream.java
# 3	0	src/main/java/org/apache/commons/compress/compressors/snappy/FramedSnappyCompressorOutputStream.java
# 3	0	src/main/java/org/apache/commons/compress/compressors/snappy/SnappyCompressorOutputStream.java
# 3	0	src/main/java/org/apache/commons/compress/parallel/FileBasedScatterGatherBackingStore.java
# 3	0	src/main/java/org/apache/commons/compress/utils/FixedLengthBlockOutputStream.java
# 15	0	src/test/java/org/apache/commons/compress/archivers/ArchiveOutputStreamTest.java
# e9f2dadb getCanonicalPath may return a path ending in a / already
# 4	1	src/main/java/org/apache/commons/compress/archivers/examples/Expander.java
# c03704d7 COMPRESS-456 adapt description to code change
# 2	3	src/changes/changes.xml
# 8ed5daaa COMPRESS-456 make optional dependencies explicit
# 7	1	pom.xml
# f5571df0 COMPRESS-456 ensure we import all packages we actually need
# 1	3	pom.xml
# 5	0	src/changes/changes.xml
# 20ad59f7 typo
# 1	1	src/site/xdoc/zip.xml
# 9ce9e4be anchor seems to be different now
# 1	1	src/site/xdoc/examples.xml
# a080293d fix edge case vulnerability detected by @DidierLoiseau
# 6	0	src/changes/changes.xml
# 1	1	src/main/java/org/apache/commons/compress/archivers/examples/Expander.java
# 21	0	src/test/java/org/apache/commons/compress/archivers/examples/ExpanderTest.java
# ba12419e Remove @version $Id$ tags from pre-git SVN days.
# 0	1	src/main/java/org/apache/commons/compress/utils/CharsetNames.java
# 0	1	src/test/java/org/apache/commons/compress/utils/CharsetsTest.java
# 1132bc0b follow @PascalSchumacher's example and prepare for Java10+
# 1	0	.travis.yml
# 2	2	pom.xml
# b5401c47 Merge tag 'rel/1.17' and prepare next iteration
# 83900471 typos
# 2	2	RELEASE-NOTES.txt
# 2	2	src/changes/changes.xml
# d9993f8f prepare RC1 of Commons Compress 1.17
# 1	1	README.md
# 1	1	pom.xml
# 1	0	src/site/site.xml
# 14	14	src/site/xdoc/download_compress.xml
# 3	6	src/site/xdoc/index.xml
# 2683e564 trailing whitespace
# 19	19	RELEASE-NOTES.txt
# b9701d58 update release notes
# 51	0	RELEASE-NOTES.txt
# c2ace886 COMPRESS-454 search for STORED data descriptor stopped too soon
# 4	0	src/changes/changes.xml
# 1	1	src/main/java/org/apache/commons/compress/archivers/zip/ZipArchiveInputStream.java
# a1d952c2 COMPRESS-453 record change
# 4	0	src/changes/changes.xml
# e8c44e60 COMPRESS-453 replace while loop with equivalent Arrays.fill
# 3	3	src/main/java/org/apache/commons/compress/compressors/bzip2/BZip2CompressorInputStream.java
# 4224709b COMPRESS-453 improve exception message
# 4	2	src/main/java/org/apache/commons/compress/compressors/bzip2/BZip2CompressorInputStream.java
# 6c52485c Typo: 'JavaDoc' -> 'Javadoc'.
# 1	1	README.md
# 1	1	src/site/xdoc/conventions.xml
# e9ba2a3a examples -> use guide
# 1	1	src/site/site.xml
# 1	1	src/site/xdoc/examples.xml
# 1	1	src/site/xdoc/index.xml
# 8cc2702c add test for path sanity check
# 39	1	src/test/java/org/apache/commons/compress/archivers/examples/ExpanderTest.java
# 63eeef3e don't leak resources
# 6	2	src/test/java/org/apache/commons/compress/archivers/examples/ExpanderTest.java
# 2544a0cf typo
# 1	1	src/main/java/org/apache/commons/compress/archivers/examples/Expander.java
# 040685c8 typo
# 1	1	src/main/java/org/apache/commons/compress/archivers/examples/Archiver.java
# c67040b8 add tests for Expander
# 1	0	src/main/java/org/apache/commons/compress/archivers/examples/Expander.java
# 170	0	src/test/java/org/apache/commons/compress/archivers/examples/ExpanderTest.java
# 157	0	src/test/java/org/apache/commons/compress/archivers/examples/ParameterizedExpanderTest.java
# 789c3955 unit tests for Archiver
# 1	0	src/main/java/org/apache/commons/compress/archivers/examples/Archiver.java
# 153	0	src/test/java/org/apache/commons/compress/archivers/examples/ParameterizedArchiverTest.java
# 124	0	src/test/java/org/apache/commons/compress/archivers/examples/SevenZArchiverTest.java
# 6edf2fc7 changes report doesn't seem to allow HTML
# 7	8	src/changes/changes.xml
# d7544572 hightlight COMPRESS-445 in "what's new" section
# 6	11	src/site/xdoc/index.xml
# 7a34528b COMPRESS-452 use password-less constructor in test
# 1	2	src/test/java/org/apache/commons/compress/archivers/sevenz/SevenZOutputFileTest.java
# 34cf64fa COMPRESS-452 document new constructors
# 10	0	src/changes/changes.xml
# 16	1	src/site/xdoc/examples.xml
# bafc8e74 char[] overloads don't need to talk about encoding
# 2	6	src/main/java/org/apache/commons/compress/archivers/sevenz/SevenZFile.java
# dc52c6b8 add another constructor overload without password
# 17	0	src/main/java/org/apache/commons/compress/archivers/sevenz/SevenZFile.java
# b87e8e87 whitespace
# 15	15	src/test/java/org/apache/commons/compress/archivers/sevenz/SevenZFileTest.java
# 44785c78 add char[] constructors to SevenZFile
# 75	2	src/main/java/org/apache/commons/compress/archivers/sevenz/SevenZFile.java
# 20	2	src/test/java/org/apache/commons/compress/archivers/sevenz/SevenZFileTest.java
# 1	1	src/test/java/org/apache/commons/compress/archivers/sevenz/SevenZOutputFileTest.java
# 436a2ce3 use Arrays.copyOf
# 1	2	src/main/java/org/apache/commons/compress/archivers/sevenz/SevenZFile.java
# 763c383f COMPRESS-450 add a bit of documentation to examples page
# 15	0	src/site/xdoc/examples.xml
# 58cef126 better check result of mkdirs
# 7	2	src/main/java/org/apache/commons/compress/archivers/examples/Expander.java
# 7	2	src/site/xdoc/examples.xml
# 7a10230e remove more complex examples package, move remaining example code
# 1	1	pom.xml
# 0	148	src/main/java/org/apache/commons/compress/archivers/examples/Archive.java
# 0	44	src/main/java/org/apache/commons/compress/archivers/examples/ArchiveCli.java
# 0	36	src/main/java/org/apache/commons/compress/archivers/examples/ArchiveEntrySource.java
# 0	100	src/main/java/org/apache/commons/compress/archivers/examples/ArchiveSinks.java
# 0	139	src/main/java/org/apache/commons/compress/archivers/examples/ArchiveSources.java
# 5	3	src/main/java/org/apache/commons/compress/archivers/{ => examples}/Archiver.java
# 0	54	src/main/java/org/apache/commons/compress/archivers/examples/Chain.java
# 0	70	src/main/java/org/apache/commons/compress/archivers/examples/ChainDefinition.java
# 0	74	src/main/java/org/apache/commons/compress/archivers/examples/ChainPayload.java
# 0	46	src/main/java/org/apache/commons/compress/archivers/examples/ChainRunner.java
# 0	42	src/main/java/org/apache/commons/compress/archivers/examples/ChainStep.java
# 0	104	src/main/java/org/apache/commons/compress/archivers/examples/DirectoryBasedSource.java
# 0	73	src/main/java/org/apache/commons/compress/archivers/examples/DirectorySink.java
# 0	123	src/main/java/org/apache/commons/compress/archivers/examples/Expand.java
# 0	48	src/main/java/org/apache/commons/compress/archivers/examples/ExpandCli.java
# 5	3	src/main/java/org/apache/commons/compress/archivers/{ => examples}/Expander.java
# 0	37	src/main/java/org/apache/commons/compress/archivers/examples/FileFilterAdapter.java
# 0	68	src/main/java/org/apache/commons/compress/archivers/examples/FileToArchiveSink.java
# 0	44	src/main/java/org/apache/commons/compress/archivers/examples/Filter.java
# 0	68	src/main/java/org/apache/commons/compress/archivers/examples/ListerCli.java
# 0	124	src/main/java/org/apache/commons/compress/archivers/examples/SevenZArchiveEntrySource.java
# 0	78	src/main/java/org/apache/commons/compress/archivers/examples/SevenZOutputFileSink.java
# 0	54	src/main/java/org/apache/commons/compress/archivers/examples/Sink.java
# 0	28	src/main/java/org/apache/commons/compress/archivers/examples/Source.java
# 0	97	src/main/java/org/apache/commons/compress/archivers/examples/StreamBasedArchiveEntrySource.java
# 0	37	src/main/java/org/apache/commons/compress/archivers/examples/Supplier.java
# 0	30	src/main/java/org/apache/commons/compress/archivers/examples/ThrowingIterator.java
# 0	41	src/main/java/org/apache/commons/compress/archivers/examples/Transformer.java
# 0	96	src/main/java/org/apache/commons/compress/archivers/examples/ZipArchiveEntrySource.java
# 1	68	src/main/java/org/apache/commons/compress/archivers/examples/package.html
# 0	43	src/main/java/org/apache/commons/compress/utils/NoCloseInputStream.java
# 848be9d9 reduce API surface by removing filter from signatures
# 14	105	src/main/java/org/apache/commons/compress/archivers/Archiver.java
# 17	167	src/main/java/org/apache/commons/compress/archivers/Expander.java
# 2b8171bd provide some more detailed examples
# 154	0	src/site/xdoc/examples.xml
# 81398f69 avoid "new File*putStream" constructor
# 4	3	src/main/java/org/apache/commons/compress/archivers/Archiver.java
# 4	3	src/main/java/org/apache/commons/compress/archivers/Expander.java
# 58eb1a78 whitespace
# 6	6	src/site/xdoc/examples.xml
# 446555b1 findbugs doesn't like the class shadowing its superclass' name
# 5	4	src/main/java/org/apache/commons/compress/archivers/zip/{InflaterInputStream.java => InflaterInputStreamWithStatistics.java}
# 1	1	src/main/java/org/apache/commons/compress/archivers/zip/ZipFile.java
# 77addfc2 COMPRESS-452 example for reading an encrypted archive
# 27	1	src/site/xdoc/examples.xml
# 4da56433 add 7z support to Lister CLI class
# 27	0	src/main/java/org/apache/commons/compress/archivers/Lister.java
# d3dac8c0 include CVE-2018-1324 in limitations page
# 8	0	src/site/xdoc/limitations.xml
# af0f6c83 list library dependency for zstd/brotli like we do for XZ/lzma
# 6	0	src/site/xdoc/examples.xml
# fb883897 add a separate menu section for API docs
# 18	16	src/site/site.xml
# b78ced2f alpha-sort formats
# 263	263	src/site/xdoc/examples.xml
# 66347f43 split examples into separate sections
# 34	28	src/site/xdoc/examples.xml
# d6cda401 framed LZ4 also supports concatenated streams.
# 2	1	src/site/xdoc/examples.xml
# f763ccc0 clarify what to expect from the entry's name
# 2	0	src/main/java/org/apache/commons/compress/archivers/ArchiveEntry.java
# 2	0	src/main/java/org/apache/commons/compress/archivers/arj/ArjArchiveEntry.java
# 2	0	src/main/java/org/apache/commons/compress/archivers/cpio/CpioArchiveEntry.java
# 3	0	src/main/java/org/apache/commons/compress/archivers/dump/Dirent.java
# 3	0	src/main/java/org/apache/commons/compress/archivers/dump/DumpArchiveEntry.java
# 2	0	src/main/java/org/apache/commons/compress/archivers/sevenz/SevenZArchiveEntry.java
# 2	0	src/main/java/org/apache/commons/compress/archivers/tar/TarArchiveEntry.java
# 3	0	src/main/java/org/apache/commons/compress/archivers/zip/ZipArchiveEntry.java
# 0aeda4fc COMPRESS-451 reject 0 buffersize in IOUtils.copy
# 3	0	src/changes/changes.xml
# 6	1	src/main/java/org/apache/commons/compress/utils/IOUtils.java
# 6	0	src/test/java/org/apache/commons/compress/utils/IOUtilsTest.java
# ff10aeaa wrong ticket number
# 1	1	src/changes/changes.xml
# e15c80ae COMPRESS-443 provide a custom InputStream for special skip problems
# 4	0	src/changes/changes.xml
# 51	0	src/main/java/org/apache/commons/compress/utils/SkipShieldingInputStream.java
# 15	0	src/site/xdoc/limitations.xml
# 91	0	src/test/java/org/apache/commons/compress/utils/SkipShieldingInputStreamTest.java
# ffb618d5 COMPRESS-445 provide statistics for 7z as well
# 2	0	src/changes/changes.xml
# 62	5	src/main/java/org/apache/commons/compress/archivers/sevenz/SevenZFile.java
# 06c4b62c COMPRESS-118 add package level javdocs
# 92	0	src/main/java/org/apache/commons/compress/archivers/examples/package.html
# 78cf6565 fix javadoc warnings
# 28	10	src/main/java/org/apache/commons/compress/archivers/Archiver.java
# 33	1	src/main/java/org/apache/commons/compress/archivers/Expander.java
# 17	0	src/main/java/org/apache/commons/compress/archivers/examples/Archive.java
# 2	0	src/main/java/org/apache/commons/compress/archivers/examples/ArchiveEntrySource.java
# 24	3	src/main/java/org/apache/commons/compress/archivers/examples/ArchiveSinks.java
# 30	3	src/main/java/org/apache/commons/compress/archivers/examples/ArchiveSources.java
# 12	0	src/main/java/org/apache/commons/compress/archivers/examples/Chain.java
# 7	1	src/main/java/org/apache/commons/compress/archivers/examples/ChainPayload.java
# 2	0	src/main/java/org/apache/commons/compress/archivers/examples/ChainStep.java
# 3	0	src/main/java/org/apache/commons/compress/archivers/examples/DirectoryBasedSource.java
# 4	0	src/main/java/org/apache/commons/compress/archivers/examples/DirectorySink.java
# 13	0	src/main/java/org/apache/commons/compress/archivers/examples/Expand.java
# 2	0	src/main/java/org/apache/commons/compress/archivers/examples/FileToArchiveSink.java
# 1	1	src/main/java/org/apache/commons/compress/archivers/examples/Filter.java
# 7	0	src/main/java/org/apache/commons/compress/archivers/examples/Sink.java
# 7	0	src/main/java/org/apache/commons/compress/archivers/examples/Supplier.java
# 1	0	src/main/java/org/apache/commons/compress/utils/BitInputStream.java
# 75a7edc7 COMPRESS-118 make listing just another sink for expanding
# 1	1	pom.xml
# 68	0	src/main/java/org/apache/commons/compress/archivers/examples/ListerCli.java
# 33558253 COMPRESS-118 add archuve expansion API
# 1	18	src/main/java/org/apache/commons/compress/archivers/examples/Archive.java
# 34	0	src/main/java/org/apache/commons/compress/archivers/examples/ArchiveEntrySource.java
# 112	0	src/main/java/org/apache/commons/compress/archivers/examples/ArchiveSources.java
# 4	4	src/main/java/org/apache/commons/compress/archivers/examples/ChainDefinition.java
# 46	0	src/main/java/org/apache/commons/compress/archivers/examples/ChainRunner.java
# 69	0	src/main/java/org/apache/commons/compress/archivers/examples/DirectorySink.java
# 110	0	src/main/java/org/apache/commons/compress/archivers/examples/Expand.java
# 48	0	src/main/java/org/apache/commons/compress/archivers/examples/ExpandCli.java
# 124	0	src/main/java/org/apache/commons/compress/archivers/examples/SevenZArchiveEntrySource.java
# 97	0	src/main/java/org/apache/commons/compress/archivers/examples/StreamBasedArchiveEntrySource.java
# 96	0	src/main/java/org/apache/commons/compress/archivers/examples/ZipArchiveEntrySource.java
# 43	0	src/main/java/org/apache/commons/compress/utils/NoCloseInputStream.java
# 44980ffc COMPRESS-118 remove trivial factory method
# 1	9	src/main/java/org/apache/commons/compress/archivers/examples/ArchiveSinks.java
# 15e9c80f COMPRESS-118 allow generic steps to be used
# 16	3	src/main/java/org/apache/commons/compress/archivers/examples/Archive.java
# fe2ba8d3 COMPRESS-118 make source a first-class abstraction
# 12	13	src/main/java/org/apache/commons/compress/archivers/examples/Archive.java
# 6	3	src/main/java/org/apache/commons/compress/archivers/examples/{DirectoryBasedSupplier.java => DirectoryBasedSource.java}
# 28	0	src/main/java/org/apache/commons/compress/archivers/examples/Source.java
# b15221d6 COMPRESS-118 extract factory methods from FileToArchiveSink
# 1	1	src/main/java/org/apache/commons/compress/archivers/examples/ArchiveCli.java
# 87	0	src/main/java/org/apache/commons/compress/archivers/examples/ArchiveSinks.java
# 0	57	src/main/java/org/apache/commons/compress/archivers/examples/FileToArchiveSink.java
# 9a84b4ee COMRESS-118 inner class can be static
# 1	1	src/main/java/org/apache/commons/compress/archivers/examples/DirectoryBasedSupplier.java
# d1f9ac3a COMPRESS-118 simplify code
# 2	16	src/main/java/org/apache/commons/compress/archivers/examples/DirectoryBasedSupplier.java
# 5694aaa8 COMPRESS-118 and one more missing generic
# 1	1	src/main/java/org/apache/commons/compress/archivers/examples/Archive.java
# 251936e2 COMPRESS-118 should have specified type parameter
# 1	1	src/main/java/org/apache/commons/compress/archivers/examples/Archive.java
# 30a595d0 COMPRESS-118 add projection operation
# 8	0	src/main/java/org/apache/commons/compress/archivers/examples/Archive.java
# 41	0	src/main/java/org/apache/commons/compress/archivers/examples/Transformer.java
# 82f9bfcb make code compile on Java7
# 5	0	src/main/java/org/apache/commons/compress/archivers/examples/DirectoryBasedSupplier.java
# f62c5231 COMPRESS-118 provide a more fluent archiving interface
# 128	0	src/main/java/org/apache/commons/compress/archivers/examples/Archive.java
# 44	0	src/main/java/org/apache/commons/compress/archivers/examples/ArchiveCli.java
# 42	0	src/main/java/org/apache/commons/compress/archivers/examples/Chain.java
# 70	0	src/main/java/org/apache/commons/compress/archivers/examples/ChainDefinition.java
# 68	0	src/main/java/org/apache/commons/compress/archivers/examples/ChainPayload.java
# 40	0	src/main/java/org/apache/commons/compress/archivers/examples/ChainStep.java
# 107	0	src/main/java/org/apache/commons/compress/archivers/examples/DirectoryBasedSupplier.java
# 37	0	src/main/java/org/apache/commons/compress/archivers/examples/FileFilterAdapter.java
# 123	0	src/main/java/org/apache/commons/compress/archivers/examples/FileToArchiveSink.java
# 44	0	src/main/java/org/apache/commons/compress/archivers/examples/Filter.java
# 78	0	src/main/java/org/apache/commons/compress/archivers/examples/SevenZOutputFileSink.java
# 47	0	src/main/java/org/apache/commons/compress/archivers/examples/Sink.java
# 30	0	src/main/java/org/apache/commons/compress/archivers/examples/Supplier.java
# 30	0	src/main/java/org/apache/commons/compress/archivers/examples/ThrowingIterator.java
# eee4d197 COMPRESS-445 make most CompressorInputs implement InputStatistics
# 1	1	src/changes/changes.xml
# 16	0	src/main/java/org/apache/commons/compress/compressors/CompressorInputStream.java
# 15	3	src/main/java/org/apache/commons/compress/compressors/brotli/BrotliCompressorInputStream.java
# 0	8	src/main/java/org/apache/commons/compress/compressors/bzip2/BZip2CompressorInputStream.java
# 15	2	src/main/java/org/apache/commons/compress/compressors/deflate/DeflateCompressorInputStream.java
# 0	8	src/main/java/org/apache/commons/compress/compressors/deflate64/Deflate64CompressorInputStream.java
# 21	5	src/main/java/org/apache/commons/compress/compressors/gzip/GzipCompressorInputStream.java
# 14	3	src/main/java/org/apache/commons/compress/compressors/lz4/FramedLZ4CompressorInputStream.java
# 14	3	src/main/java/org/apache/commons/compress/compressors/lz77support/AbstractLZ77CompressorInputStream.java
# 16	3	src/main/java/org/apache/commons/compress/compressors/lzma/LZMACompressorInputStream.java
# 0	8	src/main/java/org/apache/commons/compress/compressors/lzw/LZWInputStream.java
# 18	2	src/main/java/org/apache/commons/compress/compressors/snappy/FramedSnappyCompressorInputStream.java
# 18	4	src/main/java/org/apache/commons/compress/compressors/xz/XZCompressorInputStream.java
# 13	2	src/main/java/org/apache/commons/compress/compressors/zstandard/ZstdCompressorInputStream.java
# a5103a8d fix whitespace
# 1	1	src/main/java/org/apache/commons/compress/utils/InputStreamStatistics.java
# 0daa0c9b COMPRESS-443 record test
# 4	0	src/changes/changes.xml
# 92c8fc16 COMPRESS-443 jar-plugin needs help finding the manifest
# 4	1	pom.xml
# 9146faa1 COMPRESS-443 use native container and reference URI for bundle
# 14	16	pom.xml
# 14	44	src/test/java/org/apache/commons/compress/OsgiITest.java
# 0de76f15 crude attempt for adding a PAX Exam test
# 66	0	pom.xml
# 85	0	src/test/java/org/apache/commons/compress/OsgiITest.java
# 97867f6f COMPRESS-118 provide a high-level API for expanding archives
# 375	0	src/main/java/org/apache/commons/compress/archivers/Expander.java
# a2913167 COMPRESS-118 use correct overload when using ZipArchiveInputStream
# 1	1	src/main/java/org/apache/commons/compress/archivers/Archiver.java
# 0bb584bb CMPRESS-118 make 7z creator API public
# 27	9	src/main/java/org/apache/commons/compress/archivers/Archiver.java
# 9c3c448c entry names of directories should end with slashes
# 3	2	src/main/java/org/apache/commons/compress/archivers/Archiver.java
# 69d5b2f0 channel-arg version shouldn't close the channel, owned by caller
# 1	3	src/main/java/org/apache/commons/compress/archivers/Archiver.java
# f45ba62d COMPRESS-118 first cut at a high-level API for archive creation
# 269	0	src/main/java/org/apache/commons/compress/archivers/Archiver.java
# 906d2770 COMPRESS-445 compressed size must include size of trees for IMPLODE
# 16	6	src/main/java/org/apache/commons/compress/archivers/zip/ExplodingInputStream.java
# 0	1	src/test/java/org/apache/commons/compress/archivers/ZipTestCase.java
# c5e3fbe0 ExplodingInputStream doesn't close nested stream
# 8	0	src/main/java/org/apache/commons/compress/archivers/zip/ExplodingInputStream.java
# be86c623 COMPRESS-445 fix stats for Stored entries in ZipArchiveInputStream
# 1	1	src/main/java/org/apache/commons/compress/archivers/zip/ZipArchiveInputStream.java
# 0	1	src/test/java/org/apache/commons/compress/archivers/ZipTestCase.java
# 36a5631e COMPRESS-445 test cases for the remaining ZIP methods
# 48	5	src/test/java/org/apache/commons/compress/archivers/ZipTestCase.java
# 0db4e9a6 COMPRESS-445 document ZipFile's new contract
# 2	1	src/main/java/org/apache/commons/compress/archivers/zip/ZipFile.java
# 74abd5b7 COMPRESS-445 make ZipFile return statistics for stored entries
# 19	1	src/main/java/org/apache/commons/compress/archivers/zip/ZipFile.java
# b8f7d772 COMPRESS-445 can't use decoder after stream has been exhausted
# 3	1	src/main/java/org/apache/commons/compress/compressors/deflate64/Deflate64CompressorInputStream.java
# d6b07a11 COMPRESS-445 refactor statistics test
# 22	10	src/test/java/org/apache/commons/compress/archivers/ZipTestCase.java
# ac7f09c8 upgrade to Commons Parent 46
# 1	1	pom.xml
# 25bf90c4 RAT doesn't detect Apache license when https is used
# 1	1	README.md
# c6689ab7 COMPRESS-445 document change
# 8	0	src/changes/changes.xml
# 0646aa7d COMPRESS-445 try to get compressed count for all supported methods
# 22	3	src/main/java/org/apache/commons/compress/archivers/zip/ZipArchiveInputStream.java
# 22c79b2f COMPRESS-445 cosmetics
# 6	0	src/main/java/org/apache/commons/compress/archivers/zip/ExplodingInputStream.java
# 2	0	src/main/java/org/apache/commons/compress/archivers/zip/InflaterInputStream.java
# 7	1	src/main/java/org/apache/commons/compress/compressors/bzip2/BZip2CompressorInputStream.java
# 6	0	src/main/java/org/apache/commons/compress/compressors/deflate64/Deflate64CompressorInputStream.java
# 4	1	src/main/java/org/apache/commons/compress/compressors/deflate64/HuffmanDecoder.java
# 8	0	src/main/java/org/apache/commons/compress/compressors/lzw/LZWInputStream.java
# 11	4	src/main/java/org/apache/commons/compress/utils/BitInputStream.java
# 2	0	src/main/java/org/apache/commons/compress/utils/InputStreamStatistics.java
# 6	1	src/test/java/org/apache/commons/compress/archivers/ZipTestCase.java
# 02c963a4 COMPRESS-445 provide statistics when uncompressing
# 21	2	src/main/java/org/apache/commons/compress/archivers/zip/ExplodingInputStream.java
# 80	0	src/main/java/org/apache/commons/compress/archivers/zip/InflaterInputStream.java
# 19	1	src/main/java/org/apache/commons/compress/archivers/zip/ZipArchiveInputStream.java
# 0	1	src/main/java/org/apache/commons/compress/archivers/zip/ZipFile.java
# 13	2	src/main/java/org/apache/commons/compress/compressors/bzip2/BZip2CompressorInputStream.java
# 13	1	src/main/java/org/apache/commons/compress/compressors/deflate64/Deflate64CompressorInputStream.java
# 4	0	src/main/java/org/apache/commons/compress/compressors/deflate64/HuffmanDecoder.java
# 10	1	src/main/java/org/apache/commons/compress/compressors/lzw/LZWInputStream.java
# 7	2	src/main/java/org/apache/commons/compress/utils/BitInputStream.java
# 36	0	src/main/java/org/apache/commons/compress/utils/InputStreamStatistics.java
# 54	3	src/test/java/org/apache/commons/compress/archivers/ZipTestCase.java
# -	-	src/test/resources/zipbomb.xlsx
# 166b186e whitespace
# 5	6	src/main/java/org/apache/commons/compress/archivers/zip/ExtraFieldUtils.java
# bd3e6cf2 COMPRESS-447 turn ArrayIndexOutOfBoundsExceptions into ZipExceptions
# 5	0	src/changes/changes.xml
# 5	0	src/main/java/org/apache/commons/compress/archivers/zip/ExtraFieldUtils.java
# 29	0	src/test/java/org/apache/commons/compress/archivers/zip/ExtraFieldUtilsTest.java
# 77785336 ensure all skip call go through IOUtils.skip
# 1	1	src/main/java/org/apache/commons/compress/archivers/zip/ZipArchiveInputStream.java
# 2	1	src/main/java/org/apache/commons/compress/compressors/brotli/BrotliCompressorInputStream.java
# 2	1	src/main/java/org/apache/commons/compress/compressors/deflate/DeflateCompressorInputStream.java
# 2	1	src/main/java/org/apache/commons/compress/compressors/gzip/GzipCompressorInputStream.java
# 2	1	src/main/java/org/apache/commons/compress/compressors/lzma/LZMACompressorInputStream.java
# 2	1	src/main/java/org/apache/commons/compress/compressors/pack200/Pack200CompressorInputStream.java
# 2	1	src/main/java/org/apache/commons/compress/compressors/xz/XZCompressorInputStream.java
# 2	1	src/main/java/org/apache/commons/compress/compressors/zstandard/ZstdCompressorInputStream.java
# 765b8f88 use IOUtils.skip
# 1	1	src/main/java/org/apache/commons/compress/archivers/tar/TarArchiveInputStream.java
# 69f38e81 Deprecate charset constants superseded by Java 7
# 3	3	src/main/java/org/apache/commons/compress/archivers/zip/ZipEncodingHelper.java
# 14	7	src/main/java/org/apache/commons/compress/utils/Charsets.java
# 0	30	src/test/java/org/apache/commons/compress/utils/CharsetsTest.java
# 7a8f3c37 record change, closes #63
# 4	0	src/changes/changes.xml
# e144806c (doc) use BufferedOutputStream in examples for compressing
# 6	6	src/site/xdoc/examples.xml
# a189697f fix the error in the gzip compression example
# 3	3	src/site/xdoc/examples.xml
# 1	1	src/site/xdoc/pack200.xml
# f13364b0 whitespace
# 4	4	src/main/java/org/apache/commons/compress/archivers/zip/ParallelScatterZipCreator.java
# 8faba699 COMPRESS-446 fix resource leak in ParallelScatterZipCreator#writeTo.
# 3	0	src/changes/changes.xml
# 8	1	src/main/java/org/apache/commons/compress/archivers/zip/ParallelScatterZipCreator.java
# 0437b184 update security reports page
# 22	0	src/site/xdoc/security-reports.xml
# b3a27116 upgrade to Commons Parent 45
# 1	1	pom.xml
# f35ff5f4 use https in javadoc links where possible
# 1	1	src/changes/release-notes.vm
# 1	1	src/main/java/org/apache/commons/compress/archivers/ar/ArArchiveEntry.java
# 1	1	src/main/java/org/apache/commons/compress/archivers/cpio/CpioArchiveEntry.java
# 1	1	src/main/java/org/apache/commons/compress/archivers/sevenz/Coders.java
# 1	1	src/main/java/org/apache/commons/compress/archivers/tar/TarUtils.java
# 1	1	src/main/java/org/apache/commons/compress/archivers/zip/ExplodingInputStream.java
# 1	1	src/main/java/org/apache/commons/compress/archivers/zip/UnicodeCommentExtraField.java
# 1	1	src/main/java/org/apache/commons/compress/archivers/zip/UnicodePathExtraField.java
# 1	1	src/main/java/org/apache/commons/compress/archivers/zip/UnparseableExtraFieldData.java
# 1	1	src/main/java/org/apache/commons/compress/archivers/zip/Zip64ExtendedInformationExtraField.java
# 1	1	src/main/java/org/apache/commons/compress/archivers/zip/ZipArchiveInputStream.java
# 17	17	src/main/java/org/apache/commons/compress/archivers/zip/ZipMethod.java
# 1	1	src/main/java/org/apache/commons/compress/compressors/gzip/GzipCompressorOutputStream.java
# 1	1	src/main/java/org/apache/commons/compress/compressors/lz4/XXHash32.java
# 1	1	src/main/java/org/apache/commons/compress/compressors/lzma/package.html
# 4	4	src/main/java/org/apache/commons/compress/compressors/pack200/Pack200Utils.java
# 1	1	src/main/java/org/apache/commons/compress/compressors/pack200/package.html
# 1	1	src/main/java/org/apache/commons/compress/compressors/snappy/PureJavaCrc32C.java
# 1	1	src/main/java/org/apache/commons/compress/compressors/xz/package.html
# 8	8	src/main/java/org/apache/commons/compress/utils/CharsetNames.java
# 8	8	src/main/java/org/apache/commons/compress/utils/Charsets.java
# 91b8432e use https links where possible
# 1	1	NOTICE.txt
# 2	2	README.md
# 1	1	README.txt
# 2	2	RELEASE-NOTES.txt
# 3	3	pom.xml
# 1	1	src/site/site.xml
# 1	1	src/site/xdoc/download_compress.xml
# 2	2	src/site/xdoc/examples.xml
# 3	3	src/site/xdoc/index.xml
# 1	1	src/site/xdoc/issue-tracking.xml
# 4	4	src/site/xdoc/limitations.xml
# 18	18	src/site/xdoc/mail-lists.xml
# 1	1	src/site/xdoc/pack200.xml
# 14	14	src/site/xdoc/security-reports.xml
# 67c2f681 Merge tag 'rel/1.16.1'
# 3d76662c record removal of objenesis dependency
# 7	0	src/changes/changes.xml
# be132f70 the objenensis dependency seems to not be required at all
# 0	5	pom.xml
# b5204113 prepare RC1 of 1.16.1
# 1	1	README.md
# 8	0	RELEASE-NOTES.txt
# 1	1	pom.xml
# 2	2	src/changes/changes.xml
# 1	0	src/site/site.xml
# 13	13	src/site/xdoc/download_compress.xml
# 6	0	src/site/xdoc/index.xml
# 3026d1f9 update zstd-jni dependency
# 1	1	pom.xml
# c70dc2eb COMPRESS-442 fix OSGi manifest
# 1	1	pom.xml
# 4	0	src/changes/changes.xml
# 0c644264 Merge tag 'rel/1.16', prepare for next iteration
# ecaa767c mention the Block class is considered internal.
# 8	1	src/main/java/org/apache/commons/compress/compressors/lz77support/LZ77Compressor.java
# c6e38999 prepare RC1 of Commons Compress 1.16
# 3	3	README.md
# 1	1	pom.xml
# 1	0	src/site/site.xml
# 13	13	src/site/xdoc/download_compress.xml
# 6	11	src/site/xdoc/index.xml
# 2e44bbeb create release notes for 1.16
# 56	2	RELEASE-NOTES.txt
# 69a4a558 mention DEFLATE64 in POM
# 2	2	pom.xml
# d9d5ce4a mention drive letters wherever leading slashes are mentioned
# 7	6	src/main/java/org/apache/commons/compress/archivers/tar/TarArchiveEntry.java
# 2e74d637 and another trivial error inside the Windows-only test
# 1	1	src/test/java/org/apache/commons/compress/archivers/tar/TarArchiveEntryTest.java
# 4f2f4727 this is what you get for writing tests you can't run :-)
# 1	1	src/test/java/org/apache/commons/compress/archivers/tar/TarArchiveEntryTest.java
# 7dcce66f allow preserveAbsolutePath to be final
# 7	7	src/main/java/org/apache/commons/compress/archivers/tar/TarArchiveEntry.java
# 1bad4f41 whitespace
# 18	18	src/main/java/org/apache/commons/compress/archivers/tar/TarArchiveEntry.java
# 66607ddc optionally preserve the drive letter on Windows
# 5	0	src/changes/changes.xml
# 25	21	src/main/java/org/apache/commons/compress/archivers/tar/TarArchiveEntry.java
# 10	0	src/test/java/org/apache/commons/compress/archivers/tar/TarArchiveEntryTest.java
# 04f88700 COMPRESS-434 improve docs on decompressConcatenated
# 23	2	src/main/java/org/apache/commons/compress/compressors/gzip/GzipCompressorInputStream.java
# 237b7e3d make PMD less unhappy
# 3	1	src/main/java/org/apache/commons/compress/archivers/tar/TarUtils.java
# 1	1	src/main/java/org/apache/commons/compress/compressors/deflate64/HuffmanDecoder.java
# cce7005a document the slash normalization for all constructors
# 5	3	src/main/java/org/apache/commons/compress/archivers/tar/TarArchiveEntry.java
# beb43a55 make construction of tar entry names more explicit
# 26	0	src/main/java/org/apache/commons/compress/archivers/tar/TarArchiveEntry.java
# 34a1f829 rename variable to match SonarQube's expectations
# 3	3	src/main/java/org/apache/commons/compress/compressors/deflate64/Deflate64CompressorInputStream.java
# e44fe0ed looks like another linefeed problem on Windows
# 0	3	src/test/resources/zstandard.testdata
# -	-	src/test/resources/zstd-tests.tar
# 3c452f77 slightly reduce memory pressure
# 4	3	src/main/java/org/apache/commons/compress/compressors/deflate64/Deflate64CompressorInputStream.java
# c1470f52 remove magic value
# 5	5	src/main/java/org/apache/commons/compress/utils/BitInputStream.java
# 0e1e80c2 whitespace
# 17	17	src/main/java/org/apache/commons/compress/compressors/deflate64/HuffmanDecoder.java
# 0367fb31 make SonarQube less unhappy
# 3	3	src/main/java/org/apache/commons/compress/compressors/bzip2/BZip2CompressorInputStream.java
# 56	44	src/main/java/org/apache/commons/compress/compressors/deflate64/HuffmanDecoder.java
# 1	1	src/main/java/org/apache/commons/compress/compressors/lz77support/LZ77Compressor.java
# 1	1	src/main/java/org/apache/commons/compress/compressors/zstandard/ZstdUtils.java
# d5f61b43 reading from the cache doesn't need to throw an exception
# 15	12	src/main/java/org/apache/commons/compress/utils/BitInputStream.java
# 271e0a76 explicit tests for new BitInputStream methods
# 35	0	src/test/java/org/apache/commons/compress/utils/BitInputStreamTest.java
# d8e4e255 record changes, closes #61, many thanks to @shahabkondri
# 4	0	src/changes/changes.xml
# bfbe9966 Revert to the original logic.
# 6	2	src/main/java/org/apache/commons/compress/archivers/dump/DumpArchiveEntry.java
# bf0dd95b Add braces for the else block.
# 3	1	src/main/java/org/apache/commons/compress/archivers/ar/ArArchiveEntry.java
# 3	1	src/main/java/org/apache/commons/compress/archivers/cpio/CpioArchiveEntry.java
# f43590aa 'long' literal ending with lowercase 'l' instead of 'L'
# 1	1	src/main/java/org/apache/commons/compress/archivers/arj/ArjArchiveEntry.java
# 3	3	src/main/java/org/apache/commons/compress/archivers/cpio/CpioArchiveOutputStream.java
# 1	1	src/main/java/org/apache/commons/compress/archivers/tar/TarArchiveEntry.java
# 1	1	src/main/java/org/apache/commons/compress/archivers/tar/TarArchiveOutputStream.java
# 2	2	src/main/java/org/apache/commons/compress/archivers/tar/TarUtils.java
# 1	1	src/main/java/org/apache/commons/compress/archivers/zip/ParallelScatterZipCreator.java
# 2	2	src/main/java/org/apache/commons/compress/archivers/zip/X000A_NTFS.java
# 1	1	src/main/java/org/apache/commons/compress/compressors/gzip/GzipCompressorInputStream.java
# 5	5	src/main/java/org/apache/commons/compress/compressors/lz4/XXHash32.java
# 1	1	src/main/java/org/apache/commons/compress/compressors/snappy/FramedSnappyCompressorInputStream.java
# 1	1	src/main/java/org/apache/commons/compress/compressors/snappy/FramedSnappyCompressorOutputStream.java
# 2	2	src/main/java/org/apache/commons/compress/utils/BitInputStream.java
# 1	1	src/main/java/org/apache/commons/compress/utils/ByteUtils.java
# 1	1	src/main/java/org/apache/commons/compress/utils/CRC32VerifyingInputStream.java
# 5b569853 Explicit manual boxing is unnecessary under Java 5 and newer, and can be safely removed.
# 4	4	src/main/java/org/apache/commons/compress/archivers/zip/PKWareExtraHeader.java
# 1	1	src/main/java/org/apache/commons/compress/compressors/CompressorStreamFactory.java
# e816ab75 remove unused import.
# 0	1	src/main/java/org/apache/commons/compress/archivers/sevenz/Coders.java
# 6c203ab4 There is General exception 'IOException' in the throws list already.
# 1	2	src/main/java/org/apache/commons/compress/archivers/zip/ZipFile.java
# f8e33e70 Local variable is redundant.
# 1	2	src/main/java/org/apache/commons/compress/archivers/tar/TarUtils.java
# 1	2	src/main/java/org/apache/commons/compress/compressors/bzip2/BZip2CompressorInputStream.java
# f21a7054 if statement can be simplified.
# 2	7	src/main/java/org/apache/commons/compress/archivers/ar/ArArchiveEntry.java
# 2	7	src/main/java/org/apache/commons/compress/archivers/cpio/CpioArchiveEntry.java
# 2	6	src/main/java/org/apache/commons/compress/archivers/dump/DumpArchiveEntry.java
# 1	5	src/main/java/org/apache/commons/compress/archivers/dump/DumpArchiveUtil.java
# 1	5	src/main/java/org/apache/commons/compress/archivers/tar/TarArchiveEntry.java
# 4	8	src/main/java/org/apache/commons/compress/archivers/tar/TarArchiveInputStream.java
# 2	18	src/main/java/org/apache/commons/compress/compressors/bzip2/BZip2CompressorInputStream.java
# 1	14	src/main/java/org/apache/commons/compress/compressors/gzip/GzipCompressorInputStream.java
# 3	18	src/main/java/org/apache/commons/compress/compressors/lzma/LZMACompressorInputStream.java
# 0194bb8c if statement can be simplified.
# 5	29	src/main/java/org/apache/commons/compress/archivers/ar/ArArchiveInputStream.java
# eb816f66 Modifier 'static' is redundant for enum constructors.
# 1	1	src/main/java/org/apache/commons/compress/archivers/sevenz/CLI.java
# 1	1	src/main/java/org/apache/commons/compress/compressors/brotli/BrotliUtils.java
# 1	1	src/main/java/org/apache/commons/compress/compressors/lz77support/LZ77Compressor.java
# 1	1	src/main/java/org/apache/commons/compress/compressors/lzma/LZMAUtils.java
# 1	1	src/main/java/org/apache/commons/compress/compressors/zstandard/ZstdUtils.java
# c30de4b2 Modifier 'private' is redundant for enum constructors.
# 2	2	src/main/java/org/apache/commons/compress/archivers/dump/DumpArchiveConstants.java
# 2	2	src/main/java/org/apache/commons/compress/archivers/dump/DumpArchiveEntry.java
# 1	1	src/main/java/org/apache/commons/compress/archivers/sevenz/CLI.java
# 1	1	src/main/java/org/apache/commons/compress/archivers/sevenz/SevenZMethod.java
# 1	1	src/main/java/org/apache/commons/compress/compressors/lz4/FramedLZ4CompressorOutputStream.java
# 2	2	src/main/java/org/apache/commons/compress/compressors/snappy/FramedSnappyDialect.java
# 1	1	src/main/java/org/apache/commons/compress/compressors/xz/XZUtils.java
# 08cdbe29 gitattributes don't work reliably on Windows Jenkins nodes
# 19	0	pom.xml
# -	-	src/test/resources/bla.tar.zst
# -	-	src/test/resources/zstandard.testdata.zst
# -	-	src/test/resources/zstd-tests.tar
# b2fac804 COMPRESS-441 tweaks by Dawid Weiss
# 4	1	src/main/java/org/apache/commons/compress/archivers/sevenz/Coders.java
# 12	10	src/main/java/org/apache/commons/compress/archivers/zip/ZipFile.java
# 8efea833 typo
# 1	1	src/main/java/org/apache/commons/compress/archivers/zip/ZipFile.java
# 43e8d3d5 COMPRESS-441 simplify code for zlib dummy byte workarounds
# 4	0	src/changes/changes.xml
# 7	36	src/main/java/org/apache/commons/compress/archivers/sevenz/Coders.java
# 7	16	src/main/java/org/apache/commons/compress/archivers/zip/ZipFile.java
# c66db899 COMPRESS-436 sanity check compressed size is known for bzip etc
# 4	0	src/changes/changes.xml
# 7	0	src/main/java/org/apache/commons/compress/archivers/zip/UnsupportedZipFeatureException.java
# 19	2	src/main/java/org/apache/commons/compress/archivers/zip/ZipArchiveInputStream.java
# 16	0	src/test/java/org/apache/commons/compress/archivers/zip/ZipArchiveInputStreamTest.java
# a12adc36 add known limitations for stand-alone DEFLATE64
# 7	0	src/site/xdoc/limitations.xml
# 738c708b COMPRESS-437 add read-only DEFLATE64 support to 7z
# 3	0	src/changes/changes.xml
# 16	0	src/main/java/org/apache/commons/compress/archivers/sevenz/Coders.java
# 5	0	src/main/java/org/apache/commons/compress/archivers/sevenz/SevenZMethod.java
# 1	1	src/site/xdoc/examples.xml
# 1	1	src/site/xdoc/index.xml
# 5	0	src/test/java/org/apache/commons/compress/archivers/sevenz/SevenZFileTest.java
# -	-	src/test/resources/bla.deflate64.7z
# 5b004bfc COMPRESS-440 record change
# 5	1	src/changes/changes.xml
# e8720d6a whitespace
# 2	2	src/main/java/org/apache/commons/compress/compressors/deflate64/HuffmanDecoder.java
# 90d775ce 10% speed improvements and decreased memory allocation rate in deflate64
# 10	6	src/main/java/org/apache/commons/compress/compressors/deflate64/HuffmanDecoder.java
# 49f65470 COMPRESS-407 make changed defaults more explicit
# 3	0	src/changes/changes.xml
# 13	0	src/main/java/org/apache/commons/compress/archivers/tar/TarArchiveOutputStream.java
# 220c45d1 typo
# 1	1	src/site/xdoc/limitations.xml
# 46eeba4b update javadoc links and fix gzip stream class name
# 3	3	src/site/xdoc/pack200.xml
# 9240ae1b remove local variable that's no longer needed
# 0	1	src/main/java/org/apache/commons/compress/archivers/zip/ZipUtil.java
# 5f69a4be javadoc warnings
# 1	0	src/main/java/org/apache/commons/compress/compressors/CompressorStreamFactory.java
# 4	0	src/main/java/org/apache/commons/compress/utils/BitInputStream.java
# 3ead6780 changes.xml wasn't well formed
# 1	0	src/changes/changes.xml
# 135dd48f COMPRESS-438 buffer bounded streams in ZipFile for better performance
# 4	0	src/changes/changes.xml
# 10	6	src/main/java/org/apache/commons/compress/archivers/zip/ZipFile.java
# 6ef3fd45 COMPRESS-380 lost Christian's name during merge
# 1	1	src/changes/changes.xml
# 0504d0bf GroupId is duplicate of parent groupId.
# 0	1	pom.xml
# 881d014c Pickup Maven Javadoc plugin version from commons-parent.
# 1	0	pom.xml
# f2430853 Update maven-pmd-plugin 3.7 to 3.8.
# 1	1	pom.xml
# cc7a6051 Update findbugs-maven-plugin from 3.0.4 to 3.0.5.
# 1	1	pom.xml
# b49663a5 Update tests from Powermock 1.7.0 to 1.7.3.
# 1	1	pom.xml
# 593f3e6d Pickup maven-bundle-plugin version from commons-parent.
# 1	1	pom.xml
# 4e640cfc Update commons-parent from 42 to 43.
# 1	1	pom.xml
# 3bf9dad7 Use try-with-resources.
# 93	93	src/test/java/org/apache/commons/compress/archivers/ZipTestCase.java
# 29ce3e0e The exception is not thrown.
# 1	1	src/main/java/org/apache/commons/compress/archivers/zip/ZipArchiveOutputStream.java
# 45b5e0cb The exception is not thrown.
# 1	1	src/main/java/org/apache/commons/compress/compressors/deflate64/Deflate64CompressorInputStream.java
# 9021c5a7 Javadoc: Make these tables easier to read by using <pre> tags.
# ...
# 16	13	src/test/org/apache/commons/compress/zip/ZipEntryTestCase.java
# 16	13	src/test/org/apache/commons/compress/zip/ZipLongTestCase.java
# 16	13	src/test/org/apache/commons/compress/zip/ZipShortTestCase.java
# e2e969c7 Moving the copyright into the NOTICE file. Missed lots of entries with the script, need to investigate why
# 3	0	NOTICE.txt
# 6	5	checkstyle.xml
# 6	5	maven.xml
# 6	5	project.xml
# 6	5	src/site/xdoc/cvs-usage.xml
# 6	5	src/site/xdoc/downloads.xml
# 6	5	src/site/xdoc/issue-tracking.xml
# 4dbd36e9 Renaming the sandbox pom to commons-sandbox from commons-sandbox-parent
# 1	1	pom.xml
# 76af64d5 The BZip2 tests have problems when they are instrumented, they hang and the site can't be built. Added configuration so those classes do not get instrumented
# 24	0	pom.xml
# 91d4cff7 Changing to m2 format
# 17	25	src/site/site.xml
# 8d6e1210 Moving navigation to the m2 name of site.xml
# 0	0	src/site/{xdoc/navigation.xml => site.xml}
# 09f50fdb Moving Compress to an m2 site
# 0	0	{xdocs => src/site/xdoc}/cvs-usage.xml
# 0	0	{xdocs => src/site/xdoc}/downloads.xml
# -	-	{xdocs => src/site/xdoc}/images/compress-logo-white.png
# -	-	{xdocs => src/site/xdoc}/images/compress-logo-white.xcf
# 0	0	{xdocs => src/site/xdoc}/index.xml
# 0	0	{xdocs => src/site/xdoc}/issue-tracking.xml
# 0	0	{xdocs => src/site/xdoc}/navigation.xml
# 0	0	{xdocs => src/site/xdoc}/style/project.css
# db43350a Switching from minotaur.apache.org to people.apache.org in the distributionManagement
# 1	1	pom.xml
# 0538397c 1.4 compiler settings (not sure what min JDK is)
# 4	0	project.properties
# 786e4c21 Fixing the parent-pom version
# 1	1	pom.xml
# be36da78 forgot a few files to add: draft 8 from C. Grobmeier, grant has been received, cheers
# 162	0	src/java/org/apache/commons/compress/AbstractCompressor.java
# 96	0	src/java/org/apache/commons/compress/Archive.java
# 155	0	src/java/org/apache/commons/compress/ArchiverFactory.java
# 55	0	src/java/org/apache/commons/compress/CompressException.java
# 61	0	src/java/org/apache/commons/compress/CompressUtils.java
# 115	0	src/java/org/apache/commons/compress/Compressor.java
# 181	0	src/java/org/apache/commons/compress/CompressorFactory.java
# 139	0	src/java/org/apache/commons/compress/PackableObject.java
# 88220840 draft 8 from C. Grobmeier, grant has been received, cheers
# 74	0	README.txt
# 2	8	project.properties
# 11	95	project.xml
# 123	0	src/examples/org/apache/commons/compress/examples/BZip2Example.java
# 70	0	src/examples/org/apache/commons/compress/examples/Bzip2Compress.java
# 76	0	src/examples/org/apache/commons/compress/examples/Bzip2Uncompress.java
# 69	0	src/examples/org/apache/commons/compress/examples/TarExample.java
# 62	0	src/examples/org/apache/commons/compress/examples/ZipExample.java
# 143	0	src/java/org/apache/commons/compress/AbstractArchive.java
# 61	0	src/java/org/apache/commons/compress/ArchiveEntry.java
# 53	0	src/java/org/apache/commons/compress/ArchiveException.java
# 53	0	src/java/org/apache/commons/compress/PackableObjectException.java
# 55	0	src/java/org/apache/commons/compress/UnpackException.java
# 192	0	src/java/org/apache/commons/compress/archivers/tar/TarArchive.java
# 497	0	src/java/org/apache/commons/compress/archivers/tar/TarBuffer.java
# 811	0	src/java/org/apache/commons/compress/archivers/tar/TarEntry.java
# 470	0	src/java/org/apache/commons/compress/archivers/tar/TarInputStream.java
# 422	0	src/java/org/apache/commons/compress/archivers/tar/TarOutputStream.java
# 233	0	src/java/org/apache/commons/compress/archivers/tar/TarUtils.java
# 406	0	src/java/org/apache/commons/compress/archivers/zip/AsiExtraField.java
# 204	0	src/java/org/apache/commons/compress/archivers/zip/ExtraFieldUtils.java
# 76	0	src/java/org/apache/commons/compress/archivers/zip/UnixStat.java
# 156	0	src/java/org/apache/commons/compress/archivers/zip/UnrecognizedExtraField.java
# 173	0	src/java/org/apache/commons/compress/archivers/zip/ZipArchive.java
# 451	0	src/java/org/apache/commons/compress/archivers/zip/ZipEntry.java
# 88	0	src/java/org/apache/commons/compress/archivers/zip/ZipExtraField.java
# 119	0	src/java/org/apache/commons/compress/archivers/zip/ZipLong.java
# 728	0	src/java/org/apache/commons/compress/archivers/zip/ZipOutputStream.java
# 115	0	src/java/org/apache/commons/compress/archivers/zip/ZipShort.java
# 14	0	src/java/org/apache/commons/compress/archivers/zip/package.html
# 133	0	src/java/org/apache/commons/compress/compressors/bzip2/BZip2Compressor.java
# 99	0	src/java/org/apache/commons/compress/compressors/bzip2/BZip2Constants.java
# 994	0	src/java/org/apache/commons/compress/compressors/bzip2/BZip2InputStream.java
# 2036	0	src/java/org/apache/commons/compress/compressors/bzip2/BZip2OutputStream.java
# 127	0	src/java/org/apache/commons/compress/compressors/bzip2/CRC.java
# 10	0	src/java/org/apache/commons/compress/compressors/bzip2/package.html
# 43	0	src/test/org/apache/commons/compress/CompressUtilsTest.java
# 319	0	src/test/org/apache/commons/compress/archivers/tar/TarTestCase.java
# 32	0	src/test/org/apache/commons/compress/archivers/tar/TarTestSuite.java
# 15	0	src/test/org/apache/commons/compress/archivers/tar/data.txt
# -	-	src/test/org/apache/commons/compress/archivers/tar/gnu.tar
# -	-	src/test/org/apache/commons/compress/archivers/tar/posix.tar
# 3	0	src/test/org/apache/commons/compress/archivers/tar/update-tars.bat
# 178	0	src/test/org/apache/commons/compress/archivers/zip/AsiExtraFieldTestCase.java
# 130	0	src/test/org/apache/commons/compress/archivers/zip/ExtraFieldUtilsTestCase.java
# 110	0	src/test/org/apache/commons/compress/archivers/zip/ZipEntryTestCase.java
# 90	0	src/test/org/apache/commons/compress/archivers/zip/ZipLongTestCase.java
# 86	0	src/test/org/apache/commons/compress/archivers/zip/ZipShortTestCase.java
# 265	0	src/test/org/apache/commons/compress/compressors/bzip2/BzipTestCase.java
# -	-	src/test/org/apache/commons/compress/compressors/bzip2/asf-logo-huge.tar
# -	-	src/test/org/apache/commons/compress/compressors/bzip2/asf-logo-huge.tar.bz2
# 7	23	xdocs/navigation.xml
# 38ba1e94 Fix copy-and-paste mistake.
# 3	3	project.xml
# 1	1	xdocs/downloads.xml
# c99cad4a Update site/build
# 83	0	maven.xml
# 8	2	project.properties
# 94	10	project.xml
# 51	0	xdocs/cvs-usage.xml
# 56	0	xdocs/downloads.xml
# 71	0	xdocs/issue-tracking.xml
# 23	7	xdocs/navigation.xml
# 1	0	xdocs/style/project.css
# 0473f980 Changing cvs.apache.org to people.apache.org. None of these locations appear to point to an svn or cvs url
# 1	1	project.xml
# e1bfd3ce Applied Ant fix: http://svn.apache.org/viewcvs.cgi/ant/core/trunk/src/main/org/apache/tools/tar/TarBuffer.java?rev=277329&r1=276208&r2=277329
# 10	1	src/java/org/apache/commons/compress/tar/TarBuffer.java
# 0d1c8b38 Killing apt port of xdocs, it is unnecessary
# 0	36	src/site/apt/index.apt
# 0	18	src/site/site.xml
# efa31fff apt port of the xdocs site - I must be doing something wrong as it doesn't generate well, but I thought I would check the latest in anyway
# 36	0	src/site/apt/index.apt
# 18	0	src/site/site.xml
# 7c222cdc M2 file for compress
# 66	0	pom.xml
# a97bbcf7 Modify maven build to add two non-standard attributes to the jar's manifest file to indicate the values of "maven.compile.source" and "maven.compile.target". Also modify the build to include an "Implementation-Vendor-Id" of "org.apache" in the jar's manifest.
# 6	0	project.properties
# b8734879 added siteAddress and issueTrackingUrl
# 2	0	project.xml
# 90595018 PR: 36597 Submitted by: Hiroki Ata <hiroki.ata -at- mail.com>
# 11	1	src/java/org/apache/commons/compress/bzip2/CBZip2InputStream.java
# 24	0	src/test/org/apache/commons/compress/bzip2/test/BzipTestCase.java
# 46bb5d48 The underlying InputStream really should be closed
# 5	0	src/java/org/apache/commons/compress/bzip2/CBZip2InputStream.java
# bbbb3f55 convert .cvsignore to svn:ignore
# 0	9	.cvsignore
# 3bfb8394 svn:keywords correction
# 1	1	src/java/org/apache/commons/compress/tar/TarBuffer.java
# 1	1	src/java/org/apache/commons/compress/tar/TarConstants.java
# 1	1	src/java/org/apache/commons/compress/tar/TarEntry.java
# 1	1	src/java/org/apache/commons/compress/tar/TarInputStream.java
# 1	1	src/java/org/apache/commons/compress/tar/TarOutputStream.java
# 1	1	src/java/org/apache/commons/compress/tar/TarUtils.java
# 1	1	src/java/org/apache/commons/compress/zip/AsiExtraField.java
# 1	1	src/java/org/apache/commons/compress/zip/ExtraFieldUtils.java
# 1	1	src/java/org/apache/commons/compress/zip/UnixStat.java
# 1	1	src/java/org/apache/commons/compress/zip/UnrecognizedExtraField.java
# 1	1	src/java/org/apache/commons/compress/zip/ZipEntry.java
# 1	1	src/java/org/apache/commons/compress/zip/ZipExtraField.java
# 1	1	src/java/org/apache/commons/compress/zip/ZipLong.java
# 1	1	src/java/org/apache/commons/compress/zip/ZipOutputStream.java
# 1	1	src/java/org/apache/commons/compress/zip/ZipShort.java
# 1	1	src/test/org/apache/commons/compress/bzip2/example/Bzip2Compress.java
# 1	1	src/test/org/apache/commons/compress/bzip2/example/Bzip2Uncompress.java
# 1	1	src/test/org/apache/commons/compress/bzip2/test/BzipTestCase.java
# 1	1	src/test/org/apache/commons/compress/tar/TarTestCase.java
# d8b467db CVS => SVN conversion
# 2	2	xdocs/index.xml
# 1	1	xdocs/navigation.xml
# 3cdd147e using svn:externals the commons-build directory is included into trunks-sandbox, this removes the dependency on the ../jakarta-commons/ directory path
# 3	1	project.properties
# 1	1	project.xml
# 1	1	xdocs/navigation.xml
# e267d01d update to commons l&f, new navigation, license info
# 2	2	project.properties
# 1	1	project.xml
# 5	20	xdocs/navigation.xml
# 3071602c white component logo
# -	-	xdocs/images/compress-logo-white.png
# -	-	xdocs/images/compress-logo-white.xcf
# 1df52e29 Applied Ant fix:
# 8	1	src/java/org/apache/commons/compress/tar/TarInputStream.java
# c63f15bf Add status subsection around status
# 2	0	xdocs/index.xml
# 5f31d310 Fix link error
# 34	22	xdocs/index.xml
# 80053612 Update to new website design
# 20	4	project.properties
# 17	2	project.xml
# 0	61	xdocs/downloads.xml
# 43	19	xdocs/navigation.xml
# ceead0b7 Change to Apache License 2.0
# 15	0	checkstyle.xml
# a6d3fd87 menu dtd moved
# 1	1	xdocs/navigation.xml
# fe909f3c removed the need to mark as compile/runtime comment from maven b1
# 0	1	project.xml
# e64ab80b asf 2.0 notice file
# 2	0	NOTICE.txt
# 0a8e779c set the super-pom
# 1	1	project.xml
# ef23042d moved to asf 2.0 licence
# 201	60	LICENSE.txt
# 13	58	src/java/org/apache/commons/compress/bzip2/BZip2Constants.java
# 13	58	src/java/org/apache/commons/compress/bzip2/CBZip2InputStream.java
# 13	58	src/java/org/apache/commons/compress/bzip2/CBZip2OutputStream.java
# 13	58	src/java/org/apache/commons/compress/bzip2/CRC.java
# 14	59	src/java/org/apache/commons/compress/tar/TarBuffer.java
# 14	59	src/java/org/apache/commons/compress/tar/TarConstants.java
# 14	59	src/java/org/apache/commons/compress/tar/TarEntry.java
# 14	59	src/java/org/apache/commons/compress/tar/TarInputStream.java
# 14	59	src/java/org/apache/commons/compress/tar/TarOutputStream.java
# 14	59	src/java/org/apache/commons/compress/tar/TarUtils.java
# 14	59	src/java/org/apache/commons/compress/zip/AsiExtraField.java
# 14	59	src/java/org/apache/commons/compress/zip/ExtraFieldUtils.java
# 14	59	src/java/org/apache/commons/compress/zip/UnixStat.java
# 14	59	src/java/org/apache/commons/compress/zip/UnrecognizedExtraField.java
# 14	59	src/java/org/apache/commons/compress/zip/ZipEntry.java
# 14	59	src/java/org/apache/commons/compress/zip/ZipExtraField.java
# 14	59	src/java/org/apache/commons/compress/zip/ZipLong.java
# 14	59	src/java/org/apache/commons/compress/zip/ZipOutputStream.java
# 14	59	src/java/org/apache/commons/compress/zip/ZipShort.java
# 14	59	src/test/org/apache/commons/compress/bzip2/example/Bzip2Compress.java
# 14	59	src/test/org/apache/commons/compress/bzip2/example/Bzip2Uncompress.java
# 14	59	src/test/org/apache/commons/compress/bzip2/test/BzipTestCase.java
# 14	59	src/test/org/apache/commons/compress/tar/TarTestCase.java
# 13	58	src/test/org/apache/commons/compress/tar/TarTestSuite.java
# 13	58	src/test/org/apache/commons/compress/zip/AsiExtraFieldTestCase.java
# 13	58	src/test/org/apache/commons/compress/zip/ExtraFieldUtilsTestCase.java
# 13	58	src/test/org/apache/commons/compress/zip/ZipEntryTestCase.java
# 13	58	src/test/org/apache/commons/compress/zip/ZipLongTestCase.java
# 13	58	src/test/org/apache/commons/compress/zip/ZipShortTestCase.java
# ca3af2ed fix url
# 1	1	project.xml
# 20d52b23 license file
# 61	0	LICENSE.txt
# fcb84d4b make data.txt binary (file size should be 666)
# 14	14	src/test/org/apache/commons/compress/tar/data.txt
# 40845ecd compress website
# 61	0	xdocs/downloads.xml
# 45	0	xdocs/index.xml
# 21	0	xdocs/navigation.xml
# a15b4e3e move text to component website
# 0	10	README.txt
# ad894fa8 mavenize project
# 9	0	.cvsignore
# 160	0	checkstyle.xml
# 23	0	project.properties
# 53	143	project.xml
# d4c9172d test data
# -	-	src/test/org/apache/commons/compress/bzip2/test/asf-logo-huge.tar
# -	-	src/test/org/apache/commons/compress/bzip2/test/asf-logo-huge.tar.bz2
# 7b57ca37 move bzip2 tests to compress component
# 113	0	src/test/org/apache/commons/compress/bzip2/example/Bzip2Compress.java
# 119	0	src/test/org/apache/commons/compress/bzip2/example/Bzip2Uncompress.java
# 284	0	src/test/org/apache/commons/compress/bzip2/test/BzipTestCase.java
# 10b88e81 move bzip2 implementation to compress component
# 144	0	src/java/org/apache/commons/compress/bzip2/BZip2Constants.java
# 1012	0	src/java/org/apache/commons/compress/bzip2/CBZip2InputStream.java
# 2080	0	src/java/org/apache/commons/compress/bzip2/CBZip2OutputStream.java
# 172	0	src/java/org/apache/commons/compress/bzip2/CRC.java
# 10	0	src/java/org/apache/commons/compress/bzip2/package.html
# 25b0c390 full license headers
# 59	5	src/test/org/apache/commons/compress/tar/TarTestCase.java
# 58	4	src/test/org/apache/commons/compress/tar/TarTestSuite.java
# 58	4	src/test/org/apache/commons/compress/zip/AsiExtraFieldTestCase.java
# 59	4	src/test/org/apache/commons/compress/zip/ExtraFieldUtilsTestCase.java
# 58	4	src/test/org/apache/commons/compress/zip/ZipEntryTestCase.java
# 58	4	src/test/org/apache/commons/compress/zip/ZipLongTestCase.java
# 58	4	src/test/org/apache/commons/compress/zip/ZipShortTestCase.java
# 100b54b4 fix tar testcase - correct path - update *.tar binary files
# 2	2	src/test/org/apache/commons/compress/tar/TarTestCase.java
# 2e441cd0 note that this is not an active piece of code
# 10	0	README.txt
# e7a0f70e Moving all these over from inside the IO component. Currently the Tar test case fails to run, though the Zip one works fine. Possibly merge BZip2 component into this one.
# 147	0	project.xml
# 542	0	src/java/org/apache/commons/compress/tar/TarBuffer.java
# 187	0	src/java/org/apache/commons/compress/tar/TarConstants.java
# 733	0	src/java/org/apache/commons/compress/tar/TarEntry.java
# 510	0	src/java/org/apache/commons/compress/tar/TarInputStream.java
# 469	0	src/java/org/apache/commons/compress/tar/TarOutputStream.java
# 278	0	src/java/org/apache/commons/compress/tar/TarUtils.java
# 451	0	src/java/org/apache/commons/compress/zip/AsiExtraField.java
# 249	0	src/java/org/apache/commons/compress/zip/ExtraFieldUtils.java
# 121	0	src/java/org/apache/commons/compress/zip/UnixStat.java
# 225	0	src/java/org/apache/commons/compress/zip/UnrecognizedExtraField.java
# 496	0	src/java/org/apache/commons/compress/zip/ZipEntry.java
# 133	0	src/java/org/apache/commons/compress/zip/ZipExtraField.java
# 165	0	src/java/org/apache/commons/compress/zip/ZipLong.java
# 773	0	src/java/org/apache/commons/compress/zip/ZipOutputStream.java
# 161	0	src/java/org/apache/commons/compress/zip/ZipShort.java
# 14	0	src/java/org/apache/commons/compress/zip/package.html
# 306	0	src/test/org/apache/commons/compress/tar/TarTestCase.java
# 23	0	src/test/org/apache/commons/compress/tar/TarTestSuite.java
# 15	0	src/test/org/apache/commons/compress/tar/data.txt
# -	-	src/test/org/apache/commons/compress/tar/gnu.tar
# -	-	src/test/org/apache/commons/compress/tar/posix.tar
# 3	0	src/test/org/apache/commons/compress/tar/update-tars.bat
# 165	0	src/test/org/apache/commons/compress/zip/AsiExtraFieldTestCase.java
# 113	0	src/test/org/apache/commons/compress/zip/ExtraFieldUtilsTestCase.java
# 94	0	src/test/org/apache/commons/compress/zip/ZipEntryTestCase.java
# 79	0	src/test/org/apache/commons/compress/zip/ZipLongTestCase.java
# 75	0	src/test/org/apache/commons/compress/zip/ZipShortTestCase.java
# cf28ddd9 New repository initialized by cvs2svn.

# %% [markdown]
# a41ce689 COMPRESS-463 throw exception when detecting a truncated stored entry
# 5	0	src/changes/changes.xml
# 2	1	src/main/java/org/apache/commons/compress/archivers/zip/ZipArchiveInputStream.java
# 7	0	src/test/java/org/apache/commons/compress/archivers/zip/Maven221MultiVolumeTest.java
# 69	0	src/test/java/org/apache/commons/compress/archivers/zip/Zi

# %%
#f.	How many total lines of code (excluding comments and blank lines) 
#were deleted? Hint: git diff or git show
#Look at C

# %%
#g.	How many total lines of code (excluding comments and blank lines) 
#were added? Hint: git diff or git show
#Look at C

# %%
#h.	How many days were between the current fixing commit and the previous 
#commit of each affected file? Hint: git log
#AffectedFile
log_data = repo.git.log("--parents",affected_file).splitlines()
for line in log_data:
    print(line)
# Out:
# commit fff4d81f2746f0faf39f595ebbf9ab242c51247a 277d6a0c2820548fd97748ec6aff92ceceb1fd35
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sat Sep 7 18:18:32 2019 +0200
#
#     COMPRESS-491 record fix
#
# commit 277d6a0c2820548fd97748ec6aff92ceceb1fd35 ab7809b5c3de7a370a70f8236ec3f5c10c6383e2
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed Aug 28 17:46:06 2019 +0200
#
#     COMPRESS-492 eliminate a bunch of potential NPEs in SevenZFile
#
# commit ab7809b5c3de7a370a70f8236ec3f5c10c6383e2 7e7bfb5b37850d5142ae8c9d07fc78c5da04af67
# Author: Gary Gregory <gardgregory@gmail.com>
# Date:   Tue Aug 27 21:21:32 2019 -0400
#
#     Update tests from org.apache.felix:org.apache.felix.framework 6.0.2 to
#     6.0.3.
#
# commit 7e7bfb5b37850d5142ae8c9d07fc78c5da04af67 a98d68e2b5c7b018db5153eb37ba38297027c852
# Author: Gary Gregory <gardgregory@gmail.com>
# Date:   Tue Aug 27 21:19:15 2019 -0400
#
#     [COMPRESS-493] Update optional library com.github.luben:zstd-jni from
#     1.4.0-1 to 1.4.3-1.
#
# commit a98d68e2b5c7b018db5153eb37ba38297027c852 30a27cfad69f67ef4779a780b54f697bcf48105e
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Aug 27 21:13:56 2019 +0200
#
#     record CVE-2019-12402
#
# commit 30a27cfad69f67ef4779a780b54f697bcf48105e 352829af6b0486716a683921c2642f30c023bff9
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sat Aug 24 13:30:35 2019 +0200
#
#     merge 1.19 tag, prepare for next iteration
#
# commit 352829af6b0486716a683921c2642f30c023bff9 6615be084bf20b0044fbd8cb8ac869340e1336d9
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed Aug 21 07:16:55 2019 +0200
#
#     COMPRESS-478 record changes
#
# commit 6615be084bf20b0044fbd8cb8ac869340e1336d9 2492bbe8f95f25b86b863ec61487fcfdd26fe3a1
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Mon Aug 19 22:06:49 2019 +0200
#
#     COMPRESS-231 document how to read 7z multi volume archives
#
# commit 2492bbe8f95f25b86b863ec61487fcfdd26fe3a1 f5d0bb1e287038de05415ca65145d82166a7bf0f
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun Aug 18 18:04:43 2019 +0200
#
#     typo
#
# commit f5d0bb1e287038de05415ca65145d82166a7bf0f a9aabdd9ef5e822710734aafde1a90e4b619ce78
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun Aug 18 12:41:50 2019 +0200
#
#     COMPRESS-483 throw exception if stored DD doesn't match what has been read
#
# commit a9aabdd9ef5e822710734aafde1a90e4b619ce78 9584bcfd7105761d2c0b885f1042ad0d26b15b68
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun Aug 18 12:05:30 2019 +0200
#
#     COMPRESS-482 document change
#
# commit 9584bcfd7105761d2c0b885f1042ad0d26b15b68 91c2f0df50e86c65131cf9b83f1cba2e10c9786f
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sat Aug 17 12:40:33 2019 +0200
#
#     COMPRESS-479 document the change in zip extra field parsing
#
# commit 91c2f0df50e86c65131cf9b83f1cba2e10c9786f 58364058bd2903ebd1568f6df22161e142a0dc86
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun May 12 14:29:29 2019 +0200
#
#     COMPRESS-486 deal with resouce leaks in example code
#
# commit 58364058bd2903ebd1568f6df22161e142a0dc86 c5039b52e9f92ed6ec96d35a6848240d19244deb
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu Aug 8 18:28:41 2019 +0200
#
#     COMPRESS-490 throw IOException for certain malformed archives
#
# commit c5039b52e9f92ed6ec96d35a6848240d19244deb 4a101225290705e8739fe424a41aaa3b3eadc47d
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu Aug 8 11:19:20 2019 +0200
#
#     COMPRESS-485 record second part
#
# commit 4a101225290705e8739fe424a41aaa3b3eadc47d 4ff3be9b086073434049fd179a56c1bb68eee1b8
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed Aug 7 16:03:43 2019 +0200
#
#     COMPRESS-485 record change
#
# commit 4ff3be9b086073434049fd179a56c1bb68eee1b8 5a2524813bb7eac718bf8f3f15b55228d14a120c
# Author: Gary Gregory <gardgregory@gmail.com>
# Date:   Thu Jun 6 10:08:03 2019 -0400
#
#     Name "Apache Commons" in page title.
#
# commit 5a2524813bb7eac718bf8f3f15b55228d14a120c bb721bf66df933821489ef8a799103530c940132
# Author: Gary Gregory <gardgregory@gmail.com>
# Date:   Tue Apr 30 17:22:21 2019 -0400
#
#     [COMPRESS-484] Update optional library zstd-jni from 1.3.3-3 to 1.4.0-1.
#
#     Local build on Java 7 OK.
#
# commit bb721bf66df933821489ef8a799103530c940132 8712134c7a94daa52c10020976a306a4e84861c3
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu Apr 18 18:21:34 2019 +0200
#
#     forgot to record issue number for COMPRESS-481
#
# commit 8712134c7a94daa52c10020976a306a4e84861c3 15692dfd35975c93385c24379e2cea733da99033
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu Apr 18 18:19:44 2019 +0200
#
#     add a few ARJ constants stemming from more recent spec
#
# commit 15692dfd35975c93385c24379e2cea733da99033 476d47a8c7a0d63bfb14400fc369ff9f00f015aa
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Apr 16 15:42:00 2019 +0200
#
#     record change
#
# commit 476d47a8c7a0d63bfb14400fc369ff9f00f015aa 76f428958f83348692a67e9f41b86cbc7ee83878
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Mon Feb 18 18:10:38 2019 +0100
#
#     record #74
#
# commit 76f428958f83348692a67e9f41b86cbc7ee83878 2f75fbb5269bd5b2c7b799b7a4f93992fa1f9196
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sat Dec 15 18:42:47 2018 +0100
#
#     COMPRESS-475 implement equals and hashCode
#
# commit 2f75fbb5269bd5b2c7b799b7a4f93992fa1f9196 fd69d8ca2212d373a5a8f220530e8c0fa17ddf3b
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun Nov 18 16:59:31 2018 +0100
#
#     COMPRESS-470 make sure all ScatterZipOutputStreams are closed
#
# commit fd69d8ca2212d373a5a8f220530e8c0fa17ddf3b 14242fe6bbfe3dcb455ccfeaf210d3fef1c0a72f
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sat Nov 10 21:28:54 2018 +0100
#
#     COMPRESS-469 add lenient flag that allows accepting some broken tars
#
# commit 14242fe6bbfe3dcb455ccfeaf210d3fef1c0a72f 0855aec562edfcc58d6da0f07835b05aea7eb324
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun Oct 7 20:11:42 2018 +0200
#
#     COMPRESS-466 allow ZipFile to not parse local file headers
#
# commit 0855aec562edfcc58d6da0f07835b05aea7eb324 a7a95f04bfe2c0a855ff3081099f0ef82d32f35a
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Sep 7 09:51:55 2018 +0200
#
#     record fix, closes #69
#
# commit a7a95f04bfe2c0a855ff3081099f0ef82d32f35a 0c17da1e610e3d4367291cb2c9aac6ca83744675
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu Aug 16 10:13:59 2018 +0200
#
#     Merge tag 'rel/1.18' and prepare next iteration
#
# commit 0c17da1e610e3d4367291cb2c9aac6ca83744675 ba53647bf0fa16501445c7ec50d0ffa4a8288eff
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Aug 10 16:03:32 2018 +0200
#
#     take note of 1.18's changes
#
# commit ba53647bf0fa16501445c7ec50d0ffa4a8288eff a41ce6892cb0590b2e658704434ac0dbcb6834c8
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Aug 10 06:48:35 2018 +0200
#
#     COMPRESS-462 can't read from AR without opening an entry
#
# commit a41ce6892cb0590b2e658704434ac0dbcb6834c8 792da6735e532a6e7f2f2a017d999a8f7c30f2fe
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu Aug 9 20:39:23 2018 +0200
#
#     COMPRESS-463 throw exception when detecting a truncated stored entry
#
# commit 792da6735e532a6e7f2f2a017d999a8f7c30f2fe 430e1267633bf2db0ee1c833c0c5f61f4a45702d
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sat Jul 28 16:24:59 2018 +0200
#
#     COMPRESS-460 rudimentary javadocs and tests
#
#     closes #68
#
# commit 430e1267633bf2db0ee1c833c0c5f61f4a45702d af6fe141036d30bfd1613758b7a9fb413bf2bafc
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed Jul 11 18:52:16 2018 +0200
#
#     COMPRESS-459 record change
#
#     closes #67
#
# commit af6fe141036d30bfd1613758b7a9fb413bf2bafc 16e358e242b41ac350fbd7ad9a93a0cae3e92564
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun Jul 1 13:45:56 2018 +0200
#
#     COMPRESS-455 handle APK Signing Block
#
# commit 16e358e242b41ac350fbd7ad9a93a0cae3e92564 c03704d773dfa0dfc5b2e53b4c198a95d0213ca0
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun Jul 1 11:49:24 2018 +0200
#
#     COMPRESS-457 improve resource cleanup in close() implementations
#
# commit c03704d773dfa0dfc5b2e53b4c198a95d0213ca0 f5571df060ec4223894a45108ede53306bc13595
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Jun 19 17:23:51 2018 +0200
#
#     COMPRESS-456 adapt description to code change
#
# commit f5571df060ec4223894a45108ede53306bc13595 a080293da69f3fe3d11d5214432e1469ee195870
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Jun 19 11:46:17 2018 +0200
#
#     COMPRESS-456 ensure we import all packages we actually need
#
# commit a080293da69f3fe3d11d5214432e1469ee195870 b5401c47f8bc8810b6c404864743d250b2ccc201
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Jun 15 19:44:45 2018 +0200
#
#     fix edge case vulnerability detected by @DidierLoiseau
#
#     While this allows a path traversal attack it can only be exploited in
#     a special edge case.
#
# commit b5401c47f8bc8810b6c404864743d250b2ccc201 83900471ab12dcf424a78fd4584a1d716305a690 c2ace88644826c227191ca52c8d4372a13605e50
# Merge: 83900471 c2ace886
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun Jun 3 15:58:58 2018 +0200
#
#     Merge tag 'rel/1.17' and prepare next iteration
#
#     Tag Commons Compress 1.17
#
# commit 83900471ab12dcf424a78fd4584a1d716305a690 c2ace88644826c227191ca52c8d4372a13605e50
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu May 31 17:47:25 2018 +0200
#
#     typos
#
# commit c2ace88644826c227191ca52c8d4372a13605e50 a1d952c23f4fd1b9aaf94abfaf92218756d865d5
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed May 30 11:30:36 2018 +0200
#
#     COMPRESS-454 search for STORED data descriptor stopped too soon
#
# commit a1d952c23f4fd1b9aaf94abfaf92218756d865d5 6edf2fc723d92d7c2b46f4c703aab49279412d1f
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri May 25 09:47:26 2018 +0200
#
#     COMPRESS-453 record change
#
# commit 6edf2fc723d92d7c2b46f4c703aab49279412d1f 34cf64fac1218c5112e551e686a1a5f1a7c80c32
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu May 10 17:29:23 2018 +0200
#
#     changes report doesn't seem to allow HTML
#
# commit 34cf64fac1218c5112e551e686a1a5f1a7c80c32 0aeda4fcc3c6de7109acd8cf78f8779654b9f771
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed May 9 12:41:55 2018 +0200
#
#     COMPRESS-452 document new constructors
#
# commit 0aeda4fcc3c6de7109acd8cf78f8779654b9f771 ff10aeaaf2e4c343e0182840fb6e154577d1fd6c
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri May 4 06:05:29 2018 +0200
#
#     COMPRESS-451 reject 0 buffersize in IOUtils.copy
#
# commit ff10aeaaf2e4c343e0182840fb6e154577d1fd6c e15c80ae3fafe8903f220a6232c37a77b919c60e
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed May 2 06:18:43 2018 +0200
#
#     wrong ticket number
#
# commit e15c80ae3fafe8903f220a6232c37a77b919c60e ffb618d50a74e316aef01ffa2e381d4617900f3f
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed May 2 06:16:14 2018 +0200
#
#     COMPRESS-443 provide a custom InputStream for special skip problems
#
# commit ffb618d50a74e316aef01ffa2e381d4617900f3f eee4d197d25ad99614cb63445ea71557d6a75c43
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Mon Apr 30 18:13:46 2018 +0200
#
#     COMPRESS-445 provide statistics for 7z as well
#
# commit eee4d197d25ad99614cb63445ea71557d6a75c43 0daa0c9b6afa1d202a0e14b745f6a144c41cac9e
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun Apr 29 12:09:50 2018 +0200
#
#     COMPRESS-445 make most CompressorInputs implement InputStatistics
#
#     the sole exception is pack200 which is kind of special anyway
#
# commit 0daa0c9b6afa1d202a0e14b745f6a144c41cac9e c6689ab7c44dfecafcbfcc6792bcb807bbaf85b2
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed Apr 25 20:27:50 2018 +0200
#
#     COMPRESS-443 record test
#
# commit c6689ab7c44dfecafcbfcc6792bcb807bbaf85b2 bd3e6cf204f249c2d60eca2268c8b9f402149f1b
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun Apr 22 18:25:44 2018 +0200
#
#     COMPRESS-445 document change
#
# commit bd3e6cf204f249c2d60eca2268c8b9f402149f1b 7a8f3c379fdb17fc57484123a5a81b4aeb4cb234
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun Apr 22 17:44:25 2018 +0200
#
#     COMPRESS-447 turn ArrayIndexOutOfBoundsExceptions into ZipExceptions
#
# commit 7a8f3c379fdb17fc57484123a5a81b4aeb4cb234 8faba69945721e10b2bea0acda2db53298ffa124
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun Apr 1 11:12:31 2018 +0200
#
#     record change, closes #63
#
# commit 8faba69945721e10b2bea0acda2db53298ffa124 67c2f681a2966adb2c694bccb33f3d626cf4048a
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu Mar 29 16:09:33 2018 +0200
#
#     COMPRESS-446 fix resource leak in ParallelScatterZipCreator#writeTo.
#
# commit 67c2f681a2966adb2c694bccb33f3d626cf4048a 3d76662cb2c335a1405dde7d80a8e38e2a0ad0b7 b5204113485bf5961c5b09a289c99995974895ff
# Merge: 3d76662c b5204113
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sat Feb 10 09:44:34 2018 +0100
#
#     Merge tag 'rel/1.16.1'
#
#     RC1 of 1.16.1 has been accepted
#
# commit 3d76662cb2c335a1405dde7d80a8e38e2a0ad0b7 c70dc2eb5a6fa2160d91e447b737a243062e41b8
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed Feb 7 15:05:46 2018 +0100
#
#     record removal of objenesis dependency
#
# commit b5204113485bf5961c5b09a289c99995974895ff c70dc2eb5a6fa2160d91e447b737a243062e41b8
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed Feb 7 07:32:46 2018 +0100
#
#     prepare RC1 of 1.16.1
#
# commit c70dc2eb5a6fa2160d91e447b737a243062e41b8 0c644264e0788d514c5e5b357eeb611ae06b162a
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Feb 6 16:32:32 2018 +0100
#
#     COMPRESS-442 fix OSGi manifest
#
# commit 0c644264e0788d514c5e5b357eeb611ae06b162a 66607ddc07ecc319ef7cba0d9994066ad6928b9f
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Mon Feb 5 21:21:04 2018 +0100
#
#     Merge tag 'rel/1.16', prepare for next iteration
#
# commit 66607ddc07ecc319ef7cba0d9994066ad6928b9f d8e4e255d5857260b10edcd33884bf20610895db
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Mon Jan 29 06:21:46 2018 +0100
#
#     optionally preserve the drive letter on Windows
#
# commit d8e4e255d5857260b10edcd33884bf20610895db 43e8d3d5f13209ee0c0bcf4b5a7d785fcae796da
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu Jan 18 14:22:45 2018 +0100
#
#     record changes, closes #61, many thanks to @shahabkondri
#
# commit 43e8d3d5f13209ee0c0bcf4b5a7d785fcae796da c66db899cb061c79934986f0efa19a50ca33703f
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun Jan 14 12:24:20 2018 +0100
#
#     COMPRESS-441 simplify code for zlib dummy byte workarounds
#
# commit c66db899cb061c79934986f0efa19a50ca33703f 738c708be3dbfd99a6ef5c0b486bf0b55e315406
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun Jan 14 12:12:50 2018 +0100
#
#     COMPRESS-436 sanity check compressed size is known for bzip etc
#
# commit 738c708be3dbfd99a6ef5c0b486bf0b55e315406 5b004bfc180ad78ec22247b4209a2a7b70d0745d
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sat Jan 13 16:31:39 2018 +0100
#
#     COMPRESS-437 add read-only DEFLATE64 support to 7z
#
# commit 5b004bfc180ad78ec22247b4209a2a7b70d0745d 49f6547038ca5e0c9aed0db061dff518cfaf240e
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Jan 12 17:26:11 2018 +0100
#
#     COMPRESS-440 record change
#
#     closes #59
#
# commit 49f6547038ca5e0c9aed0db061dff518cfaf240e 3ead67802753cb89870342664f0be43b1b2f989a
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu Jan 11 08:25:12 2018 +0100
#
#     COMPRESS-407 make changed defaults more explicit
#
# commit 3ead67802753cb89870342664f0be43b1b2f989a 135dd48fda61f81d9b8e0aec0661c1d48226ae3c
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed Jan 10 10:31:37 2018 +0100
#
#     changes.xml wasn't well formed
#
# commit 135dd48fda61f81d9b8e0aec0661c1d48226ae3c 6ef3fd45083c60dd35fcd0e61bd417530740aa45
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed Jan 10 10:09:17 2018 +0100
#
#     COMPRESS-438 buffer bounded streams in ZipFile for better performance
#
# commit 6ef3fd45083c60dd35fcd0e61bd417530740aa45 b18ef2a10393824bd9a79c908bda656de4d45006
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed Jan 10 10:05:36 2018 +0100
#
#     COMPRESS-380 lost Christian's name during merge
#
# commit b18ef2a10393824bd9a79c908bda656de4d45006 eb32d62fac68a7b046d32952af9e83c1fc2746c1 87a3cfaf42bc8bdbbde3815947e2b8b4c267beee
# Merge: eb32d62f 87a3cfaf
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Jan 9 18:40:31 2018 +0100
#
#     Merge branch 'COMPRESS-380'
#
# commit eb32d62fac68a7b046d32952af9e83c1fc2746c1 c3be6fb3dda1b433aaf61f5053c5d85370b28e35
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Jan 5 18:01:14 2018 +0100
#
#     record change
#
# commit 87a3cfaf42bc8bdbbde3815947e2b8b4c267beee ecd1fbe0f3857617f75d5e197aba3d25a3f7944f
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Jan 5 14:43:02 2018 +0100
#
#     COMPRESS-380 document DEFLATE64 support
#
# commit c3be6fb3dda1b433aaf61f5053c5d85370b28e35 ecd1fbe0f3857617f75d5e197aba3d25a3f7944f
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu Jan 4 17:54:59 2018 +0100
#
#     Update XZ for Java dependency
#
# commit ecd1fbe0f3857617f75d5e197aba3d25a3f7944f 0691adfaa9eb67a0f7e7f8c6804c55468be0e2e4
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sat Dec 30 11:09:03 2017 +0100
#
#     Revert "update zstd and xz dependencies" - XZ now requires Java8
#
#     This reverts commit 0691adfaa9eb67a0f7e7f8c6804c55468be0e2e4.
#
# commit 0691adfaa9eb67a0f7e7f8c6804c55468be0e2e4 ecb6e94adf85c1e978d2ee040b33dddf475ce4c9
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sat Dec 30 11:02:42 2017 +0100
#
#     update zstd and xz dependencies
#
# commit ecb6e94adf85c1e978d2ee040b33dddf475ce4c9 34b75c6f0ac96df0221bfbd11cafdc62dc0baa79
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sat Dec 30 11:00:42 2017 +0100
#
#     COMPRESS-424 record fix
#
# commit 34b75c6f0ac96df0221bfbd11cafdc62dc0baa79 6ae716d458c52e1fbe205c78edf37af4fbb304cf
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu Dec 28 14:20:16 2017 +0100
#
#     add write support for Zstandard
#
# commit 6ae716d458c52e1fbe205c78edf37af4fbb304cf 9db5028656f9be41ae5809f88ddd4c8ac0b48364
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed Dec 27 15:19:30 2017 +0100
#
#     COMPRESS-432 record fix
#
# commit 9db5028656f9be41ae5809f88ddd4c8ac0b48364 78cb9bf36dab81e15887f451fbc964cf57e94739
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed Dec 27 15:07:37 2017 +0100
#
#     COMPRESS-435 Replaces instanceof checks with a type marker in LZ77 support code.
#
#     Submitted-By: BELUGA BEHR
#
# commit 78cb9bf36dab81e15887f451fbc964cf57e94739 a0aec901f411b4bc26734745297b7651d7e6b9a2
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sat Nov 25 16:56:41 2017 +0100
#
#     record fix for COMPRESS-430
#
#     closes #57
#
# commit a0aec901f411b4bc26734745297b7651d7e6b9a2 099cdc213efa00355f3b6d968423b8ef09fede47
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun Oct 22 07:06:19 2017 +0200
#
#     COMPRESS-425 add auto-detection of Zstandard inputs
#
# commit 099cdc213efa00355f3b6d968423b8ef09fede47 ce5ada6c57eac893ae95a3bffc06eeee3fa07711
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Oct 17 21:07:25 2017 +0200
#
#     COMPRESS-423 it's Zstandard not ZStandard
#
# commit ce5ada6c57eac893ae95a3bffc06eeee3fa07711 129032f46ef3ef0f43966ca6d87936dc1d14b948
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Oct 17 20:34:21 2017 +0200
#
#     COMPRESS-423 documentation for ZStandard
#
# commit 129032f46ef3ef0f43966ca6d87936dc1d14b948 c82dc1fc6238b6f22797c678f10b64c9cd36ddcb
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Oct 17 17:00:43 2017 +0200
#
#     Merge tag 'rel/1.15' and prepare for next iteration
#
#     Create Commons Compress 1.15 release tag
#
# commit c82dc1fc6238b6f22797c678f10b64c9cd36ddcb 5b3ff035f452b6a3f061d9c3919485c59e9c9333
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun Oct 8 18:54:22 2017 +0200
#
#     COMPRESS-409 remove internal buffering from TarArchiveOutputStream
#
# commit 5b3ff035f452b6a3f061d9c3919485c59e9c9333 44177914110cbc8d0c549e29d67cfb0dbe0d11f8
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Oct 6 19:11:17 2017 +0200
#
#     COMPRESS-421 record fix
#
#     closes #54
#
# commit 44177914110cbc8d0c549e29d67cfb0dbe0d11f8 990df6f88794c1fcb44d0244ee38b0dfe2fbf106
# Author: Gary Gregory <garydgregory@gmail.com>
# Date:   Mon Sep 11 13:10:51 2017 -0600
#
#     Typos.
#
# commit 990df6f88794c1fcb44d0244ee38b0dfe2fbf106 934b97e978f03f957bca9fac220bda10fcea9c5e
# Author: Gary Gregory <garydgregory@gmail.com>
# Date:   Mon Sep 11 13:05:40 2017 -0600
#
#     Typo.
#
# commit 934b97e978f03f957bca9fac220bda10fcea9c5e 52cb7925a00115867b6ef2d19c9dd9397d2a1e58
# Author: Gary Gregory <garydgregory@gmail.com>
# Date:   Mon Sep 11 13:04:55 2017 -0600
#
#     Typos.
#
# commit 52cb7925a00115867b6ef2d19c9dd9397d2a1e58 9ae52491c2f3510d83d08489632177b134868fc4
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed Jul 19 13:18:28 2017 +0200
#
#     COMPRESS-417 record change
#
# commit 9ae52491c2f3510d83d08489632177b134868fc4 9052f4df8d3fe61632dbb4f48a257954d2eade81
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed Jul 5 17:33:52 2017 +0200
#
#     COMPRESS-410 record change
#
#     closes #37
#
# commit 9052f4df8d3fe61632dbb4f48a257954d2eade81 5481dd326025de2da7d89089cb969759972e7a8c
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Jul 4 10:56:01 2017 +0200
#
#     COMPRESS-416 document X5455 fix
#
#     closes #48
#
# commit 5481dd326025de2da7d89089cb969759972e7a8c 446843e14a7be6d921bd0076d65092829bed3216
# Author: Simon Spero <sesuncedu@gmail.com>
# Date:   Fri Jun 30 16:01:53 2017 -0700
#
#     [COMPRESS-413] Travis build redundantly repeats compilation and tests
#     redundantly #43. Patch applied except removal of Oracle 7 and 8 from
#     Travis build. Closes #43.
#
# commit 446843e14a7be6d921bd0076d65092829bed3216 53b45071004a33b703f3d8b0bebf28dda62f0f11
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Jun 27 10:50:34 2017 +0200
#
#     COMPRESS-415 fix capitalization of CpioArchive(Entry|InputStream)
#
# commit 53b45071004a33b703f3d8b0bebf28dda62f0f11 fb9b6180428694c45a8befab3ca32834d99acece
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Mon Jun 26 15:22:21 2017 +0200
#
#     COMPRESS-400 record changes
#
#     closes #46
#
# commit fb9b6180428694c45a8befab3ca32834d99acece 8c3201bbd8f10d5162443aa617a7711219f55d46
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sat Jun 24 17:13:24 2017 +0200
#
#     COMPRESS-407 record backwards incompatible change
#
#     closes #40 && closes #41 && closes #42
#
# commit 8c3201bbd8f10d5162443aa617a7711219f55d46 8a6d8a5748d6cce9e0ea748b9cdbf11699e20d18
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sat Jun 17 20:34:27 2017 +0200
#
#     COMPRESS-412 record change.
#
#     closes #35
#
# commit 8a6d8a5748d6cce9e0ea748b9cdbf11699e20d18 0d8ab18c86f4edb38a73de1512483bb5b876bb1f
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu Jun 15 18:19:29 2017 +0200
#
#     record changes for COMPRESS-405
#
#     closes #28
#
# commit 0d8ab18c86f4edb38a73de1512483bb5b876bb1f 1fc6f8b06e513aebc462deb757f7aeb1c5ae50ef
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Mon Jun 12 16:18:26 2017 +0200
#
#     COMPRESS-406 record fix
#
#     closes #29
#
# commit 1fc6f8b06e513aebc462deb757f7aeb1c5ae50ef 6917adc1f9cf7dd4772d866b31e2d9a956fe5255
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue May 23 14:18:31 2017 +0200
#
#     COMPRESS-397 document change
#
# commit 6917adc1f9cf7dd4772d866b31e2d9a956fe5255 d75b89856ef29bbec6784cd6aa714eafe0eeb312
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue May 23 14:13:56 2017 +0200
#
#     COMPRESS-396 bring back OSGi Import-Package for XZ for Java
#
# commit d75b89856ef29bbec6784cd6aa714eafe0eeb312 469752132b291f3174af9679a5eb858aa7c1a04f
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Mon May 22 18:11:06 2017 +0200
#
#     COMPRESS-394/395 use same "version needed to extract" in LFH and CDH
#
#     ... and skip data descriptor when copying raw entries
#
# commit 469752132b291f3174af9679a5eb858aa7c1a04f 86fbbe2884f28e4fcc45db0ba7a7dc898adaf09c
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun May 14 22:28:53 2017 +0200
#
#     Merge tag 'rel/1.14' and prepare for next cycle
#
# commit 86fbbe2884f28e4fcc45db0ba7a7dc898adaf09c abfdf35fa5df95853d0f1f9fe0c60f4a1ae8fdee
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu May 11 20:16:59 2017 +0200
#
#     COMPRESS-391 record fix
#
#     closes #24
#
# commit abfdf35fa5df95853d0f1f9fe0c60f4a1ae8fdee 092bcac5be680480860dbddae4217347b8b14fab
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun May 7 17:10:18 2017 +0200
#
#     COMPRESS-393 don't try to invoke LZMAOutputStream#flush
#
# commit 092bcac5be680480860dbddae4217347b8b14fab a793612b9e09795feb253aab9a738bd1f7280700
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu May 4 16:49:49 2017 +0200
#
#     COMPRESS-390 record change
#
#     closes #22
#
# commit a793612b9e09795feb253aab9a738bd1f7280700 0ee8f1e8ab53746ea9f735aa07e857a0c4e55656
# Author: Philippe Mouawad <p.mouawad@ubik-ingenierie.com>
# Date:   Tue May 2 12:22:04 2017 -0700
#
#     [COMPRESS-392] Add Brotli decoder based on the Google Brotli library.
#
# commit 0ee8f1e8ab53746ea9f735aa07e857a0c4e55656 5def510d00f73b25db8ce44303df49050f99dfbc
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed Apr 26 06:24:43 2017 +0200
#
#     COMPRESS-389 only increment loc when anything has been read
#
# commit 5def510d00f73b25db8ce44303df49050f99dfbc 08f0aba102d494c0b26a9f8c53ca26b792295b23 f668f7bb87d3b0a0ad0642acdbf56d6e2fb18476
# Merge: 08f0aba1 f668f7bb
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Apr 25 20:41:32 2017 +0200
#
#     Merge branch 'COMPRESS-382'
#
#     closes #20
#
# commit 08f0aba102d494c0b26a9f8c53ca26b792295b23 f668f7bb87d3b0a0ad0642acdbf56d6e2fb18476
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Apr 25 20:04:33 2017 +0200
#
#     COMPRESS-388 record merged PR
#
#     closes #21
#
# commit f668f7bb87d3b0a0ad0642acdbf56d6e2fb18476 f05101e28403494b81704029cc50e66703c34151
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Apr 18 17:02:12 2017 +0200
#
#     COMPRESS-387 record changes
#
#     closes #19
#
# commit f05101e28403494b81704029cc50e66703c34151 2cf575115748e9865daaa369507019141573b86c
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Apr 18 16:40:02 2017 +0200
#
#     COMPRESS-385 some tweaks to Tim's code, allow detection of 7z
#
#     closes #18
#
# commit 2cf575115748e9865daaa369507019141573b86c 44d376b737199d42f0d3f195f1c2f82d33b77033
# Author: tballison <tallison@mitre.org>
# Date:   Fri Apr 14 12:35:01 2017 -0400
#
#     COMPRESS-385, add ArchiveStreamFactory; undo boneheaded RELEASE-NOTES.txt fiasco.
#
# commit 44d376b737199d42f0d3f195f1c2f82d33b77033 7b5816d968d05236821832aecb071e891627ea4e
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed Mar 29 14:29:19 2017 +0200
#
#     record Daniel's fix, closes #17
#
# commit 7b5816d968d05236821832aecb071e891627ea4e ea85631d28996451bb8d78cfb03c42147a94c36f c59fc43c527610ae18d7596eb191817ce674cb29
# Merge: ea85631d c59fc43c
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed Feb 15 17:49:20 2017 +0100
#
#     Merge branch 'PR13' closes #13 by @thomasmey
#
# commit ea85631d28996451bb8d78cfb03c42147a94c36f c59fc43c527610ae18d7596eb191817ce674cb29
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Feb 7 21:29:43 2017 +0100
#
#     COMPRESS-271 record LZ4 support
#
# commit c59fc43c527610ae18d7596eb191817ce674cb29 5a5abeeb1bdf4bf7a1930af97d500927caeb39d7
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun Jan 15 22:07:19 2017 +0100
#
#     COMPRESS-379 fix symlink logic
#
# commit 5a5abeeb1bdf4bf7a1930af97d500927caeb39d7 4282bc34d6b64fee1a9f4f55fb14fc6d3fd89521
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Jan 10 17:51:35 2017 +0100
#
#     COMPRESS-358 make block size configurable in framed snappy input
#
# commit 4282bc34d6b64fee1a9f4f55fb14fc6d3fd89521 6ac58a5915cb471ae58c13cf667ad81f574dde34
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Jan 10 15:07:52 2017 +0100
#
#     COMPRESS-378 record fixes to SnappyCompressorInputStream
#
# commit 6ac58a5915cb471ae58c13cf667ad81f574dde34 35891d3b359dc2c402a89989f809950cafdca5d1
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Jan 10 15:07:26 2017 +0100
#
#     COMPRESS-246 support for framed Snappy format
#
# commit 35891d3b359dc2c402a89989f809950cafdca5d1 c497504c0f5952ebebc133e6617d1bd3e808b81e
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu Dec 29 18:53:50 2016 +0100
#
#     bump version
#
# commit c497504c0f5952ebebc133e6617d1bd3e808b81e 85184c3a8945ee1cd22a3fa3a9b8cb71346f2d73
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Dec 20 15:53:00 2016 +0100
#
#     COMPRESS-372 record changes
#
# commit 85184c3a8945ee1cd22a3fa3a9b8cb71346f2d73 726ba6f0f3af7f827d31627088a5e73c93be6aca
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Dec 20 15:39:50 2016 +0100
#
#     COMPRESS-377 properly close StreamCompressor
#
# commit 726ba6f0f3af7f827d31627088a5e73c93be6aca 66726eabfbf22080cab9587696ccb54e1bd82e7a
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Dec 9 23:03:22 2016 +0100
#
#     COMPRESS-367 record Mike Mole's patch
#
# commit 66726eabfbf22080cab9587696ccb54e1bd82e7a 9238eab678395743bce4bd273c4534d10f77f715
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun Dec 4 12:23:36 2016 +0100
#
#     COMPRESS-375 record changes made by Plamen
#
#     closes #12
#
# commit 9238eab678395743bce4bd273c4534d10f77f715 e8cee818c48c3dadcbb9ca643d602fb82e9d1bdd
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Nov 29 22:27:58 2016 +0100
#
#     COMPRESS-374 support writing LZMA in 7z archives
#
# commit e8cee818c48c3dadcbb9ca643d602fb82e9d1bdd 7117039b146155d81857ec29cc48b64324e5f19c
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Nov 29 22:24:07 2016 +0100
#
#     copy paste error
#
# commit 7117039b146155d81857ec29cc48b64324e5f19c 22edc12a0c1b2fa0b73973f375ddf0f0ada672ae
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Nov 29 21:32:08 2016 +0100
#
#     COMPRESS-373 support for writing legacy lzma streams
#
# commit 22edc12a0c1b2fa0b73973f375ddf0f0ada672ae f965bc23bc9f12748b6693424f829b6b08c8a71b
# Author: Gary Gregory <ggregory@apache.org>
# Date:   Tue Nov 15 22:09:39 2016 -0800
#
#     [COMPRESS-369]
#
#     Allow archive extensions through a standard JRE ServiceLoader.
#
# commit f965bc23bc9f12748b6693424f829b6b08c8a71b 57511f57d8ec53663f3ad964582431d6e9c00d9e
# Author: Gary Gregory <ggregory@apache.org>
# Date:   Tue Nov 15 20:20:03 2016 -0800
#
#     [COMPRESS-368]
#
#     Allow compressor extensions through a standard JRE ServiceLoader.
#
# commit 57511f57d8ec53663f3ad964582431d6e9c00d9e 9e32a2ce77b9cc28e1e34dd5efeb9de48f5bc006
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed Oct 12 22:11:05 2016 +0200
#
#     COMPRESS-327 update documentation
#
# commit 9e32a2ce77b9cc28e1e34dd5efeb9de48f5bc006 f0102601d2b949ab63f9f3e6d20618a0b53323ee
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Oct 7 18:20:28 2016 +0200
#
#     record fix for COMPRESS-364
#
# commit f0102601d2b949ab63f9f3e6d20618a0b53323ee 52dd5908e374973d69c51856b74d4d93d591c90a
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Oct 7 17:52:46 2016 +0200
#
#     COMPRESS-366 clarify TarArchiveEntry javadocs
#
# commit 52dd5908e374973d69c51856b74d4d93d591c90a f5a98515ef3b0b5a1318fb6c89cd57177e1e40a4
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Jul 1 21:37:24 2016 +0200
#
#     COMPRESS-363 properly handle overflow inside BitInputStream
#
# commit f5a98515ef3b0b5a1318fb6c89cd57177e1e40a4 f8e09945ea6bd6e59c41f44f0db2afef817a4df2
# Author: Gary Gregory <ggregory@apache.org>
# Date:   Sat Jun 25 13:34:31 2016 -0700
#
#     [COMPRESS-360] Update Java requirement from 6 to 7.
#
# commit f8e09945ea6bd6e59c41f44f0db2afef817a4df2 9a677fbe3bb47b489412a0c381b99cadbadcebd1
# Author: Gary Gregory <ggregory@apache.org>
# Date:   Sat Jun 25 13:34:07 2016 -0700
#
#     [COMPRESS-360] Update Java requirement from 6 to 7.
#
# commit 9a677fbe3bb47b489412a0c381b99cadbadcebd1 712e7c106d43b920399c0c909ca4d5fa3e51c384
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Jun 21 21:27:57 2016 +0200
#
#     Bump to next development version
#
# commit 712e7c106d43b920399c0c909ca4d5fa3e51c384 2424036c286f0b3dfc280f00a1e835cb52e39375
# Author: Sebb <sebb@apache.org>
# Date:   Wed Jun 15 12:57:09 2016 +0100
#
#     Note re finalizer guarantee
#
# commit 2424036c286f0b3dfc280f00a1e835cb52e39375 f87a7ce9321b4901a77786387cfe8026f1249721
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed Jun 15 06:16:39 2016 +0200
#
#     COMPRESS-357 - no longer invoke finish from finalize
#
# commit f87a7ce9321b4901a77786387cfe8026f1249721 8769bb6980ea9d46f8fbec1fa1075128d6f61936
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sat Jun 11 17:27:25 2016 +0200
#
#     Revert "fix COMPRESS-357 with a volatile flag"
#
#     This reverts commit 8769bb6980ea9d46f8fbec1fa1075128d6f61936.
#
# commit 8769bb6980ea9d46f8fbec1fa1075128d6f61936 c86cc39af6dcae9bb67e7015fa25f3469c7bcf02
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Jun 10 14:59:28 2016 +0200
#
#     fix COMPRESS-357 with a volatile flag
#
# commit c86cc39af6dcae9bb67e7015fa25f3469c7bcf02 b5071c2f8bcaa96cc9efb0214b2896cc26996ca9
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu Jun 9 20:56:11 2016 +0200
#
#     record COMPRESS-352 as fixed
#
# commit b5071c2f8bcaa96cc9efb0214b2896cc26996ca9 57107c0192b3b4e279a3c7ddbce0234b71190266
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Jun 7 18:46:10 2016 +0200
#
#     COMPRESS-351 CPIO InputStream sanitizes file names now
#
# commit 57107c0192b3b4e279a3c7ddbce0234b71190266 952a50372dea32e78800b5127ce3e969ce8ba5f0
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri May 27 06:17:48 2016 +0200
#
#     typo in method name
#
# commit 952a50372dea32e78800b5127ce3e969ce8ba5f0 823cdee9b18508e9e51913d110a20a406f55582b
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu May 26 17:02:01 2016 +0200
#
#     COMPRESS-357 better synchronize finished method
#
# commit 823cdee9b18508e9e51913d110a20a406f55582b 19a620c904587dc0397b43bfe9071ff60033c097
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri May 20 18:42:10 2016 +0200
#
#     COMPRESS-356 properly deal with PAX header entries ending in slash
#
#     Suggested-by: Jeremy Gustie <jeremy at gustie dot com>
#
# commit 19a620c904587dc0397b43bfe9071ff60033c097 f59dd65ca1858641dc8fff4a5d28d23a0eb86de8
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri May 20 18:18:05 2016 +0200
#
#     COMPRESS-355 properly deal with blank PAX header lines
#
#     Patch-by: Jeremy Gustie
#
# commit f59dd65ca1858641dc8fff4a5d28d23a0eb86de8 3083ea535f6d76c93825d7a7bd1dbea227f447a5
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Mon May 16 06:25:44 2016 +0200
#
#     assuming COMPRESS-348 is fixed now
#
# commit 3083ea535f6d76c93825d7a7bd1dbea227f447a5 59e7352a4a44087ec34ad94d0842619b1be8dd43
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Mon May 16 06:20:44 2016 +0200
#
#     COMPRESS-354 make PureJavaCrc32C final
#
# commit 59e7352a4a44087ec34ad94d0842619b1be8dd43 ed12d59522a0a1db296584668fe76576b42f23b8
# Author: ggregory <ggregory@apache.org>
# Date:   Fri May 6 10:27:26 2016 -0700
#
#     [COMPRESS-353] Javadoc for
#     BZip2CompressorInputStream.BZip2CompressorInputStream(InputStream,
#     boolean) should refer to IOEx, not NPE.
#
# commit ed12d59522a0a1db296584668fe76576b42f23b8 c84c34e862a02bcb43b7db77f9f6da9b93ed9d70
# Author: ggregory <ggregory@apache.org>
# Date:   Fri May 6 10:27:10 2016 -0700
#
#     [COMPRESS-353] Javadoc for
#     BZip2CompressorInputStream.BZip2CompressorInputStream(InputStream,
#     boolean) should refer to IOEx, not NPE.
#
# commit c84c34e862a02bcb43b7db77f9f6da9b93ed9d70 9cc0604f7fdab2b23ead5f72a93feb2196660736
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sat Apr 9 18:42:27 2016 +0200
#
#     statement similar to what we did when we required Java5
#
# commit 9cc0604f7fdab2b23ead5f72a93feb2196660736 35d616f8e3d5ac2af4e982bc5092f71ac67485ec
# Author: ggregory <ggregory@apache.org>
# Date:   Sat Apr 9 09:10:36 2016 -0700
#
#     [COMPRESS-350] TarArchiveEntry wastefully allocates empty arrays.
#
# commit 35d616f8e3d5ac2af4e982bc5092f71ac67485ec 3cbd999cfb7a92e5b5cc536cc3c0e1089460ab2c
# Author: ggregory <ggregory@apache.org>
# Date:   Sat Apr 9 09:02:59 2016 -0700
#
#     [COMPRESS-349] Update requirement from Java 5 to 6.
#
# commit 3cbd999cfb7a92e5b5cc536cc3c0e1089460ab2c 62f86d5c1eed6e2c294524a4bf472e5ea17eecd6
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed Apr 6 06:17:14 2016 +0200
#
#     Merge tag 'rel/1.11' and bump version
#
# commit 62f86d5c1eed6e2c294524a4bf472e5ea17eecd6 c37115b71e2a04d2266dbfa7b2962f03c49ef5da
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed Mar 23 21:12:06 2016 +0100
#
#     COMPRESS-346 support star PAX headers for sparse files
#
# commit c37115b71e2a04d2266dbfa7b2962f03c49ef5da af2da2e151a8c76e217bc239616174cafbb702ec
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed Mar 23 20:55:37 2016 +0100
#
#     COMPRESS-347 support for global PAX headers
#
# commit af2da2e151a8c76e217bc239616174cafbb702ec a5eca568368b287f875149133a7ff6029b07aad8
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed Mar 23 18:29:33 2016 +0100
#
#     COMPRESS-345 add support for GNU sparse files using PAX dialects
#
# commit a5eca568368b287f875149133a7ff6029b07aad8 9ff8334ff25822f70a8313e14c8499891dc47688
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Mar 22 18:14:07 2016 +0100
#
#     COMPRESS-344 accept NUL as terminator for GNU extended names
#
# commit 9ff8334ff25822f70a8313e14c8499891dc47688 6e9acfa668f1a10bc8cb9a3542531f8ae3e043ff
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun Mar 20 21:11:36 2016 +0100
#
#     COMPRESS-341 listing of 7z archives
#
# commit 6e9acfa668f1a10bc8cb9a3542531f8ae3e043ff c02b2d50ebc6609518841321bdc8edad80e2ef87
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu Mar 17 10:32:00 2016 +0100
#
#     record fix for COMPRESS-343
#
#     closes #11
#
# commit c02b2d50ebc6609518841321bdc8edad80e2ef87 687b360f8c6d9ba2fd7dcf399cae9eb9e49b49dd
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Mar 15 21:32:36 2016 +0100
#
#     created a separate issue for "skipping" in COMPRESS-340
#
# commit 687b360f8c6d9ba2fd7dcf399cae9eb9e49b49dd 1d66f12089aadbc90924ecad82e974d0491d62b4
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sat Mar 5 21:57:21 2016 +0100
#
#     record change, closes #10
#
# commit 1d66f12089aadbc90924ecad82e974d0491d62b4 32633c39ffe7aa2ba24899877c7425803b10444d
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed Feb 24 15:53:21 2016 +0100
#
#     document Dawid's changes
#
#     closes #8
#
# commit 32633c39ffe7aa2ba24899877c7425803b10444d 7250daa429020181bb5a4c40d1aaa169631b8496
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun Feb 14 12:03:15 2016 +0100
#
#     COMPRESS-336 properly parse prefix in xstar tar headers
#
# commit 7250daa429020181bb5a4c40d1aaa169631b8496 36335e3face4b866c7bb88b39fa8a99959d0a907
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Feb 5 21:20:19 2016 +0100
#
#     COMPRESS-335 yet another strange case of tar checksum
#
# commit 36335e3face4b866c7bb88b39fa8a99959d0a907 b67a14697fcf363bc2d7f18407e51b12ca05c1a9
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Feb 5 18:30:46 2016 +0100
#
#     COMPRESS-334 ArArchiveInputStream fails for BSD long names
#
# commit b67a14697fcf363bc2d7f18407e51b12ca05c1a9 1fb42987de0d21c9b6777272320b64230eadb277
# Author: Torsten Curdt <tcurdt@vafer.org>
# Date:   Wed Feb 3 15:32:11 2016 +0100
#
#     Added buffering for random access which speeds up 7Z support. (by Dawid Weiss)
#
#     fixes https://github.com/apache/commons-compress/pull/7
#
# commit 1fb42987de0d21c9b6777272320b64230eadb277 7a6e507dcd5788e3c41e6c249f505283c9f4adf0
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun Jan 31 13:12:31 2016 +0100
#
#     COMPRESS-331 make tar checksum check as strict as GNU tar
#
# commit 7a6e507dcd5788e3c41e6c249f505283c9f4adf0 e0a76ac46cc6a65c3eb33404edb8e6341b5f6199
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Jan 29 21:58:12 2016 +0100
#
#     COMPRESS-323 ZipFile.getRawInputStream is public now
#
# commit e0a76ac46cc6a65c3eb33404edb8e6341b5f6199 30f1ac1dcf7c333bbf5f2aa77e143f001216130c
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Jan 29 21:43:35 2016 +0100
#
#     record two changes made over the past two weeks
#
# commit 30f1ac1dcf7c333bbf5f2aa77e143f001216130c af72adb563d105c7a7d816619d2c6686fc3ce0e8
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Jan 29 21:33:45 2016 +0100
#
#     COMPRESS-332 snappy stream returns 0 when it should return -1
#
# commit af72adb563d105c7a7d816619d2c6686fc3ce0e8 a184b3ad1ec5977a896c9e8971a65c1efb0ca948
# Author: Kristian Rosenvold <krosenvold@apache.org>
# Date:   Sat Nov 14 10:20:16 2015 +0100
#
#     Fixed typo
#
# commit a184b3ad1ec5977a896c9e8971a65c1efb0ca948 a2cda30be14b3da01cbbbedc41b70daf6d88da8b
# Author: Stefan Bodewig <stefan.bodewig@innoq.com>
# Date:   Wed Nov 11 06:21:25 2015 +0100
#
#     record read-only support for ZIP
#
#     closes #4
#
# commit a2cda30be14b3da01cbbbedc41b70daf6d88da8b 1e592b52c54ff3186b5d11fe64021ab758db7234
# Author: Stefan Bodewig <stefan.bodewig@innoq.com>
# Date:   Sat Oct 24 08:18:59 2015 +0200
#
#     COMPRESS-326 adjust tests to changes in Java's zip package
#
# commit 1e592b52c54ff3186b5d11fe64021ab758db7234 1930eed89459d1ea726762e362143a5aa2ccaeb4
# Author: Stefan Bodewig <stefan.bodewig@innoq.com>
# Date:   Sun Oct 11 10:13:57 2015 +0200
#
#     COMPRESS-324 document why tars may look like they do
#
# commit 1930eed89459d1ea726762e362143a5aa2ccaeb4 e6e24766377e705e89358fb9cf6253e2e9e645db
# Author: Stefan Bodewig <stefan.bodewig@innoq.com>
# Date:   Tue Oct 6 05:37:28 2015 +0200
#
#     COMPRESS-324 be more lenient when detecting GNU tar extensions
#
# commit e6e24766377e705e89358fb9cf6253e2e9e645db b1e2a02c09936e604d8f5259ad7a0cf9ab99e55d
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sat Aug 22 19:01:32 2015 +0000
#
#     COMPRESS-321 X7875_NewUnix doesn't handle centra directory correctly
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1697106 13f79535-47bb-0310-9956-ffa450edef68
#
# commit b1e2a02c09936e604d8f5259ad7a0cf9ab99e55d 8682c8d4f2281f838765a213d0241366255c99a0
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Aug 18 17:49:15 2015 +0000
#
#     prepare for new development
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1696469 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 8682c8d4f2281f838765a213d0241366255c99a0 b72b5c716ac18150396d05988d9eab745bea02b9
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Jun 9 04:18:23 2015 +0000
#
#     COMPRESS-317 ArrayIndexOutOfBoundsException in ZipArchiveEntry#getMergedFields
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1684309 13f79535-47bb-0310-9956-ffa450edef68
#
# commit b72b5c716ac18150396d05988d9eab745bea02b9 3c4a09bf28e7cd600b919b8c799fbbfd19a94c0b
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sat May 23 15:05:43 2015 +0000
#
#     COMPRESS-316 detect DEFLATE streams with ZLIB header, submitted by Nick Burch
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1681356 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 3c4a09bf28e7cd600b919b8c799fbbfd19a94c0b 24a3100e9897837b513a0d9f2ae26fd02ec91246
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri May 8 19:11:27 2015 +0000
#
#     COMPRESS-314 read group/user ids > 0x80000000 from (posix) tars
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1678430 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 24a3100e9897837b513a0d9f2ae26fd02ec91246 6e8bb88263dd64b703679bf853c15f40ac07e347
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed May 6 04:32:48 2015 +0000
#
#     COMPRESS-315 allow tar entries with gid/uid > Integer.MAX_INT
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1677921 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 6e8bb88263dd64b703679bf853c15f40ac07e347 f24b9fd5ca348d8c482c3c50499c3e9582edb1f9
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Mon Mar 30 15:59:17 2015 +0000
#
#     COMPRESS-313 add auto-detection for LZMA streams
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1670129 13f79535-47bb-0310-9956-ffa450edef68
#
# commit f24b9fd5ca348d8c482c3c50499c3e9582edb1f9 31b546aecd87725c8a1274d1485cee89bdddfdce
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sat Mar 28 19:00:01 2015 +0000
#
#     sort 1.10 changelog entries by date
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1669823 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 31b546aecd87725c8a1274d1485cee89bdddfdce af1f8163af8b52bc28a18109858744967935d828
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sat Mar 28 18:58:16 2015 +0000
#
#     COMPRESS-312 normalize filename in TarArchiveEntry's (File, String) constructor
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1669822 13f79535-47bb-0310-9956-ffa450edef68
#
# commit af1f8163af8b52bc28a18109858744967935d828 4355c0d224342b5c94881b7aabb441f765867dfe
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Feb 20 16:44:36 2015 +0000
#
#     don't read system properties for default charset - COMPRESS-308
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1661157 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 4355c0d224342b5c94881b7aabb441f765867dfe 5cf68bdc46c7bcc0fc5eb3cacd1c84514ef552cf
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Feb 20 16:21:26 2015 +0000
#
#     add/fix a few dates in changes report
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1661153 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 5cf68bdc46c7bcc0fc5eb3cacd1c84514ef552cf d50feb67569fb5881b8a2ff5996f656c5f207c2e
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Feb 20 16:18:00 2015 +0000
#
#     return 0 from read when asked to read 0 bytes - COMPRESS-309
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1661151 13f79535-47bb-0310-9956-ffa450edef68
#
# commit d50feb67569fb5881b8a2ff5996f656c5f207c2e 0b33b14271675a78b8bc2e538089af2ecde7d2a0
# Author: Sebastian Bazley <sebb@apache.org>
# Date:   Mon Feb 16 23:13:01 2015 +0000
#
#     COMPRESS-306 ArchiveStreamFactory fails to pass on the encoding when creating some streams.
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1660245 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 0b33b14271675a78b8bc2e538089af2ecde7d2a0 121cae778dcb63a4ca4f1ee2743e58bffcbfe4be
# Author: Sebastian Bazley <sebb@apache.org>
# Date:   Sun Feb 15 23:09:26 2015 +0000
#
#     COMPRESS-302 Restore immutability/thread-safety to ArchiveStreamFactory.
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1660005 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 121cae778dcb63a4ca4f1ee2743e58bffcbfe4be 8e7d71fce1aed00ffdfea85629fdf0d5da0b1186
# Author: Sebastian Bazley <sebb@apache.org>
# Date:   Sun Feb 15 22:49:01 2015 +0000
#
#     COMPRESS-303 Restore immutability/thread-safety to CompressorStreamFactory.
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1660002 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 8e7d71fce1aed00ffdfea85629fdf0d5da0b1186 e0c0a10d271cc8bd9ccf4cf029e8e03ab0c96ecb
# Author: Sebastian Bazley <sebb@apache.org>
# Date:   Sun Feb 15 22:42:13 2015 +0000
#
#     Easier to read outline in Eclipse IDE if issue number is put first
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1660000 13f79535-47bb-0310-9956-ffa450edef68
#
# commit e0c0a10d271cc8bd9ccf4cf029e8e03ab0c96ecb 70900a3cf93480fa95d4716b40eeb6a2d5f85f92
# Author: Sebastian Bazley <sebb@apache.org>
# Date:   Wed Feb 4 19:05:30 2015 +0000
#
#     Synch with RN contents
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1657373 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 70900a3cf93480fa95d4716b40eeb6a2d5f85f92 e707c8233405d1a2eda96649f0fbcb10b623386b
# Author: Kristian Rosenvold <krosenvold@apache.org>
# Date:   Tue Jan 20 16:20:26 2015 +0000
#
#     Updated changes.xml, fixed a small javadoc issue
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1653282 13f79535-47bb-0310-9956-ffa450edef68
#
# commit e707c8233405d1a2eda96649f0fbcb10b623386b 8aa559f2da10a595d114bd4890197a5a81d3d8ed
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Jan 20 14:24:34 2015 +0000
#
# ...
#
# commit 8376ecf5e6ff140f3836c51a910b89504e1c3300 86aaf84a2ba3f4687aee130d0bb1834e465662bc
# Author: Sebastian Bazley <sebb@apache.org>
# Date:   Wed Mar 23 11:06:43 2011 +0000
#
#     COMPRESS-127 Calling close() on inputStream returned by CompressorStreamFactory.createCompressorInputStream() does not close the underlying input stream
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1084536 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 86aaf84a2ba3f4687aee130d0bb1834e465662bc 7dd4301ee74455a83d12aec87caa08f2be1b3539
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Oct 29 15:03:49 2010 +0000
#
#     provide access to TarArchiveEntry's knowledge of the entry's type.  COMPRESS-122
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1028793 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 7dd4301ee74455a83d12aec87caa08f2be1b3539 1eb9dbb7fd336b1e8a160977722b570354040798
# Author: Sebastian Bazley <sebb@apache.org>
# Date:   Thu Oct 28 14:15:27 2010 +0000
#
#     typo
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1028305 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 1eb9dbb7fd336b1e8a160977722b570354040798 75c871141d7505bb25b8d1e272097997be0ba32a
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Oct 26 09:44:59 2010 +0000
#
#     write all buffered data to the stream in TarArchiveOutputStream#finish.  COMPRESS-119
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1027427 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 75c871141d7505bb25b8d1e272097997be0ba32a 35e4e4fb6848ddfa3878270523f3f9336ae7f9b8
# Author: Sebastian Bazley <sebb@apache.org>
# Date:   Wed Jun 2 11:15:23 2010 +0000
#
#     COMPRESS-72 - Move acknowledgements from NOTICE to README
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@950496 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 35e4e4fb6848ddfa3878270523f3f9336ae7f9b8 78e0f2c74ce4436afc2b39112f35fa6f23c6387c
# Author: Sebastian Bazley <sebb@apache.org>
# Date:   Wed Jun 2 11:00:25 2010 +0000
#
#     COMPRESS-113:  TarArchiveEntry.parseTarHeader() includes the trailing space/NUL when parsing the octal size
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@950489 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 78e0f2c74ce4436afc2b39112f35fa6f23c6387c dfc6638392f80bf8c15ee7781951fbe1f072d772
# Author: Sebastian Bazley <sebb@apache.org>
# Date:   Tue Jun 1 16:38:13 2010 +0000
#
#     Another fix
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@950152 13f79535-47bb-0310-9956-ffa450edef68
#
# commit dfc6638392f80bf8c15ee7781951fbe1f072d772 050db3da30466df67787f59c8d4d035cde17c79a
# Author: Sebastian Bazley <sebb@apache.org>
# Date:   Sun May 23 11:53:07 2010 +0000
#
#     COMPRESS-108: add initial implementation of command-line interface to list archive contents
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@947399 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 050db3da30466df67787f59c8d4d035cde17c79a c83d9f7180cc9c9dcacc3326068d5a323ea9876d
# Author: Sebastian Bazley <sebb@apache.org>
# Date:   Mon May 17 15:09:29 2010 +0000
#
#     COMPRESS-118:  TarUtils.parseName does not properly handle characters outside the range 0-127
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@945200 13f79535-47bb-0310-9956-ffa450edef68
#
# commit c83d9f7180cc9c9dcacc3326068d5a323ea9876d 27dea24d42f04c5b9ebb7d7e283165edc34bddb7
# Author: Sebastian Bazley <sebb@apache.org>
# Date:   Thu May 13 10:25:15 2010 +0000
#
#     COMPRESS-112 ArArchiveInputStream does not handle GNU extended filename records (//)
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@943863 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 27dea24d42f04c5b9ebb7d7e283165edc34bddb7 23bfa665c08ed98fd39e2148479b597954f6978f
# Author: Sebastian Bazley <sebb@apache.org>
# Date:   Mon May 10 17:42:37 2010 +0000
#
#     Trailing spaces
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@942829 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 23bfa665c08ed98fd39e2148479b597954f6978f 8fcd06e4148cf1b77b1136864b37f62be0a443ff
# Author: Sebastian Bazley <sebb@apache.org>
# Date:   Mon May 10 15:10:27 2010 +0000
#
#     Update changes list
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@942781 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 8fcd06e4148cf1b77b1136864b37f62be0a443ff 58c4dad1a6d9a0836c5e33b088a8349d3fffa7e2
# Author: Sebastian Bazley <sebb@apache.org>
# Date:   Sun May 9 20:46:59 2010 +0000
#
#     COMPRESS-110 Support "ustar" prefix field
#     Document change
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@942618 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 58c4dad1a6d9a0836c5e33b088a8349d3fffa7e2 69f6d0616db4c2ea41b0a9ef48b4e64f84009e50
# Author: Sebastian Bazley <sebb@apache.org>
# Date:   Wed May 5 13:42:00 2010 +0000
#
#     Remove reference to removal of method that was never released
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@941285 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 69f6d0616db4c2ea41b0a9ef48b4e64f84009e50 6021ccbca53627d09fc34b889dc4f0dcb3248887
# Author: Sebastian Bazley <sebb@apache.org>
# Date:   Wed May 5 10:59:58 2010 +0000
#
#     Recent changes
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@941242 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 6021ccbca53627d09fc34b889dc4f0dcb3248887 886f71b43dbbe2a7d234b70386f65527507f7d84
# Author: Sebastian Bazley <sebb@apache.org>
# Date:   Wed Apr 14 00:49:28 2010 +0000
#
#     Add profile "relnotes" so can optionally override changes plugin template.
#     This means that the changes plugin can still be used to generate the announcement.
#     Changes plugin does not need to be mentioned in build section.
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@933821 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 886f71b43dbbe2a7d234b70386f65527507f7d84 48882f1d95ae3c171b2ff8806e4a16ffca442b37
# Author: Sebastian Bazley <sebb@apache.org>
# Date:   Tue Apr 13 21:21:03 2010 +0000
#
#     Synch with JIRA Fix versions
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@933782 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 48882f1d95ae3c171b2ff8806e4a16ffca442b37 03e94a450fcd6e8b4d185caee3cb6b693c34d8ae
# Author: Sebastian Bazley <sebb@apache.org>
# Date:   Tue Apr 13 21:02:37 2010 +0000
#
#     Add release-notes.vm for generating RELEASE-NOTES.txt
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@933780 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 03e94a450fcd6e8b4d185caee3cb6b693c34d8ae 62cb9c480ecd71491e6b2452ff8add4d35706290
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Mar 19 15:08:23 2010 +0000
#
#     optionally read STORED entries with data descriptors.  COMPRESS-103
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@925257 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 62cb9c480ecd71491e6b2452ff8add4d35706290 d7ea9ff05a28a73508b57f369a0b06b3fab46479
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Mar 12 16:06:20 2010 +0000
#
#     provide access to the general purpose bit flag field of a zip entry and fail when a STORED entry requires a data descriptor.  COMPRESS-100
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@922309 13f79535-47bb-0310-9956-ffa450edef68
#
# commit d7ea9ff05a28a73508b57f369a0b06b3fab46479 30e1cc85c49860d3f5f26d35c7a90e840f3efe95
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Mar 12 15:35:44 2010 +0000
#
#     Check a data descriptor actually uses the signature before skipping too many bytes if it doesn't.  COMPRESS-101
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@922298 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 30e1cc85c49860d3f5f26d35c7a90e840f3efe95 ade937933227766ae2c5fdc41fb842a33f7a36c5
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Mar 9 11:23:41 2010 +0000
#
#     provide more information if an entry cannot be read/written.  OCMPRESS-98
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@920808 13f79535-47bb-0310-9956-ffa450edef68
#
# commit ade937933227766ae2c5fdc41fb842a33f7a36c5 292e185188ed2d8a1c2d1a13ef0c5f4f28a7aedf
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Mon Mar 8 12:00:25 2010 +0000
#
#     return Zipentries in predictable order.  COMPRESS-99
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@920286 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 292e185188ed2d8a1c2d1a13ef0c5f4f28a7aedf e0692eca48f9b86131d41ec6697c7f2d14715b0b
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu Mar 4 15:54:09 2010 +0000
#
#     make archive/compressor name constants public.
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@919035 13f79535-47bb-0310-9956-ffa450edef68
#
# commit e0692eca48f9b86131d41ec6697c7f2d14715b0b 9e94237b80053da48c888ee5333ceee602271da0
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed Feb 24 15:35:47 2010 +0000
#
#     canRead => canReadEntryData as discussed on the list
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@915826 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 9e94237b80053da48c888ee5333ceee602271da0 a33505b5c6bf810025567b1c6ce244cd1c85f078
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Feb 19 12:29:19 2010 +0000
#
#     typo
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@911797 13f79535-47bb-0310-9956-ffa450edef68
#
# commit a33505b5c6bf810025567b1c6ce244cd1c85f078 e0ffbc118e78b263033461bfab6352f29eb76427
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Feb 19 12:23:27 2010 +0000
#
#     move canRead/canWrite up.  Remove isSupportedCompressionMethod.  COMPRESS-93
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@911795 13f79535-47bb-0310-9956-ffa450edef68
#
# commit e0ffbc118e78b263033461bfab6352f29eb76427 a1015f312480c697c8dbc2772e4076eb15e41406
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Feb 19 10:59:01 2010 +0000
#
#     document fix for COMPRESS-89 which was based on a contribution by Antoni Mylka
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@911783 13f79535-47bb-0310-9956-ffa450edef68
#
# commit a1015f312480c697c8dbc2772e4076eb15e41406 315b947350def29078dde98703cb9bdd6734b3a5
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu Feb 18 16:11:13 2010 +0000
#
#     properly count bytes read.  COMPRESS-74
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@911467 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 315b947350def29078dde98703cb9bdd6734b3a5 91695e47a11e0ca7eb09555ea5c06f711d117036
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu Feb 18 14:56:03 2010 +0000
#
#     document fix for COMPRESS-85
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@911427 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 91695e47a11e0ca7eb09555ea5c06f711d117036 124f97c18eb3fc29fd4e03c982905cadac1feb0b
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Feb 16 13:59:03 2010 +0000
#
#     Allow extra fields to violate the recommended structure.  COMPRESS-73
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@910519 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 124f97c18eb3fc29fd4e03c982905cadac1feb0b e7517b8d5d43910f4317a64f549d58b2db21a64c
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Feb 12 11:35:14 2010 +0000
#
#     improve error message for unparseable extra data.  COMPRESS-73
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@909366 13f79535-47bb-0310-9956-ffa450edef68
#
# commit e7517b8d5d43910f4317a64f549d58b2db21a64c 5066e9aeb98f386b29a31cd4acb97aa43844cd30
# Author: Christian Grobmeier <grobmeier@apache.org>
# Date:   Fri Jan 29 07:47:21 2010 +0000
#
#     Applied COMPRESS-95 from Joerg Bellmann: Improve ExceptionMessages in ArchiveStreamFactory
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@904403 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 5066e9aeb98f386b29a31cd4acb97aa43844cd30 dc3fc4703211876fb38cccf55adc92ee5cbc28d0
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu Jan 7 09:34:55 2010 +0000
#
#     ZipArchiveEntry#equals is broken if the String-arg constructor is used.  COMPRESS-94 - submitted by Anon Devs
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@896818 13f79535-47bb-0310-9956-ffa450edef68
#
# commit dc3fc4703211876fb38cccf55adc92ee5cbc28d0 7bb5d8862665e0cc60cee52d2b48ebbd7fca61fd
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Oct 30 05:29:17 2009 +0000
#
#     make ZipArchiveInputStream deal better with truncated archives.  Submitted by Antoni Mylka.  COMPRESS-87
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@831204 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 7bb5d8862665e0cc60cee52d2b48ebbd7fca61fd 3e2ddad124ea6ab1bc690487793bf88560ca3732
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu Oct 8 12:07:19 2009 +0000
#
#     properly indicate "oldgnu" mode for long file name entries in tar.  COMPRESS-86
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@823139 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 3e2ddad124ea6ab1bc690487793bf88560ca3732 7be8ef66c108c3845d387af053606798b2ae2811
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Aug 25 08:11:44 2009 +0000
#
#     The tar Ant task has a usecase where absolute paths inside archives are required - allow creation of such entries
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@807514 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 7be8ef66c108c3845d387af053606798b2ae2811 47b706e15161c22bbd51ed83500bf76d56328c8c
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sat Aug 1 20:25:13 2009 +0000
#
#     document today's changes
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@799918 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 47b706e15161c22bbd51ed83500bf76d56328c8c 2318ba308b4d36c493330c9286a86878bc24af55
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Jun 30 08:23:08 2009 +0000
#
#     Add a BZip2Utils class matching GZipUtils.  Submitted by Jukka Zitting.  COMPRESS-78
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@789607 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 2318ba308b4d36c493330c9286a86878bc24af55 35ac05e632f7a04b98134a75f14e9ac458890b4d
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Jun 30 07:25:44 2009 +0000
#
#     clear block after write to avoid garbage in the final block if it isn't full.  COMPRESS-81.  Merge from Ant.
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@789597 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 35ac05e632f7a04b98134a75f14e9ac458890b4d f03f2f969376c36a344f8486d94672624c78accd
# Author: Christian Grobmeier <grobmeier@apache.org>
# Date:   Sun May 10 17:32:20 2009 +0000
#
#     inital release
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@773369 13f79535-47bb-0310-9956-ffa450edef68
#
# commit f03f2f969376c36a344f8486d94672624c78accd
# Author: Siegfried Goeschl <sgoeschl@apache.org>
# Date:   Mon Mar 23 14:52:23 2009 +0000
#
#     +) Cleaned up the site generation
#     +) enabled Cobetura again
#     +) add PMD reports
#     +) add assembly descriptors
#     +) fixd a few minor issues for moving it to commons-proper
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@757405 13f79535-47bb-0310-9956-ffa450edef68

# %% [markdown]
# commit a41ce6892cb0590b2e658704434ac0dbcb6834c8 792da6735e532a6e7f2f2a017d999a8f7c30f2fe
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu Aug 9 20:39:23 2018 +0200
#
#     COMPRESS-463 throw exception when detecting a truncated stored entry
#
# commit 792da6735e532a6e7f2f2a017d999a8f7c30f2fe 430e1267633bf2db0ee1c833c0c5f61f4a45702d
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sat Jul 28 16:24:59 2018 +0200
#
#     COMPRESS-460 rudimentary javadocs and tests
#
#     closes #68
#
# 12 days

# %%
#h.	How many days were between the current fixing commit and the previous 
#commit of each affected file? Hint: git log
#AffectedFile1
log_data = repo.git.log("--parents",affected_file1).splitlines()
for line in log_data:
    print(line)
# Out:
# commit d3a0a309d902e3639654731e07ccfb51fed9688a b2f97b2460747c82329e1247c59e74d2cfee1cbd
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sat Aug 31 14:18:00 2019 +0200
#
#     COMPRESS-491 InputStream contract says "return 0 if length is 0, don't try to read"
#
# commit b2f97b2460747c82329e1247c59e74d2cfee1cbd f5d0bb1e287038de05415ca65145d82166a7bf0f
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Aug 23 16:55:00 2019 +0200
#
#     avoid NPE warning in Sonar
#
# commit f5d0bb1e287038de05415ca65145d82166a7bf0f d3ed06a07b880fca2ef2610ba1f3d33f7f566caa
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun Aug 18 12:41:50 2019 +0200
#
#     COMPRESS-483 throw exception if stored DD doesn't match what has been read
#
# commit d3ed06a07b880fca2ef2610ba1f3d33f7f566caa 82986dd12fc255d218a6454364a50eb9ae3f812d
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun Aug 18 12:02:58 2019 +0200
#
#     COMPRESS-482 ensure there is enough data available for a DD
#
# commit 82986dd12fc255d218a6454364a50eb9ae3f812d 88e26c9ffac61713372378c6f0225cd1a8b676e9
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun Aug 18 11:57:40 2019 +0200
#
#     COMPRESS-482 stored with data descriptor now works without DD signature
#
# commit 88e26c9ffac61713372378c6f0225cd1a8b676e9 0c4f64c2bebd85a96be8a07b1ad700c7688cbe02
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Aug 13 18:41:40 2019 +0200
#
#     Revert "COMPRESS-479 introduce a parameter class for zip readers"
#
#     This reverts commit 0c4f64c2bebd85a96be8a07b1ad700c7688cbe02.
#
# commit 0c4f64c2bebd85a96be8a07b1ad700c7688cbe02 1b3f112b52d8fdcbfd3bdef9040def01c15f4c5d
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Mon Aug 12 22:15:44 2019 +0200
#
#     COMPRESS-479 introduce a parameter class for zip readers
#
# commit 1b3f112b52d8fdcbfd3bdef9040def01c15f4c5d 087e4a9d51437243eb0a4698b3bd2b71b4567c3e
# Author: Gary Gregory <gardgregory@gmail.com>
# Date:   Thu May 30 14:48:21 2019 -0400
#
#     Javadoc: Use "file name" instead of "filename". Camel case vars
#     "filename" to "fileName".
#
# commit 087e4a9d51437243eb0a4698b3bd2b71b4567c3e a41ce6892cb0590b2e658704434ac0dbcb6834c8
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu Aug 16 14:48:50 2018 +0200
#
#     make Sonar less unhappy
#
# commit a41ce6892cb0590b2e658704434ac0dbcb6834c8 22b0d0629267b88749f78412caea672d6539a5b6
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu Aug 9 20:39:23 2018 +0200
#
#     COMPRESS-463 throw exception when detecting a truncated stored entry
#
# commit 22b0d0629267b88749f78412caea672d6539a5b6 af6fe141036d30bfd1613758b7a9fb413bf2bafc
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun Jul 1 13:46:45 2018 +0200
#
#     whitespace
#
# commit af6fe141036d30bfd1613758b7a9fb413bf2bafc c2ace88644826c227191ca52c8d4372a13605e50
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun Jul 1 13:45:56 2018 +0200
#
#     COMPRESS-455 handle APK Signing Block
#
# commit c2ace88644826c227191ca52c8d4372a13605e50 be86c6236d4cbea207f3a4924687a0bbd99af360
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed May 30 11:30:36 2018 +0200
#
#     COMPRESS-454 search for STORED data descriptor stopped too soon
#
# commit be86c6236d4cbea207f3a4924687a0bbd99af360 0646aa7d4d0ece484e26e8ab262265cc9263c350
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun Apr 22 20:17:33 2018 +0200
#
#     COMPRESS-445 fix stats for Stored entries in ZipArchiveInputStream
#
# commit 0646aa7d4d0ece484e26e8ab262265cc9263c350 02c963a47ecb50a7f84b9711841e60447f9bfcc1
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun Apr 22 18:20:29 2018 +0200
#
#     COMPRESS-445 try to get compressed count for all supported methods
#
# commit 02c963a47ecb50a7f84b9711841e60447f9bfcc1 7778533696b9644be3680228f25fce21e680e364
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun Apr 22 17:58:39 2018 +0200
#
#     COMPRESS-445 provide statistics when uncompressing
#
#     patch by Andreas Beeker
#
# commit 7778533696b9644be3680228f25fce21e680e364 f35ff5f49f9255f1d0dddbf8aa9d810ce51c7f0a
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun Apr 22 16:25:16 2018 +0200
#
#     ensure all skip call go through IOUtils.skip
#
# commit f35ff5f49f9255f1d0dddbf8aa9d810ce51c7f0a c66db899cb061c79934986f0efa19a50ca33703f
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu Mar 8 11:56:01 2018 +0100
#
#     use https in javadoc links where possible
#
# commit c66db899cb061c79934986f0efa19a50ca33703f b18ef2a10393824bd9a79c908bda656de4d45006
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun Jan 14 12:12:50 2018 +0100
#
#     COMPRESS-436 sanity check compressed size is known for bzip etc
#
# commit b18ef2a10393824bd9a79c908bda656de4d45006 d549178f36aaf95fd1aa2fe6a3c1403c095929b2 27b16a26212d5e4b61ebe07c4bd9c36465f56702
# Merge: d549178f 27b16a26
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Jan 9 18:40:31 2018 +0100
#
#     Merge branch 'COMPRESS-380'
#
# commit d549178f36aaf95fd1aa2fe6a3c1403c095929b2 6b12eab8ef3255eed66d2e382411e973883f608a
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Jan 5 17:50:22 2018 +0100
#
#     COMPRESS-429 also set NameSource from within stream
#
# commit 27b16a26212d5e4b61ebe07c4bd9c36465f56702 bca3b08b2779c1bc95d23455bae441dfaf781e83
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Jan 5 13:31:23 2018 +0100
#
#     COMPRESS-380 support data descriptors with ENHANCED_DEFLATED
#
# commit bca3b08b2779c1bc95d23455bae441dfaf781e83 ccc3067f5216630d6c96f21f1ed2ef174aba9bd5
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Jan 5 07:33:14 2018 +0100
#
#     small fixme
#
# commit ccc3067f5216630d6c96f21f1ed2ef174aba9bd5 6b12eab8ef3255eed66d2e382411e973883f608a
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Jan 5 06:52:55 2018 +0100
#
#     COMPRESS-380 add DEFLATE64 support to ZipArchiveInputStream
#
# commit 6b12eab8ef3255eed66d2e382411e973883f608a 19e1b02f754a9b7bc969eb17bd52cc36a85c4d74
# Author: Gary Gregory <garydgregory@gmail.com>
# Date:   Wed Nov 1 16:25:38 2017 -0600
#
#     Remove trailing white spaces on all lines.
#
# commit 19e1b02f754a9b7bc969eb17bd52cc36a85c4d74 3bf400edc1add6078a9bd935e3ae684b8bf8493f
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sat Jun 24 18:46:30 2017 +0200
#
#     silence Sonar where we intentionally break its rules
#
# commit 3bf400edc1add6078a9bd935e3ae684b8bf8493f c61c68d802266e0265a60e81f2eb5ae56e14b315
# Author: Zbynek Vyskovsky <kvr000@gmail.com>
# Date:   Sun Apr 30 22:03:07 2017 -0700
#
#     COMPRESS-390: Expose stream offsets and size
#
# commit c61c68d802266e0265a60e81f2eb5ae56e14b315 6b75de47f629a88aa7962fd2b9a2f1f1c1eaf63c
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Dec 20 15:00:58 2016 +0100
#
#     rename instance fields that look like class fields
#
# commit 6b75de47f629a88aa7962fd2b9a2f1f1c1eaf63c 8705e97fbd1aa9de951456f05dff9ec56c4344b2
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Mon Dec 19 18:39:55 2016 +0100
#
#     silence Sonar where I disagree with it
#
# commit 8705e97fbd1aa9de951456f05dff9ec56c4344b2 f015344879f1bc3505bc616fc7ae517cf9f60838
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Mon Dec 19 18:38:34 2016 +0100
#
#     trivial fixes of "bugs" reported by Sonar
#
# commit f015344879f1bc3505bc616fc7ae517cf9f60838 658812c85fe762e361c998161cfb61bd477e1b24
# Author: Mike Mole <michael.mole@lookout.com>
# Date:   Fri Oct 28 08:03:48 2016 -0400
#
#     COMPRESS-367 Throw ZipException on invalid entry with ZipArchiveInputStream
#
#     ZipArchiveInputStream.getNextZipEntry() throws a ZipException rather
#     than returning null if an invalid entry is encountered in order to
#     differentiate between "no more entries" and "error" conditions.
#
# commit 658812c85fe762e361c998161cfb61bd477e1b24 318de9ae84f1731fda8ce0785ae537f149ea5fcf
# Author: Mike Mole <michael.mole@lookout.com>
# Date:   Fri Aug 19 09:08:42 2016 -0400
#
#     ZipArchiveInputStream.closeEntry fails to advance
#
#     Properly advances to next entry upon calling closeEntry when there
#     are extra junk bytes after the compressed data section of a
#     zip entry. This applies to the ZipArchiveInputStream implementation.
#
# commit 318de9ae84f1731fda8ce0785ae537f149ea5fcf ddb8f08c79b8568c9cba3af61fb5a613e0ccba22
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Mon Apr 25 06:31:16 2016 +0200
#
#     COMPRESS-351 extract method that sanitizes file names
#
# commit ddb8f08c79b8568c9cba3af61fb5a613e0ccba22 3f2c760a4eb82d880e62a03cb9450d9dcf2793f7
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun Apr 17 07:06:24 2016 +0200
#
#     COMPRESS-351 try to sanitize entry name in exception message
#
# commit 3f2c760a4eb82d880e62a03cb9450d9dcf2793f7 478bef366f84544eb4ac89553eeb7d57680fc521
# Author: ggregory <ggregory@apache.org>
# Date:   Sat Apr 9 10:10:28 2016 -0700
#
#     Add final modifier to local variables.
#
# commit 478bef366f84544eb4ac89553eeb7d57680fc521 8954b8be675333bafc75f9c3ccbf1839bbff8c62
# Author: ggregory <ggregory@apache.org>
# Date:   Sat Apr 9 10:06:38 2016 -0700
#
#     Add final modifier to method parameters.
#
# commit 8954b8be675333bafc75f9c3ccbf1839bbff8c62 ab85f00b6d327907ee23291979a6998c54cf88ad
# Author: ggregory <ggregory@apache.org>
# Date:   Sat Apr 9 08:59:51 2016 -0700
#
#     Refactor magic string.
#
# commit ab85f00b6d327907ee23291979a6998c54cf88ad f9334473bd9993f38458ecee137ba9e7f7b79abb
# Author: ggregory <ggregory@apache.org>
# Date:   Sat Apr 9 00:55:39 2016 -0700
#
#     These static fields should be accessed directly.
#
# commit f9334473bd9993f38458ecee137ba9e7f7b79abb 6eac426de89fe077a181f39452dee6f6ca4c2f52
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu Mar 17 11:04:08 2016 +0100
#
#     plug a few more native memory leaks
#
#     aftermaths of COMPRESS-343, inspired by #11
#
# commit 6eac426de89fe077a181f39452dee6f6ca4c2f52 9e1ac89660190ec4d895855655891ad16d790fc4
# Author: Sören Glimm <git@uncleowen.de>
# Date:   Tue Nov 10 20:00:20 2015 +0100
#
#     Implement uncompressing of BZip2 compressed entries in ZipArchiveInputStream
#
# commit 9e1ac89660190ec4d895855655891ad16d790fc4 171c3ac8d32ed884392b057800e691a621585d2a
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed Aug 12 03:24:07 2015 +0000
#
#     lots of useless javadoc tags to make site build work on Java8
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1695419 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 171c3ac8d32ed884392b057800e691a621585d2a d50feb67569fb5881b8a2ff5996f656c5f207c2e
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun Aug 9 16:06:09 2015 +0000
#
#     COMPRESS-318 document ZipArchiveInputStream's limitations in the javadocs
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1694895 13f79535-47bb-0310-9956-ffa450edef68
#
# commit d50feb67569fb5881b8a2ff5996f656c5f207c2e deeb355c2253b49f39f0be7bf16de1e119f69581
# Author: Sebastian Bazley <sebb@apache.org>
# Date:   Mon Feb 16 23:13:01 2015 +0000
#
#     COMPRESS-306 ArchiveStreamFactory fails to pass on the encoding when creating some streams.
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1660245 13f79535-47bb-0310-9956-ffa450edef68
#
# commit deeb355c2253b49f39f0be7bf16de1e119f69581 26210c670ab1e432f5457a011949806eea0c9ee3
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Jan 9 17:58:15 2015 +0000
#
#     replace a few magic numbers with constants
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1650615 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 26210c670ab1e432f5457a011949806eea0c9ee3 aed56110ff582b96aecf7675a9cfe5247ffa3e7d
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Feb 21 14:48:33 2014 +0000
#
#     cosmetics
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1570594 13f79535-47bb-0310-9956-ffa450edef68
#
# commit aed56110ff582b96aecf7675a9cfe5247ffa3e7d f9487ac192219b1c0419d80eb2b3cc6674992788
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Feb 21 14:21:12 2014 +0000
#
#     COMPRESS-264 make sure the very first read operation actually fills the ByteBuffer
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1570582 13f79535-47bb-0310-9956-ffa450edef68
#
# commit f9487ac192219b1c0419d80eb2b3cc6674992788 3fd6f60ca21a18baad27d31a5d9b253de11a3944
# Author: Emmanuel Bourg <ebourg@apache.org>
# Date:   Thu Dec 19 16:09:54 2013 +0000
#
#     Explode support for ZipFile and ZipArchiveInputStream (COMPRESS-115)
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1552325 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 3fd6f60ca21a18baad27d31a5d9b253de11a3944 8d44f86110b0d4c0efd120c5af7a60b5db956ed9
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu Dec 19 13:39:09 2013 +0000
#
#     data descriptor is not supported for shrunk entries
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1552319 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 8d44f86110b0d4c0efd120c5af7a60b5db956ed9 1b47ffe3bb81de2a922d72782b6b685de610f7a6
# Author: Emmanuel Bourg <ebourg@apache.org>
# Date:   Thu Dec 19 13:12:28 2013 +0000
#
#     Changed canReadEntryData() to support shrunk entries
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1552309 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 1b47ffe3bb81de2a922d72782b6b685de610f7a6 bfc8e03bdcf73162cc0f52c5ccb20b24961d54a8
# Author: Emmanuel Bourg <ebourg@apache.org>
# Date:   Thu Dec 19 12:30:01 2013 +0000
#
#     Support shrunk entries in ZipArchiveInputStream
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1552293 13f79535-47bb-0310-9956-ffa450edef68
#
# commit bfc8e03bdcf73162cc0f52c5ccb20b24961d54a8 429462a14d4f87846adf3e9a7109d8afdf3d5195
# Author: Emmanuel Bourg <ebourg@apache.org>
# Date:   Thu Dec 19 10:01:06 2013 +0000
#
#     Defer checking the inflater state to the readDeflated() method
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1552274 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 429462a14d4f87846adf3e9a7109d8afdf3d5195 d11e8d1cc1bc180a742df9df57cd890d4967ec41
# Author: Emmanuel Bourg <ebourg@apache.org>
# Date:   Thu Dec 19 09:53:17 2013 +0000
#
#     Formatting
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1552269 13f79535-47bb-0310-9956-ffa450edef68
#
# commit d11e8d1cc1bc180a742df9df57cd890d4967ec41 8bfb8987a3f5c73a38880c2c10cf7eda06ac9ddd
# Author: Emmanuel Bourg <ebourg@apache.org>
# Date:   Thu Dec 19 09:35:28 2013 +0000
#
#     Moved the entry crc into the CurrentEntry inner class
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1552260 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 8bfb8987a3f5c73a38880c2c10cf7eda06ac9ddd c6c7ec486fbb1a9c919853e35ca1a40300733098
# Author: Emmanuel Bourg <ebourg@apache.org>
# Date:   Thu Dec 19 08:51:47 2013 +0000
#
#     Update the entry CRC in the main read() method only (fixes the CRC for stored entries with a data descriptor)
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1552252 13f79535-47bb-0310-9956-ffa450edef68
#
# commit c6c7ec486fbb1a9c919853e35ca1a40300733098 c83c462de4e8f865f0a22539f2ba53ab5bb7fd3c
# Author: Emmanuel Bourg <ebourg@apache.org>
# Date:   Thu Dec 19 00:31:14 2013 +0000
#
#     Renamed the 'start' parameter in the read methods to 'offset' for consistency with the standard terminology
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1552179 13f79535-47bb-0310-9956-ffa450edef68
#
# commit c83c462de4e8f865f0a22539f2ba53ab5bb7fd3c 29f975ea99d9b9310c6fc33ac4f844fb10f4d98a
# Author: Emmanuel Bourg <ebourg@apache.org>
# Date:   Wed Dec 18 23:19:56 2013 +0000
#
#     Exception chaining
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1552157 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 29f975ea99d9b9310c6fc33ac4f844fb10f4d98a 8301ee7fec23ffdee9ea2c8ce5a8b80f343744e5
# Author: Emmanuel Bourg <ebourg@apache.org>
# Date:   Wed Dec 18 23:14:26 2013 +0000
#
#     Replaced ZipArchiveInputStream.Buffer with a ByteBuffer
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1552156 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 8301ee7fec23ffdee9ea2c8ce5a8b80f343744e5 345b8fc41910e2c27c57925c4265d3a9f1b1b993
# Author: Emmanuel Bourg <ebourg@apache.org>
# Date:   Wed Dec 18 22:10:19 2013 +0000
#
#     Modified ZipArchiveInputStream.Buffer to look more like a java.nio.ByteBuffer
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1552127 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 345b8fc41910e2c27c57925c4265d3a9f1b1b993 655f35b6c9837c49d1cc2423b6880877a6182479
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Dec 10 14:35:13 2013 +0000
#
#     got my logic backwards, missing test?
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1549848 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 655f35b6c9837c49d1cc2423b6880877a6182479 3685eeae9077221b27c617f9e8eb9836cfbb39d1
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Dec 10 12:59:50 2013 +0000
#
#     some explicit checks as long as ZipArchiveInputStream doesn't support unshrinking
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1549831 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 3685eeae9077221b27c617f9e8eb9836cfbb39d1 c87331031f18d5a41266f0fa83b0eb119d840e05
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Oct 4 13:17:32 2013 +0000
#
#     one readFully method to rule them all
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1529157 13f79535-47bb-0310-9956-ffa450edef68
#
# commit c87331031f18d5a41266f0fa83b0eb119d840e05 b86d8a6d4b2ed50b79a2c25887a34de01656f699
# Author: Emmanuel Bourg <ebourg@apache.org>
# Date:   Wed Aug 7 11:27:36 2013 +0000
#
#     Removed the unnecessary @inheritDoc tags
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1511248 13f79535-47bb-0310-9956-ffa450edef68
#
# commit b86d8a6d4b2ed50b79a2c25887a34de01656f699 df8b3b2e51a9385e02eba25e72f3927fd1e3ea63
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed Jul 17 14:37:22 2013 +0000
#
#     Remove direct citations form APPNOTE.TXT in javadocs, obey to section
#     1.4.2 in http://www.pkware.com/documents/casestudies/APPNOTE.TXT
#
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1504154 13f79535-47bb-0310-9956-ffa450edef68
#
# commit df8b3b2e51a9385e02eba25e72f3927fd1e3ea63 d9b559615109e94e6e7cad91e4f6dfa891f51e82
# Author: Sebastian Bazley <sebb@apache.org>
# Date:   Tue May 14 00:19:04 2013 +0000
#
#     Avoid NPE warning
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1482156 13f79535-47bb-0310-9956-ffa450edef68
#
# commit d9b559615109e94e6e7cad91e4f6dfa891f51e82 2f69e63d0a6ad2d5a527434f679c4c783fda271c
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed Feb 20 19:22:39 2013 +0000
#
#     COMPRESS-219 reading stored entries could try to read past the end of the internal buffer
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1448357 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 2f69e63d0a6ad2d5a527434f679c4c783fda271c 7181d54ff1170865f066a41f7e2568be34f3a749
# Author: Sebastian Bazley <sebb@apache.org>
# Date:   Tue Jan 22 17:00:33 2013 +0000
#
#     Drop trailing spaces where file has at least one instance of multiple trailing spaces
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1437047 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 7181d54ff1170865f066a41f7e2568be34f3a749 a6072ce36e786677fed5f703b13afb0900f4f9d3
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Jan 22 12:45:24 2013 +0000
#
#     consume remainder of ZIP when last LF-entry has been read
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1436879 13f79535-47bb-0310-9956-ffa450edef68
#
# commit a6072ce36e786677fed5f703b13afb0900f4f9d3 a2f978e97f13697e7adfddc3f96a9131803db679
# Author: Sebastian Bazley <sebb@apache.org>
# Date:   Mon Jan 7 22:54:12 2013 +0000
#
#     Document why local buffers are used (and restrictions on their use)
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1430074 13f79535-47bb-0310-9956-ffa450edef68
#
# commit a2f978e97f13697e7adfddc3f96a9131803db679 0d6defe95b3fc620943343d3a56cec131950c33e
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sat Jan 5 19:28:42 2013 +0000
#
#     COMPRESS-172 reuse temporary byte-arrays in several places to reduce garbage collection pressure - inspired by a patch by Thomas Mair
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1429363 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 0d6defe95b3fc620943343d3a56cec131950c33e e10ce2c37a9dd72efa8b8d706067c6960276933c
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Jan 1 11:05:48 2013 +0000
#
#     COMPRESS-208 properly detect split ZIP files
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1427363 13f79535-47bb-0310-9956-ffa450edef68
#
# commit e10ce2c37a9dd72efa8b8d706067c6960276933c 92d8c57a90b7fbdd8c3fd1304db2b513f57bbb02
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Jan 1 10:57:23 2013 +0000
#
#     COMPRESS-208: skip over PK00 splitting marker which really only says 'nothing to see here'
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1427357 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 92d8c57a90b7fbdd8c3fd1304db2b513f57bbb02 b4a985f516bf5a06c49321e9070b09f356a1b852
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Jan 1 10:51:42 2013 +0000
#
#     explicitly fail when ZipArchiveInputStream reads a split/spanned archive
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1427353 13f79535-47bb-0310-9956-ffa450edef68
#
# commit b4a985f516bf5a06c49321e9070b09f356a1b852 e2cf412a7856a7a9f314c3927df2f5a04f42177d
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Dec 28 17:29:53 2012 +0000
#
#     if the inflater needs a dictionary, that's worth an exception
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1426586 13f79535-47bb-0310-9956-ffa450edef68
#
# commit e2cf412a7856a7a9f314c3927df2f5a04f42177d 2ab43b0a1d56be413754424910362811fa3d85c4
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Dec 28 06:53:21 2012 +0000
#
#     COMPRESS-189 Inflater may return 0 if it needs more input, we don't handle this case properly
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1426417 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 2ab43b0a1d56be413754424910362811fa3d85c4 04173636b705ae43c29e22f52b8b75a1136ffddd
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sat Jul 7 19:34:11 2012 +0000
#
#     COMPRESS-192 add an encoding option to ArchiveStreamFactory for zip and tar.  Based on patch by Jukka Zitting
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1358626 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 04173636b705ae43c29e22f52b8b75a1136ffddd 2bd0dd4057e274901de8971f1d70de229afc0e54
# Author: Gary D. Gregory <ggregory@apache.org>
# Date:   Sun Apr 1 13:26:55 2012 +0000
#
#     Change access using declaring type.
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1308105 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 2bd0dd4057e274901de8971f1d70de229afc0e54 3b3f4cf68cddb96fc5b38d5b2ec45ef0476491f2
# Author: Gary D. Gregory <ggregory@apache.org>
# Date:   Sun Apr 1 13:02:39 2012 +0000
#
#     Normalize all @since tags to "@since version" instead of "@since Apache Commons Compress version"
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1308095 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 3b3f4cf68cddb96fc5b38d5b2ec45ef0476491f2 9dd152d46cfd2c5153c44691f424c8660d422346
# Author: Sebastian Bazley <sebb@apache.org>
# Date:   Sun Aug 21 13:53:03 2011 +0000
#
#     Unthrown Exception
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1159983 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 9dd152d46cfd2c5153c44691f424c8660d422346 794c20fe50038a8fe88852e4ab95e6381ed8027b
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu Aug 11 14:22:37 2011 +0000
#
#     whitespace - and rename of local variables in ZAIS.bufferContainsSignature
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1156627 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 794c20fe50038a8fe88852e4ab95e6381ed8027b cadc527d7d2a9841131597ba3a6116ead76480c0
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu Aug 11 14:08:54 2011 +0000
#
#     a few 'extract method' refactorings to make code more readable, still won't win a beauty-contest
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1156621 13f79535-47bb-0310-9956-ffa450edef68
#
# commit cadc527d7d2a9841131597ba3a6116ead76480c0 d48f106f8758056606e5d50d20f3893978d693a1
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed Aug 3 14:33:44 2011 +0000
#
#     work around unexpected result from Inflater#getBytesRead
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1153507 13f79535-47bb-0310-9956-ffa450edef68
#
# commit d48f106f8758056606e5d50d20f3893978d693a1 04e132b74b62cac7bb2d171825d5975e4fbfc155
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed Aug 3 13:36:01 2011 +0000
#
#     finalize deflater and inflater instances in ZIP streams.  COMPRESS-152
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1153483 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 04e132b74b62cac7bb2d171825d5975e4fbfc155 1e708a040893a987b9d03bcfa422c5a79e09a2e6
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed Aug 3 13:08:33 2011 +0000
#
#     separate state of stream from state of entry current being read from state of temporary buffer data is read into.  Document a few fields
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1153470 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 1e708a040893a987b9d03bcfa422c5a79e09a2e6 679449a86df00fff62bf3b29c997ad800ead3800
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed Aug 3 09:55:53 2011 +0000
#
#     don't rely on archives to implement ZIP64 correctly when reading the data descriptor.  Works around a bug in java.util.ZipArchiveOutputStream of Java7, may be useful for other implementations as well.  COMPRESS-148
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1153415 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 679449a86df00fff62bf3b29c997ad800ead3800 5031a979acd4a373968f22b81e97336a10cbbbc5
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu Jul 28 14:41:16 2011 +0000
#
#     unused imports
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/branches/zip64@1151876 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 5031a979acd4a373968f22b81e97336a10cbbbc5 3879e477a60c6e2bf5e23842d2a5d9a8734a46ce
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Jul 26 05:31:16 2011 +0000
#
#     ignore 'version made by' and use the Zip64 field if present
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/branches/zip64@1150988 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 3879e477a60c6e2bf5e23842d2a5d9a8734a46ce 865908836ab2a9e22a4c3f875736ee56eab5e351
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Jul 26 04:38:35 2011 +0000
#
#     Assume a record is using ZIP64 if and only if the ZIP64 extended information
#     extra field is present.
#
#     http://www.pkware.com/documents/casestudies/APPNOTE.TXT says:
#
#           When extracting, if
#           the zip64 extended information extra field is present for
#           the file the compressed and uncompressed sizes will be 8
#           byte values.
#
#     when talking about the data descriptor, making the extra field the the
#     thing to decide upon.  InfoZip's ZIP 3.0 agrees with this interpretation.
#     I even found this in ZIP 3.0' zipfile.c:
#
#           /* PKZIP does not care of the version set in a CDH: if  */
#           /* there is a zip64 extra field assigned to a CDH PKZIP */
#           /* uses it, we should do so, too.                       */
#
#     so "version made by" is ignored in the central directory.  The comment
#     is not present when looking at the local file header, I'm not yet decided
#     whether to ignore the version there as well.
#
#
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/branches/zip64@1150985 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 865908836ab2a9e22a4c3f875736ee56eab5e351 825b46d748279b9d29f53bc1e4223648f98fbb7b
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Mon Jul 25 20:17:05 2011 +0000
#
#     minor optimization
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/branches/zip64@1150881 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 825b46d748279b9d29f53bc1e4223648f98fbb7b 6c5f04b0f4489aab92cb3a178b59ab4392bfd9f5
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Mon Jul 25 20:15:32 2011 +0000
#
#     whitespace
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/branches/zip64@1150879 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 6c5f04b0f4489aab92cb3a178b59ab4392bfd9f5 e53e88aa4e35a066ab83942fd6b4cc1fc2a8ebb0
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Mon Jul 25 20:14:59 2011 +0000
#
#     first cut at reading Zip64 without any real tests, yet.  At least the existing test still pass.  COMPRESS-148
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/branches/zip64@1150878 13f79535-47bb-0310-9956-ffa450edef68
#
# commit e53e88aa4e35a066ab83942fd6b4cc1fc2a8ebb0 3f1a7c496cb915dd2f4205fe236f5b6a633dd4b8
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Mon Jul 25 13:28:31 2011 +0000
#
#     Java5ify ZipArchiveInputStream implementation and related classes
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/branches/zip64@1150694 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 3f1a7c496cb915dd2f4205fe236f5b6a633dd4b8 934a96e0fb2f4aceadfd0ebbd713d43e687e4a1d
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Mon Jul 25 09:53:30 2011 +0000
#
#     use long returning methods in Java5's Inflater/Deflater.  Addresses COMPRESS-129.
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/branches/zip64@1150608 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 934a96e0fb2f4aceadfd0ebbd713d43e687e4a1d 797d74fd75ef76e37698dcb3ef93423d1e4cccbd
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sat Jul 23 04:33:44 2011 +0000
#
#     Provide access to the raw bytes that made up the ZIP entry's name.  COMPRESS-123
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1149796 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 797d74fd75ef76e37698dcb3ef93423d1e4cccbd 7a76c479371ef20f604eb1f1f2fca9f1b2b8f74a
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu Jul 21 03:49:35 2011 +0000
#
#     deal with entries of a size between Integer.MAX_VALUE and 2 * Integer.MAX_VALUE (size is unsigned in ZIPs).  COMPRESS-129.  As pointed out by Sebb the solution is incomplete and a more complete resolution is not possible without requiring Java5.
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1149029 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 7a76c479371ef20f604eb1f1f2fca9f1b2b8f74a 8006d3148251f3f68e475e21c67dabe9364ec015
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed Jul 20 14:55:50 2011 +0000
#
#     'our' skip method will not return early.  COMPRESS-130
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1148806 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 8006d3148251f3f68e475e21c67dabe9364ec015 6209f812e69f00f4fbd49c82260142bf591d8091
# Author: Sebastian Bazley <sebb@apache.org>
# Date:   Wed May 12 18:18:19 2010 +0000
#
#     Javadoc tidyup
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@943610 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 6209f812e69f00f4fbd49c82260142bf591d8091 03e94a450fcd6e8b4d185caee3cb6b693c34d8ae
# Author: Sebastian Bazley <sebb@apache.org>
# Date:   Mon May 10 17:36:40 2010 +0000
#
#     @since markers
#     Javadoc updates
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@942826 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 03e94a450fcd6e8b4d185caee3cb6b693c34d8ae 02e2be6c590a474f0db5065c375c5e27d1c8c763
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Mar 19 15:08:23 2010 +0000
#
#     optionally read STORED entries with data descriptors.  COMPRESS-103
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@925257 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 02e2be6c590a474f0db5065c375c5e27d1c8c763 1154e7bbd4be91f3383a93b0a1b5605efc640eec
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed Mar 17 15:55:00 2010 +0000
#
#     STORED entry with data descriptors are not a problem for ZipFile and the output stream doesn't care anyway - so only check for the combination inside the input stream.
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@924342 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 1154e7bbd4be91f3383a93b0a1b5605efc640eec 62cb9c480ecd71491e6b2452ff8add4d35706290
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed Mar 17 15:47:57 2010 +0000
#
#     actually read content of data descriptor
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@924336 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 62cb9c480ecd71491e6b2452ff8add4d35706290 d7ea9ff05a28a73508b57f369a0b06b3fab46479
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Mar 12 16:06:20 2010 +0000
#
#     provide access to the general purpose bit flag field of a zip entry and fail when a STORED entry requires a data descriptor.  COMPRESS-100
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@922309 13f79535-47bb-0310-9956-ffa450edef68
#
# commit d7ea9ff05a28a73508b57f369a0b06b3fab46479 b6814d4f07ba2b98b4bae4dd1f2f83cbecbe6f56
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Mar 12 15:35:44 2010 +0000
#
#     Check a data descriptor actually uses the signature before skipping too many bytes if it doesn't.  COMPRESS-101
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@922298 13f79535-47bb-0310-9956-ffa450edef68
#
# commit b6814d4f07ba2b98b4bae4dd1f2f83cbecbe6f56 e0692eca48f9b86131d41ec6697c7f2d14715b0b
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Mar 9 11:15:10 2010 +0000
#
#     extract common code
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@920800 13f79535-47bb-0310-9956-ffa450edef68
#
# commit e0692eca48f9b86131d41ec6697c7f2d14715b0b 734e6f780498f63263090fb88d19421300ff40d0
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed Feb 24 15:35:47 2010 +0000
#
#     canRead => canReadEntryData as discussed on the list
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@915826 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 734e6f780498f63263090fb88d19421300ff40d0 a33505b5c6bf810025567b1c6ce244cd1c85f078
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Feb 19 12:33:28 2010 +0000
#
#     if it's not a ZipArchiveEntry then the stream can't read/write it
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@911798 13f79535-47bb-0310-9956-ffa450edef68
#
# commit a33505b5c6bf810025567b1c6ce244cd1c85f078 c7e51ede7a9894e57bb72877ab6b77a0c3ef0705
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Feb 19 12:23:27 2010 +0000
#
#     move canRead/canWrite up.  Remove isSupportedCompressionMethod.  COMPRESS-93
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@911795 13f79535-47bb-0310-9956-ffa450edef68
#
# commit c7e51ede7a9894e57bb72877ab6b77a0c3ef0705 4d68ddaedca7219f4b12b3c239f9238d5e1c185b
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Feb 19 10:55:27 2010 +0000
#
#     detect encrypted entries and say that you can't read/write them.  COMPRESS-89
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@911781 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 4d68ddaedca7219f4b12b3c239f9238d5e1c185b 2b2099395b165cc549232570213ef63cfcf8c10c
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Feb 19 09:56:37 2010 +0000
#
#     extract general purpose bit logic
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@911765 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 2b2099395b165cc549232570213ef63cfcf8c10c a1015f312480c697c8dbc2772e4076eb15e41406
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Feb 19 08:41:23 2010 +0000
#
#     EFS in APPNOTE.TXT stands for 'Early Feature Specification' so our usage of it as 'use the general purpose field to signal UTF8' is wrong.
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@911740 13f79535-47bb-0310-9956-ffa450edef68
#
# commit a1015f312480c697c8dbc2772e4076eb15e41406 41aa509d836dcdd316a40e68680cc54e0f6c1e04
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu Feb 18 16:11:13 2010 +0000
#
#     properly count bytes read.  COMPRESS-74
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@911467 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 41aa509d836dcdd316a40e68680cc54e0f6c1e04 b6886eb41d060b9569bf101a017abdf89acb29f2
# Author: Jukka Zitting <jukka@apache.org>
# Date:   Sun Dec 13 20:07:59 2009 +0000
#
#     COMPRESS-93: Support for alternative ZIP compression methods
#
#     Fix the Maven221MultiVolumeTest failure by not using skip() to skip bytes. The FileInputStream implementation of skip() will happily skip past the end of the file, so we never see the EOFException that Maven221MultiVolumeTest expects to see when closing a truncated entry.
#
#     Also added an explicit test case for the ability to skip entries with unsupported compression methods.
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@890110 13f79535-47bb-0310-9956-ffa450edef68
#
# commit b6886eb41d060b9569bf101a017abdf89acb29f2 7b125a334e513349a4445e38b9d5a109f5e26f99
# Author: Jukka Zitting <jukka@apache.org>
# Date:   Sun Dec 13 19:44:37 2009 +0000
#
#     COMPRESS-93: Support for alternative ZIP compression methods
#
#     Allow entries with unsupported compression methods to be safely skipped if the compressed size of the entry is stored in the entry header.
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@890104 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 7b125a334e513349a4445e38b9d5a109f5e26f99 dc3fc4703211876fb38cccf55adc92ee5cbc28d0
# Author: Jukka Zitting <jukka@apache.org>
# Date:   Sun Dec 13 18:31:55 2009 +0000
#
#     COMPRESS-93: Support for alternative ZIP compression methods
#
#     Override the ZipEntry compression method getter and setter in ZipArchiveEntry. This prevents the IllegalArgumentException that was thrown whenever a zip entry with an unsupported compression method was encountered. With this change an IOException is thrown instead only if or when the entry is actually being read or written. In addition, a public ZipArchiveEntry.isSupportedCompressionMethod() method is introduced so client code can choose to explicitly skip reading ZIP entries with unsupported compression methods.
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@890088 13f79535-47bb-0310-9956-ffa450edef68
#
# commit dc3fc4703211876fb38cccf55adc92ee5cbc28d0 f84dd362bbf15c19cb5f3a3b4563951ba529f585
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Oct 30 05:29:17 2009 +0000
#
#     make ZipArchiveInputStream deal better with truncated archives.  Submitted by Antoni Mylka.  COMPRESS-87
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@831204 13f79535-47bb-0310-9956-ffa450edef68
#
# commit f84dd362bbf15c19cb5f3a3b4563951ba529f585 7ae0eec9b2f17265be850ce49f987f68abfcbb45
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Apr 28 08:31:15 2009 +0000
#
#     Only use the zip-extra-field if configured to do so and the entry didn't set the EFS flag - COMPRESS-70
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@769291 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 7ae0eec9b2f17265be850ce49f987f68abfcbb45 4bce1fb1a4774dca5b05d6c1c783603c910e38ed
# Author: Sebastian Bazley <sebb@apache.org>
# Date:   Sat Apr 25 14:55:05 2009 +0000
#
#     Remove or document unused fields
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@768542 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 4bce1fb1a4774dca5b05d6c1c783603c910e38ed f7f6b188661d473a66b9aa21fae5a4cc11240bed
# Author: Christian Grobmeier <grobmeier@apache.org>
# Date:   Fri Apr 10 15:36:15 2009 +0000
#
#     COMPRESS-56: enabled counting read bytes in InputStreams and added this information to exceptions, where it seems to fit.
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@763964 13f79535-47bb-0310-9956-ffa450edef68
#
# commit f7f6b188661d473a66b9aa21fae5a4cc11240bed 6117cc1f45661fb42037b95d4c04b541db85dbc9
# Author: Sebastian Bazley <sebb@apache.org>
# Date:   Tue Mar 31 10:36:25 2009 +0000
#
#     Javadoc
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@760392 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 6117cc1f45661fb42037b95d4c04b541db85dbc9 fa526cb413683d47f8a54cb905dc8ff911e41e57
# Author: Sebastian Bazley <sebb@apache.org>
# Date:   Mon Mar 30 18:11:46 2009 +0000
#
#     Remove unnecessary override methods
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@760082 13f79535-47bb-0310-9956-ffa450edef68
#
# commit fa526cb413683d47f8a54cb905dc8ff911e41e57 99870ef59c93a4a00d8719ed6cb0dbef5795912d
# Author: Sebastian Bazley <sebb@apache.org>
# Date:   Mon Mar 30 00:39:05 2009 +0000
#
#     Empty Zip files start with End of Central directory
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@759807 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 99870ef59c93a4a00d8719ed6cb0dbef5795912d 958e1bcfc14cec7f47013e3db386622c31d4909c
# Author: Sebastian Bazley <sebb@apache.org>
# Date:   Sat Mar 28 00:04:36 2009 +0000
#
#     Not thread-safe
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@759399 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 958e1bcfc14cec7f47013e3db386622c31d4909c 008ca948dadacea8d1a2662c577fdcb25f32d5e2
# Author: Sebastian Bazley <sebb@apache.org>
# Date:   Fri Mar 27 18:59:24 2009 +0000
#
#     unused
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@759305 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 008ca948dadacea8d1a2662c577fdcb25f32d5e2 eadbe116f9d59b38acf2aec9c4de43e5c5f68d49
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu Mar 26 22:29:59 2009 +0000
#
#     support as much as possible of ZipFile as a stream can do in ZipArchiveInputStream, COMPRESS-47
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@758896 13f79535-47bb-0310-9956-ffa450edef68
#
# commit eadbe116f9d59b38acf2aec9c4de43e5c5f68d49 a7049abc85c6f318de9e466457d97e52418b6ea0
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu Feb 26 09:31:43 2009 +0000
#
#     correct signature detection of ZIP archives.
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/sandbox/compress/trunk@748067 13f79535-47bb-0310-9956-ffa450edef68
#
# commit a7049abc85c6f318de9e466457d97e52418b6ea0 3f9bcc6928539331f042830387032dc8240a50c0
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed Feb 11 07:44:00 2009 +0000
#
#     provide convenience getNext*Entry methods to ArchiveInputStream subclasses
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/sandbox/compress/trunk@743259 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 3f9bcc6928539331f042830387032dc8240a50c0 463d6ebdebb2ea194254f1c3fab0a0f63ee212ce
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Feb 10 14:20:05 2009 +0000
#
#     fix whitespace
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/sandbox/compress/trunk@742977 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 463d6ebdebb2ea194254f1c3fab0a0f63ee212ce af2b66dbbc67ddf2b7a49835511a7a258463a4b5
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Feb 6 17:11:40 2009 +0000
#
#     rename ZipEntry to ZipArchiveEntry
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/sandbox/compress/trunk@741637 13f79535-47bb-0310-9956-ffa450edef68
#
# commit af2b66dbbc67ddf2b7a49835511a7a258463a4b5 dff9001560b49c623a47386b0e706397b9038841
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Feb 6 17:02:21 2009 +0000
#
#     merge ZipEntry and ZipArchiveEntry into a single class
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/sandbox/compress/trunk@741632 13f79535-47bb-0310-9956-ffa450edef68
#
# commit dff9001560b49c623a47386b0e706397b9038841 fa8fea76c4577d2ee9836104ec09cedd22bf1978
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Feb 6 08:59:14 2009 +0000
#
#     use length of signature read when trying to match input stream formats
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/sandbox/compress/trunk@741476 13f79535-47bb-0310-9956-ffa450edef68
#
# commit fa8fea76c4577d2ee9836104ec09cedd22bf1978 743d7c5498d64d6ee9badb95655e3e7178735a09
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Feb 6 08:49:49 2009 +0000
#
#     whitespace only
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/sandbox/compress/trunk@741473 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 743d7c5498d64d6ee9badb95655e3e7178735a09 ca16539029cd63e0ab5c9e3cba354a539f94e316
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu Feb 5 11:01:35 2009 +0000
#
#     some indentation changes and add myself to the POM
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/sandbox/compress/trunk@741075 13f79535-47bb-0310-9956-ffa450edef68
#
# commit ca16539029cd63e0ab5c9e3cba354a539f94e316
# Author: Torsten Curdt <tcurdt@apache.org>
# Date:   Thu Jul 10 10:17:44 2008 +0000
#
#     import of new redesign branch
#
#     https://issues.apache.org/jira/browse/SANDBOX-247
#
#
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/sandbox/compress/branches/redesign@675498 13f79535-47bb-0310-9956-ffa450edef68

# %% [markdown]
# commit a41ce6892cb0590b2e658704434ac0dbcb6834c8 22b0d0629267b88749f78412caea672d6539a5b6
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu Aug 9 20:39:23 2018 +0200
#
#     COMPRESS-463 throw exception when detecting a truncated stored entry
#
# commit 22b0d0629267b88749f78412caea672d6539a5b6 af6fe141036d30bfd1613758b7a9fb413bf2bafc
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun Jul 1 13:46:45 2018 +0200
#
#     whitespace
# 39 days

# %%
#h.	How many days were between the current fixing commit and the previous 
#commit of each affected file? Hint: git log
#AffectedFile2
log_data = repo.git.log("--parents",affected_file2).splitlines()
for line in log_data:
    print(line)
# Out:
# commit 88e26c9ffac61713372378c6f0225cd1a8b676e9 0c4f64c2bebd85a96be8a07b1ad700c7688cbe02
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Aug 13 18:41:40 2019 +0200
#
#     Revert "COMPRESS-479 introduce a parameter class for zip readers"
#
#     This reverts commit 0c4f64c2bebd85a96be8a07b1ad700c7688cbe02.
#
# commit 0c4f64c2bebd85a96be8a07b1ad700c7688cbe02 a41ce6892cb0590b2e658704434ac0dbcb6834c8
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Mon Aug 12 22:15:44 2019 +0200
#
#     COMPRESS-479 introduce a parameter class for zip readers
#
# commit a41ce6892cb0590b2e658704434ac0dbcb6834c8 acab253ab45dfa7b6b80dbec9f3623969c4a57a5
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu Aug 9 20:39:23 2018 +0200
#
#     COMPRESS-463 throw exception when detecting a truncated stored entry
#
# commit acab253ab45dfa7b6b80dbec9f3623969c4a57a5 3f2c760a4eb82d880e62a03cb9450d9dcf2793f7
# Author: Sebb <sebb@apache.org>
# Date:   Mon Feb 27 23:28:34 2017 +0000
#
#     Avoid some resource leak warnings
#
# commit 3f2c760a4eb82d880e62a03cb9450d9dcf2793f7 999821c2549e641bd9c9a223be04497982eebaca
# Author: ggregory <ggregory@apache.org>
# Date:   Sat Apr 9 10:10:28 2016 -0700
#
#     Add final modifier to local variables.
#
# commit 999821c2549e641bd9c9a223be04497982eebaca 58fa9a673547c884cd1f11a8927414e563480358
# Author: Sebb <sebb@apache.org>
# Date:   Sat Apr 9 01:42:34 2016 +0100
#
#     Simplify
#
# commit 58fa9a673547c884cd1f11a8927414e563480358 bb74f0c4cd5febd41fd6ab74f978a6219dc33f64
# Author: Sebastian Bazley <sebb@apache.org>
# Date:   Tue Feb 17 00:40:20 2015 +0000
#
#     COMPRESS-305 Convert all tests to JUnit4 style
#     All but AbstractTestCase and subclasses
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1660261 13f79535-47bb-0310-9956-ffa450edef68
#
# commit bb74f0c4cd5febd41fd6ab74f978a6219dc33f64 b2a9dd0e14adf6a80af03d8f8273141495cf90f5
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun Jan 27 09:45:53 2013 +0000
#
#     COMPRESS-205 - allow tests to pass even if source tree is placed in strange directories.  Based on patch by Daniel Lowe
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1439043 13f79535-47bb-0310-9956-ffa450edef68
#
# commit b2a9dd0e14adf6a80af03d8f8273141495cf90f5 d7119be63642c0cc862e636071b96daaa0b99ec0
# Author: Gary D. Gregory <ggregory@apache.org>
# Date:   Sun Apr 1 13:19:03 2012 +0000
#
#     Convert to enhanced for loop.
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1308103 13f79535-47bb-0310-9956-ffa450edef68
#
# commit d7119be63642c0cc862e636071b96daaa0b99ec0 c37c629de73830587270c57ecc70c1dd83aa68b2
# Author: Gary D. Gregory <ggregory@apache.org>
# Date:   Sat Mar 31 22:36:04 2012 +0000
#
#     Replace magic strings "UTF-8", "US-ASCII", and so on with references to a new .util class CharsetNames (like in other commons components.) The Charsets class will be more useful when [compress] moves to Java 6 and can use String#getBytes(Charset) instead of String#getBytes(String).
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1307926 13f79535-47bb-0310-9956-ffa450edef68
#
# commit c37c629de73830587270c57ecc70c1dd83aa68b2 dc3fc4703211876fb38cccf55adc92ee5cbc28d0
# Author: Sebastian Bazley <sebb@apache.org>
# Date:   Tue Mar 2 23:26:03 2010 +0000
#
#     Tab police
#     tidy code slightly
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@918253 13f79535-47bb-0310-9956-ffa450edef68
#
# commit dc3fc4703211876fb38cccf55adc92ee5cbc28d0
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Oct 30 05:29:17 2009 +0000
#
#     make ZipArchiveInputStream deal better with truncated archives.  Submitted by Antoni Mylka.  COMPRESS-87
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@831204 13f79535-47bb-0310-9956-ffa450edef68

# %% [markdown]
# commit a41ce6892cb0590b2e658704434ac0dbcb6834c8 acab253ab45dfa7b6b80dbec9f3623969c4a57a5
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu Aug 9 20:39:23 2018 +0200
#
#     COMPRESS-463 throw exception when detecting a truncated stored entry
#
# commit acab253ab45dfa7b6b80dbec9f3623969c4a57a5 3f2c760a4eb82d880e62a03cb9450d9dcf2793f7
# Author: Sebb <sebb@apache.org>
# Date:   Mon Feb 27 23:28:34 2017 +0000
#
#     Avoid some resource leak warnings
# 528 days

# %%
#h.	How many days were between the current fixing commit and the previous 
#commit of each affected file? Hint: git log
#AffectedFile3
log_data = repo.git.log("--parents",affected_file3).splitlines()
for line in log_data:
    print(line)
# Out:
# commit f5d0bb1e287038de05415ca65145d82166a7bf0f 82986dd12fc255d218a6454364a50eb9ae3f812d
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun Aug 18 12:41:50 2019 +0200
#
#     COMPRESS-483 throw exception if stored DD doesn't match what has been read
#
# commit 82986dd12fc255d218a6454364a50eb9ae3f812d a41ce6892cb0590b2e658704434ac0dbcb6834c8
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun Aug 18 11:57:40 2019 +0200
#
#     COMPRESS-482 stored with data descriptor now works without DD signature
#
# commit a41ce6892cb0590b2e658704434ac0dbcb6834c8 64ed6dde03afbef6715fdfdeab5fc04be6192899
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu Aug 9 20:39:23 2018 +0200
#
#     COMPRESS-463 throw exception when detecting a truncated stored entry
#
# commit 64ed6dde03afbef6715fdfdeab5fc04be6192899 c66db899cb061c79934986f0efa19a50ca33703f
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu Aug 9 20:29:39 2018 +0200
#
#     ensure archive streams really mean EOF if they say so
#
# commit c66db899cb061c79934986f0efa19a50ca33703f b18ef2a10393824bd9a79c908bda656de4d45006
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun Jan 14 12:12:50 2018 +0100
#
#     COMPRESS-436 sanity check compressed size is known for bzip etc
#
# commit b18ef2a10393824bd9a79c908bda656de4d45006 0517c7f2e4ea6806098453b295f230dd42a8f510 77a0a69e3135253b3762672ef6bdf96ebaa8a882
# Merge: 0517c7f2 77a0a69e
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Jan 9 18:40:31 2018 +0100
#
#     Merge branch 'COMPRESS-380'
#
# commit 77a0a69e3135253b3762672ef6bdf96ebaa8a882 27b16a26212d5e4b61ebe07c4bd9c36465f56702
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun Jan 7 11:06:12 2018 +0100
#
#     move a few files around
#
#     closes #58
#
# commit 0517c7f2e4ea6806098453b295f230dd42a8f510 6b12eab8ef3255eed66d2e382411e973883f608a
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Jan 5 17:54:15 2018 +0100
#
#     COMPRESS-429 tests
#
# commit 27b16a26212d5e4b61ebe07c4bd9c36465f56702 ccc3067f5216630d6c96f21f1ed2ef174aba9bd5
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Jan 5 13:31:23 2018 +0100
#
#     COMPRESS-380 support data descriptors with ENHANCED_DEFLATED
#
# commit ccc3067f5216630d6c96f21f1ed2ef174aba9bd5 6b12eab8ef3255eed66d2e382411e973883f608a
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Jan 5 06:52:55 2018 +0100
#
#     COMPRESS-380 add DEFLATE64 support to ZipArchiveInputStream
#
# commit 6b12eab8ef3255eed66d2e382411e973883f608a 3bf400edc1add6078a9bd935e3ae684b8bf8493f
# Author: Gary Gregory <garydgregory@gmail.com>
# Date:   Wed Nov 1 16:25:38 2017 -0600
#
#     Remove trailing white spaces on all lines.
#
# commit 3bf400edc1add6078a9bd935e3ae684b8bf8493f f015344879f1bc3505bc616fc7ae517cf9f60838
# Author: Zbynek Vyskovsky <kvr000@gmail.com>
# Date:   Sun Apr 30 22:03:07 2017 -0700
#
#     COMPRESS-390: Expose stream offsets and size
#
# commit f015344879f1bc3505bc616fc7ae517cf9f60838 658812c85fe762e361c998161cfb61bd477e1b24
# Author: Mike Mole <michael.mole@lookout.com>
# Date:   Fri Oct 28 08:03:48 2016 -0400
#
#     COMPRESS-367 Throw ZipException on invalid entry with ZipArchiveInputStream
#
#     ZipArchiveInputStream.getNextZipEntry() throws a ZipException rather
#     than returning null if an invalid entry is encountered in order to
#     differentiate between "no more entries" and "error" conditions.
#
# commit 658812c85fe762e361c998161cfb61bd477e1b24 32c30f6f072ccfea6ead90f8eef0c205d88d00d3
# Author: Mike Mole <michael.mole@lookout.com>
# Date:   Fri Aug 19 09:08:42 2016 -0400
#
#     ZipArchiveInputStream.closeEntry fails to advance
#
#     Properly advances to next entry upon calling closeEntry when there
#     are extra junk bytes after the compressed data section of a
#     zip entry. This applies to the ZipArchiveInputStream implementation.
#
# commit 32c30f6f072ccfea6ead90f8eef0c205d88d00d3 77388c82c0f484ebf11b5f3292f0103514fd00f1
# Author: Kristian Rosenvold <krosenvold@apache.org>
# Date:   Mon Jun 27 10:02:45 2016 +0200
#
#     More java7 language features
#
# commit 77388c82c0f484ebf11b5f3292f0103514fd00f1 a1d6b33f5f6c21f8f74a70edc3b05af42515e734
# Author: Gary Gregory <ggregory@apache.org>
# Date:   Sat Jun 25 14:35:06 2016 -0700
#
#     Add final modifier to local variables.
#
# commit a1d6b33f5f6c21f8f74a70edc3b05af42515e734 3f2c760a4eb82d880e62a03cb9450d9dcf2793f7
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Mon Apr 25 09:53:28 2016 +0200
#
#     COMPRESS-351 Testcase
#
# commit 3f2c760a4eb82d880e62a03cb9450d9dcf2793f7 6eac426de89fe077a181f39452dee6f6ca4c2f52
# Author: ggregory <ggregory@apache.org>
# Date:   Sat Apr 9 10:10:28 2016 -0700
#
#     Add final modifier to local variables.
#
# commit 6eac426de89fe077a181f39452dee6f6ca4c2f52 aed56110ff582b96aecf7675a9cfe5247ffa3e7d
# Author: Sören Glimm <git@uncleowen.de>
# Date:   Tue Nov 10 20:00:20 2015 +0100
#
#     Implement uncompressing of BZip2 compressed entries in ZipArchiveInputStream
#
# commit aed56110ff582b96aecf7675a9cfe5247ffa3e7d bc741b19e88749d66b03bf8dc292f3ae0fc74156
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Feb 21 14:21:12 2014 +0000
#
#     COMPRESS-264 make sure the very first read operation actually fills the ByteBuffer
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1570582 13f79535-47bb-0310-9956-ffa450edef68
#
# commit bc741b19e88749d66b03bf8dc292f3ae0fc74156 8d44f86110b0d4c0efd120c5af7a60b5db956ed9
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Feb 21 13:30:53 2014 +0000
#
#     COMPRESS-264 add a (failing) Unit Test
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1570567 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 8d44f86110b0d4c0efd120c5af7a60b5db956ed9 1b47ffe3bb81de2a922d72782b6b685de610f7a6
# Author: Emmanuel Bourg <ebourg@apache.org>
# Date:   Thu Dec 19 13:12:28 2013 +0000
#
#     Changed canReadEntryData() to support shrunk entries
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1552309 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 1b47ffe3bb81de2a922d72782b6b685de610f7a6 9ad93a932d19c46edf40d8e48f843877fa60de48
# Author: Emmanuel Bourg <ebourg@apache.org>
# Date:   Thu Dec 19 12:30:01 2013 +0000
#
#     Support shrunk entries in ZipArchiveInputStream
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1552293 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 9ad93a932d19c46edf40d8e48f843877fa60de48 60f4ac24f9d03ff26789002138bb71f227e1526b
# Author: Sebastian Bazley <sebb@apache.org>
# Date:   Mon May 13 23:51:29 2013 +0000
#
#     Unused imports
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1482151 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 60f4ac24f9d03ff26789002138bb71f227e1526b 340a3442abb37a188a005f01f9c37e525698cbac
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Feb 22 05:02:33 2013 +0000
#
#     enable test for COMPRESS-219
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1448896 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 340a3442abb37a188a005f01f9c37e525698cbac d9b559615109e94e6e7cad91e4f6dfa891f51e82
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed Feb 20 19:24:03 2013 +0000
#
#     Disable test until I know we can include the zip that is needed for the test
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1448361 13f79535-47bb-0310-9956-ffa450edef68
#
# commit d9b559615109e94e6e7cad91e4f6dfa891f51e82 284b0450f2c3e645a688413aafce5be5d3bbbf41
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Wed Feb 20 19:22:39 2013 +0000
#
#     COMPRESS-219 reading stored entries could try to read past the end of the internal buffer
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1448357 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 284b0450f2c3e645a688413aafce5be5d3bbbf41 bb74f0c4cd5febd41fd6ab74f978a6219dc33f64
# Author: Sebastian Bazley <sebb@apache.org>
# Date:   Sun Jan 27 13:13:57 2013 +0000
#
#     Unused imports
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1439077 13f79535-47bb-0310-9956-ffa450edef68
#
# commit bb74f0c4cd5febd41fd6ab74f978a6219dc33f64 fdcf80dfe8e5314a9220cbcd74f4e2dd03b71b81
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sun Jan 27 09:45:53 2013 +0000
#
#     COMPRESS-205 - allow tests to pass even if source tree is placed in strange directories.  Based on patch by Daniel Lowe
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1439043 13f79535-47bb-0310-9956-ffa450edef68
#
# commit fdcf80dfe8e5314a9220cbcd74f4e2dd03b71b81 50b419b97bb0d61a4874e8b84b0d268fe69621a1
# Author: Sebastian Bazley <sebb@apache.org>
# Date:   Tue Jan 22 16:54:36 2013 +0000
#
#     Oops, closed the stream too early
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1437046 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 50b419b97bb0d61a4874e8b84b0d268fe69621a1 7181d54ff1170865f066a41f7e2568be34f3a749
# Author: Sebastian Bazley <sebb@apache.org>
# Date:   Tue Jan 22 16:43:03 2013 +0000
#
#     Remove spurious ;
#     Ensure stream is closed
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1437041 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 7181d54ff1170865f066a41f7e2568be34f3a749 4497c3cba901cedc1c201a04aaeda4555d0e46ae
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Jan 22 12:45:24 2013 +0000
#
#     consume remainder of ZIP when last LF-entry has been read
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1436879 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 4497c3cba901cedc1c201a04aaeda4555d0e46ae e2cf412a7856a7a9f314c3927df2f5a04f42177d
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Sat Jan 5 13:08:49 2013 +0000
#
#     enable testcase for COMPRESS-189
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1429275 13f79535-47bb-0310-9956-ffa450edef68
#
# commit e2cf412a7856a7a9f314c3927df2f5a04f42177d d7119be63642c0cc862e636071b96daaa0b99ec0
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Fri Dec 28 06:53:21 2012 +0000
#
#     COMPRESS-189 Inflater may return 0 if it needs more input, we don't handle this case properly
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1426417 13f79535-47bb-0310-9956-ffa450edef68
#
# commit d7119be63642c0cc862e636071b96daaa0b99ec0 10f26cba7ea32ae321749e182937f0b5b5cf42fc
# Author: Gary D. Gregory <ggregory@apache.org>
# Date:   Sat Mar 31 22:36:04 2012 +0000
#
#     Replace magic strings "UTF-8", "US-ASCII", and so on with references to a new .util class CharsetNames (like in other commons components.) The Charsets class will be more useful when [compress] moves to Java 6 and can use String#getBytes(Charset) instead of String#getBytes(String).
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1307926 13f79535-47bb-0310-9956-ffa450edef68
#
# commit 10f26cba7ea32ae321749e182937f0b5b5cf42fc c75c10faae27781aeb51713f42153cad1fd242a4
# Author: Sebastian Bazley <sebb@apache.org>
# Date:   Sat Mar 31 10:34:46 2012 +0000
#
#     Javadoc syntax
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1307759 13f79535-47bb-0310-9956-ffa450edef68
#
# commit c75c10faae27781aeb51713f42153cad1fd242a4
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Tue Feb 28 05:00:26 2012 +0000
#
#     add workaround for broken implementations that use backslashes rather than slashes in file names.  COMPRESS-176
#
#     git-svn-id: https://svn.apache.org/repos/asf/commons/proper/compress/trunk@1294460 13f79535-47bb-0310-9956-ffa450edef68

# %% [markdown]
# commit a41ce6892cb0590b2e658704434ac0dbcb6834c8 64ed6dde03afbef6715fdfdeab5fc04be6192899
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu Aug 9 20:39:23 2018 +0200
#
#     COMPRESS-463 throw exception when detecting a truncated stored entry
#
# commit 64ed6dde03afbef6715fdfdeab5fc04be6192899 c66db899cb061c79934986f0efa19a50ca33703f
# Author: Stefan Bodewig <bodewig@apache.org>
# Date:   Thu Aug 9 20:29:39 2018 +0200
#
#     ensure archive streams really mean EOF if they say so
# 0 days

# %%
#i.	How many time has each affected file of the current fixing commit 
#been modified in the past since their creation (including rename of the file)? Hint: git log
#Affected File
log_data = repo.git.log("--oneline",affected_file).splitlines()
print("Number of commits in between:", len(log_data))
for line in log_data:
    print(line)
# Out:
# Number of commits in between: 388
# fff4d81f COMPRESS-491 record fix
# 277d6a0c COMPRESS-492 eliminate a bunch of potential NPEs in SevenZFile
# ab7809b5 Update tests from org.apache.felix:org.apache.felix.framework 6.0.2 to 6.0.3.
# 7e7bfb5b [COMPRESS-493] Update optional library com.github.luben:zstd-jni from 1.4.0-1 to 1.4.3-1.
# a98d68e2 record CVE-2019-12402
# 30a27cfa merge 1.19 tag, prepare for next iteration
# 352829af COMPRESS-478 record changes
# 6615be08 COMPRESS-231 document how to read 7z multi volume archives
# 2492bbe8 typo
# f5d0bb1e COMPRESS-483 throw exception if stored DD doesn't match what has been read
# a9aabdd9 COMPRESS-482 document change
# 9584bcfd COMPRESS-479 document the change in zip extra field parsing
# 91c2f0df COMPRESS-486 deal with resouce leaks in example code
# 58364058 COMPRESS-490 throw IOException for certain malformed archives
# c5039b52 COMPRESS-485 record second part
# 4a101225 COMPRESS-485 record change
# 4ff3be9b Name "Apache Commons" in page title.
# 5a252481 [COMPRESS-484] Update optional library zstd-jni from 1.3.3-3 to 1.4.0-1.
# bb721bf6 forgot to record issue number for COMPRESS-481
# 8712134c add a few ARJ constants stemming from more recent spec
# 15692dfd record change
# 476d47a8 record #74
# 76f42895 COMPRESS-475 implement equals and hashCode
# 2f75fbb5 COMPRESS-470 make sure all ScatterZipOutputStreams are closed
# fd69d8ca COMPRESS-469 add lenient flag that allows accepting some broken tars
# 14242fe6 COMPRESS-466 allow ZipFile to not parse local file headers
# 0855aec5 record fix, closes #69
# a7a95f04 Merge tag 'rel/1.18' and prepare next iteration
# 0c17da1e take note of 1.18's changes
# ba53647b COMPRESS-462 can't read from AR without opening an entry
# a41ce689 COMPRESS-463 throw exception when detecting a truncated stored entry
# 792da673 COMPRESS-460 rudimentary javadocs and tests
# 430e1267 COMPRESS-459 record change
# af6fe141 COMPRESS-455 handle APK Signing Block
# 16e358e2 COMPRESS-457 improve resource cleanup in close() implementations
# c03704d7 COMPRESS-456 adapt description to code change
# f5571df0 COMPRESS-456 ensure we import all packages we actually need
# a080293d fix edge case vulnerability detected by @DidierLoiseau
# b5401c47 Merge tag 'rel/1.17' and prepare next iteration
# 83900471 typos
# c2ace886 COMPRESS-454 search for STORED data descriptor stopped too soon
# a1d952c2 COMPRESS-453 record change
# 6edf2fc7 changes report doesn't seem to allow HTML
# 34cf64fa COMPRESS-452 document new constructors
# 0aeda4fc COMPRESS-451 reject 0 buffersize in IOUtils.copy
# ff10aeaa wrong ticket number
# e15c80ae COMPRESS-443 provide a custom InputStream for special skip problems
# ffb618d5 COMPRESS-445 provide statistics for 7z as well
# eee4d197 COMPRESS-445 make most CompressorInputs implement InputStatistics
# 0daa0c9b COMPRESS-443 record test
# c6689ab7 COMPRESS-445 document change
# bd3e6cf2 COMPRESS-447 turn ArrayIndexOutOfBoundsExceptions into ZipExceptions
# 7a8f3c37 record change, closes #63
# 8faba699 COMPRESS-446 fix resource leak in ParallelScatterZipCreator#writeTo.
# 67c2f681 Merge tag 'rel/1.16.1'
# 3d76662c record removal of objenesis dependency
# b5204113 prepare RC1 of 1.16.1
# c70dc2eb COMPRESS-442 fix OSGi manifest
# 0c644264 Merge tag 'rel/1.16', prepare for next iteration
# 66607ddc optionally preserve the drive letter on Windows
# d8e4e255 record changes, closes #61, many thanks to @shahabkondri
# 43e8d3d5 COMPRESS-441 simplify code for zlib dummy byte workarounds
# c66db899 COMPRESS-436 sanity check compressed size is known for bzip etc
# 738c708b COMPRESS-437 add read-only DEFLATE64 support to 7z
# 5b004bfc COMPRESS-440 record change
# 49f65470 COMPRESS-407 make changed defaults more explicit
# 3ead6780 changes.xml wasn't well formed
# 135dd48f COMPRESS-438 buffer bounded streams in ZipFile for better performance
# 6ef3fd45 COMPRESS-380 lost Christian's name during merge
# b18ef2a1 Merge branch 'COMPRESS-380'
# eb32d62f record change
# 87a3cfaf COMPRESS-380 document DEFLATE64 support
# c3be6fb3 Update XZ for Java dependency
# ecd1fbe0 Revert "update zstd and xz dependencies" - XZ now requires Java8
# 0691adfa update zstd and xz dependencies
# ecb6e94a COMPRESS-424 record fix
# 34b75c6f add write support for Zstandard
# 6ae716d4 COMPRESS-432 record fix
# 9db50286 COMPRESS-435 Replaces instanceof checks with a type marker in LZ77 support code.
# 78cb9bf3 record fix for COMPRESS-430
# a0aec901 COMPRESS-425 add auto-detection of Zstandard inputs
# 099cdc21 COMPRESS-423 it's Zstandard not ZStandard
# ce5ada6c COMPRESS-423 documentation for ZStandard
# 129032f4 Merge tag 'rel/1.15' and prepare for next iteration
# c82dc1fc COMPRESS-409 remove internal buffering from TarArchiveOutputStream
# 5b3ff035 COMPRESS-421 record fix
# 44177914 Typos.
# 990df6f8 Typo.
# 934b97e9 Typos.
# 52cb7925 COMPRESS-417 record change
# 9ae52491 COMPRESS-410 record change
# 9052f4df COMPRESS-416 document X5455 fix
# 5481dd32 [COMPRESS-413] Travis build redundantly repeats compilation and tests redundantly #43. Patch applied except removal of Oracle 7 and 8 from Travis build. Closes #43.
# 446843e1 COMPRESS-415 fix capitalization of CpioArchive(Entry|InputStream)
# 53b45071 COMPRESS-400 record changes
# fb9b6180 COMPRESS-407 record backwards incompatible change
# 8c3201bb COMPRESS-412 record change.
# 8a6d8a57 record changes for COMPRESS-405
# 0d8ab18c COMPRESS-406 record fix
# 1fc6f8b0 COMPRESS-397 document change
# 6917adc1 COMPRESS-396 bring back OSGi Import-Package for XZ for Java
# d75b8985 COMPRESS-394/395 use same "version needed to extract" in LFH and CDH
# 46975213 Merge tag 'rel/1.14' and prepare for next cycle
# 86fbbe28 COMPRESS-391 record fix
# abfdf35f COMPRESS-393 don't try to invoke LZMAOutputStream#flush
# 092bcac5 COMPRESS-390 record change
# a793612b [COMPRESS-392] Add Brotli decoder based on the Google Brotli library.
# 0ee8f1e8 COMPRESS-389 only increment loc when anything has been read
# 5def510d Merge branch 'COMPRESS-382'
# 08f0aba1 COMPRESS-388 record merged PR
# f668f7bb COMPRESS-387 record changes
# f05101e2 COMPRESS-385 some tweaks to Tim's code, allow detection of 7z
# 2cf57511 COMPRESS-385, add ArchiveStreamFactory; undo boneheaded RELEASE-NOTES.txt fiasco.
# 44d376b7 record Daniel's fix, closes #17
# 7b5816d9 Merge branch 'PR13' closes #13 by @thomasmey
# ea85631d COMPRESS-271 record LZ4 support
# c59fc43c COMPRESS-379 fix symlink logic
# 5a5abeeb COMPRESS-358 make block size configurable in framed snappy input
# 4282bc34 COMPRESS-378 record fixes to SnappyCompressorInputStream
# 6ac58a59 COMPRESS-246 support for framed Snappy format
# 35891d3b bump version
# c497504c COMPRESS-372 record changes
# 85184c3a COMPRESS-377 properly close StreamCompressor
# 726ba6f0 COMPRESS-367 record Mike Mole's patch
# 66726eab COMPRESS-375 record changes made by Plamen
# 9238eab6 COMPRESS-374 support writing LZMA in 7z archives
# e8cee818 copy paste error
# 7117039b COMPRESS-373 support for writing legacy lzma streams
# 22edc12a [COMPRESS-369]
# f965bc23 [COMPRESS-368]
# 57511f57 COMPRESS-327 update documentation
# 9e32a2ce record fix for COMPRESS-364
# f0102601 COMPRESS-366 clarify TarArchiveEntry javadocs
# 52dd5908 COMPRESS-363 properly handle overflow inside BitInputStream
# f5a98515 [COMPRESS-360] Update Java requirement from 6 to 7.
# f8e09945 [COMPRESS-360] Update Java requirement from 6 to 7.
# 9a677fbe Bump to next development version
# 712e7c10 Note re finalizer guarantee
# 2424036c COMPRESS-357 - no longer invoke finish from finalize
# f87a7ce9 Revert "fix COMPRESS-357 with a volatile flag"
# 8769bb69 fix COMPRESS-357 with a volatile flag
# c86cc39a record COMPRESS-352 as fixed
# b5071c2f COMPRESS-351 CPIO InputStream sanitizes file names now
# 57107c01 typo in method name
# 952a5037 COMPRESS-357 better synchronize finished method
# 823cdee9 COMPRESS-356 properly deal with PAX header entries ending in slash
# 19a620c9 COMPRESS-355 properly deal with blank PAX header lines
# f59dd65c assuming COMPRESS-348 is fixed now
# 3083ea53 COMPRESS-354 make PureJavaCrc32C final
# 59e7352a [COMPRESS-353] Javadoc for BZip2CompressorInputStream.BZip2CompressorInputStream(InputStream, boolean) should refer to IOEx, not NPE.
# ed12d595 [COMPRESS-353] Javadoc for BZip2CompressorInputStream.BZip2CompressorInputStream(InputStream, boolean) should refer to IOEx, not NPE.
# c84c34e8 statement similar to what we did when we required Java5
# 9cc0604f [COMPRESS-350] TarArchiveEntry wastefully allocates empty arrays.
# 35d616f8 [COMPRESS-349] Update requirement from Java 5 to 6.
# 3cbd999c Merge tag 'rel/1.11' and bump version
# 62f86d5c COMPRESS-346 support star PAX headers for sparse files
# c37115b7 COMPRESS-347 support for global PAX headers
# af2da2e1 COMPRESS-345 add support for GNU sparse files using PAX dialects
# a5eca568 COMPRESS-344 accept NUL as terminator for GNU extended names
# 9ff8334f COMPRESS-341 listing of 7z archives
# 6e9acfa6 record fix for COMPRESS-343
# c02b2d50 created a separate issue for "skipping" in COMPRESS-340
# 687b360f record change, closes #10
# 1d66f120 document Dawid's changes
# 32633c39 COMPRESS-336 properly parse prefix in xstar tar headers
# 7250daa4 COMPRESS-335 yet another strange case of tar checksum
# 36335e3f COMPRESS-334 ArArchiveInputStream fails for BSD long names
# b67a1469 Added buffering for random access which speeds up 7Z support. (by Dawid Weiss)
# 1fb42987 COMPRESS-331 make tar checksum check as strict as GNU tar
# 7a6e507d COMPRESS-323 ZipFile.getRawInputStream is public now
# e0a76ac4 record two changes made over the past two weeks
# 30f1ac1d COMPRESS-332 snappy stream returns 0 when it should return -1
# af72adb5 Fixed typo
# a184b3ad record read-only support for ZIP
# a2cda30b COMPRESS-326 adjust tests to changes in Java's zip package
# 1e592b52 COMPRESS-324 document why tars may look like they do
# 1930eed8 COMPRESS-324 be more lenient when detecting GNU tar extensions
# e6e24766 COMPRESS-321 X7875_NewUnix doesn't handle centra directory correctly
# b1e2a02c prepare for new development
# 8682c8d4 COMPRESS-317 ArrayIndexOutOfBoundsException in ZipArchiveEntry#getMergedFields
# b72b5c71 COMPRESS-316 detect DEFLATE streams with ZLIB header, submitted by Nick Burch
# 3c4a09bf COMPRESS-314 read group/user ids > 0x80000000 from (posix) tars
# 24a3100e COMPRESS-315 allow tar entries with gid/uid > Integer.MAX_INT
# 6e8bb882 COMPRESS-313 add auto-detection for LZMA streams
# f24b9fd5 sort 1.10 changelog entries by date
# 31b546ae COMPRESS-312 normalize filename in TarArchiveEntry's (File, String) constructor
# af1f8163 don't read system properties for default charset - COMPRESS-308
# 4355c0d2 add/fix a few dates in changes report
# 5cf68bdc return 0 from read when asked to read 0 bytes - COMPRESS-309
# d50feb67 COMPRESS-306 ArchiveStreamFactory fails to pass on the encoding when creating some streams.
# 0b33b142 COMPRESS-302 Restore immutability/thread-safety to ArchiveStreamFactory.
# 121cae77 COMPRESS-303 Restore immutability/thread-safety to CompressorStreamFactory.
# 8e7d71fc Easier to read outline in Eclipse IDE if issue number is put first
# e0c0a10d Synch with RN contents
# 70900a3c Updated changes.xml, fixed a small javadoc issue
# e707c823 throw a special exception when there is no password for an encrpyted 7z archive - COMPRESS-298
# 8aa559f2 record fix for COMPRESS-290
# 14187056 Cut overall object instantiation in half by changing file header generation algorithm, for a 10-15 percent performance improvement when archive contains lots of small files.
# bc685791 record @krosenvold's changes for COMPRESS-295
# 56c83a5d COMPRESS-297 only mark file as non-closed when it can be read
# 7ac9b8e0 document change in package structure
# de633069 moving forward
# 2ebeef52 grammar
# 23d15f6c COMPRESS-289 applies to PAX-headers as well
# 99dfe90a record fix of COMPRESS-289
# 8d547cab COMPRESS-285 docs
# f86a4986 COMPRESS-286 tell LZMAInputStream the amount of data to expect
# 7e6c7136 COMPRESS-287 ignore unknown properties in 7z file headers
# 5c0f2b23 COMPRESS-263 add DEFLATE support, submitted by Matthias Stevens
# b7b5e5e8 post-release merging and bumping
# c42e4917 typo
# b32018ec change version of next release to 1.8.1
# c9c15659 COMPRESS-280 don't call read in TarArchiveInputStream#skip
# ddb5fd6d COMPRESS-279 detect a truncated tar archive and throw an exception
# 1ea7e01e COMPRESS-278 all empty numeric fields should be ignored in tars
# 383d9039 fix date
# 5ab06da2 COMPRESS-273 sprinkle in a few null checks
# 8e5f665d COMPRESS-274 unnanmed entries cause trouble for ChangeSet#delete*
# a1379c09 ArjArchiveInputStream#canReadEntryData wasn't checking the entry it was supposed to check
# c28a1c05 actually, these have been bug fixes
# aa0c705e COMPRESS-276 verify there is a current archive entry before reading from or writing to the stream
# 557800a5 COMPRESS-277 make sure IOUtils#skip deals with streams that return 0 on skip even though more could be read
# c5f9ceb3 COMPRESS-272 add auto-detect for .Z
# 627e1bb7 COMPRESS-270 record fix
# 61792c92 Mark the dependency on org.tukaani:xz as optional
# a0a8f3c9 open for next iteration
# 2db47810 make XML valid
# 02006b5c COMPRESS-257 Lasse has released XZ for Java 1.5
# 59c17803 COMPRESS-257 turn error thrown by XZ into a more useful exception
# e9364369 add delta filter to 7z
# 891f0565 COMPRESS-258 read back some of the method's options as well
# 845b3707 COMPRESS-261 allow content compression to be overriden per entry
# 1144ed74 COMPRESS-266 document changes
# d3cbe226 wrong dates and a typo
# a99d1e3d COMPRESS-267 throw a specific exception in ArchiveStreamFactory if asked to read/write 7z - or any other future format we don't support streaming for
# c608c330 COMPRESS-265 tariling backslashes are as bad for PAX headers as trailing slashes - on Windows
# aed56110 COMPRESS-264 make sure the very first read operation actually fills the ByteBuffer
# 8da37729 COMPRESS-262 be more lenient when parsing tar headers as some dialect use up all space for big numbers
# 7c068db3 COMPRESS-260 provide read access to GZIP metadata
# 07b15a15 COMPRESS-259 also honor decompressConcatenated when the format has been specified explicitly
# cbb5a1ad COMPRESS-256 bad calculation of LZMA dictionary sizes
# 71e4eead no longer try to read one byte ahead in BZip2CompressorInputStream - COMPRESS-253
# ad634c0c prepare for next development iteration
# 96947344 record fix for COMPRESS-252
# 34ad7f3a try-with-resources support for the *File classes
# f9487ac1 Explode support for ZipFile and ZipArchiveInputStream (COMPRESS-115)
# 1b47ffe3 Support shrunk entries in ZipArchiveInputStream
# 30e3ded8 sort by date
# 3c6e807d GzipCompressorOutputStream revamp to support custom compression level and header metadata (COMPRESS-250)
# 408b4a54 add a test for unshrinking support in ZipFile
# 09a4199d COMPRESS-242 make X5455_ExtendedTimestamp more convenient
# b0cd9d48 track .Z and Snappy additions
# b3302339 wrong fix-date
# 2221ee87 COMPRESS-245 TarArchiveInputStream might fail to read a stream if a single call to read() returns less than a full record
# db0ea954 COMPRESS-244 might overflow a 32bit int in SevenZFile#readUint64 - based on patch by Nico Kruber
# 46600216 COMPRESS-241 SevenZOutputFile#closeArchiveEntry throws XZException on Java8
# 61741ade preparations for next version
# eb9318d8 [COMPRESS-240] ZipEncodingHelper.isUTF8(String) does not check all UTF-8 aliases.
# 4a154174 release preparations
# c90c2dfa update documentation
# f3d34aa6 allow format-detection to deal with blocking inputs - COMPRESS-239
# 40e16ccc properly document the current level of support provided for 7z
# cd47ed96 XZ for Java 1.4 has been released, merge the LZMA branch.
# 90b73bf9 Add encoding support to CPIO package - related to COMPRESS-180
# 5972cab6 Add encoding support to DumpArchiveInputStream - related to COMPRESS-180
# 866f6d2e typo
# 2ba22033 COMPRESS-237 properly write TAR entries with long link names.  Patch by Emmanuel Bourg
# 040e42d0 COMPRESS-236 - CpioArchiveInputStream doesn't like Redline RPM's archives.  Patch by Andrew Duffy
# a671a703 COMPRESS-234 read/skip performance improvements to TarArchiveInputStream - patch by BELUGA BEHR
# d2bcb037 COMPRESS-233 performance and readability tweak for TarBuffer
# d57a6629 COMPRESS-232 improve readability of TarArchiveInputStream
# 026afc55 keep track of changes
# 601e4d7d COMPRESS-229 properly parse GNU_LONGLNK entries, patch by Christoph Gysin
# e860d2f3 COMPRESS-228 be more lenient when parsing zip64 extra field
# d4baeb15 COMPRESS-223 fix NPE in TarBuffer.tryToConsumeSecondEOFRecord - patch by Jeremy Gustie
# a7be29e1 1.5 has been released
# 01c3fe92 COMPRESS-200 support decompressConcatenated in CompressorStreamFactory
# 62200b41 COMPRESS-221 make XZ for Jaca truely optional for CompressorStreamFactory, based on patch description by Matt Quigley
# d9b55961 COMPRESS-219 reading stored entries could try to read past the end of the internal buffer
# 853576ac COMPRESS-218 Typo in CompressorStreamFactory Javadoc
# b19fe701 fix changelog comment about XZ not providing a bundle
# 6caf54d7 XZ for Java 1.2 is a proper OSGi bundle, update dependency version
# bb74f0c4 COMPRESS-205 - allow tests to pass even if source tree is placed in strange directories.  Based on patch by Daniel Lowe
# 7181d54f consume remainder of ZIP when last LF-entry has been read
# 3161093a Don't close dump's input when the archive has been consumed
# 79a7d826 COMPRESS-206 read second Tar-EOF record as well, if there is one.  Based on patch by Peter De Maeyer
# df4c479d COMPRESS-215 improve central directory location for Zip32 archives, based on patch by Robin Power
# 8f398dde changes.xml for COMPRESS-214
# 2a2c5fcf added COMPRESS-210, COMPRESS-211, and COMPRESS-213 to changes.xml.  Added myself to pom.xml.
# a2f978e9 COMPRESS-172 reuse temporary byte-arrays in several places to reduce garbage collection pressure - inspired by a patch by Thomas Mair
# f4044dd0 COMPRESS-212 use specified encoding when reading GNU long names in TarAIS
# ec0f5850 COMPRESS-159 make ChangeSetPerformer work on ZipFiles as well
# 65837142 COMPRESS-201 add an additional convenience constructor to TarArchiveEntry
# 376f7d6e record changes WRT COMPRESS-208
# ca5721d1 Credit, where credit is due.  These guys did the whole bug analysis, I only had to write small snippets of code following their suggestions
# e2cf412a COMPRESS-189 Inflater may return 0 if it needs more input, we don't handle this case properly
# 09b8f6d7 COMPRESS-203 the "file name" of a PAX header must not end with a slash or it is mistaken as a directory
# e9d7bcf5 COMPRESS-200 use the backing array of the returned ByteBuffer properly
# 73603cd6 COMPRESS-199 XZ for Java doesn't provide an OSGi bundle, mark the dependency as optional
# c96b2e2f COMPRESS-188 improve exception method for unsupported compression methods in zips.  Submitted by Harald Kuhn
# 2ab43b0a COMPRESS-192 add an encoding option to ArchiveStreamFactory for zip and tar.  Based on patch by Jukka Zitting
# 9bdacbfb COMPRESS-191 ArchiveStreamFactory false positive for tar format.  Submitted by Jukka Zitting
# c567466f site updates post-release
# 15883a6e record changes
# bbb461e0 1.4 has been released, move on to 1.5-SNAPSHOT
# 7badf0e3 Fix how to run docs
# 96292659 optionally use PAX headers when writing non-ASCII file names.  COMPRESS-183
# 4f42b00e feels like yesterday
# c2bc7a49 properly parse non-ASCII content in PAX extension headers.  COMPRESS-184
# 42398710 rename bigFileMode to bigNumberMode.  COMPRESS-182
# 40f2e638 workaround for tar implementations that insert a NUL byte into header fields.  COMPRESS-181
# c75c10fa add workaround for broken implementations that use backslashes rather than slashes in file names.  COMPRESS-176
# 432543da COMPRESS-131 ArrayOutOfBounds while decompressing bz2. Added test case - code already seems to have been fixed.
# bc84d208 COMPRESS-178 TarArchiveInputStream throws IllegalArgumentException instead of IOException
# 915e8ef9 COMPRESS-179 TarUtils.formatLongOctalOrBinaryBytes() assumes the field will be 12 bytes long
# 7ee6b67c COMPRESS-175 - GNU Tar sometimes uses binary encoding for UID and GID
# a933173f Only assume a TAR is a TAR if it at least contains one 512 byte block.  COMPRESS-171
# 00cc49e7 throw an IOException rather than a RuntimeException for a certain type of corrupted ZIPs.  COMPRESS-169
# f90c1cba documenation for big file support and PAX support fro writing long file names in tar.  COMPRESS-165 and COMPRESS-166
# c4704beb test that proves PAX archives with big entries are read correctly.  COMPRESS-16
# 34766064 ZipFile doesn't work properly for unicode extra fields.  Based on patch by Volker Leidl.  COMPRESS-164
# 6846564d Add read-support for big files using GNU tar extensions.  write support will be added later.  Based on patch by John Kodis.  COMPRESS-16
# fa237ccb document support for concatenated streams
# 20fd83a9 support uncompressing concatenated .bz2 files.  COMPRESS-146.  Submitted by Lasse Collin
# e166fa74 documentation for XZ
# 3447a368 1.3 has been released, open up for 1.4
# fdac1475 TarArchiveOutputStream's getBytesWritten doesn't work.  COMPRESS-160
# f4ff2000 obviously incomplete documentation for pack200 streams.  COMPRESS-142
# 67248f09 Add documentation for dump support.  COMPRESS-132
# 3ae0c50f document ZIP64 support
# 1b915c70 support writing of BSD dialect AR archives with long file names.  COMPRESS-144
# c84526b1 typo
# 0299191f Bzip2CompressorInputStream never called count() - reported by Lasse Collin
# d48f106f finalize deflater and inflater instances in ZIP streams.  COMPRESS-152
# 7df24265 interim commit for a site build with release date but 1.2 Javadocs
# 947e9836 newly generated release notes, add a blurb on Java 1.4 compatibility
# a9bd2e29 For non-ZIP64 entries this should actually fix COMPRESS-129
# 2b90da6d document limited sparse file support in tar package.  COMPRESS-145
# eedeff97 detect sparse entries in tar and allow users to skip them.  Submitted by Patrick Dreyer.  COMPRESS-145
# 934a96e0 Provide access to the raw bytes that made up the ZIP entry's name.  COMPRESS-123
# 7a76c479 'our' skip method will not return early.  COMPRESS-130
# 541898ff AR entries may contain blanks in groupId or userId.  Submitted by Treykaz.  COMPRESS-140
# b4d7505f Make sure Inflator is cleaned up.  COMPRESS-139
# 8c2e5e69 add a finalize method to ZipFile as suggested on the user list
# 60d6b6ac COMPRESS-117 Certain tar files not recognised by ArchiveStreamFactory Check if first entry can be read as a Tar entry
# 9f68b5d3  COMPRESS-125 BZip2CompressorInputStream throws IOException if underlying stream returns available() == 0.  Removed the check.
# 8376ecf5 COMPRESS-127 Calling close() on inputStream returned by CompressorStreamFactory.createCompressorInputStream() does not close the underlying input stream
# 86aaf84a provide access to TarArchiveEntry's knowledge of the entry's type.  COMPRESS-122
# 7dd4301e typo
# 1eb9dbb7 write all buffered data to the stream in TarArchiveOutputStream#finish.  COMPRESS-119
# 75c87114 COMPRESS-72 - Move acknowledgements from NOTICE to README
# 35e4e4fb COMPRESS-113:  TarArchiveEntry.parseTarHeader() includes the trailing space/NUL when parsing the octal size
# 78e0f2c7 Another fix
# dfc66383 COMPRESS-108: add initial implementation of command-line interface to list archive contents
# 050db3da COMPRESS-118:  TarUtils.parseName does not properly handle characters outside the range 0-127
# c83d9f71 COMPRESS-112 ArArchiveInputStream does not handle GNU extended filename records (//)
# 27dea24d Trailing spaces
# 23bfa665 Update changes list
# 8fcd06e4 COMPRESS-110 Support "ustar" prefix field Document change
# 58c4dad1 Remove reference to removal of method that was never released
# 69f6d061 Recent changes
# 6021ccbc Add profile "relnotes" so can optionally override changes plugin template. This means that the changes plugin can still be used to generate the announcement. Changes plugin does not need to be mentioned in build section.
# 886f71b4 Synch with JIRA Fix versions
# 48882f1d Add release-notes.vm for generating RELEASE-NOTES.txt
# 03e94a45 optionally read STORED entries with data descriptors.  COMPRESS-103
# 62cb9c48 provide access to the general purpose bit flag field of a zip entry and fail when a STORED entry requires a data descriptor.  COMPRESS-100
# d7ea9ff0 Check a data descriptor actually uses the signature before skipping too many bytes if it doesn't.  COMPRESS-101
# 30e1cc85 provide more information if an entry cannot be read/written.  OCMPRESS-98
# ade93793 return Zipentries in predictable order.  COMPRESS-99
# 292e1851 make archive/compressor name constants public.
# e0692eca canRead => canReadEntryData as discussed on the list
# 9e94237b typo
# a33505b5 move canRead/canWrite up.  Remove isSupportedCompressionMethod.  COMPRESS-93
# e0ffbc11 document fix for COMPRESS-89 which was based on a contribution by Antoni Mylka
# a1015f31 properly count bytes read.  COMPRESS-74
# 315b9473 document fix for COMPRESS-85
# 91695e47 Allow extra fields to violate the recommended structure.  COMPRESS-73
# 124f97c1 improve error message for unparseable extra data.  COMPRESS-73
# e7517b8d Applied COMPRESS-95 from Joerg Bellmann: Improve ExceptionMessages in ArchiveStreamFactory
# 5066e9ae ZipArchiveEntry#equals is broken if the String-arg constructor is used.  COMPRESS-94 - submitted by Anon Devs
# dc3fc470 make ZipArchiveInputStream deal better with truncated archives.  Submitted by Antoni Mylka.  COMPRESS-87
# 7bb5d886 properly indicate "oldgnu" mode for long file name entries in tar.  COMPRESS-86
# 3e2ddad1 The tar Ant task has a usecase where absolute paths inside archives are required - allow creation of such entries
# 7be8ef66 document today's changes
# 47b706e1 Add a BZip2Utils class matching GZipUtils.  Submitted by Jukka Zitting.  COMPRESS-78
# 2318ba30 clear block after write to avoid garbage in the final block if it isn't full.  COMPRESS-81.  Merge from Ant.
# 35ac05e6 inital release
# f03f2f96 +) Cleaned up the site generation +) enabled Cobetura again +) add PMD reports +) add assembly descriptors +) fixd a few minor issues for moving it to commons-proper

# %%
#i.	How many time has each affected file of the current fixing commit 
#been modified in the past since their creation (including rename of the file)? Hint: git log
#Affected File1
log_data = repo.git.log("--oneline",affected_file1).splitlines()
print("Number of commits in between:", len(log_data))
for line in log_data:
    print(line)
# Out:
# Number of commits in between: 132
# d3a0a309 COMPRESS-491 InputStream contract says "return 0 if length is 0, don't try to read"
# b2f97b24 avoid NPE warning in Sonar
# f5d0bb1e COMPRESS-483 throw exception if stored DD doesn't match what has been read
# d3ed06a0 COMPRESS-482 ensure there is enough data available for a DD
# 82986dd1 COMPRESS-482 stored with data descriptor now works without DD signature
# 88e26c9f Revert "COMPRESS-479 introduce a parameter class for zip readers"
# 0c4f64c2 COMPRESS-479 introduce a parameter class for zip readers
# 1b3f112b Javadoc: Use "file name" instead of "filename". Camel case vars "filename" to "fileName".
# 087e4a9d make Sonar less unhappy
# a41ce689 COMPRESS-463 throw exception when detecting a truncated stored entry
# 22b0d062 whitespace
# af6fe141 COMPRESS-455 handle APK Signing Block
# c2ace886 COMPRESS-454 search for STORED data descriptor stopped too soon
# be86c623 COMPRESS-445 fix stats for Stored entries in ZipArchiveInputStream
# 0646aa7d COMPRESS-445 try to get compressed count for all supported methods
# 02c963a4 COMPRESS-445 provide statistics when uncompressing
# 77785336 ensure all skip call go through IOUtils.skip
# f35ff5f4 use https in javadoc links where possible
# c66db899 COMPRESS-436 sanity check compressed size is known for bzip etc
# b18ef2a1 Merge branch 'COMPRESS-380'
# d549178f COMPRESS-429 also set NameSource from within stream
# 27b16a26 COMPRESS-380 support data descriptors with ENHANCED_DEFLATED
# bca3b08b small fixme
# ccc3067f COMPRESS-380 add DEFLATE64 support to ZipArchiveInputStream
# 6b12eab8 Remove trailing white spaces on all lines.
# 19e1b02f silence Sonar where we intentionally break its rules
# 3bf400ed COMPRESS-390: Expose stream offsets and size
# c61c68d8 rename instance fields that look like class fields
# 6b75de47 silence Sonar where I disagree with it
# 8705e97f trivial fixes of "bugs" reported by Sonar
# f0153448 COMPRESS-367 Throw ZipException on invalid entry with ZipArchiveInputStream
# 658812c8 ZipArchiveInputStream.closeEntry fails to advance
# 318de9ae COMPRESS-351 extract method that sanitizes file names
# ddb8f08c COMPRESS-351 try to sanitize entry name in exception message
# 3f2c760a Add final modifier to local variables.
# 478bef36 Add final modifier to method parameters.
# 8954b8be Refactor magic string.
# ab85f00b These static fields should be accessed directly.
# f9334473 plug a few more native memory leaks
# 6eac426d Implement uncompressing of BZip2 compressed entries in ZipArchiveInputStream
# 9e1ac896 lots of useless javadoc tags to make site build work on Java8
# 171c3ac8 COMPRESS-318 document ZipArchiveInputStream's limitations in the javadocs
# d50feb67 COMPRESS-306 ArchiveStreamFactory fails to pass on the encoding when creating some streams.
# deeb355c replace a few magic numbers with constants
# 26210c67 cosmetics
# aed56110 COMPRESS-264 make sure the very first read operation actually fills the ByteBuffer
# f9487ac1 Explode support for ZipFile and ZipArchiveInputStream (COMPRESS-115)
# 3fd6f60c data descriptor is not supported for shrunk entries
# 8d44f861 Changed canReadEntryData() to support shrunk entries
# 1b47ffe3 Support shrunk entries in ZipArchiveInputStream
# bfc8e03b Defer checking the inflater state to the readDeflated() method
# 429462a1 Formatting
# d11e8d1c Moved the entry crc into the CurrentEntry inner class
# 8bfb8987 Update the entry CRC in the main read() method only (fixes the CRC for stored entries with a data descriptor)
# c6c7ec48 Renamed the 'start' parameter in the read methods to 'offset' for consistency with the standard terminology
# c83c462d Exception chaining
# 29f975ea Replaced ZipArchiveInputStream.Buffer with a ByteBuffer
# 8301ee7f Modified ZipArchiveInputStream.Buffer to look more like a java.nio.ByteBuffer
# 345b8fc4 got my logic backwards, missing test?
# 655f35b6 some explicit checks as long as ZipArchiveInputStream doesn't support unshrinking
# 3685eeae one readFully method to rule them all
# c8733103 Removed the unnecessary @inheritDoc tags
# b86d8a6d Remove direct citations form APPNOTE.TXT in javadocs, obey to section 1.4.2 in http://www.pkware.com/documents/casestudies/APPNOTE.TXT
# df8b3b2e Avoid NPE warning
# d9b55961 COMPRESS-219 reading stored entries could try to read past the end of the internal buffer
# 2f69e63d Drop trailing spaces where file has at least one instance of multiple trailing spaces
# 7181d54f consume remainder of ZIP when last LF-entry has been read
# a6072ce3 Document why local buffers are used (and restrictions on their use)
# a2f978e9 COMPRESS-172 reuse temporary byte-arrays in several places to reduce garbage collection pressure - inspired by a patch by Thomas Mair
# 0d6defe9 COMPRESS-208 properly detect split ZIP files
# e10ce2c3 COMPRESS-208: skip over PK00 splitting marker which really only says 'nothing to see here'
# 92d8c57a explicitly fail when ZipArchiveInputStream reads a split/spanned archive
# b4a985f5 if the inflater needs a dictionary, that's worth an exception
# e2cf412a COMPRESS-189 Inflater may return 0 if it needs more input, we don't handle this case properly
# 2ab43b0a COMPRESS-192 add an encoding option to ArchiveStreamFactory for zip and tar.  Based on patch by Jukka Zitting
# 04173636 Change access using declaring type.
# 2bd0dd40 Normalize all @since tags to "@since version" instead of "@since Apache Commons Compress version"
# 3b3f4cf6 Unthrown Exception
# 9dd152d4 whitespace - and rename of local variables in ZAIS.bufferContainsSignature
# 794c20fe a few 'extract method' refactorings to make code more readable, still won't win a beauty-contest
# cadc527d work around unexpected result from Inflater#getBytesRead
# d48f106f finalize deflater and inflater instances in ZIP streams.  COMPRESS-152
# 04e132b7 separate state of stream from state of entry current being read from state of temporary buffer data is read into.  Document a few fields
# 1e708a04 don't rely on archives to implement ZIP64 correctly when reading the data descriptor.  Works around a bug in java.util.ZipArchiveOutputStream of Java7, may be useful for other implementations as well.  COMPRESS-148
# 679449a8 unused imports
# 5031a979 ignore 'version made by' and use the Zip64 field if present
# 3879e477 Assume a record is using ZIP64 if and only if the ZIP64 extended information extra field is present.
# 86590883 minor optimization
# 825b46d7 whitespace
# 6c5f04b0 first cut at reading Zip64 without any real tests, yet.  At least the existing test still pass.  COMPRESS-148
# e53e88aa Java5ify ZipArchiveInputStream implementation and related classes
# 3f1a7c49 use long returning methods in Java5's Inflater/Deflater.  Addresses COMPRESS-129.
# 934a96e0 Provide access to the raw bytes that made up the ZIP entry's name.  COMPRESS-123
# 797d74fd deal with entries of a size between Integer.MAX_VALUE and 2 * Integer.MAX_VALUE (size is unsigned in ZIPs).  COMPRESS-129.  As pointed out by Sebb the solution is incomplete and a more complete resolution is not possible without requiring Java5.
# 7a76c479 'our' skip method will not return early.  COMPRESS-130
# 8006d314 Javadoc tidyup
# 6209f812 @since markers Javadoc updates
# 03e94a45 optionally read STORED entries with data descriptors.  COMPRESS-103
# 02e2be6c STORED entry with data descriptors are not a problem for ZipFile and the output stream doesn't care anyway - so only check for the combination inside the input stream.
# 1154e7bb actually read content of data descriptor
# 62cb9c48 provide access to the general purpose bit flag field of a zip entry and fail when a STORED entry requires a data descriptor.  COMPRESS-100
# d7ea9ff0 Check a data descriptor actually uses the signature before skipping too many bytes if it doesn't.  COMPRESS-101
# b6814d4f extract common code
# e0692eca canRead => canReadEntryData as discussed on the list
# 734e6f78 if it's not a ZipArchiveEntry then the stream can't read/write it
# a33505b5 move canRead/canWrite up.  Remove isSupportedCompressionMethod.  COMPRESS-93
# c7e51ede detect encrypted entries and say that you can't read/write them.  COMPRESS-89
# 4d68ddae extract general purpose bit logic
# 2b209939 EFS in APPNOTE.TXT stands for 'Early Feature Specification' so our usage of it as 'use the general purpose field to signal UTF8' is wrong.
# a1015f31 properly count bytes read.  COMPRESS-74
# 41aa509d COMPRESS-93: Support for alternative ZIP compression methods
# b6886eb4 COMPRESS-93: Support for alternative ZIP compression methods
# 7b125a33 COMPRESS-93: Support for alternative ZIP compression methods
# dc3fc470 make ZipArchiveInputStream deal better with truncated archives.  Submitted by Antoni Mylka.  COMPRESS-87
# f84dd362 Only use the zip-extra-field if configured to do so and the entry didn't set the EFS flag - COMPRESS-70
# 7ae0eec9 Remove or document unused fields
# 4bce1fb1 COMPRESS-56: enabled counting read bytes in InputStreams and added this information to exceptions, where it seems to fit.
# f7f6b188 Javadoc
# 6117cc1f Remove unnecessary override methods
# fa526cb4 Empty Zip files start with End of Central directory
# 99870ef5 Not thread-safe
# 958e1bcf unused
# 008ca948 support as much as possible of ZipFile as a stream can do in ZipArchiveInputStream, COMPRESS-47
# eadbe116 correct signature detection of ZIP archives.
# a7049abc provide convenience getNext*Entry methods to ArchiveInputStream subclasses
# 3f9bcc69 fix whitespace
# 463d6ebd rename ZipEntry to ZipArchiveEntry
# af2b66db merge ZipEntry and ZipArchiveEntry into a single class
# dff90015 use length of signature read when trying to match input stream formats
# fa8fea76 whitespace only
# 743d7c54 some indentation changes and add myself to the POM
# ca165390 import of new redesign branch

# %%
#i.	How many time has each affected file of the current fixing commit 
#been modified in the past since their creation (including rename of the file)? Hint: git log
#Affected File2
log_data = repo.git.log("--oneline",affected_file2).splitlines()
print("Number of commits in between:", len(log_data))
for line in log_data:
    print(line)
# Out:
# Number of commits in between: 12
# 88e26c9f Revert "COMPRESS-479 introduce a parameter class for zip readers"
# 0c4f64c2 COMPRESS-479 introduce a parameter class for zip readers
# a41ce689 COMPRESS-463 throw exception when detecting a truncated stored entry
# acab253a Avoid some resource leak warnings
# 3f2c760a Add final modifier to local variables.
# 999821c2 Simplify
# 58fa9a67 COMPRESS-305 Convert all tests to JUnit4 style All but AbstractTestCase and subclasses
# bb74f0c4 COMPRESS-205 - allow tests to pass even if source tree is placed in strange directories.  Based on patch by Daniel Lowe
# b2a9dd0e Convert to enhanced for loop.
# d7119be6 Replace magic strings "UTF-8", "US-ASCII", and so on with references to a new .util class CharsetNames (like in other commons components.) The Charsets class will be more useful when [compress] moves to Java 6 and can use String#getBytes(Charset) instead of String#getBytes(String).
# c37c629d Tab police tidy code slightly
# dc3fc470 make ZipArchiveInputStream deal better with truncated archives.  Submitted by Antoni Mylka.  COMPRESS-87

# %%
#i.	How many time has each affected file of the current fixing commit 
#been modified in the past since their creation (including rename of the file)? Hint: git log
#Affected File3
log_data = repo.git.log("--oneline",affected_file3).splitlines()
print("Number of commits in between:", len(log_data))
for line in log_data:
    print(line)
# Out:
# Number of commits in between: 37
# f5d0bb1e COMPRESS-483 throw exception if stored DD doesn't match what has been read
# 82986dd1 COMPRESS-482 stored with data descriptor now works without DD signature
# a41ce689 COMPRESS-463 throw exception when detecting a truncated stored entry
# 64ed6dde ensure archive streams really mean EOF if they say so
# c66db899 COMPRESS-436 sanity check compressed size is known for bzip etc
# b18ef2a1 Merge branch 'COMPRESS-380'
# 77a0a69e move a few files around
# 0517c7f2 COMPRESS-429 tests
# 27b16a26 COMPRESS-380 support data descriptors with ENHANCED_DEFLATED
# ccc3067f COMPRESS-380 add DEFLATE64 support to ZipArchiveInputStream
# 6b12eab8 Remove trailing white spaces on all lines.
# 3bf400ed COMPRESS-390: Expose stream offsets and size
# f0153448 COMPRESS-367 Throw ZipException on invalid entry with ZipArchiveInputStream
# 658812c8 ZipArchiveInputStream.closeEntry fails to advance
# 32c30f6f More java7 language features
# 77388c82 Add final modifier to local variables.
# a1d6b33f COMPRESS-351 Testcase
# 3f2c760a Add final modifier to local variables.
# 6eac426d Implement uncompressing of BZip2 compressed entries in ZipArchiveInputStream
# aed56110 COMPRESS-264 make sure the very first read operation actually fills the ByteBuffer
# bc741b19 COMPRESS-264 add a (failing) Unit Test
# 8d44f861 Changed canReadEntryData() to support shrunk entries
# 1b47ffe3 Support shrunk entries in ZipArchiveInputStream
# 9ad93a93 Unused imports
# 60f4ac24 enable test for COMPRESS-219
# 340a3442 Disable test until I know we can include the zip that is needed for the test
# d9b55961 COMPRESS-219 reading stored entries could try to read past the end of the internal buffer
# 284b0450 Unused imports
# bb74f0c4 COMPRESS-205 - allow tests to pass even if source tree is placed in strange directories.  Based on patch by Daniel Lowe
# fdcf80df Oops, closed the stream too early
# 50b419b9 Remove spurious ; Ensure stream is closed
# 7181d54f consume remainder of ZIP when last LF-entry has been read
# 4497c3cb enable testcase for COMPRESS-189
# e2cf412a COMPRESS-189 Inflater may return 0 if it needs more input, we don't handle this case properly
# d7119be6 Replace magic strings "UTF-8", "US-ASCII", and so on with references to a new .util class CharsetNames (like in other commons components.) The Charsets class will be more useful when [compress] moves to Java 6 and can use String#getBytes(Charset) instead of String#getBytes(String).
# 10f26cba Javadoc syntax
# c75c10fa add workaround for broken implementations that use backslashes rather than slashes in file names.  COMPRESS-176

# %%
#j.	Which developers have modified each affected file since its creation? 
#Hint: git log
#AffectedFile
log_data = repo.git.log("--pretty=format:%an",affected_file).splitlines()
df = pd.DataFrame(log_data, columns=['Author'])
df['count'] = 1
answer1 = df.groupby(['Author']).count().reset_index(0, drop=False)
print(answer1)
# Out:
#                  Author  count
# 0   Christian Grobmeier      2
# 1        Emmanuel Bourg      4
# 2       Gary D. Gregory      1
# 3          Gary Gregory     11
# 4         Julius Davies      2
# 5    Kristian Rosenvold      3
# 6      Philippe Mouawad      1
# 7      Sebastian Bazley     29
# 8                  Sebb      1
# 9     Siegfried Goeschl      1
# 10          Simon Spero      1
# 11       Stefan Bodewig    326
# 12        Torsten Curdt      1
# 13             ggregory      4
# 14            tballison      1

# %%
#j.	Which developers have modified each affected file since its creation? 
#Hint: git log
#AffectedFile1
log_data = repo.git.log("--pretty=format:%an",affected_file1).splitlines()
df = pd.DataFrame(log_data, columns=['Author'])
df['count'] = 1
answer2 = df.groupby(['Author']).count().reset_index(0, drop=False)
print(answer2)
# Out:
#                  Author  count
# 0   Christian Grobmeier      1
# 1        Emmanuel Bourg     12
# 2       Gary D. Gregory      2
# 3          Gary Gregory      2
# 4         Jukka Zitting      3
# 5             Mike Mole      2
# 6      Sebastian Bazley     13
# 7        Stefan Bodewig     90
# 8           Sören Glimm      1
# 9         Torsten Curdt      1
# 10     Zbynek Vyskovsky      1
# 11             ggregory      4

# %%
#j.	Which developers have modified each affected file since its creation? 
#Hint: git log
#AffectedFile2
log_data = repo.git.log("--pretty=format:%an",affected_file2).splitlines()
df = pd.DataFrame(log_data, columns=['Author'])
df['count'] = 1
answer3 = df.groupby(['Author']).count().reset_index(0, drop=False)
print(answer3)
# Out:
#              Author  count
# 0   Gary D. Gregory      2
# 1  Sebastian Bazley      2
# 2              Sebb      2
# 3    Stefan Bodewig      5
# 4          ggregory      1

# %%
#j.	Which developers have modified each affected file since its creation? 
#Hint: git log
#AffectedFile3
log_data = repo.git.log("--pretty=format:%an",affected_file3).splitlines()
df = pd.DataFrame(log_data, columns=['Author'])
df['count'] = 1
answer4 = df.groupby(['Author']).count().reset_index(0, drop=False)
answer4
# Out:
#                Author  count
# 0      Emmanuel Bourg      2
# 1     Gary D. Gregory      1
# 2        Gary Gregory      2
# 3  Kristian Rosenvold      1
# 4           Mike Mole      2
# 5    Sebastian Bazley      5
# 6      Stefan Bodewig     21
# 7         Sören Glimm      1
# 8    Zbynek Vyskovsky      1
# 9            ggregory      1

# %%
#k.	For each developer identified, how many commits have each of them 
#submitted? From your observation, are the involving developers
#experienced (with many commits) or new ones (with few commits) or both? 
#Hint: git log or git shortlog
commit_authors = repo.git.shortlog("-sne", "--all").splitlines()

author_commits = []

for commit_author in commit_authors:
    commit, author = commit_author.split("\t")
    author_commits.append([int(commit), author])
df = pd.DataFrame(author_commits, columns=['Commit', 'Author'])
print(df)
# Out:
#     Commit                                             Author
# 0     1681                Stefan Bodewig <bodewig@apache.org>
# 1      437                 Sebastian Bazley <sebb@apache.org>
# 2       97         Christian Grobmeier <grobmeier@apache.org>
# 3       75              Gary D. Gregory <ggregory@apache.org>
# 4       60                 Gary Gregory <ggregory@apache.org>
# 5       48                 Emmanuel Bourg <ebourg@apache.org>
# 6       45                  Henri Yandell <bayard@apache.org>
# 7       42         Kristian Rosenvold <krosenvold@apache.org>
# 8       37                  Torsten Curdt <tcurdt@apache.org>
# 9       33              Gary Gregory <garydgregory@gmail.com>
# 10      29                     ggregory <ggregory@apache.org>
# 11      25                  Simon Spero <sesuncedu@gmail.com>
# 12      22                             Sebb <sebb@apache.org>
# 13      21                Niall Pemberton <niallp@apache.org>
# 14      20               Damjan Jovanovic <damjan@apache.org>
# 15      18                   Dirk Verbeeck <dirkv@apache.org>
# 16      16               Gary Gregory <gardgregory@gmail.com>
# 17      13                     tballison <tallison@mitre.org>
# 18      12               Dennis Lundberg <dennisl@apache.org>
# 19      11                   shahab <shahab.kondri@gmail.com>
# 20      10          Stefan Bodewig <stefan.bodewig@innoq.com>
# 21       8                  Julius Davies <julius@apache.org>
# 22       7    Michael Hausegger <michael.hausegger@tugraz.at>
# 23       7   ggregory <ggregory@US-L-GG02.rocketsoftware.com>
# 24       7        pascalschumacher <pascalschumacher@gmx.net>
# 25       6         Dawid Weiss <dawid.weiss@carrotsearch.com>
# 26       6                   Jukka Zitting <jukka@apache.org>
# 27       5                     Thomas Meyer <thomas@m3y3r.de>
# 28       5                Zbynek Vyskovsky <kvr000@gmail.com>
# 29       4         Stefan Bodewig <stefan.bodewig@freenet.de>
# ..     ...                                                ...
# 41       2                    Rene Preissel <rp@eToSquare.de>
# 42       2       Robert James Oxspring <roxspring@apache.org>
# 43       2                 Roel Spilker <r.spilker@gmail.com>
# 44       2                     Sören Glimm <git@uncleowen.de>
# 45       2          theobisproject <theobisproject@gmail.com>
# 46       1               Alex Bertram <alex@bedatadriven.com>
# 47       1  Andre F de Miranda <trixpan@users.noreply.gith...
# 48       1            Arne Babenhauserheide <arne_bab@web.de>
# 49       1               Aurélien Pupier <apupier@redhat.com>
# 50       1    Bruno P. Kinoshita <brunodepaulak@yahoo.com.br>
# 51       1                       Carmi Grushko <carmi@fb.com>
# 52       1  David Georg Reichelt <davidgeorg_reichelt@dage...
# 53       1                Hervé Boutemy <hboutemy@apache.org>
# 54       1     Ioana Leontiuc <i.leontiuc@student.tudelft.nl>
# 55       1               Jeanne Boyarsky <nyjeanne@gmail.com>
# 56       1                     Matt Hovey <matt@weirdkid.com>
# 57       1                     Matt Sicker <boards@gmail.com>
# 58       1          Matthew Jason Benson <mbenson@apache.org>
# 59       1  Michael Hausegger <hausegger.michael@googlemai...
# 60       1  Michael Hausegger <hausegger.michael@googlemai...
# 61       1                    Olivier Lamy <olamy@apache.org>
# 62       1                 Plamen Totev <plamenttv@gmail.com>
# 63       1                  Rob Tompkins <chtompki@gmail.com>
# 64       1              Robin Dupret <robin.dupret@gmail.com>
# 65       1            Sean Sullivan <github@seansullivan.com>
# 66       1            Siegfried Goeschl <sgoeschl@apache.org>
# 67       1           Yishai Galatzer <yigalatz@microsoft.com>
# 68       1         dcollin <dcollin@users.noreply.github.com>
# 69       1                    no_author <no_author@no_author>
# 70       1               tibordigana <tibordigana@apache.org>
#
# [71 rows x 2 columns]

# %%
def AddName(name1,name2,name3,name4): 
    final_list = [] 
    for name in name1: 
        if name not in final_list: 
            final_list.append(name)
    for name in name2: 
        if name not in final_list: 
            final_list.append(name)
    for name in name3: 
        if name not in final_list: 
            final_list.append(name)
    for name in name4: 
        if name not in final_list: 
            final_list.append(name)
    return final_list

com = df[["Commit"]].copy()
df = pd.DataFrame(df.Author.str.split(' <',1).tolist(),columns = ['Author','email'])
df["Commit"] = com["Commit"]
names1 = answer1["Author"].tolist()
names2 = answer2["Author"].tolist()
names3 = answer3["Author"].tolist()
names4 = answer4["Author"].tolist()
names = AddName(names1,names2,names3,names4)
for name in names:
    print(df[(df["Author"] == name)])
# Out:
#                 Author                  email  Commit
# 2  Christian Grobmeier  grobmeier@apache.org>      97
#            Author               email  Commit
# 5  Emmanuel Bourg  ebourg@apache.org>      48
#             Author                 email  Commit
# 3  Gary D. Gregory  ggregory@apache.org>      75
#           Author                    email  Commit
# 4   Gary Gregory     ggregory@apache.org>      60
# 9   Gary Gregory  garydgregory@gmail.com>      33
# 16  Gary Gregory   gardgregory@gmail.com>      16
#            Author               email  Commit
# 21  Julius Davies  julius@apache.org>       8
#                Author                   email  Commit
# 7  Kristian Rosenvold  krosenvold@apache.org>      42
#               Author                           email  Commit
# 39  Philippe Mouawad  p.mouawad@ubik-ingenierie.com>       2
#              Author             email  Commit
# 1  Sebastian Bazley  sebb@apache.org>     437
#    Author             email  Commit
# 12   Sebb  sebb@apache.org>      22
#                Author                 email  Commit
# 66  Siegfried Goeschl  sgoeschl@apache.org>       1
#          Author                 email  Commit
# 11  Simon Spero  sesuncedu@gmail.com>      25
#             Author                       email  Commit
# 0   Stefan Bodewig         bodewig@apache.org>    1681
# 20  Stefan Bodewig   stefan.bodewig@innoq.com>      10
# 29  Stefan Bodewig  stefan.bodewig@freenet.de>       4
#            Author               email  Commit
# 8   Torsten Curdt  tcurdt@apache.org>      37
# 31  Torsten Curdt   tcurdt@vafer.org>       4
#       Author                                   email  Commit
# 10  ggregory                    ggregory@apache.org>      29
# 23  ggregory  ggregory@US-L-GG02.rocketsoftware.com>       7
#        Author                email  Commit
# 17  tballison  tallison@mitre.org>      13
#            Author              email  Commit
# 26  Jukka Zitting  jukka@apache.org>       6
#        Author                      email  Commit
# 37  Mike Mole  michael.mole@lookout.com>       2
#          Author              email  Commit
# 44  Sören Glimm  git@uncleowen.de>       2
#               Author              email  Commit
# 28  Zbynek Vyskovsky  kvr000@gmail.com>       5
