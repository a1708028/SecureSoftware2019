# %%
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install pygithub
# !{sys.executable} -m pip install gitpython
# !conda install --yes --prefix {sys.prefix} git
# Out:
# Requirement already satisfied: pygithub in c:\users\shaun\anaconda4\lib\site-packages (1.43.8)
# Requirement already satisfied: pyjwt in c:\users\shaun\anaconda4\lib\site-packages (from pygithub) (1.7.1)
# Requirement already satisfied: requests>=2.14.0 in c:\users\shaun\anaconda4\lib\site-packages (from pygithub) (2.21.0)
# Requirement already satisfied: deprecated in c:\users\shaun\anaconda4\lib\site-packages (from pygithub) (1.2.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shaun\anaconda4\lib\site-packages (from requests>=2.14.0->pygithub) (2019.3.9)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\shaun\anaconda4\lib\site-packages (from requests>=2.14.0->pygithub) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\shaun\anaconda4\lib\site-packages (from requests>=2.14.0->pygithub) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\shaun\anaconda4\lib\site-packages (from requests>=2.14.0->pygithub) (1.24.1)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\shaun\anaconda4\lib\site-packages (from deprecated->pygithub) (1.11.1)
# Requirement already satisfied: gitpython in c:\users\shaun\anaconda4\lib\site-packages (3.0.2)
# Requirement already satisfied: gitdb2>=2.0.0 in c:\users\shaun\anaconda4\lib\site-packages (from gitpython) (2.0.5)
# Requirement already satisfied: smmap2>=2.0.0 in c:\users\shaun\anaconda4\lib\site-packages (from gitdb2>=2.0.0->gitpython) (2.0.5)
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
import numpy as np
import pandas as pd
import os

# Specify git executable file for GitPython in Jupyter Notebook (In IDE, it can still work without this line.)
os.environ["GIT_PYTHON_GIT_EXECUTABLE"] = "C:\Program Files\Git\cmd\git.exe"

import git
from git import RemoteProgress

from git import Repo
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

class Progress(RemoteProgress):
    def update(self, op_code, cur_count, max_count=None, message=''):
        print(self._cur_line)
        
remote_link = "https://github.com/apache/groovy"
local_link = "repo/apache"
# Uncomment to clone
Repo.clone_from(remote_link, local_link, progress=Progress())

repo = Repo(local_link)
fixing_commit = "4df8b652aa018a5d5d1cda8fba938bf3422db31c"
affected_file = "src/main/org/codehaus/groovy/runtime/MethodClosure.java"
# Out:
# remote: Counting objects:   6% (1/15)
# remote: Counting objects:  13% (2/15)
# remote: Counting objects:  20% (3/15)
# remote: Counting objects:  26% (4/15)
# remote: Counting objects:  33% (5/15)
# remote: Counting objects:  40% (6/15)
# remote: Counting objects:  46% (7/15)
# remote: Counting objects:  53% (8/15)
# remote: Counting objects:  60% (9/15)
# remote: Counting objects:  66% (10/15)
# remote: Counting objects:  73% (11/15)
# remote: Counting objects:  80% (12/15)
# remote: Counting objects:  86% (13/15)
# remote: Counting objects:  93% (14/15)
# remote: Counting objects: 100% (15/15)
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects:   7% (1/14)
# remote: Compressing objects:  14% (2/14)
# remote: Compressing objects:  21% (3/14)
# remote: Compressing objects:  28% (4/14)
# remote: Compressing objects:  35% (5/14)
# remote: Compressing objects:  42% (6/14)
# remote: Compressing objects:  50% (7/14)
# remote: Compressing objects:  57% (8/14)
# remote: Compressing objects:  64% (9/14)
# remote: Compressing objects:  71% (10/14)
# remote: Compressing objects:  78% (11/14)
# remote: Compressing objects:  85% (12/14)
# remote: Compressing objects:  92% (13/14)
# remote: Compressing objects: 100% (14/14)
# remote: Compressing objects: 100% (14/14), done.
# Receiving objects:   0% (1/313017)
# Receiving objects:   0% (2610/313017), 196.01 KiB | 333.00 KiB/s
# Receiving objects:   1% (3131/313017), 636.01 KiB | 587.00 KiB/s
# Receiving objects:   2% (6261/313017), 636.01 KiB | 587.00 KiB/s
# Receiving objects:   3% (9391/313017), 1.66 MiB | 1.05 MiB/s
# Receiving objects:   3% (11056/313017), 1.66 MiB | 1.05 MiB/s
# Receiving objects:   4% (12521/313017), 2.47 MiB | 1.15 MiB/s
# Receiving objects:   4% (14454/313017), 2.93 MiB | 1.10 MiB/s
# Receiving objects:   5% (15651/313017), 3.35 MiB | 1.06 MiB/s
# Receiving objects:   5% (17971/313017), 3.77 MiB | 1.02 MiB/s
# Receiving objects:   6% (18782/313017), 4.21 MiB | 1.00 MiB/s
# Receiving objects:   7% (21912/313017), 4.74 MiB | 1.01 MiB/s
# Receiving objects:   7% (22705/313017), 4.74 MiB | 1.01 MiB/s
# Receiving objects:   7% (24972/313017), 5.49 MiB | 1.04 MiB/s
# Receiving objects:   8% (25042/313017), 5.49 MiB | 1.04 MiB/s
# Receiving objects:   8% (26994/313017), 6.00 MiB | 781.00 KiB/s
# Receiving objects:   9% (28172/313017), 6.27 MiB | 738.00 KiB/s
# Receiving objects:   9% (29366/313017), 6.58 MiB | 716.00 KiB/s
# Receiving objects:   9% (30213/313017), 7.32 MiB | 694.00 KiB/s
# Receiving objects:   9% (31151/313017), 8.12 MiB | 646.00 KiB/s
# Receiving objects:  10% (31302/313017), 8.12 MiB | 646.00 KiB/s
# Receiving objects:  10% (31707/313017), 8.73 MiB | 656.00 KiB/s
# Receiving objects:  10% (32011/313017), 9.26 MiB | 658.00 KiB/s
# Receiving objects:  10% (32645/313017), 9.76 MiB | 623.00 KiB/s
# Receiving objects:  10% (33021/313017), 10.56 MiB | 621.00 KiB/s
# Receiving objects:  11% (34432/313017), 11.04 MiB | 641.00 KiB/s
# Receiving objects:  11% (34488/313017), 11.04 MiB | 641.00 KiB/s
# Receiving objects:  11% (35643/313017), 11.78 MiB | 673.00 KiB/s
# Receiving objects:  11% (37042/313017), 12.45 MiB | 704.00 KiB/s
# Receiving objects:  12% (37563/313017), 13.34 MiB | 795.00 KiB/s
# Receiving objects:  12% (38077/313017), 13.34 MiB | 795.00 KiB/s
# Receiving objects:  12% (39514/313017), 14.18 MiB | 803.00 KiB/s
# Receiving objects:  13% (40693/313017), 14.62 MiB | 794.00 KiB/s
# Receiving objects:  13% (41534/313017), 15.15 MiB | 817.00 KiB/s
# Receiving objects:  14% (43823/313017), 16.37 MiB | 961.00 KiB/s
# Receiving objects:  14% (43998/313017), 16.37 MiB | 961.00 KiB/s
# Receiving objects:  14% (45923/313017), 17.37 MiB | 1003.00 KiB/s
# Receiving objects:  14% (46773/313017), 19.10 MiB | 1.08 MiB/s
# Receiving objects:  14% (46834/313017), 19.66 MiB | 1.11 MiB/s
# Receiving objects:  15% (46953/313017), 19.66 MiB | 1.11 MiB/s
# Receiving objects:  15% (48231/313017), 20.64 MiB | 1.07 MiB/s
# Receiving objects:  15% (49878/313017), 22.18 MiB | 1.05 MiB/s
# Receiving objects:  15% (49878/313017), 23.02 MiB | 1012.00 KiB/s
# Receiving objects:  15% (49878/313017), 23.88 MiB | 931.00 KiB/s
# Receiving objects:  15% (49878/313017), 24.97 MiB | 955.00 KiB/s
# Receiving objects:  15% (49878/313017), 25.91 MiB | 935.00 KiB/s
# Receiving objects:  15% (49878/313017), 26.66 MiB | 898.00 KiB/s
# Receiving objects:  15% (49879/313017), 27.69 MiB | 964.00 KiB/s
# Receiving objects:  15% (49879/313017), 28.53 MiB | 927.00 KiB/s
# Receiving objects:  15% (49879/313017), 28.89 MiB | 765.00 KiB/s
# Receiving objects:  15% (49880/313017), 29.20 MiB | 732.00 KiB/s
# Receiving objects:  15% (49880/313017), 30.53 MiB | 757.00 KiB/s
# Receiving objects:  15% (49880/313017), 31.57 MiB | 756.00 KiB/s
# Receiving objects:  15% (49895/313017), 32.21 MiB | 825.00 KiB/s
# Receiving objects:  16% (50083/313017), 32.21 MiB | 825.00 KiB/s
# Receiving objects:  16% (51394/313017), 34.20 MiB | 1.10 MiB/s
# Receiving objects:  16% (51394/313017), 34.73 MiB | 1.13 MiB/s
# Receiving objects:  16% (51394/313017), 36.07 MiB | 1.21 MiB/s
# Receiving objects:  16% (51394/313017), 37.59 MiB | 1.32 MiB/s
# Receiving objects:  16% (51394/313017), 38.62 MiB | 1.26 MiB/s
# Receiving objects:  16% (51394/313017), 40.02 MiB | 1.28 MiB/s
# Receiving objects:  16% (51395/313017), 41.64 MiB | 1.39 MiB/s
# Receiving objects:  16% (51402/313017), 42.82 MiB | 1.31 MiB/s
# Receiving objects:  16% (52942/313017), 43.49 MiB | 1.29 MiB/s
# Receiving objects:  17% (53213/313017), 44.25 MiB | 1.34 MiB/s
# Receiving objects:  17% (56071/313017), 44.94 MiB | 1.37 MiB/s
# Receiving objects:  18% (56344/313017), 44.94 MiB | 1.37 MiB/s
# Receiving objects:  18% (58356/313017), 46.16 MiB | 1.33 MiB/s
# Receiving objects:  19% (59474/313017), 46.83 MiB | 1.30 MiB/s
# Receiving objects:  19% (61507/313017), 48.43 MiB | 1.35 MiB/s
# Receiving objects:  19% (61507/313017), 50.09 MiB | 1.44 MiB/s
# Receiving objects:  19% (61507/313017), 51.29 MiB | 1.40 MiB/s
# Receiving objects:  19% (61507/313017), 52.76 MiB | 1.46 MiB/s
# Receiving objects:  19% (61507/313017), 54.48 MiB | 1.53 MiB/s
# Receiving objects:  19% (61507/313017), 56.12 MiB | 1.50 MiB/s
# Receiving objects:  19% (61507/313017), 58.04 MiB | 1.63 MiB/s
# Receiving objects:  19% (61507/313017), 60.18 MiB | 1.81 MiB/s
# Receiving objects:  19% (61507/313017), 62.07 MiB | 1.85 MiB/s
# Receiving objects:  19% (61508/313017), 62.68 MiB | 1.81 MiB/s
# Receiving objects:  19% (61927/313017), 63.08 MiB | 1.43 MiB/s
# Receiving objects:  19% (62262/313017), 63.16 MiB | 1.25 MiB/s
# Receiving objects:  20% (62604/313017), 63.36 MiB | 902.00 KiB/s
# Receiving objects:  20% (62621/313017), 63.36 MiB | 902.00 KiB/s
# Receiving objects:  20% (62730/313017), 63.54 MiB | 462.00 KiB/s
# Receiving objects:  20% (62858/313017), 63.64 MiB | 178.00 KiB/s
# Receiving objects:  20% (63074/313017), 63.79 MiB | 153.00 KiB/s
# Receiving objects:  20% (63162/313017), 64.33 MiB | 229.00 KiB/s
# Receiving objects:  20% (63175/313017), 65.27 MiB | 374.00 KiB/s
# Receiving objects:  20% (63533/313017), 66.60 MiB | 621.00 KiB/s
# Receiving objects:  21% (65734/313017), 67.39 MiB | 853.00 KiB/s
# Receiving objects:  21% (67149/313017), 68.27 MiB | 1.01 MiB/s
# Receiving objects:  22% (68864/313017), 68.77 MiB | 1.09 MiB/s
# Receiving objects:  22% (69480/313017), 69.35 MiB | 1.17 MiB/s
# Receiving objects:  23% (71994/313017), 69.97 MiB | 1.23 MiB/s
# Receiving objects:  23% (74303/313017), 70.74 MiB | 1.31 MiB/s
# Receiving objects:  23% (74888/313017), 72.43 MiB | 1.43 MiB/s
# Receiving objects:  24% (75125/313017), 72.43 MiB | 1.43 MiB/s
# Receiving objects:  24% (75703/313017), 74.02 MiB | 1.45 MiB/s
# Receiving objects:  24% (76936/313017), 77.00 MiB | 1.68 MiB/s
# Receiving objects:  24% (76945/313017), 78.67 MiB | 1.73 MiB/s
# Receiving objects:  24% (76945/313017), 79.40 MiB | 1.71 MiB/s
# Receiving objects:  24% (76960/313017), 81.06 MiB | 1.73 MiB/s
# Receiving objects:  24% (76961/313017), 82.93 MiB | 1.75 MiB/s
# Receiving objects:  24% (77810/313017), 84.18 MiB | 1.57 MiB/s
# Receiving objects:  25% (78255/313017), 84.94 MiB | 1.53 MiB/s
# Receiving objects:  25% (78354/313017), 85.83 MiB | 1.58 MiB/s
# Receiving objects:  25% (78354/313017), 87.82 MiB | 1.68 MiB/s
# Receiving objects:  25% (78361/313017), 90.13 MiB | 1.78 MiB/s
# Receiving objects:  25% (78803/313017), 91.77 MiB | 1.82 MiB/s
# Receiving objects:  25% (78804/313017), 93.50 MiB | 1.88 MiB/s
# Receiving objects:  25% (79138/313017), 95.01 MiB | 1.82 MiB/s
# Receiving objects:  25% (79610/313017), 96.78 MiB | 1.72 MiB/s
# Receiving objects:  25% (80632/313017), 98.39 MiB | 1.62 MiB/s
# Receiving objects:  25% (80632/313017), 99.65 MiB | 1.56 MiB/s
# Receiving objects:  25% (80632/313017), 100.86 MiB | 1.46 MiB/s
# Receiving objects:  26% (81385/313017), 100.86 MiB | 1.46 MiB/s
# Receiving objects:  26% (83811/313017), 101.45 MiB | 1.41 MiB/s
# Receiving objects:  27% (84515/313017), 101.76 MiB | 1.28 MiB/s
# Receiving objects:  27% (85579/313017), 102.58 MiB | 1.10 MiB/s
# Receiving objects:  27% (85579/313017), 103.64 MiB | 1002.00 KiB/s
# Receiving objects:  27% (85579/313017), 104.50 MiB | 955.00 KiB/s
# Receiving objects:  27% (85579/313017), 105.25 MiB | 846.00 KiB/s
# Receiving objects:  27% (85579/313017), 106.22 MiB | 918.00 KiB/s
# Receiving objects:  27% (85579/313017), 107.58 MiB | 999.00 KiB/s
# Receiving objects:  27% (85579/313017), 108.58 MiB | 997.00 KiB/s
# Receiving objects:  27% (85580/313017), 109.18 MiB | 1.02 MiB/s
# Receiving objects:  28% (87645/313017), 109.85 MiB | 1.09 MiB/s
# Receiving objects:  28% (90555/313017), 110.61 MiB | 1.17 MiB/s
# Receiving objects:  29% (90775/313017), 110.61 MiB | 1.17 MiB/s
# Receiving objects:  30% (93906/313017), 111.47 MiB | 1.25 MiB/s
# Receiving objects:  30% (94646/313017), 112.32 MiB | 1.33 MiB/s
# Receiving objects:  31% (97036/313017), 113.34 MiB | 1.41 MiB/s
# Receiving objects:  31% (99764/313017), 114.35 MiB | 1.49 MiB/s
# Receiving objects:  32% (100166/313017), 114.35 MiB | 1.49 MiB/s
# Receiving objects:  33% (103296/313017), 115.50 MiB | 1.63 MiB/s
# Receiving objects:  34% (106426/313017), 115.50 MiB | 1.63 MiB/s
# Receiving objects:  35% (109556/313017), 116.43 MiB | 1.73 MiB/s
# Receiving objects:  35% (110022/313017), 116.43 MiB | 1.73 MiB/s
# Receiving objects:  36% (112687/313017), 117.17 MiB | 1.75 MiB/s
# Receiving objects:  37% (115817/313017), 117.92 MiB | 1.77 MiB/s
# Receiving objects:  37% (117288/313017), 117.92 MiB | 1.77 MiB/s
# Receiving objects:  38% (118947/313017), 117.92 MiB | 1.77 MiB/s
# Receiving objects:  39% (122077/313017), 117.92 MiB | 1.77 MiB/s
# Receiving objects:  40% (125207/313017), 118.71 MiB | 1.78 MiB/s
# Receiving objects:  41% (128337/313017), 118.71 MiB | 1.78 MiB/s
# Receiving objects:  42% (131468/313017), 119.57 MiB | 1.78 MiB/s
# Receiving objects:  42% (131648/313017), 119.57 MiB | 1.78 MiB/s
# Receiving objects:  43% (134598/313017), 119.57 MiB | 1.78 MiB/s
# Receiving objects:  44% (137728/313017), 119.57 MiB | 1.78 MiB/s
# Receiving objects:  45% (140858/313017), 120.61 MiB | 1.82 MiB/s
# Receiving objects:  46% (143988/313017), 120.61 MiB | 1.82 MiB/s
# Receiving objects:  46% (145506/313017), 121.65 MiB | 1.82 MiB/s
# Receiving objects:  46% (145508/313017), 124.89 MiB | 1.86 MiB/s
# Receiving objects:  46% (145511/313017), 127.21 MiB | 2.05 MiB/s
# Receiving objects:  46% (145516/313017), 129.02 MiB | 2.07 MiB/s
# Receiving objects:  46% (145517/313017), 129.75 MiB | 2.00 MiB/s
# Receiving objects:  47% (147118/313017), 130.55 MiB | 1.95 MiB/s
# Receiving objects:  48% (150249/313017), 130.55 MiB | 1.95 MiB/s
# Receiving objects:  48% (151819/313017), 131.49 MiB | 1.90 MiB/s
# Receiving objects:  49% (153379/313017), 131.49 MiB | 1.90 MiB/s
# Receiving objects:  50% (156509/313017), 132.35 MiB | 1.85 MiB/s
# Receiving objects:  50% (159106/313017), 133.04 MiB | 1.78 MiB/s
# Receiving objects:  51% (159639/313017), 133.04 MiB | 1.78 MiB/s
# Receiving objects:  52% (162769/313017), 133.49 MiB | 1.63 MiB/s
# Receiving objects:  52% (163304/313017), 134.00 MiB | 1.48 MiB/s
# Receiving objects:  53% (165900/313017), 134.00 MiB | 1.48 MiB/s
# Receiving objects:  54% (169030/313017), 134.61 MiB | 1.39 MiB/s
# Receiving objects:  55% (172160/313017), 134.61 MiB | 1.39 MiB/s
# Receiving objects:  55% (173763/313017), 135.31 MiB | 1.38 MiB/s
# Receiving objects:  56% (175290/313017), 135.31 MiB | 1.38 MiB/s
# Receiving objects:  57% (178420/313017), 135.31 MiB | 1.38 MiB/s
# Receiving objects:  58% (181550/313017), 135.31 MiB | 1.38 MiB/s
# Receiving objects:  59% (184681/313017), 136.12 MiB | 1.40 MiB/s
# Receiving objects:  60% (187811/313017), 136.12 MiB | 1.40 MiB/s
# Receiving objects:  61% (190941/313017), 136.12 MiB | 1.40 MiB/s
# Receiving objects:  62% (194071/313017), 136.12 MiB | 1.40 MiB/s
# Receiving objects:  62% (194105/313017), 136.12 MiB | 1.40 MiB/s
# Receiving objects:  63% (197201/313017), 137.53 MiB | 1.32 MiB/s
# Receiving objects:  63% (197314/313017), 137.53 MiB | 1.32 MiB/s
# Receiving objects:  64% (200331/313017), 137.92 MiB | 1.21 MiB/s
# Receiving objects:  65% (203462/313017), 138.40 MiB | 1.17 MiB/s
# Receiving objects:  65% (204750/313017), 138.40 MiB | 1.17 MiB/s
# Receiving objects:  66% (206592/313017), 138.98 MiB | 1.20 MiB/s
# Receiving objects:  67% (209722/313017), 138.98 MiB | 1.20 MiB/s
# Receiving objects:  68% (212852/313017), 139.65 MiB | 1.24 MiB/s
# Receiving objects:  68% (214697/313017), 139.65 MiB | 1.24 MiB/s
# Receiving objects:  69% (215982/313017), 140.43 MiB | 1.27 MiB/s
# Receiving objects:  70% (219112/313017), 140.43 MiB | 1.27 MiB/s
# Receiving objects:  71% (222243/313017), 140.43 MiB | 1.27 MiB/s
# Receiving objects:  72% (225373/313017), 141.07 MiB | 1.26 MiB/s
# Receiving objects:  73% (228503/313017), 141.07 MiB | 1.26 MiB/s
# Receiving objects:  73% (230926/313017), 141.07 MiB | 1.26 MiB/s
# Receiving objects:  74% (231633/313017), 141.07 MiB | 1.26 MiB/s
# Receiving objects:  75% (234763/313017), 141.78 MiB | 1.24 MiB/s
# Receiving objects:  76% (237893/313017), 141.78 MiB | 1.24 MiB/s
# Receiving objects:  77% (241024/313017), 141.78 MiB | 1.24 MiB/s
# Receiving objects:  78% (244154/313017), 141.78 MiB | 1.24 MiB/s
# Receiving objects:  79% (247284/313017), 142.54 MiB | 1.22 MiB/s
# Receiving objects:  80% (250414/313017), 142.54 MiB | 1.22 MiB/s
# Receiving objects:  81% (253544/313017), 142.54 MiB | 1.22 MiB/s
# Receiving objects:  81% (254133/313017), 142.54 MiB | 1.22 MiB/s
# Receiving objects:  82% (256674/313017), 143.40 MiB | 1.29 MiB/s
# Receiving objects:  83% (259805/313017), 143.40 MiB | 1.29 MiB/s
# Receiving objects:  84% (262935/313017), 144.36 MiB | 1.42 MiB/s
# Receiving objects:  85% (266065/313017), 144.36 MiB | 1.42 MiB/s
# Receiving objects:  85% (267013/313017), 144.36 MiB | 1.42 MiB/s
# Receiving objects:  85% (268963/313017), 146.66 MiB | 1.53 MiB/s
# Receiving objects:  86% (269195/313017), 146.66 MiB | 1.53 MiB/s
# Receiving objects:  87% (272325/313017), 146.66 MiB | 1.53 MiB/s
# Receiving objects:  88% (275455/313017), 146.66 MiB | 1.53 MiB/s
# Receiving objects:  89% (278586/313017), 147.40 MiB | 1.53 MiB/s
# Receiving objects:  90% (281716/313017), 147.40 MiB | 1.53 MiB/s
# Receiving objects:  90% (282886/313017), 147.40 MiB | 1.53 MiB/s
# Receiving objects:  91% (284846/313017), 147.40 MiB | 1.53 MiB/s
# Receiving objects:  92% (287976/313017), 148.22 MiB | 1.56 MiB/s
# Receiving objects:  93% (291106/313017), 148.22 MiB | 1.56 MiB/s
# Receiving objects:  93% (292724/313017), 149.14 MiB | 1.61 MiB/s
# Receiving objects:  93% (292739/313017), 150.66 MiB | 1.58 MiB/s
# Receiving objects:  93% (292741/313017), 151.96 MiB | 1.44 MiB/s
# Receiving objects:  93% (292742/313017), 154.36 MiB | 1.53 MiB/s
# Receiving objects:  93% (292746/313017), 154.89 MiB | 1.46 MiB/s
# Receiving objects:  93% (292750/313017), 156.07 MiB | 1.30 MiB/s
# Receiving objects:  93% (292751/313017), 158.11 MiB | 1.32 MiB/s
# Receiving objects:  93% (292753/313017), 158.86 MiB | 1.31 MiB/s
# Receiving objects:  93% (293311/313017), 159.82 MiB | 1.17 MiB/s
# Receiving objects:  93% (293321/313017), 161.01 MiB | 1.18 MiB/s
# Receiving objects:  93% (293324/313017), 162.28 MiB | 1.20 MiB/s
# Receiving objects:  93% (293633/313017), 163.78 MiB | 1.23 MiB/s
# Receiving objects:  94% (294236/313017), 163.78 MiB | 1.23 MiB/s
# Receiving objects:  94% (295501/313017), 166.32 MiB | 1.41 MiB/s
# Receiving objects:  94% (297035/313017), 167.22 MiB | 1.49 MiB/s
# Receiving objects:  95% (297367/313017), 167.22 MiB | 1.49 MiB/s
# Receiving objects:  96% (300497/313017), 168.14 MiB | 1.57 MiB/s
# Receiving objects:  96% (301695/313017), 170.33 MiB | 1.77 MiB/s
# Receiving objects:  96% (303238/313017), 171.18 MiB | 1.80 MiB/s
# Receiving objects:  96% (303482/313017), 172.22 MiB | 1.65 MiB/s
# Receiving objects:  97% (303627/313017), 172.22 MiB | 1.65 MiB/s
# Receiving objects:  97% (304788/313017), 173.66 MiB | 1.61 MiB/s
# Receiving objects:  98% (306757/313017), 174.52 MiB | 1.61 MiB/s
# Receiving objects:  99% (309887/313017), 174.52 MiB | 1.61 MiB/s
# Receiving objects:  99% (312429/313017), 174.52 MiB | 1.61 MiB/s
# Receiving objects: 100% (313017/313017), 175.30 MiB | 1.57 MiB/s
# Receiving objects: 100% (313017/313017), 175.44 MiB | 1.24 MiB/s, done.
# Resolving deltas:   0% (0/195108)
# Resolving deltas:   1% (2120/195108)
# Resolving deltas:   2% (3945/195108)
# Resolving deltas:   3% (5868/195108)
# Resolving deltas:   4% (7819/195108)
# Resolving deltas:   5% (9765/195108)
# Resolving deltas:   6% (11793/195108)
# Resolving deltas:   7% (13695/195108)
# Resolving deltas:   8% (15701/195108)
# Resolving deltas:   9% (17566/195108)
# Resolving deltas:  10% (19562/195108)
# Resolving deltas:  11% (21474/195108)
# Resolving deltas:  12% (23458/195108)
# Resolving deltas:  13% (25371/195108)
# Resolving deltas:  14% (27323/195108)
# Resolving deltas:  15% (29305/195108)
# Resolving deltas:  16% (31220/195108)
# Resolving deltas:  17% (33195/195108)
# Resolving deltas:  17% (35102/195108)
# Resolving deltas:  18% (35128/195108)
# Resolving deltas:  19% (37082/195108)
# Resolving deltas:  20% (39051/195108)
# Resolving deltas:  21% (40974/195108)
# Resolving deltas:  22% (43039/195108)
# Resolving deltas:  23% (45126/195108)
# Resolving deltas:  24% (46895/195108)
# Resolving deltas:  25% (48831/195108)
# Resolving deltas:  26% (50872/195108)
# Resolving deltas:  27% (52825/195108)
# Resolving deltas:  28% (54877/195108)
# Resolving deltas:  29% (57044/195108)
# Resolving deltas:  30% (58554/195108)
# Resolving deltas:  31% (60812/195108)
# Resolving deltas:  32% (62570/195108)
# Resolving deltas:  33% (64392/195108)
# Resolving deltas:  35% (68354/195108)
# Resolving deltas:  36% (70526/195108)
# Resolving deltas:  37% (72223/195108)
# Resolving deltas:  38% (74143/195108)
# Resolving deltas:  39% (76404/195108)
# Resolving deltas:  40% (78076/195108)
# Resolving deltas:  41% (80021/195108)
# Resolving deltas:  42% (82062/195108)
# Resolving deltas:  43% (83939/195108)
# Resolving deltas:  44% (85892/195108)
# Resolving deltas:  45% (87924/195108)
# Resolving deltas:  46% (89760/195108)
# Resolving deltas:  47% (91701/195108)
# Resolving deltas:  48% (93660/195108)
# Resolving deltas:  49% (95613/195108)
# Resolving deltas:  50% (97598/195108)
# Resolving deltas:  51% (99509/195108)
# Resolving deltas:  52% (101461/195108)
# Resolving deltas:  53% (103684/195108)
# Resolving deltas:  54% (105484/195108)
# Resolving deltas:  55% (107470/195108)
# Resolving deltas:  56% (109372/195108)
# Resolving deltas:  57% (111217/195108)
# Resolving deltas:  58% (113169/195108)
# Resolving deltas:  59% (115121/195108)
# Resolving deltas:  60% (117249/195108)
# Resolving deltas:  61% (119061/195108)
# Resolving deltas:  62% (120973/195108)
# Resolving deltas:  63% (124070/195108)
# Resolving deltas:  64% (125113/195108)
# Resolving deltas:  65% (127650/195108)
# Resolving deltas:  66% (129009/195108)
# Resolving deltas:  67% (130923/195108)
# Resolving deltas:  68% (132773/195108)
# Resolving deltas:  69% (134722/195108)
# Resolving deltas:  70% (136596/195108)
# Resolving deltas:  71% (138618/195108)
# Resolving deltas:  72% (140495/195108)
# Resolving deltas:  73% (142433/195108)
# Resolving deltas:  74% (144397/195108)
# Resolving deltas:  75% (146332/195108)
# Resolving deltas:  76% (148310/195108)
# Resolving deltas:  77% (150303/195108)
# Resolving deltas:  78% (152195/195108)
# Resolving deltas:  79% (154136/195108)
# Resolving deltas:  80% (156101/195108)
# Resolving deltas:  81% (158038/195108)
# Resolving deltas:  82% (160089/195108)
# Resolving deltas:  83% (161950/195108)
# Resolving deltas:  84% (163949/195108)
# Resolving deltas:  85% (165852/195108)
# Resolving deltas:  86% (167802/195108)
# Resolving deltas:  87% (169750/195108)
# Resolving deltas:  88% (171697/195108)
# Resolving deltas:  89% (173648/195108)
# Resolving deltas:  90% (175610/195108)
# Resolving deltas:  91% (177549/195108)
# Resolving deltas:  92% (179503/195108)
# Resolving deltas:  93% (181453/195108)
# Resolving deltas:  94% (183421/195108)
# Resolving deltas:  95% (185361/195108)
# Resolving deltas:  96% (187329/195108)
# Resolving deltas:  97% (189265/195108)
# Resolving deltas:  98% (191206/195108)
# Resolving deltas:  99% (193300/195108)
# Resolving deltas: 100% (195108/195108)
# Resolving deltas: 100% (195108/195108), done.
# Checking out files:  10% (504/4602)
# Checking out files:  11% (507/4602)
# Checking out files:  12% (553/4602)
# Checking out files:  13% (599/4602)
# Checking out files:  14% (645/4602)
# Checking out files:  15% (691/4602)
# Checking out files:  16% (737/4602)
# Checking out files:  17% (783/4602)
# Checking out files:  18% (829/4602)
# Checking out files:  19% (875/4602)
# Checking out files:  20% (921/4602)
# Checking out files:  21% (967/4602)
# Checking out files:  22% (1013/4602)
# Checking out files:  23% (1059/4602)
# Checking out files:  24% (1105/4602)
# Checking out files:  25% (1151/4602)
# Checking out files:  26% (1197/4602)
# Checking out files:  27% (1243/4602)
# Checking out files:  28% (1289/4602)
# Checking out files:  29% (1335/4602)
# Checking out files:  30% (1381/4602)
# Checking out files:  31% (1427/4602)
# Checking out files:  32% (1473/4602)
# Checking out files:  33% (1519/4602)
# Checking out files:  34% (1565/4602)
# Checking out files:  35% (1611/4602)
# Checking out files:  36% (1657/4602)
# Checking out files:  37% (1703/4602)
# Checking out files:  38% (1749/4602)
# Checking out files:  39% (1795/4602)
# Checking out files:  40% (1841/4602)
# Checking out files:  41% (1887/4602)
# Checking out files:  42% (1933/4602)
# Checking out files:  43% (1979/4602)
# Checking out files:  44% (2025/4602)
# Checking out files:  45% (2071/4602)
# Checking out files:  46% (2117/4602)
# Checking out files:  47% (2163/4602)
# Checking out files:  48% (2209/4602)
# Checking out files:  49% (2255/4602)
# Checking out files:  50% (2301/4602)
# Checking out files:  51% (2348/4602)
# Checking out files:  52% (2394/4602)
# Checking out files:  53% (2440/4602)
# Checking out files:  54% (2486/4602)
# Checking out files:  55% (2532/4602)
# Checking out files:  56% (2578/4602)
# Checking out files:  57% (2624/4602)
# Checking out files:  58% (2670/4602)
# Checking out files:  59% (2716/4602)
# Checking out files:  60% (2762/4602)
# Checking out files:  60% (2764/4602)
# Checking out files:  61% (2808/4602)
# Checking out files:  62% (2854/4602)
# Checking out files:  63% (2900/4602)
# Checking out files:  64% (2946/4602)
# Checking out files:  65% (2992/4602)
# Checking out files:  66% (3038/4602)
# Checking out files:  67% (3084/4602)
# Checking out files:  68% (3130/4602)
# Checking out files:  69% (3176/4602)
# Checking out files:  70% (3222/4602)
# Checking out files:  71% (3268/4602)
# Checking out files:  72% (3314/4602)
# Checking out files:  73% (3360/4602)
# Checking out files:  74% (3406/4602)
# Checking out files:  75% (3452/4602)
# Checking out files:  76% (3498/4602)
# Checking out files:  77% (3544/4602)
# Checking out files:  78% (3590/4602)
# Checking out files:  79% (3636/4602)
# Checking out files:  80% (3682/4602)
# Checking out files:  81% (3728/4602)
# Checking out files:  82% (3774/4602)
# Checking out files:  83% (3820/4602)
# Checking out files:  84% (3866/4602)
# Checking out files:  85% (3912/4602)
# Checking out files:  86% (3958/4602)
# Checking out files:  87% (4004/4602)
# Checking out files:  88% (4050/4602)
# Checking out files:  89% (4096/4602)
# Checking out files:  90% (4142/4602)
# Checking out files:  91% (4188/4602)
# Checking out files:  92% (4234/4602)
# Checking out files:  93% (4280/4602)
# Checking out files:  94% (4326/4602)
# Checking out files:  95% (4372/4602)
# Checking out files:  96% (4418/4602)
# Checking out files:  97% (4464/4602)
# Checking out files:  98% (4510/4602)
# Checking out files:  99% (4556/4602)
# Checking out files: 100% (4602/4602)
# Checking out files: 100% (4602/4602), done.

# %%
#a.	What was the message and title of the fixing commit? 
#Was there any mention of fixing a bug or vulnerability? 
#Hint: git diff or git show
show_data = repo.git.show("-s",fixing_commit).splitlines()
for line in show_data:
    print(line)
# Out:
# commit 4df8b652aa018a5d5d1cda8fba938bf3422db31c
# Author: Jochen Theodorou <blackdrag@gmx.org>
# Date:   Mon Oct 3 18:22:28 2016 +0200
#
#     fix possible deserialization exploit by overriding readObject

# %%
#b.	How many total files were affected in the fixing commit? 
#Hint: git diff or git show
diff_data = repo.git.diff(fixing_commit + "^", fixing_commit).splitlines()
for line in diff_data:
    print(line)
# Out:
# diff --git a/src/main/org/codehaus/groovy/runtime/MethodClosure.java b/src/main/org/codehaus/groovy/runtime/MethodClosure.java
# index 6dfb2f3010..cacdca8421 100644
# --- a/src/main/org/codehaus/groovy/runtime/MethodClosure.java
# +++ b/src/main/org/codehaus/groovy/runtime/MethodClosure.java
# @@ -21,6 +21,7 @@ package org.codehaus.groovy.runtime;
#  import groovy.lang.Closure;
#  import groovy.lang.MetaMethod;
#
# +import java.io.IOException;
#  import java.util.List;
#
#
# @@ -71,6 +72,13 @@ public class MethodClosure extends Closure {
#          }
#          throw new UnsupportedOperationException();
#      }
# +
# +    private void readObject(java.io.ObjectInputStream stream) throws IOException, ClassNotFoundException {
# +        if (ALLOW_RESOLVE) {
# +            stream.defaultReadObject();
# +        }
# +        throw new UnsupportedOperationException();
# +    }
#
#      public Object getProperty(String property) {
#          if ("method".equals(property)) {

# %%
#c.	How many total directories were affected in the fixing commit? 
#For example, if a file path is: abc/def/File.java, 
#then its directory is abc/def. Hint: git diff or git show
diff_data = repo.git.diff(fixing_commit + "^", fixing_commit).splitlines()
for line in diff_data:
    print(line)
# Out:
# diff --git a/src/main/org/codehaus/groovy/runtime/MethodClosure.java b/src/main/org/codehaus/groovy/runtime/MethodClosure.java
# index 6dfb2f3010..cacdca8421 100644
# --- a/src/main/org/codehaus/groovy/runtime/MethodClosure.java
# +++ b/src/main/org/codehaus/groovy/runtime/MethodClosure.java
# @@ -21,6 +21,7 @@ package org.codehaus.groovy.runtime;
#  import groovy.lang.Closure;
#  import groovy.lang.MetaMethod;
#
# +import java.io.IOException;
#  import java.util.List;
#
#
# @@ -71,6 +72,13 @@ public class MethodClosure extends Closure {
#          }
#          throw new UnsupportedOperationException();
#      }
# +
# +    private void readObject(java.io.ObjectInputStream stream) throws IOException, ClassNotFoundException {
# +        if (ALLOW_RESOLVE) {
# +            stream.defaultReadObject();
# +        }
# +        throw new UnsupportedOperationException();
# +    }
#
#      public Object getProperty(String property) {
#          if ("method".equals(property)) {

# %%
#d.	How many total lines of code (including comments and blank lines) \
#were deleted? Hint: git diff or git show
#e.	How many total lines of code (including comments and blank lines) 
#were added? Hint: git diff or git show
del_data = repo.git.log("--numstat","--oneline",fixing_commit).splitlines()
for line in del_data:
    print(line)
# Out:
# 4df8b652aa fix possible deserialization exploit by overriding readObject
# 8	0	src/main/org/codehaus/groovy/runtime/MethodClosure.java
# 675a04eab7 GROOVY-7930: @SelfType in hierarchy with an interface in the middle (closes #428)
# 1	1	src/main/org/codehaus/groovy/ast/tools/GeneralUtils.java
# 16	0	src/test/org/codehaus/groovy/transform/traitx/TraitASTTransformationTest.groovy
# da30fa2005 GROOVY-7946 - allow writable values for StreamingJsonBuilder (closes #429)
# 21	3	subprojects/groovy-json/src/main/java/groovy/json/StreamingJsonBuilder.java
# 24	0	subprojects/groovy-json/src/test/groovy/groovy/json/StreamingJsonBuilderTest.groovy
# e36835d58a GROOVY-7933: fix method selection for boolean and char primitives (closes #424)
# 42	22	src/main/org/codehaus/groovy/runtime/MetaClassHelper.java
# 48	0	src/test/groovy/bugs/Groovy7933Bug.groovy
# 1	1	src/test/org/codehaus/groovy/transform/CanonicalComponentsTransformTest.groovy
# a982938330 GROOVY-7935: fix style guide example for required parentheses
# 3	4	src/spec/doc/style-guide.adoc
# 82c9d20a16 Compatibility with Gradle's classloader cleanup (closes #427)
# 18	6	src/main/org/codehaus/groovy/reflection/ClassInfo.java
# ed85b205cb GROOVY-6831: Access to static fields/properties from within nested classes is inconsistent (closes #425)
# 4	1	src/main/groovy/lang/MetaClassImpl.java
# 38	2	src/main/org/codehaus/groovy/classgen/InnerClassCompletionVisitor.java
# 23	0	src/test/gls/innerClass/InnerClassTest.groovy
# 90549729aa Merge remote-tracking branch 'origin/GROOVY_2_4_X' into GROOVY_2_4_X
# 0b4559a869 bump version numbers
# 2	2	gradle.properties
# 3	3	src/spec/doc/tools-groovyc.adoc
# d40f188a86 formatting
# 11	11	src/main/org/codehaus/groovy/transform/stc/StaticTypeCheckingSupport.java
# 18	0	src/test/groovy/bugs/Groovy7922Bug.groovy
# 32d5d1f077 GROOVY-7922: Static type checking not strict enough in the presence of ambiguous method matching (closes #422)
# 65	43	src/main/org/codehaus/groovy/transform/stc/StaticTypeCheckingSupport.java
# 42	0	src/test/groovy/bugs/Groovy7922Bug.groovy
# 369e9826ac GROOVY-7938: inconsistent access of methods in outer class (closes #421)
# 19	1	src/main/org/codehaus/groovy/classgen/InnerClassCompletionVisitor.java
# 68	0	src/test/groovy/bugs/Groovy7938Bug.groovy
# 0a6135b54f cleanup examples: convert EOL from crlf to lf
# 44	44	src/examples/astbuilder/build.xml
# 36	17	src/examples/astbuilder/readme.txt
# 264	264	src/examples/org/codehaus/groovy/grails/compiler/injection/DefaultGrailsDomainClassInjector.java
# 38	38	src/examples/org/codehaus/groovy/grails/compiler/injection/DomainClass.java
# 62	62	src/examples/swing/BindingExample.groovy
# 87	87	src/examples/swing/ModelNodeExample.groovy
# 105	105	src/examples/swing/RegexCoachController.groovy
# 52	52	src/examples/swing/RegexCoachView.groovy
# 220	220	src/examples/swing/binding/caricature/JCaricature.java
# 152	152	src/examples/swing/greet/Greet.groovy
# 161	161	src/examples/swing/greet/TwitterAPI.groovy
# 175	175	src/examples/swing/greet/View.groovy
# 46	46	src/examples/swing/timelog/TimeLogMain.groovy
# 61	61	src/examples/swing/timelog/TimeLogModel.groovy
# 66	66	src/examples/swing/timelog/TimeLogView.groovy
# 66	66	src/examples/transforms/global/CompiledAtASTTransformation.groovy
# 33	33	src/examples/transforms/global/CompiledAtExample.groovy
# 73	73	src/examples/transforms/global/LoggingASTTransformation.groovy
# 48	48	src/examples/transforms/global/LoggingExample.groovy
# 52	52	src/examples/transforms/global/build.xml
# 48	29	src/examples/transforms/global/readme.txt
# 73	73	src/examples/transforms/local/LoggingASTTransformation.groovy
# 64	64	src/examples/transforms/local/LoggingExample.groovy
# 36	36	src/examples/transforms/local/WithLogging.groovy
# 44	44	src/examples/transforms/local/build.xml
# 40	21	src/examples/transforms/local/readme.txt
# 0afacb4d3d GROOVY-7942: @Lazy transform creates unneeded getter/setter for backing store field (closes #423)
# 0	3	src/main/groovy/lang/Lazy.java
# 7	1	src/main/org/codehaus/groovy/transform/LazyASTTransformation.java
# 6	28	src/test/groovy/bugs/Groovy3726Bug.groovy
# f38d48d87a GROOVY-7940: @Lazy not generating "is" property accessor for booleans (closes #420)
# 7	2	src/main/org/codehaus/groovy/transform/LazyASTTransformation.java
# 18	0	src/test/org/codehaus/groovy/transform/LazyTransformTest.groovy
# 98b22a7673 typos
# 2	2	src/main/org/codehaus/groovy/classgen/InnerClassCompletionVisitor.java
# f2fa179fd0 GROOVY-7936: Improve doco for import aliasing
# 14	9	src/spec/doc/style-guide.adoc
# ff5dcf6402 GROOVY-7925: 'this' and 'super' as LHS of an assignment
# 11	0	src/main/org/codehaus/groovy/classgen/ClassCompletionVerifier.java
# 32	0	src/test/groovy/bugs/Groovy7925Bug.groovy
# 7e19592c11 entrySet should return a Set of Entries (closes #410)
# 1	1	subprojects/groovy-sql/src/main/java/groovy/sql/GroovyRowResult.java
# 96f1ea7540 GROOVY-7926: Method that returns void in a Trait with generics produces questionable byte code (tidy comments - closes #416)
# 36	24	src/test/org/codehaus/groovy/transform/traitx/Groovy7926Bug.groovy
# 50d4d1f13d GROOVY-7926 - Don't use a CastExpression if the return type is void.
# 2	1	src/main/org/codehaus/groovy/transform/trait/TraitComposer.java
# 50	0	src/test/org/codehaus/groovy/transform/traitx/Groovy7926Bug.groovy
# a691f510a6 minor doc fixes
# 2	2	subprojects/groovy-groovysh/src/main/groovy/org/codehaus/groovy/tools/shell/completion/ReflectionCompletor.groovy
# 2	2	subprojects/groovy-jmx/src/main/groovy/groovy/jmx/builder/JmxBuilderTools.groovy
# 1	1	subprojects/groovy-jmx/src/main/groovy/groovy/jmx/builder/JmxEmitterFactory.groovy
# 4	4	subprojects/groovy-jmx/src/main/groovy/groovy/jmx/builder/JmxMetaMapBuilder.groovy
# 1	1	subprojects/groovy-jmx/src/main/groovy/groovy/jmx/builder/JmxOperationInfoManager.groovy
# 3	3	subprojects/groovy-jmx/src/spec/doc/jmx.adoc
# 1	1	subprojects/groovy-json/src/main/java/groovy/json/JsonBuilder.java
# 1	1	subprojects/groovy-json/src/main/java/groovy/json/JsonLexer.java
# 1	1	subprojects/groovy-json/src/main/java/groovy/json/StringEscapeUtils.java
# 1	1	subprojects/groovy-json/src/main/java/groovy/json/internal/LazyMap.java
# 1	1	subprojects/groovy-json/src/main/java/groovy/json/internal/LazyValueMap.java
# 1	1	subprojects/groovy-json/src/spec/doc/json-builder.adoc
# 10	11	subprojects/groovy-swing/src/main/java/groovy/inspect/swingui/TableSorter.java
# 1	1	subprojects/groovy-templates/src/main/groovy/groovy/text/markup/TagLibAdapter.groovy
# 2	2	subprojects/groovy-templates/src/main/groovy/groovy/text/markup/TemplateConfiguration.java
# 1	1	subprojects/groovy-templates/src/spec/doc/markup-template-engine.adoc
# 1	1	subprojects/groovy-templates/src/spec/doc/template-engines.adoc
# 288134df0d findbugs fix: close stream
# 6	2	src/main/org/codehaus/groovy/control/XStreamUtils.java
# 9c69609786 GROOVY-7683 - Memory leak when using Groovy as JSR-223 scripting language (closes #219)
# 44	42	src/main/org/codehaus/groovy/reflection/ClassInfo.java
# 10	0	src/main/org/codehaus/groovy/reflection/GroovyClassValuePreJava7.java
# 287b9ab5bf minor refactor:  deprecate method
# 2	0	src/main/org/codehaus/groovy/control/ParserPluginFactory.java
# 5bae714d27 Remove outdated parser loading logic. (closes #415)
# 1	1	src/main/org/codehaus/groovy/control/CompilerConfiguration.java
# 18	32	src/main/org/codehaus/groovy/control/ParserPluginFactory.java
# 1	1	src/test/org/codehaus/groovy/control/CompilerConfigurationTest.java
# 49d5dd1590 trivial refactor: some tidying up of comments and switch away from using pop() method to avoid potential problems if we fix GROOVY-6396
# 16	14	src/main/groovy/util/ConfigSlurper.groovy
# fb7ede6e58 Fix mixed code snippet references. (closes #417)
# 2	2	src/spec/doc/working-with-collections.adoc
# 97f74ed20f Documentation fixes to [The Groocy Development Kit](http://groovy-lang.org/groovy-dev-kit.html) section on Working with collections - property access comment targets entry instead of key - two introductions followed by two corresponding code sections
# 5	0	src/spec/doc/working-with-collections.adoc
# 4	2	src/spec/test/gdk/WorkingWithCollectionsTest.groovy
# 776ea2cdfd GROOVY-7927: use inferred type from closure to find connection to SAM return type
# 2	2	src/main/org/codehaus/groovy/transform/stc/StaticTypeCheckingVisitor.java
# 9	0	src/test/groovy/transform/stc/ClosuresSTCTest.groovy
# 831550cc39 GROOVY-6764: Problem Referring To Statically Imported Constants (closes #404)
# 22	2	src/main/org/codehaus/groovy/control/StaticImportVisitor.java
# 48	0	src/test/groovy/bugs/Groovy6764Bug.groovy
# 08af17911a Merge branch 'GROOVY_2_4_X' of http://git-wip-us.apache.org/repos/asf/groovy into GROOVY_2_4_X
# 7cd05552d0 GROOVY-7924: groovyc fails with NPE for dynamic method/property use on super (closes #407)
# 10	10	src/main/org/codehaus/groovy/classgen/AsmClassGenerator.java
# 43	0	src/test/groovy/bugs/Groovy7924Bug.groovy
# a62888abf2 JsonOutput#prettyPrint: align CharBuf size with intention expressed in comment (closes #408)
# 2	2	subprojects/groovy-json/src/main/java/groovy/json/JsonOutput.java
# 359b6a93c7 trivial refactor (side effect: closes #406)
# 15	16	src/main/org/codehaus/groovy/runtime/DefaultGroovyMethods.java
# bde7da49b7 fix documentation for Iterable.last()
# 2	2	src/main/org/codehaus/groovy/runtime/DefaultGroovyMethods.java
# f78afc91f2 GROOVY-7340: GroovyDoc doesn't understand method type parameters
# 13	1	subprojects/groovy-groovydoc/src/main/java/org/codehaus/groovy/tools/groovydoc/SimpleGroovyClassDocAssembler.java
# 9	0	subprojects/groovy-groovydoc/src/main/java/org/codehaus/groovy/tools/groovydoc/SimpleGroovyMethodDoc.java
# 10	7	subprojects/groovy-groovydoc/src/main/resources/org/codehaus/groovy/tools/groovydoc/gstringTemplates/classLevel/classDocName.html
# d4209608fb GROOVY-7497: GroovyDoc reports only last method of a script (ported from master)
# 61	30	subprojects/groovy-groovydoc/src/main/java/org/codehaus/groovy/tools/groovydoc/SimpleGroovyClassDocAssembler.java
# 1	0	subprojects/groovy-groovydoc/src/main/java/org/codehaus/groovy/tools/groovydoc/SimpleGroovyDoc.java
# 2	1	subprojects/groovy-groovydoc/src/main/resources/org/codehaus/groovy/tools/groovydoc/gstringTemplates/classLevel/classDocName.html
# 14	0	subprojects/groovy-groovydoc/src/main/resources/org/codehaus/groovy/tools/groovydoc/gstringTemplates/classLevel/classDocStructuredData.xml
# 25	0	subprojects/groovy-groovydoc/src/test/groovy/org/codehaus/groovy/tools/groovydoc/GroovyDocToolTest.java
# 44	0	subprojects/groovy-groovydoc/src/test/groovy/org/codehaus/groovy/tools/groovydoc/testfiles/Script.groovy
# 8faf42e2d9 GROOVY-7921: using "this" as the target of an assignment not working with Category annotation (closes #400)
# 6	4	src/main/org/codehaus/groovy/classgen/VariableScopeVisitor.java
# 36	0	src/test/groovy/bugs/Groovy7921Bug.groovy
# 31843864d6 typos/comments
# 2	5	src/main/groovy/lang/MetaBeanProperty.java
# dd6c48e433 GROOVY-6932: @Log annotation does not check logging enablement inside closures (closes #401)
# 13	0	src/main/org/codehaus/groovy/transform/LogASTTransformation.java
# 50	0	src/test/groovy/bugs/Groovy6932Bug.groovy
# 0e50a796eb Added test cases for Collection .intersect() and .disjoint() (closes #402)
# 13	2	src/test/groovy/GroovyMethodsTest.groovy
# daccd0b1cd ClassInfo cleanup
# 86	205	src/main/org/codehaus/groovy/reflection/ClassInfo.java
# 895684334d GROOVY-7916: MissingPropertyException when accessing a static inner class member from a sub class (closes #397)
# 24	6	src/main/org/codehaus/groovy/control/ResolveVisitor.java
# 60	0	src/test/groovy/bugs/Groovy7916Bug.groovy
# e373945999 remove test dependency on javax.xml.ws package
# 10	5	src/test/groovy/transform/stc/GenericsSTCTest.groovy
# 9a32ade31d doco bugfix: instantiation using wrong parameter (closes #398)
# 1	1	src/spec/test/DesignPatternsTest.groovy
# acc20c311b GROOVY-5396: Groovy classes can't see package-local properties from a super class
# 20	3	src/main/groovy/lang/MetaClassImpl.java
# 38	0	src/test/groovy/bugs/Groovy5396Bug.groovy
# 24f432860b GROOVY-7912: MissingPropertyException when referencing a static import in a closure's optional parameters
# 8	0	src/main/org/codehaus/groovy/control/StaticImportVisitor.java
# 34	0	src/test/groovy/bugs/Groovy7912Bug.groovy
# 9696abeae1 GROOVY-7917: Sub class can't override final static property (closes #394)
# 8	2	src/main/org/codehaus/groovy/ast/ClassNode.java
# 10	5	src/main/org/codehaus/groovy/classgen/Verifier.java
# 36	0	src/test/groovy/bugs/Groovy7917Bug.groovy
# fe2a2d6554 GROOVY-7888: Type checker infers wrong type on compound assignment (e.g.  += for collection) for property (closes #390)
# 2	24	src/main/org/codehaus/groovy/classgen/asm/BinaryExpressionMultiTypeDispatcher.java
# 48	0	src/main/org/codehaus/groovy/syntax/TokenUtil.java
# 22	12	src/main/org/codehaus/groovy/transform/stc/StaticTypeCheckingVisitor.java
# 40	0	src/test/groovy/transform/stc/Groovy7888Bug.groovy
# 481d4e5e97 Removed uncessery Integer Object creation
# 1	1	src/main/groovy/lang/IntRange.java
# e5cc59e35b GROOVY-7834: Calculating hashcode of IntRange by pairing function (closes #388)
# 10	0	src/main/groovy/lang/IntRange.java
# 11	0	src/test/groovy/lang/IntRangeTest.groovy
# 0a6789d06c findbugs: un-callable method in anonymous class (closes #389)
# 5	2	src/main/groovy/lang/MetaClassImpl.java
# 25515104e9 findbugs: impossible cast
# 0	1	src/main/org/codehaus/groovy/runtime/typehandling/ShortTypeHandling.java
# 64	0	src/test/org/codehaus/groovy/runtime/typehandling/ShortTypeHandlingTest.groovy
# 2a8153b571 findbugs: impossible instanceof
# 4	3	src/main/org/codehaus/groovy/classgen/asm/StatementWriter.java
# e150025556 GROOVY-7655: track super calls to ensure there will be a mop helper method for it
# 5	0	src/main/org/codehaus/groovy/classgen/asm/InvocationWriter.java
# 8	4	src/main/org/codehaus/groovy/classgen/asm/MopWriter.java
# 7	2	src/main/org/codehaus/groovy/classgen/asm/WriterController.java
# 67	0	src/test/gls/invocation/MethodSelectionTest.groovy
# 6e4320de6f GROOVY-7907: Cannot assign value of type java.lang.Object with varargs, parameterized method and @CompileStatic (closes #385)
# 13	8	src/main/org/codehaus/groovy/transform/stc/StaticTypeCheckingSupport.java
# 41	0	src/test/groovy/transform/stc/Groovy7907Bug.groovy
# 23	0	src/test/groovy/transform/stc/Groovy7907HelperPrecompiledGroovy.groovy
# 23	0	src/test/groovy/transform/stc/Groovy7907HelperPrecompiledJava.java
# 31778234c9 GROOVY-7713: CompileStatic checking fails with null returns from Closures (closes #384)
# 3	2	src/main/org/codehaus/groovy/transform/stc/StaticTypeCheckingVisitor.java
# 12	0	src/test/groovy/transform/stc/GenericsSTCTest.groovy
# 5f86d08b06 minor refactor
# 95	72	src/main/org/codehaus/groovy/transform/stc/StaticTypeCheckingSupport.java
# d8dc2001e0 remove duplicated tests
# 2	2	src/test/org/codehaus/groovy/classgen/asm/sc/StaticCompileCastOptimizationTest.groovy
# de2082d6eb GROOVY-7014: minor prefactor
# 2	4	src/main/org/codehaus/groovy/ast/ClassNode.java
# 40	12	src/main/org/codehaus/groovy/control/StaticImportVisitor.java
# 15	7	src/main/org/codehaus/groovy/control/StaticVerifier.java
# 15	24	src/test/groovy/bugs/ConstructorThisCallBug.groovy
# 630008a1f3 GROOVY-7880: Diamond Operator for own class causes NullPointerException if Static Compilation is enabled (closes #382)
# 4	1	src/main/org/codehaus/groovy/transform/stc/StaticTypeCheckingVisitor.java
# 57	0	src/test/groovy/transform/stc/Groovy7880Bug.groovy
# 3245fcc66d remove some outdates/duplicate class headers
# 0	16	gradle/filter.gradle
# 0	1	src/examples/swing/RegexCoach.groovy
# 0	2	src/examples/swing/RegexCoachController.groovy
# 0	2	src/spec/test/CustomizersTest.groovy
# 0	1	src/spec/test/TraitsSpecificationTest.groovy
# 0	1	src/spec/test/gdk/ExpandoTest.groovy
# 0	1	src/spec/test/gdk/ObservableTest.groovy
# 0	19	src/test/gls/ch06/s05/JName1Test.java
# 0	19	src/test/gls/ch06/s05/testClasses/Tt1.java
# 052fee66d2 GROOVY-7542: CompileStatic class generation bug "register with message: rightShiftUnsigned and arguments X" (testcase plus rightShift/leftShift - closes #85)
# 5	20	src/main/org/codehaus/groovy/classgen/asm/sc/StaticTypesCallSiteWriter.java
# 28	0	src/test/groovy/transform/stc/Groovy7542Bug.groovy
# 760b0c1f8d GROOVY-7542: CompileStatic class generation bug 'register with message: rightShiftUnsigned and arguments X'
# 16	1	src/main/org/codehaus/groovy/classgen/asm/sc/StaticTypesCallSiteWriter.java
# a671fafe1e minor refactor: remove use of raw types
# 2	2	subprojects/groovy-jsr223/src/main/java/org/codehaus/groovy/jsr223/GroovyCompiledScript.java
# 9	9	subprojects/groovy-jsr223/src/main/java/org/codehaus/groovy/jsr223/GroovyScriptEngineImpl.java
# 2	2	subprojects/groovy-jsr223/src/main/java/org/codehaus/groovy/jsr223/ScriptExtensions.java
# 215e2658a1 minor cleanup: no need to import classes from java.lang
# 0	2	subprojects/groovy-jsr223/src/main/java/org/codehaus/groovy/jsr223/GroovyScriptEngineImpl.java
# 037ff6598f minor refactor: use enhanced for loop
# 2	4	subprojects/groovy-jsr223/src/main/java/org/codehaus/groovy/jsr223/GroovyScriptEngineFactory.java
# e23c7ef347 GROOVY-7884: GroovyScriptEngineImpl usage of CompilerConfiguration can lead to memory leaks (closes #377)
# 1	1	subprojects/groovy-jsr223/src/main/java/org/codehaus/groovy/jsr223/GroovyScriptEngineImpl.java
# 32fc63ee66 GROOVY-5752: DelegateASTTransformation#addGetterIfNeeded doesn't take boolean isX accessors into account (port from master)
# 25	9	src/main/org/codehaus/groovy/transform/DelegateASTTransformation.java
# 30	4	src/test/org/codehaus/groovy/transform/DelegateTransformTest.groovy
# 8a861aaf91 GROOVY-6245: @EqualsAndHashCode assumes get style getters for boolean properties (port from master)
# 38	11	src/main/org/codehaus/groovy/ast/tools/GeneralUtils.java
# 1	1	src/main/org/codehaus/groovy/transform/EqualsAndHashCodeASTTransformation.java
# 1	1	src/main/org/codehaus/groovy/transform/ToStringASTTransformation.java
# ac5ec9dbe3 no luck on CI server, revert previous change
# 2	2	security/groovy.policy
# ff61456daf test to try to fix build on Apache build server
# 2	2	security/groovy.policy
# 2504a77f9c minor cleanup: remove redundant conditional
# 1	1	src/main/groovy/util/GroovyCollections.java
# 71b6107bb5 fix javadoc
# 2	2	src/main/org/codehaus/groovy/runtime/DefaultGroovyMethods.java
# 9e9b5b650d GROOVY-7774: Collection addAll fails CompileStatic type checking when adding a collection of subtypes (minor refactor)
# 3	5	src/main/org/codehaus/groovy/runtime/DefaultGroovyMethods.java
# ca97826de7 GROOVY-7774: Collection addAll fails CompileStatic type checking when adding a collection of subtypes (same treatment for some Map methods) (closes #376)
# 6	4	src/main/org/codehaus/groovy/runtime/DefaultGroovyMethods.java
# 22	8	src/test/groovy/transform/stc/Groovy7774Bug.groovy
# 002f85e920 GROOVY-7774: Collection addAll fails CompileStatic type checking when adding a collection of subtypes
# 2	2	src/main/org/codehaus/groovy/runtime/DefaultGroovyMethods.java
# 42	0	src/test/groovy/transform/stc/Groovy7774Bug.groovy
# 6778128eb1 GROOVY-7699: collate() on an empty list is an empty list. (closes #205)
# 24	24	src/main/org/codehaus/groovy/runtime/DefaultGroovyMethods.java
# 2	2	src/test/groovy/CollateTest.groovy
# ec1f3e3f0f GROOVY-7894: Add access to declared variables within VariableScope (closes #370)
# 23	1	src/main/org/codehaus/groovy/ast/VariableScope.java
# bd8242fb9d GROOVY-5985 - Invalid hash key serialVersionUID (closes #365)
# 8	8	src/main/groovy/lang/MetaClassImpl.java
# 33	0	src/test/groovy/MapPropertyTest.groovy
# 9ff17a4943 GROOVY-7876: ClassCastException when calling DefaultTypeTransformation#compareEqual (closes #368)
# 8	1	src/main/org/codehaus/groovy/runtime/typehandling/DefaultTypeTransformation.java
# 39	0	src/test/groovy/bugs/Groovy7876Bug.groovy
# b1896fead6 test cleanup: remove println calls (closes #369)
# 0	37	src/test/groovy/ArrayCoerceTest.groovy
# 0	4	src/test/groovy/ArrayParamMethodTest.groovy
# 2	4	src/test/groovy/ArrayTypeTest.groovy
# 0	14	src/test/groovy/CastTest.groovy
# 0	6	src/test/groovy/ClassExpressionTest.groovy
# 0	3	src/test/groovy/ClassTest.groovy
# 10	6	src/test/groovy/ClosureDefaultParameterTest.groovy
# 1	1	src/test/groovy/ClosureInClosureTest.groovy
# 0	2	src/test/groovy/ClosureMethodTest.groovy
# 6	5	src/test/groovy/ClosureMethodsOnFileTest.groovy
# 0	8	src/test/groovy/ClosureMissingMethodTest.groovy
# 2	2	src/test/groovy/ClosureTest.groovy
# 1	5	src/test/groovy/ClosureUsingOuterVariablesTest.groovy
# 4	16	src/test/groovy/ClosureWithDefaultParamTest.groovy
# 1	5	src/test/groovy/ClosureWithEmptyParametersTest.groovy
# 0	2	src/test/groovy/CompareEqualsTest.groovy
# 0	5	src/test/groovy/CompileOrderTest.groovy
# 0	4	src/test/groovy/CompilerErrorTest.groovy
# 1	4	src/test/groovy/Constructor2Test.groovy
# 1	4	src/test/groovy/ConstructorTest.groovy
# 2	2	src/test/groovy/CurlyBracketLayoutTest.groovy
# 0	2	src/test/groovy/DefaultParamClosureTest.groovy
# 0	2	src/test/groovy/ExceptionInClosureTest.groovy
# 1	10	src/test/groovy/ExpandoPropertyTest.groovy
# 0	4	src/test/groovy/ForLoopTest.groovy
# 4	4	src/test/groovy/GStringTest.groovy
# 2	2	src/test/groovy/GeneratorTest.groovy
# 7	24	src/test/groovy/GroovyClosureMethodsTest.groovy
# 0	9	src/test/groovy/GroovyMethodsTest.groovy
# 0	4	src/test/groovy/IfPropertyTest.groovy
# 4	4	src/test/groovy/IfTest.groovy
# 0	4	src/test/groovy/LeftShiftTest.groovy
# 0	4	src/test/groovy/LoopBreakTest.groovy
# 1	4	src/test/groovy/MapConstructionTest.groovy
# 1	2	src/test/groovy/MethodCallTest.groovy
# 0	2	src/test/groovy/MethodCallWithoutParenthesisTest.groovy
# 0	4	src/test/groovy/MinMaxTest.groovy
# 0	1	src/test/groovy/MultilineStringTest.groovy
# 0	4	src/test/groovy/NewExpressionTest.groovy
# 0	1	src/test/groovy/SafeNavigationTest.groovy
# 0	2	src/test/groovy/SimplePostfixTest.groovy
# 3	11	src/test/groovy/SingletonBugTest.groovy
# 9	8	src/test/groovy/SpreadDotTest.groovy
# 0	1	src/test/groovy/StringBufferTest.groovy
# 0	1	src/test/groovy/ThrowTest.groovy
# 0	2	src/test/groovy/ToArrayBugTest.groovy
# 0	1	src/test/groovy/TripleQuotedStringTest.groovy
# 0	3	src/test/groovy/TryCatchTest.groovy
# 1	1	src/test/groovy/WhileLoopTest.groovy
# 1	10	src/test/groovy/bugs/AmbiguousListOrMethodTest.groovy
# 0	17	src/test/groovy/bugs/AsBoolBug.groovy
# 6	2	src/test/groovy/bugs/AssignmentInsideExpressionBug.groovy
# 0	5	src/test/groovy/bugs/BlockAsClosureBug.groovy
# 1	5	src/test/groovy/bugs/Bytecode2Bug.groovy
# 0	2	src/test/groovy/bugs/ClosureVariableBug.groovy
# 0	4	src/test/groovy/bugs/ConstructorBug.groovy
# 4	8	src/test/groovy/bugs/ConstructorThisCallBug.groovy
# 0	1	src/test/groovy/bugs/ForLoopBug.groovy
# 0	8	src/test/groovy/bugs/GetterBug.groovy
# 0	1	src/test/groovy/bugs/Groovy2350Bug.groovy
# 0	2	src/test/groovy/bugs/Groovy2365Bug.java
# 0	2	src/test/groovy/bugs/Groovy2490Bug.groovy
# 1	1	src/test/groovy/bugs/Groovy2666Bug.groovy
# 0	1	src/test/groovy/bugs/Groovy3156And2621Bug.groovy
# 1	1	src/test/groovy/bugs/Groovy3335Bug.groovy
# 0	1	src/test/groovy/bugs/Groovy3403Bug.groovy
# 0	2	src/test/groovy/bugs/Groovy3405Bug.groovy
# 0	1	src/test/groovy/bugs/Groovy3410Bug.groovy
# 1	1	src/test/groovy/bugs/Groovy3770Bug.groovy
# 0	3	src/test/groovy/bugs/Groovy4393Bug.groovy
# 0	1	src/test/groovy/bugs/Groovy6041Bug.groovy
# 0	6	src/test/groovy/bugs/Groovy770_Bug.groovy
# 0	1	src/test/groovy/bugs/Groovy872Bug.groovy
# 0	1	src/test/groovy/bugs/InterfaceImplBug.groovy
# 2	3	src/test/groovy/bugs/InvokeNormalMethodFromBuilder_Groovy657Bug.groovy
# 0	6	src/test/groovy/bugs/NestedClosure2Bug.groovy
# 1	2	src/test/groovy/bugs/NestedClosureBug.groovy
# 0	1	src/test/groovy/bugs/POJOCallSiteBug.groovy
# 0	8	src/test/groovy/bugs/PropertyNameBug.groovy
# 0	1	src/test/groovy/bugs/RodsBug.groovy
# 2	2	src/test/groovy/bugs/RussellsOptionalParenTest.groovy
# 0	2	src/test/groovy/bugs/SubscriptOnStringArrayBug.groovy
# 0	7	src/test/groovy/bugs/SynchronizedBytecodeBug.groovy
# 0	2	src/test/groovy/bugs/TestSupport.java
# 0	5	src/test/groovy/bugs/ToStringBug.groovy
# 0	14	src/test/groovy/execute/ExecuteTest.groovy
# 0	2	src/test/groovy/lang/ClassReloadingTest.groovy
# 0	1	src/test/groovy/lang/ExpandoMetaClassTest.groovy
# 3	5	src/test/org/codehaus/groovy/runtime/MethodFailureTest.java
# 0	4	src/test/org/codehaus/groovy/runtime/NewStaticMetaMethodTest.java
# 0	1	src/test/org/codehaus/groovy/runtime/PropertyTest.java
# 0	4	src/test/org/codehaus/groovy/runtime/StaticInitTest.java
# 1	6	src/test/org/codehaus/groovy/tools/TestDgmConverter.java
# 0	1	src/test/org/codehaus/groovy/tools/stubgenerator/AnnotationMemberValuesResolutionV1StubsTest.groovy
# 0	1	src/test/org/codehaus/groovy/tools/stubgenerator/AnnotationMemberValuesResolutionV2StubsTest.groovy
# 0	1	src/test/org/codehaus/groovy/tools/stubgenerator/AnnotationMemberValuesResolutionV3StubsTest.groovy
# 0	1	src/test/org/codehaus/groovy/tools/stubgenerator/DuplicateMethodAdditionInStubsTest.groovy
# 0	1	src/test/org/codehaus/groovy/tools/stubgenerator/Groovy5859Bug.groovy
# 0	2	src/test/org/codehaus/groovy/tools/stubgenerator/StubGenerationForAnAnnotationStubsTest.groovy
# 0	1	src/test/org/codehaus/groovy/tools/stubgenerator/StubGenerationForConstructorWithOptionalArgsStubsTest.groovy
# 0	1	src/test/org/codehaus/groovy/tools/stubgenerator/UnAmbigousSuperConstructorCallStubsTest.groovy
# 0	2	subprojects/groovy-xml/src/test/groovy/groovy/bugs/Groovy249_Bug.groovy
# 09cd95177e test cleanup: remove done todos
# 1	1	src/test/groovy/MultiDimArraysTest.groovy
# 1	1	src/test/groovy/PrimitiveTypeFieldTest.groovy
# 4	4	src/test/groovy/PrivateVariableAccessFromAnotherInstanceTest.groovy
# 1	2	src/test/groovy/Property2Test.groovy
# 1	1	src/test/groovy/SomeClass.java
# 6	7	src/test/groovy/VarargsMethodTest.groovy
# 2	6	src/test/groovy/bugs/Groovy1018_Bug.groovy
# 1	8	src/test/groovy/bugs/Groovy1059_Bug.groovy
# ff44e38de9 GROOVY-7872: Nested calls between @Lazy static properties throws MissingPropertyException (closes #354)
# 11	1	src/main/org/codehaus/groovy/transform/LazyASTTransformation.java
# 24	3	src/test/org/codehaus/groovy/transform/LazyTransformTest.groovy
# 8127d47a8e GROOVY-7887: Typo s/now/know/ in core-domain-specific-languages
# 1	1	src/spec/doc/core-domain-specific-languages.adoc
# 25a460f1f7 Merge branch 'GROOVY_2_4_X' of http://git-wip-us.apache.org/repos/asf/groovy into GROOVY_2_4_X
# 58aef7a94c Fix check for potential hash function collisions
# 2	2	subprojects/groovy-json/src/main/java/groovy/json/internal/LazyMap.java
# 1	1	subprojects/groovy-json/src/main/java/groovy/json/internal/LazyValueMap.java
# 6	0	subprojects/groovy-json/src/main/java/groovy/json/internal/Sys.java
# ab2b0ae36e trivial refactor - use consistent naming for iterator usage
# 3	3	src/main/groovy/lang/ObjectRange.java
# 56dfa5cbb6 GROOVY-7697 - backport changes for 2_4_X
# 2	11	src/main/org/codehaus/groovy/antlr/AntlrParserPlugin.java
# 1	11	src/main/org/codehaus/groovy/control/SourceUnit.java
# 65ce85d103 GROOVY-7697: GroovyScriptEngine.loadScriptByName doesn't support environment variable "groovy.ast"
# 64	0	src/main/org/codehaus/groovy/control/XStreamUtils.java
# 23	0	src/test/groovy/ui/GroovyMainTest.groovy
# 70	0	src/test/groovy/util/GroovyScriptEngineTest.groovy
# a14f846e8a GROOVY-7870: BinaryExpressionTransformer: Set line numbers on transformed binary expressions (closes #362)
# 2	0	src/main/org/codehaus/groovy/transform/sc/transformers/BinaryExpressionTransformer.java
# 141	0	src/test/org/codehaus/groovy/classgen/asm/sc/bugs/Groovy7870Bug.groovy
# 9ef31551b5 Security Test fix - add permissions required to run under indy
# 2	0	security/groovy.policy
# b4f9dd9bd4 Fix Security Tests (closes #363)
# 62	36	security/groovy.policy
# 16	11	src/test/groovy/security/SecurityTest.java
# 30	16	src/test/groovy/security/SecurityTestSupport.java
# bce9269a94 Cleanup Security Tests
# 0	51	security/groovy.policy
# 0	43	src/test/groovy/security/RunOneGroovyScript.java
# 0	25	src/test/groovy/security/SecurityTest.java
# 4fb0a4b5a8 minor doc update
# 1	1	src/spec/doc/tools-groovyc.adoc
# b6f1efbd08 Updated Docs for Android Plugin (closes #355)
# 5	5	src/spec/doc/tools-groovyc.adoc
# f6deab4409 GROOVY-7044: Fixed deep cloning of nodes generated by NodeBuilder
# 2	3	src/main/groovy/util/NodeBuilder.java
# 24	0	src/spec/test/builder/NodeBuilderTest.groovy
# fda7a056ee GROOVY-7558 Add private field accessors and bridge methods to dynamic classes with statically compiled inner classes
# 13	1	src/main/org/codehaus/groovy/control/CompilationUnit.java
# 1	0	src/main/org/codehaus/groovy/transform/sc/StaticCompilationMetadataKeys.java
# 21	1	src/main/org/codehaus/groovy/transform/sc/StaticCompilationVisitor.java
# 93	0	src/test/org/codehaus/groovy/classgen/asm/sc/MixedModeStaticCompilationTest.groovy
# 41a34a5b71 GROOVY-7863: Statically compiled calls to private outer class methods fail with multiple levels of nesting (closes #350)
# 8	6	src/main/org/codehaus/groovy/classgen/asm/sc/StaticInvocationWriter.java
# 22	0	src/test/org/codehaus/groovy/classgen/asm/sc/MethodCallsStaticCompilationTest.groovy
# 540595e39b Refactor: minor tidy up of style changes to Range classes (port to 2_4_X)
# 0	2	src/main/groovy/lang/EmptyRange.java
# 7	9	src/main/groovy/lang/IntRange.java
# 6	9	src/main/groovy/lang/ObjectRange.java
# 0	13	src/main/groovy/lang/Range.java
# 9	8	src/test/groovy/lang/EmptyRangeTest.java
# f87a5e9d47 Refactor: added missing @Override annotations for the Range classes (port to 2_4_X)
# 17	0	src/main/groovy/lang/EmptyRange.java
# 16	0	src/main/groovy/lang/IntRange.java
# 15	0	src/main/groovy/lang/ObjectRange.java
# 9e37804488 Refactor: unified the style of Range related classes (port to 2_4_X)
# 7	4	src/main/groovy/lang/EmptyRange.java
# 19	12	src/main/groovy/lang/IntRange.java
# 32	27	src/main/groovy/lang/ObjectRange.java
# 19	4	src/main/groovy/lang/Range.java
# 20	35	src/test/groovy/lang/EmptyRangeTest.java
# c5c2420ca8 GROOVY-7842 - MarkupTemplateEngine Totally Broken when used with a Security Manager (closes #358)
# 1	1	subprojects/groovy-templates/src/main/groovy/groovy/text/markup/MarkupTemplateEngine.java
# 5785204c2e Allow ScriptEngine to return same factory that created it
# 1	1	subprojects/groovy-jsr223/src/main/java/org/codehaus/groovy/jsr223/GroovyScriptEngineFactory.java
# 5	0	subprojects/groovy-jsr223/src/main/java/org/codehaus/groovy/jsr223/GroovyScriptEngineImpl.java
# 6	0	subprojects/groovy-jsr223/src/test/groovy/org/codehaus/groovy/jsr223/JSR223Test.groovy
# bbfe7ad074 GROOVY-7150 - Redirection of output in javax.script.ScriptEngine.invokeFunction() doesn't work (closes #230)
# 13	48	subprojects/groovy-jsr223/src/main/java/org/codehaus/groovy/jsr223/GroovyScriptEngineImpl.java
# 63	0	subprojects/groovy-jsr223/src/test/groovy/org/codehaus/groovy/jsr223/JSR223Test.groovy
# 8725d926c0 GROOVY-7875: IntRange fail fast on too large a range out by one
# 12	12	src/main/groovy/lang/IntRange.java
# 11	12	src/test/groovy/lang/IntRangeTest.groovy
# c7ae32bed8 GROOVY-7873 - Regression performance issue in string methods (closes #356)
# 8	3	src/main/org/codehaus/groovy/runtime/StringGroovyMethods.java
# 780d8281f4 correct annotation name in SourceURIASTTransformation javadoc
# 1	1	src/main/org/codehaus/groovy/transform/SourceURIASTTransformation.java
# ea940958b4 small tweak to test for GROOVY-7185
# 5	5	src/test/groovy/OverrideTest.groovy
# d84193c2a8 Merge branch 'GROOVY_2_4_X' of http://git-wip-us.apache.org/repos/asf/groovy into GROOVY_2_4_X
# cad0a650fe GROOVY-7855: NullPointerException in GenericsTypeMatcher
# 3	5	src/main/org/codehaus/groovy/ast/GenericsType.java
# 77f9b9bac1 minor refactor
# 27	0	src/main/org/codehaus/groovy/ast/tools/ClassNodeUtils.java
# 4	25	src/main/org/codehaus/groovy/classgen/Verifier.java
# bb3daa2c00 Documentation: correct StandardPropertiesModuleFactory class javadoc
# 1	1	src/main/org/codehaus/groovy/runtime/m12n/StandardPropertiesModuleFactory.java
# 115d360b37 GROOVY-7185: Add test (issue fixed by changes for GROOVY-7849)
# 24	0	src/test/groovy/OverrideTest.groovy
# 83e6268791 GROOVY-7849: Verifier should be aware of array type covariance when checking overriding method return types (closes #346)
# 1	1	src/main/org/codehaus/groovy/classgen/Verifier.java
# 18	0	src/test/groovy/OverrideTest.groovy
# 984173f3ff minor refactor: add missing assertions
# 43	47	src/test/groovy/PrimitiveDefaultValueTest.groovy
# 7390d973d4 Bump reference version
# 1	1	gradle/binarycompatibility.gradle
# 4f989414ab GROOVY-7833: exception in phase 'conversion' (also ignore blank lines - closes #329)
# 5	4	src/main/groovy/grape/GrapeIvy.groovy
# 25362dd47e GROOVY-7833: let grape ignore runner lines with hash to enable comments.
# 4	1	src/main/groovy/grape/GrapeIvy.groovy
# 036c14fa0e minor refactor
# 17	28	src/main/org/codehaus/groovy/ast/ClassNode.java
# 41	0	src/main/org/codehaus/groovy/ast/tools/ClassNodeUtils.java
# 39	0	src/main/org/codehaus/groovy/ast/tools/ParameterUtils.java
# 2	1	src/main/org/codehaus/groovy/classgen/ClassCompletionVerifier.java
# 2	17	src/main/org/codehaus/groovy/classgen/ExtendedVerifier.java
# 2	16	src/main/org/codehaus/groovy/classgen/asm/OptimizingStatementWriter.java
# df63a38da7 GROOVY-7620: No error if abstract getter is not implemented but static field exists (closes #342)
# 13	10	src/main/org/codehaus/groovy/ast/ClassNode.java
# 41	30	src/main/org/codehaus/groovy/classgen/ClassCompletionVerifier.java
# 1	1	src/test/groovy/bugs/Groovy7081Bug.groovy
# 59	0	src/test/groovy/bugs/Groovy7620Bug.groovy
# f3d031014f add a rat exclude for gradle.properties since the artifactory release plugin loses header when bumping version
# 1	0	gradle/quality.gradle
# 3a5189e8d2 GROOVY-7846: A trait that defines a static method that uses generic return types throws "BUG! Type is null" (comments/trivial formatting - closes #340)
# 15	7	src/main/org/codehaus/groovy/transform/trait/TraitComposer.java
# 8ab58a5e51 Cleanup
# 3	3	src/main/org/codehaus/groovy/transform/trait/TraitComposer.java
# 0fcaf69ae4 Make sure generics are correct for generified return types. Fixes https://issues.apache.org/jira/browse/GROOVY-7846
# 12	9	src/main/org/codehaus/groovy/transform/trait/TraitComposer.java
# 54	0	src/test/org/codehaus/groovy/transform/traitx/Groovy7846Bug.groovy
# fccc0f136b GROOVY-6950: StringGroovyMethods minor performance improvements (minor refactoring)
# 26	36	src/main/org/codehaus/groovy/runtime/StringGroovyMethods.java
# 6	6	src/main/org/codehaus/groovy/util/CharSequenceReader.java
# fc872b60d6 GROOVY-6950: StringGroovyMethods minor performance improvements (make use of line based iterator)
# 58	60	src/main/org/codehaus/groovy/runtime/StringGroovyMethods.java
# 170	0	src/main/org/codehaus/groovy/util/CharSequenceReader.java
# 16ce780c8c GROOVY-6950: StringGroovyMethods minor performance improvements (avoid calling toString)
# 48	62	src/main/org/codehaus/groovy/runtime/StringGroovyMethods.java
# 44	49	src/test/groovy/GroovyCharSequenceMethodsTest.groovy
# e4ea67c38e GROOVY-7813: Calling a non-static outer class method from a static class should fail STC (Closes #310)
# 19	12	src/main/org/codehaus/groovy/transform/stc/StaticTypeCheckingVisitor.java
# 46	0	src/test/groovy/transform/stc/MethodCallsSTCTest.groovy
# c3074762d3 GROOVY-7826: fix test name
# 1	1	src/test/org/codehaus/groovy/ast/Groovy7826Bug.java
# 97505b1d4a GROOVY-7826: fix test name
# 2	2	src/test/org/codehaus/groovy/ast/{Groovy7862Bug.java => Groovy7826Bug.java}
# dc6f2677d4 add missing license file
# 18	0	src/test/org/codehaus/groovy/ast/Groovy7862Bug.java
# 305c29363d GROOVY-7784: TypeChecked/CompileStatic: IndexOutOfBoundsException (a few more tests)
# 7	5	src/test/org/codehaus/groovy/classgen/asm/sc/BugsStaticCompileTest.groovy
# 8c1e789864 GROOVY-7784: TypeChecked/CompileStatic: IndexOutOfBoundsException (closes #339)
# 7	2	src/main/org/codehaus/groovy/transform/stc/StaticTypeCheckingVisitor.java
# 17	0	src/test/org/codehaus/groovy/classgen/asm/sc/BugsStaticCompileTest.groovy
# 6f5dfffb0b GROOVY-7841: Assert fails when accessing particular primitive values with @CompileStatic
# 7	3	src/main/org/codehaus/groovy/transform/sc/transformers/BooleanExpressionTransformer.java
# 9	2	src/test/org/codehaus/groovy/classgen/asm/sc/BugsStaticCompileTest.groovy
# a132ad8939 Add missing ':' in display command example (closes #337)
# 2	2	subprojects/groovy-groovysh/src/spec/doc/groovysh.adoc
# c0d1347b3d GROOVY-6203: GroovyScriptEngine does not take script base class into account (closes #335)
# 6	3	src/main/groovy/util/GroovyScriptEngine.java
# 17	1	src/test/groovy/util/GroovyScriptEngineReloadingTest.groovy
# d77e2bb2c8 refactor(core): use uppercase L for long literal
# 3	3	src/main/org/codehaus/groovy/runtime/MetaClassHelper.java
# 31a98aeaee GROOVY-7832: NullPointerException in GroovyConsole with an input method (closes #326)
# 5	1	subprojects/groovy-console/src/main/groovy/groovy/ui/text/StructuredSyntaxDocumentFilter.java
# de30aed509 GROOVY-7826: do not show redirect for generic type arguments to break the infinite recursion (closes #333)
# 3	4	src/main/org/codehaus/groovy/ast/ClassNode.java
# 23	0	src/test/org/codehaus/groovy/ast/Groovy7862Bug.java
# f282d21d87 GROOVY-7793: Compiler compiles class with private abstract method (closes #328)
# 16	0	src/main/org/codehaus/groovy/classgen/ClassCompletionVerifier.java
# 63	0	src/test/groovy/AbstractClassAndInterfaceTest.groovy
# 9	0	src/test/org/codehaus/groovy/classgen/ClassCompletionVerifierTest.java
# fa790d1aad Documentation: fix grammar mistake in metaprogramming section (closes https://github.com/groovy/groovy-website/issues/91)
# 1	1	src/spec/doc/core-metaprogramming.adoc
# 94f5ec8dcf GROOVY-7604: traits docs diamond problem explanation (closes #327)
# 1	2	src/spec/doc/core-traits.adoc
# 2a05758a50 refactor(core): remove unused utility classes (closes #324)
# 0	200	src/main/org/codehaus/groovy/util/AbstractConcurrentDoubleKeyMap.java
# 0	93	src/main/org/codehaus/groovy/util/DoubleKeyHashMap.java
# 0	118	src/main/org/codehaus/groovy/util/ManagedDoubleKeyMap.java
# 0	58	src/test/org/codehaus/groovy/util/ManagedDoubleKeyMapTest.groovy
# 021d3a1708 Fix for ManagedDoubleKeyMap when there are hash collisions and entry array must be expanded
# 2	2	src/main/org/codehaus/groovy/util/AbstractConcurrentDoubleKeyMap.java
# 17	0	src/test/org/codehaus/groovy/util/ManagedDoubleKeyMapTest.groovy
# e755b6229d Guard against recursive calls to ReferenceManager#removeStallEntries that could cause a StackOverflowError.  A ManagedReference#finalizeReference method may call ManagedReference#clear on other references as part of the clean up process and #clear in turns calls #removeStallEntries.  This change makes it so that a queue is not re-entered for processing once it has started to be processed.
# 47	23	src/main/org/codehaus/groovy/util/ReferenceManager.java
# 17	0	src/test/org/codehaus/groovy/util/ReferenceManagerTest.groovy
# 1dd15de8e3 GROOVY-7820: CachedMethod.compareToCachedMethod throws "Should never happen" (closes #315)
# 4	0	src/main/org/codehaus/groovy/reflection/CachedMethod.java
# 25	0	src/test/org/codehaus/groovy/reflection/CachedMethodTest.groovy
# 8ffef9a4a4 minor javadoc fixes
# 2	2	src/main/groovy/lang/BenchmarkInterceptor.java
# 4	4	src/main/groovy/lang/MetaClassImpl.java
# 2	2	src/main/groovy/lang/MetaClassRegistry.java
# 14	14	src/main/groovy/lang/MetaMethod.java
# 1	1	src/main/groovy/lang/ProxyMetaClass.java
# 1	1	src/main/groovy/transform/CompileStatic.java
# 1	1	src/main/groovy/transform/SelfType.java
# 1	1	src/main/groovy/ui/GroovySocketServer.java
# 0	1	src/main/org/codehaus/groovy/antlr/AntlrASTProcessSnippets.java
# 1	1	src/main/org/codehaus/groovy/classgen/asm/CompileStack.java
# 1	1	src/main/org/codehaus/groovy/reflection/ParameterTypes.java
# 1	1	subprojects/groovy-groovydoc/src/main/java/org/codehaus/groovy/tools/groovydoc/LinkArgument.java
# 1	1	subprojects/groovy-jmx/src/main/java/groovy/jmx/builder/JmxBuilderException.java
# 2	2	subprojects/groovy-servlet/src/main/java/groovy/servlet/TemplateServlet.java
# 1	1	subprojects/groovy-swing/src/main/java/org/codehaus/groovy/binding/PropertyPathFullBinding.java
# 1	1	subprojects/groovy-swing/src/main/java/org/codehaus/groovy/runtime/SwingGroovyMethods.java
# fa8f8db79a GROOVY-7728 - LAX parser: Commenting out key/val pairs doesn't work (closes #322)
# 12	10	subprojects/groovy-json/src/main/java/groovy/json/internal/JsonParserLax.java
# 19	0	subprojects/groovy-json/src/test/groovy/groovy/json/JsonSlurperLaxTest.groovy
# 3998f042dc Fixed a typo in groovy Documentation (closes #323)
# 1	1	src/spec/doc/core-differences-java.adoc
# 22c26f2173 make private methods static when they are plain functions (closes #290)
# 1	1	src/main/groovy/beans/BindableASTTransformation.java
# 1	1	src/main/groovy/beans/VetoableASTTransformation.java
# 2	2	src/main/groovy/grape/GrabAnnotationTransformation.java
# 5	5	src/main/groovy/lang/GroovyClassLoader.java
# 3	3	src/main/groovy/lang/GroovyShell.java
# 1	1	src/main/groovy/lang/ListWithDefault.java
# 21	21	src/main/groovy/lang/MetaClassImpl.java
# 1	1	src/main/groovy/lang/ParameterArray.java
# 6	6	src/main/groovy/transform/builder/DefaultStrategy.java
# 5	5	src/main/groovy/transform/builder/InitializerStrategy.java
# 2	2	src/main/groovy/transform/stc/FromAbstractTypeMethods.java
# 2	2	src/main/groovy/util/ConfigObject.java
# 2	2	src/main/groovy/util/Node.java
# 5	5	src/main/org/codehaus/groovy/antlr/AntlrParserPlugin.java
# 2	2	src/main/org/codehaus/groovy/antlr/java/Java2GroovyConverter.java
# 2	2	src/main/org/codehaus/groovy/antlr/treewalker/MindMapPrinter.java
# 2	2	src/main/org/codehaus/groovy/antlr/treewalker/NodeAsHTMLPrinter.java
# 1	1	src/main/org/codehaus/groovy/antlr/treewalker/SourcePrinter.java
# 2	2	src/main/org/codehaus/groovy/ast/builder/AstBuilderTransformation.java
# 1	1	src/main/org/codehaus/groovy/ast/expr/DeclarationExpression.java
# 2	2	src/main/org/codehaus/groovy/classgen/AnnotationVisitor.java
# 3	3	src/main/org/codehaus/groovy/classgen/AsmClassGenerator.java
# 6	6	src/main/org/codehaus/groovy/classgen/ClassCompletionVerifier.java
# 2	2	src/main/org/codehaus/groovy/classgen/EnumCompletionVisitor.java
# 3	3	src/main/org/codehaus/groovy/classgen/EnumVisitor.java
# 3	3	src/main/org/codehaus/groovy/classgen/ExtendedVerifier.java
# 5	5	src/main/org/codehaus/groovy/classgen/InnerClassCompletionVisitor.java
# 1	1	src/main/org/codehaus/groovy/classgen/InnerClassVisitor.java
# 1	1	src/main/org/codehaus/groovy/classgen/VariableScopeVisitor.java
# 15	15	src/main/org/codehaus/groovy/classgen/Verifier.java
# 4	4	src/main/org/codehaus/groovy/classgen/asm/BinaryExpressionMultiTypeDispatcher.java
# 2	2	src/main/org/codehaus/groovy/classgen/asm/ClosureWriter.java
# 1	1	src/main/org/codehaus/groovy/classgen/asm/CompileStack.java
# 1	1	src/main/org/codehaus/groovy/classgen/asm/InvocationWriter.java
# 1	1	src/main/org/codehaus/groovy/classgen/asm/MopWriter.java
# 3	3	src/main/org/codehaus/groovy/classgen/asm/OperandStack.java
# 2	2	src/main/org/codehaus/groovy/classgen/asm/indy/InvokeDynamicWriter.java
# 1	1	src/main/org/codehaus/groovy/classgen/asm/sc/StaticInvocationWriter.java
# 1	1	src/main/org/codehaus/groovy/classgen/asm/sc/StaticTypesClosureWriter.java
# 4	4	src/main/org/codehaus/groovy/control/AnnotationConstantsVisitor.java
# 3	3	src/main/org/codehaus/groovy/control/ClassNodeResolver.java
# 2	2	src/main/org/codehaus/groovy/control/CompilationUnit.java
# 2	2	src/main/org/codehaus/groovy/control/GenericsVisitor.java
# 6	6	src/main/org/codehaus/groovy/control/ResolveVisitor.java
# 1	1	src/main/org/codehaus/groovy/control/SourceUnit.java
# 8	8	src/main/org/codehaus/groovy/control/StaticImportVisitor.java
# 1	1	src/main/org/codehaus/groovy/control/StaticVerifier.java
# 1	1	src/main/org/codehaus/groovy/control/customizers/SecureASTCustomizer.java
# 2	2	src/main/org/codehaus/groovy/control/customizers/builder/SourceAwareCustomizerFactory.java
# 1	1	src/main/org/codehaus/groovy/reflection/CachedMethod.java
# 2	2	src/main/org/codehaus/groovy/reflection/ClassInfo.java
# 1	1	src/main/org/codehaus/groovy/reflection/MixinInMetaClass.java
# 3	3	src/main/org/codehaus/groovy/reflection/ParameterTypes.java
# 7	7	src/main/org/codehaus/groovy/runtime/ProxyGeneratorAdapter.java
# 1	1	src/main/org/codehaus/groovy/runtime/m12n/SimpleExtensionModule.java
# 4	4	src/main/org/codehaus/groovy/runtime/metaclass/ClosureMetaClass.java
# 1	1	src/main/org/codehaus/groovy/runtime/metaclass/ConcurrentReaderHashMap.java
# 1	1	src/main/org/codehaus/groovy/runtime/metaclass/MetaClassRegistryImpl.java
# 3	3	src/main/org/codehaus/groovy/runtime/metaclass/MetaMethodIndex.java
# 1	1	src/main/org/codehaus/groovy/runtime/metaclass/MethodSelectionException.java
# 2	2	src/main/org/codehaus/groovy/runtime/powerassert/SourceText.java
# 3	3	src/main/org/codehaus/groovy/tools/LoaderConfiguration.java
# 14	14	src/main/org/codehaus/groovy/tools/javac/JavaStubGenerator.java
# 1	1	src/main/org/codehaus/groovy/tools/javac/JavacJavaCompiler.java
# 3	3	src/main/org/codehaus/groovy/transform/sc/StaticCompilationVisitor.java
# 4	4	src/main/org/codehaus/groovy/transform/sc/transformers/BinaryExpressionTransformer.java
# 1	1	src/main/org/codehaus/groovy/transform/sc/transformers/CastExpressionOptimizer.java
# 2	2	src/main/org/codehaus/groovy/transform/sc/transformers/MethodCallExpressionTransformer.java
# 2	2	src/main/org/codehaus/groovy/transform/sc/transformers/VariableExpressionTransformer.java
# 1	1	src/main/org/codehaus/groovy/transform/stc/AbstractTypeCheckingExtension.java
# 16	16	src/main/org/codehaus/groovy/transform/stc/StaticTypeCheckingVisitor.java
# 2	2	src/main/org/codehaus/groovy/transform/stc/TraitTypeCheckingExtension.java
# 1	1	src/main/org/codehaus/groovy/transform/trait/NAryOperationRewriter.java
# 2	2	src/main/org/codehaus/groovy/transform/trait/TraitReceiverTransformer.java
# 2	2	src/main/org/codehaus/groovy/util/AbstractConcurrentMapBase.java
# 1	1	src/main/org/codehaus/groovy/util/ComplexKeyHashMap.java
# 2	2	src/main/org/codehaus/groovy/vmplugin/v5/Java5.java
# 1	1	subprojects/groovy-bsf/src/main/java/org/codehaus/groovy/bsf/GroovyEngine.java
# 2	2	subprojects/groovy-groovydoc/src/main/java/org/codehaus/groovy/tools/groovydoc/GroovyDocTool.java
# 1	1	subprojects/groovy-groovydoc/src/main/java/org/codehaus/groovy/tools/groovydoc/GroovyDocWriter.java
# 8	8	subprojects/groovy-groovydoc/src/main/java/org/codehaus/groovy/tools/groovydoc/GroovyRootDocBuilder.java
# 8	8	subprojects/groovy-groovydoc/src/main/java/org/codehaus/groovy/tools/groovydoc/SimpleGroovyClassDocAssembler.java
# 1	1	subprojects/groovy-json/src/main/java/groovy/json/JsonBuilder.java
# 1	1	subprojects/groovy-json/src/main/java/groovy/json/JsonDelegate.java
# 1	1	subprojects/groovy-json/src/main/java/groovy/json/internal/LazyValueMap.java
# 1	1	subprojects/groovy-json/src/main/java/groovy/json/internal/ReaderCharacterSource.java
# 2	2	subprojects/groovy-json/src/main/java/groovy/json/internal/ValueList.java
# 2	2	subprojects/groovy-jsr223/src/main/java/org/codehaus/groovy/jsr223/GroovyScriptEngineImpl.java
# 2	2	subprojects/groovy-servlet/src/main/java/groovy/servlet/ServletBinding.java
# 1	1	subprojects/groovy-sql/src/main/java/groovy/sql/DataSet.java
# 1	1	subprojects/groovy-sql/src/main/java/groovy/sql/ExtractIndexAndSql.java
# 6	6	subprojects/groovy-sql/src/main/java/groovy/sql/Sql.java
# 5	5	subprojects/groovy-swing/src/main/java/groovy/inspect/swingui/TableSorter.java
# 1	1	subprojects/groovy-swing/src/main/java/org/codehaus/groovy/binding/PropertyBinding.java
# 1	1	subprojects/groovy-xml/src/main/java/groovy/util/XmlNodePrinter.java
# 1	1	subprojects/groovy-xml/src/main/java/groovy/util/XmlParser.java
# 1	1	subprojects/groovy-xml/src/main/java/groovy/util/XmlSlurper.java
# 1	1	subprojects/groovy-xml/src/main/java/groovy/xml/DOMBuilder.java
# 1	1	subprojects/groovy-xml/src/main/java/groovy/xml/MarkupBuilder.java
# 1	1	subprojects/groovy-xml/src/main/java/groovy/xml/NamespaceBuilderSupport.java
# 1	1	subprojects/groovy-xml/src/main/java/groovy/xml/streamingmarkupsupport/StreamingMarkupWriter.java
# fdfa6e7750 refactor(json): inline to eliminate unused Classes (closes #318)
# 4	1	subprojects/groovy-json/src/main/java/groovy/json/internal/BaseJsonParser.java
# 0	30	subprojects/groovy-json/src/main/java/groovy/json/internal/Byt.java
# 2	1	subprojects/groovy-json/src/main/java/groovy/json/internal/CharBuf.java
# 0	31	subprojects/groovy-json/src/main/java/groovy/json/internal/Charsets.java
# 47d585de56 refactor(json): simplified expressions
# 1	9	subprojects/groovy-json/src/main/java/groovy/json/internal/BaseJsonParser.java
# 2	10	subprojects/groovy-json/src/main/java/groovy/json/internal/CharBuf.java
# 1	2	subprojects/groovy-json/src/main/java/groovy/json/internal/CharSequenceValue.java
# 6	14	subprojects/groovy-json/src/main/java/groovy/json/internal/Dates.java
# 3	5	subprojects/groovy-json/src/main/java/groovy/json/internal/JsonFastParser.java
# 2	4	subprojects/groovy-json/src/main/java/groovy/json/internal/JsonParserCharArray.java
# 4	10	subprojects/groovy-json/src/main/java/groovy/json/internal/JsonParserLax.java
# 1	2	subprojects/groovy-json/src/main/java/groovy/json/internal/NumberValue.java
# ...
# 110	0	src/test/groovy/notworking/SwitchTest.groovy
# 23	0	src/test/groovy/notworking/UsingTest.groovy
# e71542f9a8 all tests are working right now to make life easier for bob
# 22	0	src/test/org/codehaus/groovy/classgen/DumpClass.java
# 8dcc001e4e added try / catch / finally to the
# 81	0	src/main/org/codehaus/groovy/ast/CatchStatement.java
# 1	0	src/main/org/codehaus/groovy/ast/GroovyCodeVisitor.java
# 88	0	src/main/org/codehaus/groovy/ast/TryCatchFinally.java
# 6	0	src/main/org/codehaus/groovy/classgen/ClassGenerator.java
# 6	0	src/main/org/codehaus/groovy/interpreter/Interpreter.java
# d686ebbc47 working assertions
# 13	3	TODO.txt
# 8	0	src/main/org/codehaus/groovy/ast/ClassNode.java
# 50	44	src/main/org/codehaus/groovy/classgen/ClassGenerator.java
# 2	2	src/main/org/codehaus/groovy/runtime/InvokerHelper.java
# 5	5	src/test/org/codehaus/groovy/classgen/DumpClass.java
# 9d244e987e fixed constant bug
# 27	36	src/main/org/codehaus/groovy/classgen/ClassGenerator.java
# 535bf948c7 first checkin of the assert implementation
# 14	2	TODO.txt
# 25	5	src/main/org/codehaus/groovy/classgen/ClassGenerator.java
# 9	0	src/main/org/codehaus/groovy/runtime/InvokerHelper.java
# 13	0	src/test/org/codehaus/groovy/classgen/DumpClass.java
# 25cb20748a changes ready for if we ever get the maven test plugin fixed to allow the test classes dir to be searched
# 13	0	project.properties
# af40753aee 'return' statement
# 11	0	src/main/org/codehaus/groovy/syntax/parser/ASTBuilder.java
# 12	0	src/main/org/codehaus/groovy/syntax/parser/Parser.java
# a6ee72a353 Property (dotted) expressions functioning.
# 15	0	src/main/org/codehaus/groovy/syntax/parser/ASTBuilder.java
# bbadbfd408 Fixing binary expr construction.
# 3	1	src/main/org/codehaus/groovy/syntax/parser/ASTBuilder.java
# 2	2	src/main/org/codehaus/groovy/syntax/parser/Parser.java
# 192543f43b More debugging cleaning.
# 1	1	src/main/org/codehaus/groovy/syntax/Token.java
# 1	1	src/main/org/codehaus/groovy/syntax/parser/CSTNode.java
# 192b631e7b Fixing some debug stuff.
# 1	1	src/main/org/codehaus/groovy/syntax/Token.java
# 1	1	src/main/org/codehaus/groovy/syntax/parser/CSTNode.java
# 422e8974e2 Moving the bug around.
# 10	0	src/main/org/codehaus/groovy/syntax/parser/ASTBuilder.java
# e754912d3f Fixing groovy:test to not clutter ${basedir}
# 7	2	maven.xml
# f9687e8b03 added toString() implementations for easier tracing
# 5	0	src/main/org/codehaus/groovy/syntax/Token.java
# 5	0	src/main/org/codehaus/groovy/syntax/parser/CSTNode.java
# 6ba7af9240 fixed error handling to improve error reporting
# 45	0	src/main/org/codehaus/groovy/GroovyException.java
# 1	2	src/main/org/codehaus/groovy/syntax/SyntaxException.java
# 3	7	src/main/org/codehaus/groovy/syntax/parser/ASTBuilder.java
# 8b51c36c23 added check for null parameter
# 4	0	src/main/org/codehaus/groovy/ast/ExpressionStatement.java
# 1b3f8b9f8a Re-org to allow this.foo and super.foo in lexer/parser. Still needs to be pushed through to the ASTBuilder
# 18	0	src/main/org/codehaus/groovy/syntax/lexer/Lexer.java
# 3	3	src/main/org/codehaus/groovy/syntax/parser/Parser.java
# 82661774a6 Adding constant support.  Still fails on CompilerBugs
# 22	7	src/main/org/codehaus/groovy/syntax/Token.java
# 12	3	src/main/org/codehaus/groovy/syntax/lexer/Lexer.java
# 35	0	src/main/org/codehaus/groovy/syntax/parser/ASTBuilder.java
# 8	0	src/main/org/codehaus/groovy/syntax/parser/Parser.java
# 17	5	src/test/org/codehaus/groovy/syntax/TokenTest.java
# 2	2	src/test/org/codehaus/groovy/syntax/lexer/LexerTest.java
# e7619d322d added implementation of RangeExpression
# 1	0	src/main/org/codehaus/groovy/ast/GroovyCodeVisitor.java
# 1	1	src/main/org/codehaus/groovy/ast/RangeExpression.java
# 6	0	src/main/org/codehaus/groovy/classgen/ClassGenerator.java
# 18	0	src/main/org/codehaus/groovy/interpreter/Interpreter.java
# 8	0	src/main/org/codehaus/groovy/runtime/Invoker.java
# 4	0	src/main/org/codehaus/groovy/runtime/InvokerHelper.java
# b9a41b6d1e Tests for multiline comments.
# 42	0	src/test/org/codehaus/groovy/syntax/lexer/LexerTest.java
# 87578c39d8 Tests for single-line comments
# 33	0	src/test/org/codehaus/groovy/syntax/lexer/LexerTest.java
# fae44a3dbc Damnit.  Missed a save.
# 2	0	src/main/org/codehaus/groovy/syntax/lexer/Lexer.java
# a93ff66772 Fixing comment lexing.
# 2	3	src/main/org/codehaus/groovy/syntax/lexer/Lexer.java
# 8169b15989 added quick cut of a range expression
# 78	0	src/main/org/codehaus/groovy/ast/RangeExpression.java
# a322a829a5 lexing and ignoring single- and double-line comments.
# 58	0	src/main/org/codehaus/groovy/syntax/lexer/Lexer.java
# 68e663fc42 allow maven test to invoke all the groovy unit tests
# 69	1	maven.xml
# 1	2	project.xml
# 408b29851d refactored the source tree to make things a little cleaner.
# 2	2	.classpath
# 1	1	maven.xml
# 4	4	project.xml
# 9	0	src/main/groovy/LogMixin.groovy
# 9	0	src/main/groovy/StaticLogMixin.groovy
# 16	0	src/main/groovy/Test.groovy
# 17	0	src/main/groovy/lang/Bitwise.java
# 28	0	src/main/log4j.properties
# 7	0	src/main/org/codehaus/groovy/GroovyException.java
# 390	0	src/main/org/codehaus/groovy/ant/Groovyc.java
# 62	0	src/main/org/codehaus/groovy/ast/ASTNode.java
# 82	0	src/main/org/codehaus/groovy/ast/AssertStatement.java
# 94	0	src/main/org/codehaus/groovy/ast/BinaryExpression.java
# 69	0	src/main/org/codehaus/groovy/ast/BooleanExpression.java
# 140	0	src/main/org/codehaus/groovy/ast/ClassNode.java
# 83	0	src/main/org/codehaus/groovy/ast/ConstantExpression.java
# 82	0	src/main/org/codehaus/groovy/ast/ConstructorNode.java
# 76	0	src/main/org/codehaus/groovy/ast/DoWhileLoop.java
# 61	0	src/main/org/codehaus/groovy/ast/EmptyStatement.java
# 59	0	src/main/org/codehaus/groovy/ast/Expression.java
# 70	0	src/main/org/codehaus/groovy/ast/ExpressionStatement.java
# 77	0	src/main/org/codehaus/groovy/ast/FieldExpression.java
# 117	0	src/main/org/codehaus/groovy/ast/FieldNode.java
# 83	0	src/main/org/codehaus/groovy/ast/ForLoop.java
# 62	0	src/main/org/codehaus/groovy/ast/GroovyClassVisitor.java
# 79	0	src/main/org/codehaus/groovy/ast/GroovyCodeVisitor.java
# 83	0	src/main/org/codehaus/groovy/ast/IfElse.java
# 83	0	src/main/org/codehaus/groovy/ast/ListExpression.java
# 76	0	src/main/org/codehaus/groovy/ast/MapEntryExpression.java
# 84	0	src/main/org/codehaus/groovy/ast/MapExpression.java
# 87	0	src/main/org/codehaus/groovy/ast/MethodCallExpression.java
# 138	0	src/main/org/codehaus/groovy/ast/MethodNode.java
# 88	0	src/main/org/codehaus/groovy/ast/Parameter.java
# 80	0	src/main/org/codehaus/groovy/ast/PropertyExpression.java
# 112	0	src/main/org/codehaus/groovy/ast/PropertyNode.java
# 72	0	src/main/org/codehaus/groovy/ast/ReturnStatement.java
# 56	0	src/main/org/codehaus/groovy/ast/Statement.java
# 85	0	src/main/org/codehaus/groovy/ast/StatementBlock.java
# 84	0	src/main/org/codehaus/groovy/ast/TupleExpression.java
# 74	0	src/main/org/codehaus/groovy/ast/VariableExpression.java
# 76	0	src/main/org/codehaus/groovy/ast/WhileLoop.java
# 8	0	src/main/org/codehaus/groovy/ast/package.html
# 789	0	src/main/org/codehaus/groovy/classgen/ClassGenerator.java
# 64	0	src/main/org/codehaus/groovy/classgen/ClassGeneratorException.java
# 74	0	src/main/org/codehaus/groovy/classgen/GroovyClassLoader.java
# 110	0	src/main/org/codehaus/groovy/classgen/MethodCaller.java
# 89	0	src/main/org/codehaus/groovy/classgen/Variable.java
# 8	0	src/main/org/codehaus/groovy/classgen/package.html
# 379	0	src/main/org/codehaus/groovy/interpreter/Interpreter.java
# 64	0	src/main/org/codehaus/groovy/interpreter/InterpreterException.java
# 88	0	src/main/org/codehaus/groovy/interpreter/RuntimeContext.java
# 8	0	src/main/org/codehaus/groovy/interpreter/package.html
# 65	0	src/main/org/codehaus/groovy/lang/Closure.java
# 66	0	src/main/org/codehaus/groovy/lang/ClosureException.java
# 99	0	src/main/org/codehaus/groovy/lang/MapEntry.java
# 153	0	src/main/org/codehaus/groovy/lang/Node.java
# 120	0	src/main/org/codehaus/groovy/lang/Range.java
# 95	0	src/main/org/codehaus/groovy/lang/Tuple.java
# 8	0	src/main/org/codehaus/groovy/lang/package.html
# 8	0	src/main/org/codehaus/groovy/package.html
# 114	0	src/main/org/codehaus/groovy/runtime/ClassExtender.java
# 359	0	src/main/org/codehaus/groovy/runtime/DefaultGroovyMethods.java
# 247	0	src/main/org/codehaus/groovy/runtime/Invoker.java
# 64	0	src/main/org/codehaus/groovy/runtime/InvokerException.java
# 146	0	src/main/org/codehaus/groovy/runtime/InvokerHelper.java
# 62	0	src/main/org/codehaus/groovy/runtime/InvokerInvocationException.java
# 478	0	src/main/org/codehaus/groovy/runtime/MetaClass.java
# 100	0	src/main/org/codehaus/groovy/runtime/MetaClassRegistry.java
# 23	0	src/main/org/codehaus/groovy/runtime/MethodClosure.java
# 68	0	src/main/org/codehaus/groovy/runtime/MethodHelper.java
# 57	0	src/main/org/codehaus/groovy/runtime/TextExpression.java
# 8	0	src/main/org/codehaus/groovy/runtime/package.html
# 75	0	src/main/org/codehaus/groovy/syntax/AbstractTokenStream.java
# 19	0	src/main/org/codehaus/groovy/syntax/LookAheadExhaustionException.java
# 15	0	src/main/org/codehaus/groovy/syntax/SemanticException.java
# 61	0	src/main/org/codehaus/groovy/syntax/SyntaxException.java
# 1200	0	src/main/org/codehaus/groovy/syntax/Token.java
# 26	0	src/main/org/codehaus/groovy/syntax/TokenMismatchException.java
# 99	0	src/main/org/codehaus/groovy/syntax/TokenStream.java
# 75	0	src/main/org/codehaus/groovy/syntax/lexer/AbstractCharStream.java
# 115	0	src/main/org/codehaus/groovy/syntax/lexer/CharStream.java
# 39	0	src/main/org/codehaus/groovy/syntax/lexer/InputStreamCharStream.java
# 812	0	src/main/org/codehaus/groovy/syntax/lexer/Lexer.java
# 107	0	src/main/org/codehaus/groovy/syntax/lexer/LexerException.java
# 29	0	src/main/org/codehaus/groovy/syntax/lexer/LexerTokenStream.java
# 31	0	src/main/org/codehaus/groovy/syntax/lexer/StringCharStream.java
# 29	0	src/main/org/codehaus/groovy/syntax/lexer/UnexpectedCharacterException.java
# 12	0	src/main/org/codehaus/groovy/syntax/lexer/UnterminatedStringLiteralException.java
# 8	0	src/main/org/codehaus/groovy/syntax/lexer/package.html
# 8	0	src/main/org/codehaus/groovy/syntax/package.html
# 568	0	src/main/org/codehaus/groovy/syntax/parser/ASTBuilder.java
# 100	0	src/main/org/codehaus/groovy/syntax/parser/CSTNode.java
# 1048	0	src/main/org/codehaus/groovy/syntax/parser/Parser.java
# 9	0	src/main/org/codehaus/groovy/syntax/parser/ParserException.java
# 84	0	src/main/org/codehaus/groovy/syntax/parser/SemanticVerificationResult.java
# 14	0	src/main/org/codehaus/groovy/syntax/parser/SemanticVerifier.java
# 79	0	src/main/org/codehaus/groovy/syntax/parser/UnexpectedTokenException.java
# 355	0	src/main/org/codehaus/groovy/tools/Compiler.java
# 23	0	src/main/org/codehaus/groovy/tools/CompilerClassLoader.java
# 9	0	src/main/org/codehaus/groovy/tools/Grok.java
# 92	0	src/test/org/codehaus/groovy/GroovyTestCase.java
# 66	0	src/test/org/codehaus/groovy/classgen/ClassGeneratorTest.java
# 60	0	src/test/org/codehaus/groovy/classgen/DummyTestDerivation.java
# 122	0	src/test/org/codehaus/groovy/classgen/DumpClass.java
# 99	0	src/test/org/codehaus/groovy/classgen/ForTest.java
# 119	0	src/test/org/codehaus/groovy/classgen/IfElseTest.java
# 104	0	src/test/org/codehaus/groovy/classgen/MethodTest.java
# 109	0	src/test/org/codehaus/groovy/classgen/PropertyTest.java
# 162	0	src/test/org/codehaus/groovy/classgen/TestSupport.java
# 133	0	src/test/org/codehaus/groovy/classgen/TupleListTest.java
# 179	0	src/test/org/codehaus/groovy/interpreter/BinaryExpressionTest.java
# 73	0	src/test/org/codehaus/groovy/interpreter/CounterBean.java
# 80	0	src/test/org/codehaus/groovy/interpreter/DummyBean.java
# 92	0	src/test/org/codehaus/groovy/interpreter/ForLoopTest.java
# 100	0	src/test/org/codehaus/groovy/interpreter/IfElseTest.java
# 148	0	src/test/org/codehaus/groovy/interpreter/InterpreterTest.java
# 90	0	src/test/org/codehaus/groovy/interpreter/RuntimeContextTest.java
# 97	0	src/test/org/codehaus/groovy/interpreter/WhileLoopTest.java
# 125	0	src/test/org/codehaus/groovy/lang/NodeTest.java
# 103	0	src/test/org/codehaus/groovy/lang/RangeTest.java
# 75	0	src/test/org/codehaus/groovy/lang/TupleTest.java
# 87	0	src/test/org/codehaus/groovy/runtime/DummyBean.java
# 91	0	src/test/org/codehaus/groovy/runtime/InvokeGroovyMethodTest.java
# 230	0	src/test/org/codehaus/groovy/runtime/InvokeMethodTest.java
# 159	0	src/test/org/codehaus/groovy/runtime/InvokerTest.java
# 114	0	src/test/org/codehaus/groovy/runtime/PropertyTest.java
# 93	0	src/test/org/codehaus/groovy/runtime/TupleListTest.java
# 244	0	src/test/org/codehaus/groovy/syntax/AbstractTokenStreamTest.java
# 717	0	src/test/org/codehaus/groovy/syntax/TokenTest.java
# 230	0	src/test/org/codehaus/groovy/syntax/lexer/AbstractCharStreamTest.java
# 921	0	src/test/org/codehaus/groovy/syntax/lexer/LexerTest.java
# 47	0	src/test/org/codehaus/groovy/syntax/lexer/LexerTokenStreamTest.java
# 41	0	src/test/org/codehaus/groovy/syntax/lexer/StringCharStreamTest.java
# 60	0	src/test/org/codehaus/groovy/syntax/parser/CSTNodeTest.java
# 1560	0	src/test/org/codehaus/groovy/syntax/parser/ParserTest.java
# b6398d120c allow the compiler to pass in null when the type of an object is not known.
# 1	1	TODO.txt
# 1	0	project.xml
# 12385eebe7 Added an Ant task for compiling Groovy code. Also refactored the groovy test cases to keep only one failing test visible at once so we can start incrementally to start writing groovy unit test cases
# 2	0	.classpath
# 27	11	maven.xml
# 6	0	project.xml
# 24223c4e3b fixed failing unit test
# 0	4	TODO.txt
# 8b6e35ff4e added support for AssertStatement
# 2	0	TODO.txt
# 98cc5c0233 Added support for property expressions
# 13	0	TODO.txt
# 704b8b0560 added code generation of the use of tuples, lists and maps
# 1	1	TODO.txt
# 476da5606d Added AST for tuples, lists and maps
# 1	0	.cvsignore
# 16e7701ce0 added better links to the wiki
# 1	1	xdocs/index.html
# 4	1	xdocs/navigation.xml
# 4d0d306baf added a quick todo list of code refactorings etc required. Should use JIRA soon for larger pieces of work
# 44	0	TODO.txt
# 8ef8ef1fbc added link to the irc logs
# 2	0	xdocs/navigation.xml
# ef66b5f716 added a basic bit of documentation for the project website
# 4	0	maven.xml
# 43	0	xdocs/index.html
# 22	0	xdocs/navigation.xml
# f2d79d419d added myself as a founder and commented out some failing reports on O
# 27	0	project.xml
# 0ddb204760 Fixed the for loop test
# 6	0	.classpath
# cedbded71a Forgot to add Grok, previously. Cleaned up the tree-walking ASTBuilder. Added Bar.groovy to test with.
# 0	2	project.xml
# 8d05547e0e Mutating the classworlds config stuff to support mulitple binaries, so we can run the compiler or grok (groovydoc).
# 5	1	maven.xml
# 140	0	src/bin/grok
# 109	0	src/bin/grok.bat
# 2	2	src/bin/groovy
# 1	1	src/bin/groovy.bat
# 20	0	src/conf/grok-classworlds.conf
# 0	0	src/conf/{classworlds.conf => groovy-classworlds.conf}
# 5be8906e0e Updated to newer classworlds.
# 1	1	project.xml
# 2	2	src/bin/groovy
# 2	2	src/bin/groovy.bat
# c4c2e95722 -- Addded classworlds as a dependency -- Simple classworlds script and config for compiler -- Maven target to install groovy toolchain to a staging dir
# 23	0	maven.xml
# 1	0	project.properties
# 5	0	project.xml
# 140	0	src/bin/groovy
# 109	0	src/bin/groovy.bat
# 20	0	src/conf/classworlds.conf
# e9bf89777e Whoops, main() should be static. Adding CLI-parsing.
# 5	0	project.xml
# 10ef8e183c Tidied up code some more. Also now we have a maven goal...
# 24	1	maven.xml
# 33f538ca64 We can now generate JavaBeans! :)
# 3	1	.classpath
# 9	1	project.xml
# c84b73d4ea Initial checking of the basics of the ASM code generator and the AST for the class, method, field, property nodes.
# 3	1	.classpath
# 3d85f25a53 added cvsignore of stuff maven spits out
# 1	0	.cvsignore
# 74356e8202 added initial metadata Attribute class for @style metadata
# 13	0	project.xml
# 25d80e9e8c Added some stuff to cvsignore as well as a new switch statement test case
# 22	0	.classpath
# 3	0	.cvsignore
# 18	0	.project
# 1eb2275669 Operator docs, maybe.
# 2	0	src/latex/spec/groovy-lang-spec.tex
# 7	0	src/latex/spec/operators.tex
# b5b1132804 More skeleton docs.
# 2	0	src/latex/spec/expressions.tex
# 1	0	src/latex/spec/groovy-lang-spec.tex
# 2	0	src/latex/spec/statements.tex
# 18ed332023 Starting the language spec.  ddtdd rocks!
# 11	0	src/latex/spec/colophon.tex
# 159	0	src/latex/spec/groovy-lang-spec.tex
# 3	0	src/latex/spec/keywords.tex
# 3	0	src/latex/spec/preface.tex
# a3a3031add Whoops.  Missed some files.
# 3	0	maven.xml
# 2	0	project.properties
# 124	0	project.xml
# 449ebe9d95 Initial revision
# 47	0	LICENSE.txt

# %% [markdown]
# 4df8b652aa fix possible deserialization exploit by overriding readObject
# 8	0	src/main/org/codehaus/groovy/runtime/MethodClosure.java

# %%
#f.	How many total lines of code (excluding comments and blank lines) 
#were deleted? Hint: git diff or git show
#Look at C

# %%
#g.	How many total lines of code (excluding comments and blank lines) 
#were added? Hint: git diff or git show
#Look at C

# %%
#h.	How many days were between the current fixing commit and the previous 
#commit of each affected file? Hint: git log
#AffectedFile
log_data = repo.git.log("--parents","--",affected_file).splitlines()
for line in log_data:
    print(line)
# Out:
# commit b25d0e55ddac82fa2127c69fb1ca10555975a2a5 91c04014fb6cc6a2e09f93d81fd0bd95ea84d7dc
# Author: Cedric Champeau <cchampeau@apache.org>
# Date:   Thu Dec 14 09:49:51 2017 +0100
#
#     Move Java source set into `src/main/java`
#
# commit 91c04014fb6cc6a2e09f93d81fd0bd95ea84d7dc 716d3e67e744c7edeed7cbc3f874090d39355764
# Author: Daniel Sun <sunlan@apache.org>
# Date:   Fri Nov 11 21:24:16 2016 +0800
#
#     Implement the new parser
#
# commit 716d3e67e744c7edeed7cbc3f874090d39355764 4c829ca397aae8f86c993c000d5ab8445c2a0189
# Author: Jochen Theodorou <blackdrag@gmx.org>
# Date:   Mon Oct 3 18:22:28 2016 +0200
#
#     fix possible deserialization exploit by overriding readObject
#
# commit 4c829ca397aae8f86c993c000d5ab8445c2a0189 09e9778e8a33052d8c27105aee5310649637233d
# Author: oreissig <oreissig+github@gmail.com>
# Date:   Sat Mar 12 22:28:30 2016 +0100
#
#     make private fields final where possible (closes #292)
#
# commit 09e9778e8a33052d8c27105aee5310649637233d 27234afb0182dfc43e6ebb68f8962680b526e1a8
# Author: Cedric Champeau <cchampeau@apache.org>
# Date:   Thu Jul 9 20:12:51 2015 +0200
#
#     Fix potential problem when deserializing
#
# commit 27234afb0182dfc43e6ebb68f8962680b526e1a8 783f6d408017a23ce60c950476ebbcbef50b8a10
# Author: pascalschumacher <pascalschumacher@gmx.net>
# Date:   Mon Jun 1 20:00:27 2015 +0200
#
#     remove "@version $Revision$" from javadoc
#
# commit 783f6d408017a23ce60c950476ebbcbef50b8a10 a52d0d3c5dd1cbb342992d36235171718a563c8b
# Author: Paul King <paulk@asert.com.au>
# Date:   Wed Apr 29 16:10:36 2015 +1000
#
#     license comment shouldn't be javadoc comment
#
# commit a52d0d3c5dd1cbb342992d36235171718a563c8b 9992349e38fae72941816d609253aa67fd5d14f4
# Author: Cedric Champeau <cedric.champeau@gmail.com>
# Date:   Fri Apr 3 16:29:17 2015 +0200
#
#     Update file headers for Apache
#
# commit 9992349e38fae72941816d609253aa67fd5d14f4 9ea9d18b6e58d3be1207995bba2fe7a4370800f9
# Author: Cedric Champeau <cedric.champeau@gmail.com>
# Date:   Tue Dec 2 10:42:35 2014 +0100
#
#     Optimize memory consuption by avoiding the creation of empty arrays
#
# commit 9ea9d18b6e58d3be1207995bba2fe7a4370800f9 49c49791ae5d021fa8098b9ebc3ce2a13bbadf69
# Author: Roshan Dawrani <roshandawrani@gmail.com>
# Date:   Wed Apr 14 05:43:41 2010 +0000
#
#     GROOVY-4170
#     Fixed the issue related currying of private methods.
#
#     git-svn-id: http://svn.codehaus.org/groovy/trunk/groovy/groovy-core@19868 a5544e8c-8a19-0410-ba12-f9af4593a198
#
# commit 49c49791ae5d021fa8098b9ebc3ce2a13bbadf69 f2d80d59dd1c2fe04b480b2f7813e4d9e43e08bc
# Author: Roshan Dawrani <roshandawrani@gmail.com>
# Date:   Wed Mar 17 09:59:12 2010 +0000
#
#     GROOVY-4104
#     MethodClosure didn't handle non-private, non-public methods of super classes correctly. Fixed it.
#
#     git-svn-id: http://svn.codehaus.org/groovy/trunk/groovy/groovy-core@19609 a5544e8c-8a19-0410-ba12-f9af4593a198
#
# commit f2d80d59dd1c2fe04b480b2f7813e4d9e43e08bc f0ad471786c47dadd1a940066f9876408e582817
# Author: Alex Tkachman <alex.tkachman@gmail.com>
# Date:   Thu Jul 17 07:23:23 2008 +0000
#
#     Support for optional arguments in closure meta methods and method-closure meta methods
#
#     git-svn-id: http://svn.codehaus.org/groovy/trunk/groovy/groovy-core@13053 a5544e8c-8a19-0410-ba12-f9af4593a198
#
# commit f0ad471786c47dadd1a940066f9876408e582817 6e20de5acbfbe3812bbbd61bfc7d2ac9b6c9917b
# Author: Alex Tkachman <alex.tkachman@gmail.com>
# Date:   Fri Nov 30 12:00:37 2007 +0000
#
#     Fix for GROOVY-1993
#
#     git-svn-id: http://svn.codehaus.org/groovy/trunk/groovy/groovy-core@9556 a5544e8c-8a19-0410-ba12-f9af4593a198
#
# commit 6e20de5acbfbe3812bbbd61bfc7d2ac9b6c9917b 469e823b00b24231645708207a790587ff771f22
# Author: Guillaume Laforge <glaforge@gmail.com>
# Date:   Mon Jul 2 10:40:33 2007 +0000
#
#     GROOVY-1710: Updated source file headers to ASL 2
#
#     git-svn-id: http://svn.codehaus.org/groovy/trunk/groovy/groovy-core@6778 a5544e8c-8a19-0410-ba12-f9af4593a198
#
# commit 469e823b00b24231645708207a790587ff771f22 80c2df2bddf825863b4660c65a1f0bb4e2bb8a3f
# Author: Jochen Theodorou <blackdrag@gmx.org>
# Date:   Sat Dec 23 11:17:12 2006 +0000
#
#     modifications to ensure working method closure for static methods
#
#     git-svn-id: http://svn.codehaus.org/groovy/trunk/groovy/groovy-core@4611 a5544e8c-8a19-0410-ba12-f9af4593a198
#
# commit 80c2df2bddf825863b4660c65a1f0bb4e2bb8a3f e4ab1d6f057485ad99a27fa1e2051aa5c1e807ac
# Author: John Wilson <tug@wilson.co.uk>
# Date:   Mon Oct 10 11:23:59 2005 +0000
#
#     Remove the implementation of setDelegate whcih thows an exacption
#
#
#     git-svn-id: http://svn.codehaus.org/groovy/trunk/groovy/groovy-core@2942 a5544e8c-8a19-0410-ba12-f9af4593a198
#
# commit e4ab1d6f057485ad99a27fa1e2051aa5c1e807ac 860ef6a65d30982bc2e0ba4ace5fbd18013fda30
# Author: John Wilson <tug@wilson.co.uk>
# Date:   Mon Oct 3 18:07:37 2005 +0000
#
#     Trying to roll back the changes to invokeMethod - hold on to your hats!
#
#
#     git-svn-id: http://svn.codehaus.org/groovy/trunk/groovy/groovy-core@2910 a5544e8c-8a19-0410-ba12-f9af4593a198
#
# commit 860ef6a65d30982bc2e0ba4ace5fbd18013fda30 9d95da9c9848a4a6cf29239ebb9978654af73ac1
# Author: Pilho Kim <phkim@cluecom.co.kr>
# Date:   Mon Oct 3 16:54:04 2005 +0000
#
#     The four access modifiers (say, private, protected, public and package default)
#     to (static or not) methods should work like as they do in Java.
#
#     To do that, a new method
#
#         public Object invokeMethodAt(Class at, String name, Object args)
#
#     (which is a temporay replacement of the method "invokeMethod"),
#     has been added to the interface GroovyObject.
#
#     For a test suit, StaticMethodAccessBug.groovy and its companions have been added.
#
#
#     git-svn-id: http://svn.codehaus.org/groovy/trunk/groovy/groovy-core@2909 a5544e8c-8a19-0410-ba12-f9af4593a198
#
# commit 9d95da9c9848a4a6cf29239ebb9978654af73ac1 eec8aa0c6effec55cd4e58bdb16780aa40a1337b
# Author: Jochen Theodorou <blackdrag@gmx.org>
# Date:   Sat Aug 20 19:02:16 2005 +0000
#
#     this is a four part commit:
#     1) remove the ParameterArray workaround, but keep the functionality
#     2) transfer Closure's invocation rules to MetaClass
#     3) give all groovy methods the ability to use vargs
#     4) add a starting implementation of a replacement for ClassWorlds
#
#
#     git-svn-id: http://svn.codehaus.org/groovy/trunk/groovy/groovy-core@2724 a5544e8c-8a19-0410-ba12-f9af4593a198
#
# commit eec8aa0c6effec55cd4e58bdb16780aa40a1337b 50ed1b25233958cdafcab4b74daec840fc85b964
# Author: Pilho Kim <phkim@cluecom.co.kr>
# Date:   Sat Jul 16 23:56:18 2005 +0000
#
#     Fix the bug of MethodClosure with parameter of type Object[]
#
#
#     git-svn-id: http://svn.codehaus.org/groovy/trunk/groovy/groovy-core@2559 a5544e8c-8a19-0410-ba12-f9af4593a198
#
# commit 50ed1b25233958cdafcab4b74daec840fc85b964 bc3e65b5e6d0b0c10c946a20dcae67e2f61aeaf5
# Author: James Strachan <jastrachan@mac.com>
# Date:   Thu Dec 18 14:22:06 2003 +0000
#
#     Fixed the closure method call bug and added a test case to ensure we don't break it again.
#
#
#     git-svn-id: http://svn.codehaus.org/groovy/trunk/groovy/groovy-core@436 a5544e8c-8a19-0410-ba12-f9af4593a198
#
# commit bc3e65b5e6d0b0c10c946a20dcae67e2f61aeaf5 425d36a3978b55e7cfd66b7977e9487a18fab8f2
# Author: James Strachan <jastrachan@mac.com>
# Date:   Mon Oct 6 04:48:22 2003 +0000
#
#     Fairly large refactoring - the statements and expressions are now all named properly to make bob happier and have been refactored into sub packages to make it easier to see whats going on.
#
#     I hope this doesn't cause any merge conflicts for you bob
#
#
#     git-svn-id: http://svn.codehaus.org/groovy/trunk/groovy/groovy-core@176 a5544e8c-8a19-0410-ba12-f9af4593a198
#
# commit 425d36a3978b55e7cfd66b7977e9487a18fab8f2 ec6321cde182487f05c420be436833f232e78862
# Author: James Strachan <jastrachan@mac.com>
# Date:   Sun Oct 5 19:26:30 2003 +0000
#
#     Numerous changes
#
#     * constructors now seem to work
#     * closures now have an optional delegate - so markup builders can force all method calls to redirect to it for simpler markup
#     * various fixes and new test cases
#
#
#     git-svn-id: http://svn.codehaus.org/groovy/trunk/groovy/groovy-core@171 a5544e8c-8a19-0410-ba12-f9af4593a198
#
# commit ec6321cde182487f05c420be436833f232e78862 51ae3d70057882a98cc4b1d697d14c400b2f54ba
# Author: James Strachan <jastrachan@mac.com>
# Date:   Fri Sep 26 17:12:13 2003 +0000
#
#     refactored code so that groovy.lang is the core package available to groovy scripts which is implicitly imported
#
#
#     git-svn-id: http://svn.codehaus.org/groovy/trunk/groovy/groovy-core@155 a5544e8c-8a19-0410-ba12-f9af4593a198
#
# commit 51ae3d70057882a98cc4b1d697d14c400b2f54ba 408b29851d7bbe4d343340832297e4be7e0c5578
# Author: James Strachan <jastrachan@mac.com>
# Date:   Wed Sep 24 18:48:12 2003 +0000
#
#     nearly got closures working - just need to add the constructor to the inner class and they're just about working
#
#
#     git-svn-id: http://svn.codehaus.org/groovy/trunk/groovy/groovy-core@135 a5544e8c-8a19-0410-ba12-f9af4593a198
#
# commit 408b29851d7bbe4d343340832297e4be7e0c5578
# Author: James Strachan <jastrachan@mac.com>
# Date:   Thu Sep 11 14:11:56 2003 +0000
#
#     refactored the source tree to make things a little cleaner.
#
#     now have the more normal src/main and src/test trees
#
#
#     git-svn-id: http://svn.codehaus.org/groovy/trunk/groovy/groovy-core@34 a5544e8c-8a19-0410-ba12-f9af4593a198

# %% [markdown]
# commit 716d3e67e744c7edeed7cbc3f874090d39355764 4c829ca397aae8f86c993c000d5ab8445c2a0189
# Author: Jochen Theodorou <blackdrag@gmx.org>
# Date:   Mon Oct 3 18:22:28 2016 +0200
#
#     fix possible deserialization exploit by overriding readObject
#
# commit 4c829ca397aae8f86c993c000d5ab8445c2a0189 09e9778e8a33052d8c27105aee5310649637233d
# Author: oreissig <oreissig+github@gmail.com>
# Date:   Sat Mar 12 22:28:30 2016 +0100
#
#     make private fields final where possible (closes #292)
#
# 205 days

# %%
#i.	How many time has each affected file of the current fixing commit 
#been modified in the past since their creation (including rename of the file)? Hint: git log
#Affected File
log_data = repo.git.log("--oneline","--",affected_file).splitlines()
print("Number of commits in between:", len(log_data))
for line in log_data:
    print(line)
# Out:
# Number of commits in between: 26
# b25d0e55dd Move Java source set into `src/main/java`
# 91c04014fb Implement the new parser
# 716d3e67e7 fix possible deserialization exploit by overriding readObject
# 4c829ca397 make private fields final where possible (closes #292)
# 09e9778e8a Fix potential problem when deserializing
# 27234afb01 remove "@version $Revision$" from javadoc
# 783f6d4080 license comment shouldn't be javadoc comment
# a52d0d3c5d Update file headers for Apache
# 9992349e38 Optimize memory consuption by avoiding the creation of empty arrays
# 9ea9d18b6e GROOVY-4170 Fixed the issue related currying of private methods.
# 49c49791ae GROOVY-4104 MethodClosure didn't handle non-private, non-public methods of super classes correctly. Fixed it.
# f2d80d59dd Support for optional arguments in closure meta methods and method-closure meta methods
# f0ad471786 Fix for GROOVY-1993
# 6e20de5acb GROOVY-1710: Updated source file headers to ASL 2
# 469e823b00 modifications to ensure working method closure for static methods
# 80c2df2bdd Remove the implementation of setDelegate whcih thows an exacption
# e4ab1d6f05 Trying to roll back the changes to invokeMethod - hold on to your hats!
# 860ef6a65d The four access modifiers (say, private, protected, public and package default) to (static or not) methods should work like as they do in Java.
# 9d95da9c98 this is a four part commit: 1) remove the ParameterArray workaround, but keep the functionality 2) transfer Closure's invocation rules to MetaClass 3) give all groovy methods the ability to use vargs 4) add a starting implementation of a replacement for ClassWorlds
# eec8aa0c6e Fix the bug of MethodClosure with parameter of type Object[]
# 50ed1b2523 Fixed the closure method call bug and added a test case to ensure we don't break it again.
# bc3e65b5e6 Fairly large refactoring - the statements and expressions are now all named properly to make bob happier and have been refactored into sub packages to make it easier to see whats going on.
# 425d36a397 Numerous changes
# ec6321cde1 refactored code so that groovy.lang is the core package available to groovy scripts which is implicitly imported
# 51ae3d7005 nearly got closures working - just need to add the constructor to the inner class and they're just about working
# 408b29851d refactored the source tree to make things a little cleaner.

# %%
#j.	Which developers have modified each affected file since its creation? 
#Hint: git log
#AffectedFile
log_data = repo.git.log("--pretty=format:%an","--",affected_file).splitlines()
df = pd.DataFrame(log_data, columns=['Author'])
df['count'] = 1
answer = df.groupby(['Author']).count().reset_index(0, drop=False)
answer
# Out:
#                Author  count
# 0       Alex Tkachman      2
# 1     Cedric Champeau      4
# 2          Daniel Sun      1
# 3   Guillaume Laforge      1
# 4      James Strachan      6
# 5    Jochen Theodorou      3
# 6         John Wilson      2
# 7           Paul King      1
# 8           Pilho Kim      2
# 9      Roshan Dawrani      2
# 10           oreissig      1
# 11   pascalschumacher      1

# %%
#k.	For each developer identified, how many commits have each of them 
#submitted? From your observation, are the involving developers
#experienced (with many commits) or new ones (with few commits) or both? 
#Hint: git log or git shortlog
commit_authors = repo.git.shortlog("-sne", "--all").splitlines()

author_commits = []

for commit_author in commit_authors:
    commit, author = commit_author.split("\t")
    author_commits.append([int(commit), author])
df = pd.DataFrame(author_commits, columns=['Commit', 'Author'])
df
# Out:
#      Commit                                             Author
# 0      5858                     Paul King <paulk@asert.com.au>
# 1      2830               Jochen Theodorou <blackdrag@gmx.org>
# 2      2661        Cedric Champeau <cedric.champeau@gmail.com>
# 3      2135                James Strachan <jastrachan@mac.com>
# 4      1807                         sunlan <sunlan@apache.org>
# 5      1378             Guillaume Laforge <glaforge@gmail.com>
# 6      1306                         paulk <paulk@asert.com.au>
# 7       695           Roshan Dawrani <roshandawrani@gmail.com>
# 8       588                 Graeme Rocher <grocher@vmware.com>
# 9       491                     John Wilson <tug@wilson.co.uk>
# 10      466                     Daniel Sun <sunlan@apache.org>
# 11      443       John Wagenleitner <jwagenleitner@apache.org>
# 12      390        pascalschumacher <pascalschumacher@gmx.net>
# 13      373       Pascal Schumacher <pascalschumacher@gmx.net>
# 14      369            Danno Ferrin <danno.ferrin@shemnon.com>
# 15      355            Jeremy Rayner <jeremy.rayner@gmail.com>
# 16      340            Alex Tkachman <alex.tkachman@gmail.com>
# 17      332        PascalSchumacher <pascalschumacher@gmx.net>
# 18      306              Jason Dillon <jason.dillon@gmail.com>
# 19      276              Dierk Koenig <dierk.koenig@canoo.com>
# 20      275            danielsun1106 <realbluesun@hotmail.com>
# 21      236             Cedric Champeau <cchampeau@apache.org>
# 22      210                    Pilho Kim <phkim@cluecom.co.kr>
# 23      200                   Sam Pullara <sam@sampullara.com>
# 24      177            Franck Rasolo <franck.rasolo@gmail.com>
# 25      169               Russel Winder <russel@russel.org.uk>
# 26      161                   Boc McWhirter <bob@codehaus.org>
# 27      155                Hamlet D'Arcy <hamletdrc@gmail.com>
# 28      154                     Jim White <jim@pagesmiths.com>
# 29      147                  Thibault Kruse <kruset@in.tum.de>
# ..      ...                                                ...
# 370       1  Benjamin Porter <FreedomBen@users.noreply.gith...
# 371       1              Bruno Casali <brunoocasali@gmail.com>
# 372       1                     Christoph Frick <cf@ofnir.net>
# 373       1                         DJBen <lsh32768@gmail.com>
# 374       1        Dariusz Kobylarz <darek.kobylarz@gmail.com>
# 375       1                 David Avenante <altus34@gmail.com>
# 376       1               Gary Clayburg <gclaybur@comcast.net>
# 377       1                   Ingo Hoffmann <Ingo@Hoffmann.cx>
# 378       1                       Jakub Wilk <jwilk@jwilk.net>
# 379       1        James Williams <james.l.williams@gmail.com>
# 380       1         Jesper Steen Møller <jesper@selskabet.org>
# 381       1           Jess Sightler <jesse.sightler@gmail.com>
# 382       1                    Jesse Glick <jglick@apache.org>
# 383       1                Jochen Berger <fooberger@gmail.com>
# 384       1  Jochen Eddelbüttel <cornercouch@eddelbuettel.net>
# 385       1                         Joe <support@codehaus.org>
# 386       1                 Kohsuke Kawaguchi <kk@kohsuke.org>
# 387       1                        Larry J <larry@jalcyon.com>
# 388       1         Marcin Grzejszczak <marcin@grzejszczak.pl>
# 389       1  Marcin Zajaczkowski <szpak@users.sourceforge.net>
# 390       1                     Mark CC <support@codehaus.org>
# 391       1            Michael Frankfurter <micfra@micfra.net>
# 392       1                  Nathan Mische <nmische@gmail.com>
# 393       1                    Peter Swire <swirepe@gmail.com>
# 394       1                    Pierre Pinon <pierre@pinon1.fr>
# 395       1                  Roman Shaposhnik <rvs@apache.org>
# 396       1                  Wil Selwood <wselwood@ijento.com>
# 397       1                   Yasuharu NAKANO <ynak@jggug.org>
# 398       1                      aalmiray <aalmiray@yahoo.com>
# 399       1                          pavel <pavel@192.168.0.6>
#
# [400 rows x 2 columns]

# %%
com = df[["Commit"]].copy()
df = pd.DataFrame(df.Author.str.split(' <',1).tolist(),columns = ['Author','email'])
df["Commit"] = com["Commit"]
names = answer["Author"].tolist()
for name in names:
    print(df[(df["Author"] == name)])
# Out:
#            Author                     email  Commit
# 16  Alex Tkachman  alex.tkachman@gmail.com>     340
#              Author                       email  Commit
# 2   Cedric Champeau  cedric.champeau@gmail.com>    2661
# 21  Cedric Champeau       cchampeau@apache.org>     236
#         Author                     email  Commit
# 10  Daniel Sun        sunlan@apache.org>     466
# 39  Daniel Sun  realbluesun@hotmail.com>      84
#               Author                email  Commit
# 5  Guillaume Laforge  glaforge@gmail.com>    1378
#            Author                email  Commit
# 3  James Strachan  jastrachan@mac.com>    2135
#                Author                        email  Commit
# 1    Jochen Theodorou           blackdrag@gmx.org>    2830
# 296  Jochen Theodorou  jochen.theodorou@canoo.com>       2
#         Author              email  Commit
# 9  John Wilson  tug@wilson.co.uk>     491
#       Author                email  Commit
# 0  Paul King  paulk@asert.com.au>    5858
#        Author                 email  Commit
# 22  Pilho Kim  phkim@cluecom.co.kr>     210
#            Author                     email  Commit
# 7  Roshan Dawrani  roshandawrani@gmail.com>     695
#       Author                       email  Commit
# 59  oreissig  oreissig+github@gmail.com>      41
#               Author                      email  Commit
# 12  pascalschumacher  pascalschumacher@gmx.net>     390
